# %%
# Load packages and classes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tiffslide
import seaborn as sns
import gget
import tifffile
import zarr

# MosaicDataset and BruceDataset classes allow loading and visualisation of the different data sources
from gbmhackathon import MosaicDataset, BruceDataset

from gbmhackathon.utils.visium_functions import (
    normalize_anndata_wrapper,
    convert_obsm_to_adata
)
from gbmhackathon.viz.visium_functions import (
    plot_spatial_expression,
    plot_obsm
)
from gbmhackathon.stats.visium_functions import (
    perform_multi_clustering,
    quantify_cell_population_activity
)

# %%
# Look at the available data sources
MosaicDataset.sources.keys()
# Out:
# dict_keys(['clinical', 'bulk_rna', 'spatial', 'sc_rna', 'wes', 'he'])

# %%
# The following cell will returns a dictionary with the data sources in the
# keys and the list of files (and path) used to return the data.
source_dict_mosaic = MosaicDataset.load_tabular()

# %%
source_dict_mosaic.keys()
# Out:
# dict_keys(['clinical', 'bulk_rna', 'wes', 'he'])

# %%
filename_sample_table = "/home/ec2-user/SageMaker/data/mosaic_dataset/Data availibility per modality per patient.csv"
sample_table = pd.read_csv(filename_sample_table, index_col=0)
sample_table.head(2)
# Out:
#              Visium_usable WES_usable scRNAseq_usable bulkRNAseq_usable  \
# Hackathon_ID
# HK_G_001a              Yes        Yes             Yes               Yes
# HK_G_002a              Yes        Yes             Yes               Yes
#
#              HE_usable Clinical_usable
# Hackathon_ID
# HK_G_001a          Yes             Yes
# HK_G_002a          Yes             Yes

# %%
mask_yes = sample_table["HE_usable"] == 'Yes'
mask_yes.sum()
# Out:
# 114

# %%
sample_table.shape
# Out:
# (115, 6)

# %% [markdown]
# ## Analysis of clinical data

# %%
clinical = source_dict_mosaic['clinical']

# %%
clinical.keys()
# Out:
# dict_keys(['data dictionary', 'original clinical', 'processed gbm clinical', 'treatments', 'key events clinical'])

# %%
data_clinical_dict = clinical['data dictionary']
processed_clinical = clinical["processed gbm clinical"]
treatments = clinical["treatments"]
key_events_clinical = clinical["key events clinical"]

# %%
key_events_clinical.head(10)
# Out:
#                       event_id                            event_uuid  \
# patient_id
# HK_G_002    HK_G_002_event_1.0  882c0891-f733-5bd2-bc87-bfc8bf37cab0
# HK_G_002    HK_G_002_event_2.0  40329cc2-af36-51ce-883d-d4482582d576
# HK_G_003    HK_G_003_event_1.0  63344840-9cdf-528e-a00f-f2f0475ab8b1
# HK_G_003    HK_G_003_event_2.0  1b06f64f-0255-5e6e-a404-46ff524eb503
# HK_G_004    HK_G_004_event_1.0  0874f35a-a4e4-50f2-8139-b42996e55d07
# HK_G_004    HK_G_004_event_2.0  3482236b-37a6-5a2d-93a9-023100740e29
# HK_G_005    HK_G_005_event_1.0  edcfbf19-e5a1-5ada-81a2-6d41332ba3da
# HK_G_005    HK_G_005_event_2.0  de59043c-1bf8-5218-84a9-29bca310c6a9
# HK_G_005    HK_G_005_event_3.0  b6cd0c29-d1a4-5c2a-8a8c-79b79e2d158a
# HK_G_005    HK_G_005_event_4.0  fd359bd9-776e-52ea-8923-e347fdd16ba0
#
#            progression_recurrence  \
# patient_id
# HK_G_002                      Yes
# HK_G_002                      Yes
# HK_G_003                      Yes
# HK_G_003                      Yes
# HK_G_004                      Yes
# HK_G_004                      Yes
# HK_G_005                      Yes
# HK_G_005                      Yes
# HK_G_005                      Yes
# HK_G_005                      Yes
#
#             time_interval_diagnosis_to_progression_recurrence_years
# patient_id
# HK_G_002                                             1.702943
# HK_G_002                                             2.088980
# HK_G_003                                             0.936345
# HK_G_003                                             1.281314
# HK_G_004                                             0.260096
# HK_G_004                                             0.602327
# HK_G_005                                             0.068446
# HK_G_005                                             0.424367
# HK_G_005                                             2.841889
# HK_G_005                                             3.030801

# %%
treatments.head()
# Out:
#   patient_id            treatment_id                        treatment_uuid  \
# 0   HK_G_001  HK_G_001_treatment_1.0  34e25ce3-50b5-5359-88aa-a7723d3188df
# 1   HK_G_001  HK_G_001_treatment_2.0  6f355b51-193a-52a9-94ef-be9b0685c563
# 2   HK_G_001  HK_G_001_treatment_2.0  6f355b51-193a-52a9-94ef-be9b0685c563
# 3   HK_G_001  HK_G_001_treatment_4.0  85416b21-bfd3-5a2f-9318-5dbfe2aed605
# 4   HK_G_002  HK_G_002_treatment_1.0  c329e7df-9dfd-524f-af99-fc4e297dd524
#
#   treatment_type term_for_medical_coding    custom_treatment_label  \
# 0        Surgery                     NaN     Surgery:PrimaryTumour
# 1   Radiotherapy                     NaN        Post-operative:nan
# 2   Chemotherapy            Temozolomide     Adjuvant:Temozolomide
# 3   Chemotherapy            Temozolomide  Maintenance:Temozolomide
# 4        Surgery                     NaN     Surgery:PrimaryTumour
#
#                                      surgery_specify surgery_indication  \
# 0  Right temporal craniotomy for resection of a h...  Initial treatment
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Awake craniotomy for resection of a left tempo...  Initial treatment
#
#   surgery_on_primary_tumour surgery_on_primary_tumour_type  ...  \
# 0                       Yes                      Resection  ...
# 1                       NaN                            NaN  ...
# 2                       NaN                            NaN  ...
# 3                       NaN                            NaN  ...
# 4                       Yes                      Resection  ...
#
#                                describe_toxicity_ies highest_toxicity_grade  \
# 0  Left facio-brachio-crural hemisyndrome with pa...                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   reason_for_treatment_end  best_response_during_treatment  \
# 0                      NaN                             NaN
# 1                    Other                  Stable disease
# 2  Scheduled treatment end                  Stable disease
# 3  Scheduled treatment end                  Stable disease
# 4                      NaN                             NaN
#
#   years_treatment_start_to_end treatment_event_order_by_start_date  \
# 0                          NaN                                 1.0
# 1                     0.054757                                 2.0
# 2                     0.054757                                 2.0
# 3                     0.982888                                 4.0
# 4                          NaN                                 1.0
#
#   treatment_ongoing  treatment_type_specific  treatment_chronology  \
# 0               NaN                      NaN                   NaN
# 1                No                    Other        Post-operative
# 2                No                      NaN              Adjuvant
# 3                No                      NaN           Maintenance
# 4               NaN                      NaN                   NaN
#
#    time_interval_between_diagnosis_treatment_start_years
# 0                                           0.000000
# 1                                           0.093087
# 2                                           0.093087
# 3                                           0.301164
# 4                                           0.000000
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Spatial data

# %%
visium_dict = MosaicDataset.load_visium(
    sample_list=["HK_G_022a_vis", "HK_G_024a_vis", "HK_G_030a_vis"], # remove this argument to load all available samples)
    resolution="hires"
)
# Out:
# Resolution of the spatial image to load:  hires
# You can change the resolution by setting the resolution parameter using the resolution argument.
# Loading Visium data, this can take few minutes...

# %%
visium_obj = normalize_anndata_wrapper(visium_dict, target_sum=1e6)

# %%
one_visium_file = visium_obj["HK_G_030a_vis"]

# %%
one_visium_file
# Out:
# AnnData object with n_obs × n_vars = 4522 × 16927
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial', 'log1p'
#     obsm: 'spatial'
#     layers: 'raw', 'CPM', 'log_CPM'

# %%
one_visium_file.obs # Sequence du gène
# Out:
#                     in_tissue  array_row  array_col
# AACACGTGCATCGCAC-1          1         76         22
# AACACTTGGCAAGGAA-1          1         47         71
# AACAGGAAGAGCATAG-1          1         69          7
# AACAGGATTCATAGTT-1          1         49         43
# AACAGGCCAACGATTA-1          1         71        127
# ...                       ...        ...        ...
# TGTTGGAACGAGGTCA-1          1         28         72
# TGTTGGAAGCTCGGTA-1          1          1         95
# TGTTGGATGGACTTCT-1          1         13         53
# TGTTGGCCAGACCTAC-1          1         49         47
# TGTTGGCCTACACGTG-1          1         37        127
#
# [4522 rows x 3 columns]

# %%
one_visium_file.var
# Out:
#                 gene_ids    feature_types  genome
# SAMD11   ENSG00000187634  Gene Expression  GRCh38
# NOC2L    ENSG00000188976  Gene Expression  GRCh38
# KLHL17   ENSG00000187961  Gene Expression  GRCh38
# PLEKHN1  ENSG00000187583  Gene Expression  GRCh38
# PERM1    ENSG00000187642  Gene Expression  GRCh38
# ...                  ...              ...     ...
# MT-ND4L  ENSG00000212907  Gene Expression  GRCh38
# MT-ND4   ENSG00000198886  Gene Expression  GRCh38
# MT-ND5   ENSG00000198786  Gene Expression  GRCh38
# MT-ND6   ENSG00000198695  Gene Expression  GRCh38
# MT-CYB   ENSG00000198727  Gene Expression  GRCh38
#
# [16927 rows x 3 columns]
