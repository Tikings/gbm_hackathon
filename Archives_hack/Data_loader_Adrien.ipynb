# %% [markdown]
# # Demo notebook to start working on the GBM Hackathon data
# This notebook demonstrates how the MOSAIC ([Owkin](https://www.mosaic-research.com/)) and BRUCE ([PICI](https://www.parkerici.org/)) data can be loaded.

# %% [markdown]
# ## Setup

# %%
# Load packages and classes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tiffslide
import seaborn as sns
import gget
import tifffile
import zarr


# MosaicDataset and BruceDataset classes allow loading and visualisation of the different data sources
from gbmhackathon import MosaicDataset, BruceDataset

# %% [markdown]
# ## Start exploring the MOSAIC data

# %%
# Look at the available data sources
MosaicDataset.sources.keys()
# Out:
# dict_keys(['clinical', 'bulk_rna', 'spatial', 'sc_rna', 'wes', 'he'])

# %%
# The following cell will returns a dictionary with the data sources in the
# keys and the list of files (and path) used to return the data.
source_dict_mosaic = MosaicDataset.load_tabular()

# %% [markdown]
# ### Load the MOSAIC sample table
# Not every data modality is available for each MOSAIC sample. The following table provides information on which modality is available for each sample.

# %%
filename_sample_table = "/home/ec2-user/SageMaker/data/mosaic_dataset/Data availibility per modality per patient.csv"
sample_table = pd.read_csv(filename_sample_table, index_col=0)
sample_table.head(2)
# Out:
#              Visium_usable WES_usable scRNAseq_usable bulkRNAseq_usable  \
# Hackathon_ID
# HK_G_001a              Yes        Yes             Yes               Yes
# HK_G_002a              Yes        Yes             Yes               Yes
#
#              HE_usable Clinical_usable
# Hackathon_ID
# HK_G_001a          Yes             Yes
# HK_G_002a          Yes             Yes

# %% [markdown]
# ### Load and explore the six MOSAIC data modalities

# %% [markdown]
# #### 1. Clinical data

# %%
# To access the clinical data, specify the correct keys
clin_df = source_dict_mosaic["clinical"]["processed gbm clinical"]
clin_df.head(2)
print(clin_df.columns)
# Out:
# Index(['patient_id', 'cohort_code', 'cancer_indication', 'sample_source',
#        'sample_origin', 'sample_collection_chronology',
#        'administrative_gender', 'smoking_status',
#        'smoking_quantity_pack_years', 'alcohol_intake', 'os_years',
#        'os_censor', 'pfs_years', 'pfs_censor', 'age_at_diagnosis_years',
#        'primary_tumour_side', 'number_of_brain_tumour_sites',
#        'largest_diameter_of_the_primary_tumour_mm_duplicated_0',
#        'surgery_type', 'tumour_resection_chronology',
#        'microvascular_proliferation', 'necrosis', 'presence_of_small_cells',
#        'atrx_loss_of_expression_ihc', 'atrx_mutation', 'braf_mutation', 'gfap',
#        'olig2', 'p53', 'idh1_idh2_mutation', 'idh1_r132h_expression_ihc',
#        'tert_promoter_mutation', 'mgmt_promoter_methylation', 'egfr_mutation',
#        'egfr_amplification', 'pten_mutation', 'ntrk_fusion',
#        'histone_h3_g34_mutation_sequencing',
#        'histone_h3_k27m_mutation_sequencing',
#        'time_interval_sample_harvest_dearchival_years'],
#       dtype='object')

# %%
clin_df.columns.unique()
# Out:
# Index(['patient_id', 'cohort_code', 'cancer_indication', 'sample_source',
#        'sample_origin', 'sample_collection_chronology',
#        'administrative_gender', 'smoking_status',
#        'smoking_quantity_pack_years', 'alcohol_intake', 'os_years',
#        'os_censor', 'pfs_years', 'pfs_censor', 'age_at_diagnosis_years',
#        'primary_tumour_side', 'number_of_brain_tumour_sites',
#        'largest_diameter_of_the_primary_tumour_mm_duplicated_0',
#        'surgery_type', 'tumour_resection_chronology',
#        'microvascular_proliferation', 'necrosis', 'presence_of_small_cells',
#        'atrx_loss_of_expression_ihc', 'atrx_mutation', 'braf_mutation', 'gfap',
#        'olig2', 'p53', 'idh1_idh2_mutation', 'idh1_r132h_expression_ihc',
#        'tert_promoter_mutation', 'mgmt_promoter_methylation', 'egfr_mutation',
#        'egfr_amplification', 'pten_mutation', 'ntrk_fusion',
#        'histone_h3_g34_mutation_sequencing',
#        'histone_h3_k27m_mutation_sequencing',
#        'time_interval_sample_harvest_dearchival_years'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the categorical columns
categories = ["sample_collection_chronology", "administrative_gender", "smoking_status"]

# Set the figure size
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Loop through each category and plot its proportion
for i, category in enumerate(categories):
    proportions = clin_df[category].value_counts(normalize=True)  # Compute proportions
    sns.barplot(x=proportions.index, y=proportions.values, ax=axes[i], palette="viridis")
    
    axes[i].set_title(f"Proportion of {category}")
    axes[i].set_ylabel("Proportion")
    axes[i].set_xlabel(category)
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1476/666675201.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proportions.index, y=proportions.values, ax=axes[i], palette="viridis")
# /tmp/ipykernel_1476/666675201.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proportions.index, y=proportions.values, ax=axes[i], palette="viridis")
# /tmp/ipykernel_1476/666675201.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proportions.index, y=proportions.values, ax=axes[i], palette="viridis")

# %%
grouped_duplicates = clin_df.groupby(['os_years', 'pfs_years']).filter(lambda x: len(x) > 1)
grouped_duplicates
# Out:
#           patient_id cohort_code cancer_indication      sample_source  \
# sample_id
# HK_G_016a   HK_G_016   HK_GBM_#1   G: Glioblastoma             Biopsy
# HK_G_017b   HK_G_017   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_028a   HK_G_028   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_029b   HK_G_029   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_035a   HK_G_035   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_036b   HK_G_036   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_043a   HK_G_043   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_044b   HK_G_044   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_058a   HK_G_058   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_059b   HK_G_059   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_060a   HK_G_060   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_061b   HK_G_061   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_078a   HK_G_078   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_079b   HK_G_079   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_081a   HK_G_081   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_082b   HK_G_082   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_083a   HK_G_083   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_084b   HK_G_084   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_085a   HK_G_085   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_086b   HK_G_086   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_089a   HK_G_089   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_090b   HK_G_090   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_091a   HK_G_091   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_092b   HK_G_092   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_095a   HK_G_095   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_096b   HK_G_096   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_099a   HK_G_099   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_100b   HK_G_100   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_104a   HK_G_104   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_105b   HK_G_105   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_108a   HK_G_108   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_109b   HK_G_109   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_110a   HK_G_110   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_111b   HK_G_111   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_112a   HK_G_112   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_113b   HK_G_113   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_114a   HK_G_114   HK_GBM_#1   G: Glioblastoma  Surgical specimen
# HK_G_115b   HK_G_115   HK_GBM_#1   G: Glioblastoma  Surgical specimen
#
#             sample_origin sample_collection_chronology administrative_gender  \
# sample_id
# HK_G_016a  Primary tumour                     Baseline                  Male
# HK_G_017b  Primary tumour                At recurrence                  Male
# HK_G_028a  Primary tumour                     Baseline                  Male
# HK_G_029b  Primary tumour                At recurrence                  Male
# HK_G_035a  Primary tumour                     Baseline                  Male
# HK_G_036b  Primary tumour                At recurrence                  Male
# HK_G_043a  Primary tumour                     Baseline                Female
# HK_G_044b  Primary tumour                At recurrence                Female
# HK_G_058a  Primary tumour                     Baseline                Female
# HK_G_059b  Primary tumour                At recurrence                Female
# HK_G_060a  Primary tumour                     Baseline                Female
# HK_G_061b  Primary tumour                At recurrence                Female
# HK_G_078a  Primary tumour                     Baseline                  Male
# HK_G_079b  Primary tumour                At recurrence                  Male
# HK_G_081a  Primary tumour                     Baseline                  Male
# HK_G_082b  Primary tumour                At recurrence                  Male
# HK_G_083a  Primary tumour                     Baseline                  Male
# HK_G_084b  Primary tumour                At recurrence                  Male
# HK_G_085a  Primary tumour                At recurrence                Female
# HK_G_086b  Primary tumour                     Baseline                Female
# HK_G_089a  Primary tumour                     Baseline                  Male
# HK_G_090b  Primary tumour                At recurrence                  Male
# HK_G_091a  Primary tumour                At recurrence                  Male
# HK_G_092b  Primary tumour                     Baseline                  Male
# HK_G_095a  Primary tumour                     Baseline                Female
# HK_G_096b  Primary tumour                At recurrence                Female
# HK_G_099a  Primary tumour                     Baseline                  Male
# HK_G_100b  Primary tumour                At recurrence                  Male
# HK_G_104a  Primary tumour                     Baseline                  Male
# HK_G_105b  Primary tumour                At recurrence                  Male
# HK_G_108a  Primary tumour                     Baseline                  Male
# HK_G_109b  Primary tumour                At recurrence                  Male
# HK_G_110a  Primary tumour                     Baseline                  Male
# HK_G_111b  Primary tumour                At recurrence                  Male
# HK_G_112a  Primary tumour                     Baseline                Female
# HK_G_113b  Primary tumour                At recurrence                Female
# HK_G_114a  Primary tumour                     Baseline                  Male
# HK_G_115b  Primary tumour                At recurrence                  Male
#
#           smoking_status  smoking_quantity_pack_years  alcohol_intake  ...  \
# sample_id                                                              ...
# HK_G_016a  Former smoker                          NaN             NaN  ...
# HK_G_017b  Former smoker                          NaN             NaN  ...
# HK_G_028a            NaN                          NaN             NaN  ...
# HK_G_029b            NaN                          NaN             NaN  ...
# HK_G_035a            NaN                          NaN             NaN  ...
# HK_G_036b            NaN                          NaN             NaN  ...
# HK_G_043a            NaN                          NaN             NaN  ...
# HK_G_044b            NaN                          NaN             NaN  ...
# HK_G_058a            NaN                          NaN             NaN  ...
# HK_G_059b            NaN                          NaN             NaN  ...
# HK_G_060a            NaN                          NaN             NaN  ...
# HK_G_061b            NaN                          NaN             NaN  ...
# HK_G_078a     Non smoker                          NaN     Non drinker  ...
# HK_G_079b     Non smoker                          NaN     Non drinker  ...
# HK_G_081a  Active smoker                          NaN             NaN  ...
# HK_G_082b  Active smoker                          NaN             NaN  ...
# HK_G_083a     Non smoker                          NaN  Active drinker  ...
# HK_G_084b     Non smoker                          NaN  Active drinker  ...
# HK_G_085a            NaN                          NaN             NaN  ...
# HK_G_086b            NaN                          NaN             NaN  ...
# HK_G_089a     Non smoker                          NaN  Active drinker  ...
# HK_G_090b     Non smoker                          NaN  Active drinker  ...
# HK_G_091a     Non smoker                          NaN  Active drinker  ...
# HK_G_092b     Non smoker                          NaN  Active drinker  ...
# HK_G_095a     Non smoker                          NaN  Active drinker  ...
# HK_G_096b     Non smoker                          NaN  Active drinker  ...
# HK_G_099a            NaN                          NaN             NaN  ...
# HK_G_100b            NaN                          NaN             NaN  ...
# HK_G_104a            NaN                          NaN             NaN  ...
# HK_G_105b            NaN                          NaN             NaN  ...
# HK_G_108a            NaN                          NaN             NaN  ...
# HK_G_109b            NaN                          NaN             NaN  ...
# HK_G_110a            NaN                          NaN             NaN  ...
# HK_G_111b            NaN                          NaN             NaN  ...
# HK_G_112a     Non smoker                          NaN     Non drinker  ...
# HK_G_113b     Non smoker                          NaN     Non drinker  ...
# HK_G_114a            NaN                          NaN             NaN  ...
# HK_G_115b            NaN                          NaN             NaN  ...
#
#            idh1_r132h_expression_ihc  tert_promoter_mutation  \
# sample_id
# HK_G_016a                   Negative                      No
# HK_G_017b                   Negative                      No
# HK_G_028a                   Negative                      No
# HK_G_029b                   Negative                      No
# HK_G_035a                   Negative                     Yes
# HK_G_036b                   Negative                     Yes
# HK_G_043a                   Negative                     NaN
# HK_G_044b                   Negative                     NaN
# HK_G_058a                   Negative                     NaN
# HK_G_059b                   Negative                     NaN
# HK_G_060a                   Negative                     NaN
# HK_G_061b                   Negative                     NaN
# HK_G_078a                   Negative                     NaN
# HK_G_079b                   Negative                     NaN
# HK_G_081a                   Negative                     NaN
# HK_G_082b                   Negative                     NaN
# HK_G_083a                   Negative                     NaN
# HK_G_084b                   Negative                     NaN
# HK_G_085a                   Negative                     NaN
# HK_G_086b                   Negative                     NaN
# HK_G_089a                   Negative                     NaN
# HK_G_090b                   Negative                     NaN
# HK_G_091a                   Negative                     NaN
# HK_G_092b                   Negative                     NaN
# HK_G_095a                   Negative                     Yes
# HK_G_096b                   Negative                     Yes
# HK_G_099a                   Negative                     NaN
# HK_G_100b                   Negative                     NaN
# HK_G_104a                   Negative                     NaN
# HK_G_105b                   Negative                     NaN
# HK_G_108a                   Negative                     NaN
# HK_G_109b                   Negative                     NaN
# HK_G_110a                   Negative                     NaN
# HK_G_111b                   Negative                     NaN
# HK_G_112a                   Negative                     NaN
# HK_G_113b                   Negative                     NaN
# HK_G_114a                   Negative                     NaN
# HK_G_115b                   Negative                     NaN
#
#            mgmt_promoter_methylation  egfr_mutation  egfr_amplification  \
# sample_id
# HK_G_016a               Unmethylated             No                  No
# HK_G_017b               Unmethylated             No                  No
# HK_G_028a                 Methylated             No                  No
# HK_G_029b                 Methylated             No                  No
# HK_G_035a               Unmethylated            NaN                 Yes
# HK_G_036b               Unmethylated            NaN                 Yes
# HK_G_043a                 Methylated            NaN                 NaN
# HK_G_044b                 Methylated            NaN                 NaN
# HK_G_058a                 Methylated            NaN                 NaN
# HK_G_059b                 Methylated            NaN                 NaN
# HK_G_060a               Unmethylated            NaN                 NaN
# HK_G_061b               Unmethylated            NaN                 NaN
# HK_G_078a               Unmethylated            NaN                 NaN
# HK_G_079b               Unmethylated            NaN                 NaN
# HK_G_081a               Unmethylated            NaN                 NaN
# HK_G_082b               Unmethylated            NaN                 NaN
# HK_G_083a               Unmethylated            NaN                 NaN
# HK_G_084b               Unmethylated            NaN                 NaN
# HK_G_085a                        NaN            NaN                 NaN
# HK_G_086b                        NaN            NaN                 NaN
# HK_G_089a               Unmethylated            NaN                 NaN
# HK_G_090b               Unmethylated            NaN                 NaN
# HK_G_091a                 Methylated            NaN                 NaN
# HK_G_092b                 Methylated            NaN                 NaN
# HK_G_095a               Unmethylated            NaN                 NaN
# HK_G_096b               Unmethylated            NaN                 NaN
# HK_G_099a               Unmethylated            NaN                 NaN
# HK_G_100b               Unmethylated            NaN                 NaN
# HK_G_104a               Unmethylated            NaN                 NaN
# HK_G_105b               Unmethylated            NaN                 NaN
# HK_G_108a               Unmethylated            NaN                 NaN
# HK_G_109b               Unmethylated            NaN                 NaN
# HK_G_110a               Unmethylated            NaN                 NaN
# HK_G_111b               Unmethylated            NaN                 NaN
# HK_G_112a               Unmethylated            NaN                 NaN
# HK_G_113b               Unmethylated            NaN                 NaN
# HK_G_114a                 Methylated            NaN                 NaN
# HK_G_115b                 Methylated            NaN                 NaN
#
#           pten_mutation  ntrk_fusion  histone_h3_g34_mutation_sequencing  \
# sample_id
# HK_G_016a            No           No                                  No
# HK_G_017b            No           No                                  No
# HK_G_028a            No           No                                  No
# HK_G_029b            No           No                                  No
# HK_G_035a           NaN          NaN                                 NaN
# HK_G_036b           NaN          NaN                                 NaN
# HK_G_043a           NaN          NaN                                 NaN
# HK_G_044b           NaN          NaN                                 NaN
# HK_G_058a           NaN          NaN                                 NaN
# HK_G_059b           NaN          NaN                                 NaN
# HK_G_060a           NaN          NaN                                 NaN
# HK_G_061b           NaN          NaN                                 NaN
# HK_G_078a           NaN          NaN                                 NaN
# HK_G_079b           NaN          NaN                                 NaN
# HK_G_081a           NaN          NaN                                 NaN
# HK_G_082b           NaN          NaN                                 NaN
# HK_G_083a           NaN          NaN                                 NaN
# HK_G_084b           NaN          NaN                                 NaN
# HK_G_085a           NaN          NaN                                 NaN
# HK_G_086b           NaN          NaN                                 NaN
# HK_G_089a           NaN          NaN                                 NaN
# HK_G_090b           NaN          NaN                                 NaN
# HK_G_091a           NaN          NaN                                 NaN
# HK_G_092b           NaN          NaN                                 NaN
# HK_G_095a           NaN          NaN                                 NaN
# HK_G_096b           NaN          NaN                                 NaN
# HK_G_099a           NaN          NaN                                 NaN
# HK_G_100b           NaN          NaN                                 NaN
# HK_G_104a           NaN          NaN                                 NaN
# HK_G_105b           NaN          NaN                                 NaN
# HK_G_108a           NaN          NaN                                 NaN
# HK_G_109b           NaN          NaN                                 NaN
# HK_G_110a           NaN          NaN                                 NaN
# HK_G_111b           NaN          NaN                                 NaN
# HK_G_112a           NaN          NaN                                 NaN
# HK_G_113b           NaN          NaN                                 NaN
# HK_G_114a           NaN          NaN                                 NaN
# HK_G_115b           NaN          NaN                                 NaN
#
#           histone_h3_k27m_mutation_sequencing  \
# sample_id
# HK_G_016a                                  No
# HK_G_017b                                  No
# HK_G_028a                                  No
# HK_G_029b                                  No
# HK_G_035a                                 NaN
# HK_G_036b                                 NaN
# HK_G_043a                                 NaN
# HK_G_044b                                 NaN
# HK_G_058a                                 NaN
# HK_G_059b                                 NaN
# HK_G_060a                                 NaN
# HK_G_061b                                 NaN
# HK_G_078a                                 NaN
# HK_G_079b                                 NaN
# HK_G_081a                                 NaN
# HK_G_082b                                 NaN
# HK_G_083a                                 NaN
# HK_G_084b                                 NaN
# HK_G_085a                                 NaN
# HK_G_086b                                 NaN
# HK_G_089a                                 NaN
# HK_G_090b                                 NaN
# HK_G_091a                                 NaN
# HK_G_092b                                 NaN
# HK_G_095a                                 NaN
# HK_G_096b                                 NaN
# HK_G_099a                                 NaN
# HK_G_100b                                 NaN
# HK_G_104a                                 NaN
# HK_G_105b                                 NaN
# HK_G_108a                                 NaN
# HK_G_109b                                 NaN
# HK_G_110a                                 NaN
# HK_G_111b                                 NaN
# HK_G_112a                                 NaN
# HK_G_113b                                 NaN
# HK_G_114a                                 NaN
# HK_G_115b                                 NaN
#
#           time_interval_sample_harvest_dearchival_years
# sample_id
# HK_G_016a                                      6.869268
# HK_G_017b                                      6.017796
# HK_G_028a                                      6.951403
# HK_G_029b                                      2.973306
# HK_G_035a                                      3.594798
# HK_G_036b                                      2.754278
# HK_G_043a                                      4.991102
# HK_G_044b                                      4.824093
# HK_G_058a                                     11.096509
# HK_G_059b                                      7.937029
# HK_G_060a                                      7.561944
# HK_G_061b                                      4.982888
# HK_G_078a                                      7.419576
# HK_G_079b                                      6.721424
# HK_G_081a                                      5.075975
# HK_G_082b                                      4.265572
# HK_G_083a                                      7.849418
# HK_G_084b                                      6.595483
# HK_G_085a                                      8.468172
# HK_G_086b                                      8.736482
# HK_G_089a                                      5.377139
# HK_G_090b                                      4.736482
# HK_G_091a                                      4.180698
# HK_G_092b                                      6.573580
# HK_G_095a                                      6.442163
# HK_G_096b                                      3.767283
# HK_G_099a                                     11.173169
# HK_G_100b                                     10.477755
# HK_G_104a                                      8.544832
# HK_G_105b                                      7.778234
# HK_G_108a                                      4.314853
# HK_G_109b                                      3.126626
# HK_G_110a                                      8.473648
# HK_G_111b                                      7.493498
# HK_G_112a                                      5.155373
# HK_G_113b                                      2.915811
# HK_G_114a                                     10.639288
# HK_G_115b                                      7.854894
#
# [38 rows x 40 columns]

# %%
from itertools import combinations
import pandas as pd

# Step 1: Select duplicates
duplicate_rows = clin_df[clin_df.duplicated(subset=['os_censor', 'os_years', 'pfs_years'], keep=False)]

# Step 2: Define columns to compare (excluding ones already used for filtering)
columns_to_compare = [col for col in clin_df.columns if col not in ['os_censor', 'os_years', 'pfs_years']]

# Step 3: Compute similarity for each pair
pairs = []
for idx1, idx2 in combinations(duplicate_rows.index, 2):  # Generate all possible pairs
    row1, row2 = duplicate_rows.loc[idx1], duplicate_rows.loc[idx2]
    
    # Count how many columns have the same values (excluding NaNs)
    similarity_score = sum(row1[col] == row2[col] for col in columns_to_compare if pd.notna(row1[col]) and pd.notna(row2[col]))
    
    pairs.append((idx1, idx2, similarity_score))

# Step 4: Sort pairs by highest similarity
pairs_sorted = sorted(pairs, key=lambda x: x[2], reverse=True)

# Step 5: Assign couples while ensuring uniqueness
assigned = set()
couples = []
for idx1, idx2, score in pairs_sorted:
    if idx1 not in assigned and idx2 not in assigned:  # Ensure unique pairing
        couples.append((idx1, idx2))
        assigned.update([idx1, idx2])

# Convert to DataFrame for readability
couples_df = pd.DataFrame(couples, columns=['Sample1', 'Sample2'])
print(couples_df)
# Out:
#       Sample1    Sample2
# 0   HK_G_016a  HK_G_017b
# 1   HK_G_028a  HK_G_029b
# 2   HK_G_035a  HK_G_036b
# 3   HK_G_095a  HK_G_096b
# 4   HK_G_089a  HK_G_090b
# 5   HK_G_091a  HK_G_092b
# 6   HK_G_043a  HK_G_044b
# 7   HK_G_078a  HK_G_079b
# 8   HK_G_081a  HK_G_082b
# 9   HK_G_083a  HK_G_084b
# 10  HK_G_108a  HK_G_109b
# 11  HK_G_112a  HK_G_113b
# 12  HK_G_060a  HK_G_061b
# 13  HK_G_099a  HK_G_100b
# 14  HK_G_110a  HK_G_111b
# 15  HK_G_085a  HK_G_086b
# 16  HK_G_104a  HK_G_105b
# 17  HK_G_114a  HK_G_115b
# 18  HK_G_058a  HK_G_059b

# %%
# For the clinical data, you also have access to a dictionary to understand the
# variable's name
data_dict = source_dict_mosaic["clinical"]["data dictionary"]
data_dict.head(3)
# Out:
#                   File name   Field name  \
# 0  sample_and_clinical_data    sample_id
# 1  sample_and_clinical_data   patient_id
# 2  sample_and_clinical_data  cohort_code
#
#                                                 Note
# 0  Unique identifier for each biological sample c...
# 1  Unique identifier assigned to each patient in ...
# 2  Code representing the cohort to which the pati...

# %% [markdown]
# #### 2. Bulk RNA sequencing data

# %%
# To access the bulk RNAseq data, you can specify a particular normalization
print(source_dict_mosaic["bulk_rna"].keys())
bRNA_TPM = source_dict_mosaic["bulk_rna"]["TPM counts"]
bRNA_TPM.head(2)
# Out:
# dict_keys(['raw counts', 'TPM counts', 'normalized counts', 'fpkm counts'])
#                  HK_G_001a_mRNA  HK_G_002a_mRNA  HK_G_003a_mRNA  \
# EnsemblID
# ENSG00000227232        2.646295        4.818720        4.988052
# ENSG00000278267       13.143915       55.589013       36.336981
#
#                  HK_G_004a_mRNA  HK_G_005a_mRNA  HK_G_006a_mRNA  \
# EnsemblID
# ENSG00000227232       10.826797       10.334242        6.164277
# ENSG00000278267       10.082953       82.126826        4.223092
#
#                  HK_G_007a_mRNA  HK_G_008a_mRNA  HK_G_009a_mRNA  \
# EnsemblID
# ENSG00000227232        1.861153        7.040015       10.019317
# ENSG00000278267        6.162789       61.345849       26.106263
#
#                  HK_G_010a_mRNA  ...  HK_G_104a_mRNA  HK_G_106a_mRNA  \
# EnsemblID                        ...
# ENSG00000227232        6.855820  ...         2.54642             0.0
# ENSG00000278267       47.673153  ...        14.45468             0.0
#
#                  HK_G_108a_mRNA  HK_G_109b_mRNA  HK_G_110a_mRNA  \
# EnsemblID
# ENSG00000227232        1.766217        0.073299        1.147692
# ENSG00000278267        3.341960       20.387991       13.681160
#
#                  HK_G_111b_mRNA  HK_G_112a_mRNA  HK_G_113b_mRNA  \
# EnsemblID
# ENSG00000227232        1.985879        1.614058        0.000000
# ENSG00000278267        3.034980       32.067527       22.379758
#
#                  HK_G_114a_mRNA  HK_G_115b_mRNA
# EnsemblID
# ENSG00000227232        0.685128        2.793477
# ENSG00000278267        3.402972       60.785522
#
# [2 rows x 104 columns]

# %%
# A quick way to convert ensemblID to gene names, using gget, but other tools exist
# ensembl_ids = bRNA_TPM.index.astype(str).tolist()[:10]
# result = gget.info(ensembl_ids, verbose=False)
# result["ensembl_gene_name"]

# %% [markdown]
# #### 3. Whole exome sequencing (WES) data
#
# The single nucleotide variant (SNV) and small insertion and deletion (indel) information are stored in a DataFrame, with rows representing samples and columns representing genes. Each cell contains a Boolean value (True/False) indicating whether a gene contains a potentially oncogenic SNV or indel in that sample.
#
# A gene is considered to have a potentially oncogenic alteration if it meets one of these criteria:
# - The variant creates a nonsense mutation in a known tumour suppressor gene (TSG)
# - The variant results in a previously documented amino acid change at a known cancer hotspot
#
# Note that the TSGs and hotspots used in this analysis are not specific to GBM. To focus specifically on likely GBM drivers, you may want to use a more restricted gene list.
#
# WES was performed on tumour samples only and we are therefore not always able to distinguish between somatic and germline variants. Some genes, such as HLA genes, likely contain false positives.

# %%
# Access SNVs and indels
snvs_indels = source_dict_mosaic["wes"]["WES mutations"]
snvs_indels.head(2)
# Out:
# gene_name  CREBBP  CD79B    BTK  BRCA1    FAS  POU2F2   ANK1   CUL3   FLT4  \
# sample_id
# HK_G_001a   False  False  False  False  False   False  False  False  False
# HK_G_002a   False  False  False  False  False   False  False  False  False
#
# gene_name   TLL1  ...  DDX3X    LTB  HLA-B  CEBPA    LYN   CUX1  TAF15  KMT2B  \
# sample_id         ...
# HK_G_001a  False  ...  False  False  False  False  False  False  False  False
# HK_G_002a  False  ...  False  False   True  False  False  False  False  False
#
# gene_name  ZNF658   H3C2
# sample_id
# HK_G_001a   False  False
# HK_G_002a   False  False
#
# [2 rows x 498 columns]

# %%
from itertools import combinations
import pandas as pd

# Step 1: Select duplicates
duplicate_rows = clin_df[clin_df.duplicated(subset=['os_censor', 'os_years', 'pfs_years'], keep=False)]

# Step 2: Define columns to compare (excluding ones already used for filtering)
columns_to_compare = [col for col in clin_df.columns if col not in ['os_censor', 'os_years', 'pfs_years']]

# Step 3: Compute similarity for each pair
pairs = []
for idx1, idx2 in combinations(duplicate_rows.index, 2):  # Generate all possible pairs
    row1, row2 = duplicate_rows.loc[idx1], duplicate_rows.loc[idx2]
    
    # Count how many columns have the same values (excluding NaNs)
    similarity_score = sum(row1[col] == row2[col] for col in columns_to_compare if pd.notna(row1[col]) and pd.notna(row2[col]))
    
    pairs.append((idx1, idx2, similarity_score))

# Step 4: Sort pairs by highest similarity
pairs_sorted = sorted(pairs, key=lambda x: x[2], reverse=True)

# Step 5: Assign couples while ensuring uniqueness
assigned = set()
couples = []
for idx1, idx2, score in pairs_sorted:
    if idx1 not in assigned and idx2 not in assigned:  # Ensure unique pairing
        couples.append((idx1, idx2))
        assigned.update([idx1, idx2])

# Convert to DataFrame for readability
couples_df = pd.DataFrame(couples, columns=['Sample1', 'Sample2'])
print(couples_df)
# Out:
#       Sample1    Sample2
# 0   HK_G_016a  HK_G_017b
# 1   HK_G_028a  HK_G_029b
# 2   HK_G_035a  HK_G_036b
# 3   HK_G_095a  HK_G_096b
# 4   HK_G_089a  HK_G_090b
# 5   HK_G_091a  HK_G_092b
# 6   HK_G_043a  HK_G_044b
# 7   HK_G_078a  HK_G_079b
# 8   HK_G_081a  HK_G_082b
# 9   HK_G_083a  HK_G_084b
# 10  HK_G_108a  HK_G_109b
# 11  HK_G_112a  HK_G_113b
# 12  HK_G_060a  HK_G_061b
# 13  HK_G_099a  HK_G_100b
# 14  HK_G_110a  HK_G_111b
# 15  HK_G_085a  HK_G_086b
# 16  HK_G_104a  HK_G_105b
# 17  HK_G_114a  HK_G_115b
# 18  HK_G_058a  HK_G_059b

# %%
snvs_indels.sum().sort_values(ascending=False).head()
# Out:
# gene_name
# HLA-B    71
# TP53     35
# PTEN     31
# HLA-A    26
# EGFR     25
# dtype: int64

# %% [markdown]
# Copy number variant (CNV) information is stored across three distinct DataFrames:
# - A binary matrix indicating which genes are affected by deletions in each sample
# - A binary matrix indicating which genes are affected by amplifications in each sample
# - A binary matrix indicating which genes are affected by potentially oncogenic CNVs in each sample
#
# A gene is considered to be affected by a potentially oncogenic CNV if it meets either of these criteria:
# - It is a known TSG and is affected by a deletion
# - It is a known oncogene and is affected by a duplication
#
# The lists of known TSGs and oncogenes are obtained from the IntOGen database. While TSGs and oncogenes can be cancer-specific, our analysis considers all TSGs and oncogenes identified in any cancer type, not just those specific to GBM.

# %%
# Access amplifications
CNVamp = source_dict_mosaic["wes"]["WES CNV amplification"]
CNVamp.head(2)
# Out:
# gene_name  TSPAN6   TNMD   DPM1  SCYL3  FIRRM    FGR    CFH  FUCA2   GCLC  \
# sample_id
# HK_G_001a   False  False  False  False  False  False  False  False  False
# HK_G_002a   False  False  False  False  False  False  False  False  False
#
# gene_name   NFYA  ...   CD99   SHOX  CSF2RA  GTPBP6  CRLF2  VAMP7  WASH6P  \
# sample_id         ...
# HK_G_001a  False  ...  False  False   False   False  False  False   False
# HK_G_002a  False  ...  False  False   False   False  False  False   False
#
# gene_name   IL9R  DUSP13B  DUSP13A
# sample_id
# HK_G_001a  False    False    False
# HK_G_002a  False    False    False
#
# [2 rows x 19458 columns]

# %%
# You can also access the deletions
CNVdel = source_dict_mosaic["wes"]["WES CNV deletion"]
CNVdel.head(2)
# Out:
# gene_name  TSPAN6   TNMD   DPM1  SCYL3  FIRRM    FGR    CFH  FUCA2   GCLC  \
# sample_id
# HK_G_001a   False  False  False  False  False  False  False  False  False
# HK_G_002a   False  False  False  False  False  False  False  False  False
#
# gene_name   NFYA  ...   CD99   SHOX  CSF2RA  GTPBP6  CRLF2  VAMP7  WASH6P  \
# sample_id         ...
# HK_G_001a  False  ...  False  False   False   False  False  False   False
# HK_G_002a  False  ...  False  False   False   False  False  False   False
#
# gene_name   IL9R  DUSP13B  DUSP13A
# sample_id
# HK_G_001a  False    False    False
# HK_G_002a  False    False    False
#
# [2 rows x 19458 columns]

# %%
print("Number of samples with information on CNV alterations: ", CNVdel.shape[0])
# Out:
# Number of samples with information on CNV alterations:  107

# %%
# Show the top deleted genes
CNVdel.sum().sort_values(ascending=False).head()
# Out:
# gene_name
# TBC1D3K    80
# TBC1D3E    80
# TBC1D3C    80
# TBC1D3L    80
# TBC1D3I    80
# dtype: int64

# %%
# Access the potentially oncogenic CNVs and show the top genes
CNVoncogenic = source_dict_mosaic["wes"]["WES CNV oncogenic"]
CNVoncogenic.sum().sort_values(ascending=False).head()
# Out:
# gene_name
# CDKN2A    80
# GATA3     66
# KLF6      37
# KAT6B     27
# CD274     17
# dtype: int64

# %% [markdown]
# #### 4. Single-cell RNA sequencing (Chromium) data
# Processed single-cell RNA sequencing data are stored as an AnnData object. Ambient RNA has been removed using [SoupX](https://academic.oup.com/gigascience/article/9/12/giaa151/6049831) and doublets identified and removed using [ScDblFinder](https://pmc.ncbi.nlm.nih.gov/articles/PMC9204188/).

# %%
# Note that it can take up to 12 minutes to load the single-cell data because it is heavy
single_cell_obj = MosaicDataset.load_singlecell()
# Display the content of the anndata object
single_cell_obj.__dict__.keys()
# Out:
# dict_keys(['_is_view', '_adata_ref', '_oidx', '_vidx', 'file', '_X', '_obs', '_var', '_uns', '_obsm', '_varm', '_obsp', '_varp', '_raw', '_layers'])

# %% [markdown]
# Various normalisations have been applied to the data. The unnormalised and normalised gene expression data can be accessed as follows.

# %%
# .layers["ambient_rna_removed"] contains the unnormalised counts
single_cell_obj.layers["ambient_rna_removed"]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1132239414 stored elements and shape (620451, 17842)>

# %%
# .layers["LogNormalize"] contains log-normalised counts
single_cell_obj.layers["LogNormalize"]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1132239414 stored elements and shape (620451, 17842)>

# %%
# .X contains the log of the SCTransform-corrected counts plus one
single_cell_obj.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 848560087 stored elements and shape (620451, 17842)>

# %% [markdown]
# The `.obs` property contains cell-level meta-data. Each row represents a cell. The most useful columns are:
# - `orig.ident` The sample ID.
# - `celltype_level1_scanvi` Level 1 cell type annotations. These are the annotations at the lowest resolution, and comprise the following five cell types: *Immune*, *Malignant*, *Neuroglia*, *Neuron*, *Stromal*.
# - `celltype_level2_scanvi` Level 2 cell type annotations. These are higher resolution than level 1 annotations.
# - `celltype_level3_scanvi` Level 3 cell type annotations. Malignant cells from each sample are annotated separately, for example, *Tu_HK_G_001* are malignant cells from sample *HK_G_001*.
# - `celltype_level4_scanvi` Level 4 cell type annotations. These are the highest-resolution annotations. Malignant cells from each sample have been subclustered based on transcriptional similarity. For example, malignant cells from *Tu_HK_G_111b* have been subclustered into *Tu_HK_G_111b_c01*, *Tu_HK_G_111b_c02*, *Tu_HK_G_111b_c03*, and *Tu_HK_G_111b_nos*.

# %%
single_cell_obj.obs.head(2)
# Out:
#                                      orig.ident  percent_reads_mt  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1  HK_G_058a          0.699828
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1  HK_G_058a          0.666423
#
#                                       percent_reads_ribo  percent_reads_hb  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                 0.0               0.0
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                 0.0               0.0
#
#                                       doublet_score_scdblfinder  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                   0.237310
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                   0.062168
#
#                                       doublet_predicted_scdblfinder  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                              0
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                              0
#
#                                      seurat_clusters seurat_clusters_res_0.1  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1               4                       0
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1               3                       0
#
#                                      seurat_clusters_res_0.2  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                       0
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                       0
#
#                                      seurat_clusters_res_0.4  ...  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                       2  ...
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                       1  ...
#
#                                      celltype_level4_scanvi  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1       Tu_HK_G_058a_c03
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1       Tu_HK_G_058a_c03
#
#                                      celltype_level_custom1_scanvi  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1              Tu_HK_G_058a_c03
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1              Tu_HK_G_058a_c03
#
#                                      SCT_snn_res.0.4 SCT_snn_res.2  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1               3            34
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1               3            23
#
#                                      seurat_clusters_heterogeneity  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                             3
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                             3
#
#                                       seurat_clusters_res_1.5  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                       29
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                       29
#
#                                       seurat_clusters_res_2.5  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                        6
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                       52
#
#                                       seurat_clusters_res_3  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                      2
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                     59
#
#                                      seurat_clusters_res_3.5  \
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                      12
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                      12
#
#                                      seurat_clusters_res_4
# HK_G_058a.AAACAAGCACGGGCTAACTTTAGG-1                    41
# HK_G_058a.AAACAAGCACTTTATGACTTTAGG-1                    28
#
# [2 rows x 31 columns]

# %% [markdown]
# PCA and UMAP embedding have already been computed. These are stored in the `.obsm` property.

# %%
# Visualize single-cell UMAP coloured by level 2 cell type annotations
embedding = single_cell_obj.obsm["X_umap"][:, :2]
df = pd.DataFrame(embedding, columns=["UMAP1", "UMAP2"])
df["cell_type"] = single_cell_obj.obs["celltype_level2_scanvi"].values
sns.scatterplot(
    data=df,
    x="UMAP1",
    y="UMAP2",
    hue="cell_type",
    palette="tab10",
    s=10,
    alpha=0.7
)
plt.title("UMAP Embedding with level 2 cell type annotations")
plt.show()

# %% [markdown]
# #### 5. Spatial transcriptomic (Visium) data
# The `notebooks/visium_starter_mosaic.ipynb` Notebook provides more information on how to process and explore Visium data.

# %%
# Load Visium data
visium_obj = MosaicDataset.load_visium(
    sample_list=["HK_G_022a_vis", "HK_G_024a_vis", "HK_G_030a_vis"], # remove this argument to load all available samples
    resolution="hires"
)
# Out:
# Resolution of the spatial image to load:  hires
# You can change the resolution by setting the resolution parameter using the resolution argument.
# Loading Visium data, this can take few minutes...

# %% [markdown]
# #### 6. Aligned H&E images

# %%
# Load the H&E slides
he = source_dict_mosaic["he"]["HE files"]
he.head(2)
# Out:
#                                                          path patient id
# Subject Id
# HK_G_001a   /home/ec2-user/SageMaker/data/mosaic_dataset/V...   HK_G_001
# HK_G_002a   /home/ec2-user/SageMaker/data/mosaic_dataset/V...   HK_G_002

# %%
he.shape
# Out:
# (86, 2)

# %%
# Display a H&E slide
slide_idx = 85  # pick a H&E slide to display

slide = tiffslide.TiffSlide(he.path.values[slide_idx])

# Display the slide
slide_img = slide.get_thumbnail(slide.level_dimensions[-2])
fig, ax = plt.subplots()
ax.imshow(slide_img)
ax.set_axis_off()
plt.show()

# %%
# Load the H1 Bioptimus features paths for each subject
h1 = source_dict_mosaic["he"]["H1 features"]
h1.head(2)
# Out:
#                                                          path patient id
# Subject Id
# HK_G_001a   /home/ec2-user/SageMaker/data/h1_bioptimus_fea...   HK_G_001
# HK_G_002a   /home/ec2-user/SageMaker/data/h1_bioptimus_fea...   HK_G_002

# %%
# Load the H1 features for one sample

slide_idx = 12  # pick a H&E slide to display

# Load the H1 zarr object for the selected slide
h1_zarr = zarr.open(h1.path.values[slide_idx], mode='r')

h1_emb = h1_zarr["emb"][:]  # (n tiles, n features) np array H1 features
h1_coords = h1_zarr["coords"][:]  # (n tiles, 2) np array coordinates
h1_level = h1_zarr["level"][:]  # (n tiles, 1) np array level of resolution

# %% [markdown]
# ## Start exploring the BRUCE Data

# %%
# Look at the available data sources
BruceDataset.sources.keys()
# Out:
# dict_keys(['metadata', 'mibi_images'])

# %%
# Load the metadata table
source_dict_bruce = BruceDataset.load_tabular()

# %%
metadata = source_dict_bruce["metadata"]["metadata"]
metadata.head(2)
# Out:
#               patient_id           fov_immune            fov_tumor      site  \
# sample_id
# Stanford-100        1777  Stanford_TA552_R1C4  Stanford_TA552_R1C4  Stanford
# Stanford-104       60074  Stanford_TA552_R2C4  Stanford_TA552_R2C4  Stanford
#
#               who_grade final_diagnosis final_diagnosis_simple who_diagnosis  \
# sample_id
# Stanford-100          4             GBM                    GBM       4 - GBM
# Stanford-104          4             GBM                    GBM       4 - GBM
#
#                             tumor_region      anatomical_location  ...  \
# sample_id                                                          ...
# Stanford-100  tumor_core_to_infiltrating   CEREBRUM_LEFT_TEMPORAL  ...
# Stanford-104  tumor_core_to_infiltrating  CEREBRUM_RIGHT_TEMPORAL  ...
#
#              egfr_egfrvIII_status row  column combined_label TMA_Patient  \
# sample_id
# Stanford-100                  unk   1       4           R1C4     33707_1
# Stanford-104                  unk   2       4           R2C4     33708_1
#
#              alignment_status comp_1  MIBI  MALDI  NS
# sample_id
# Stanford-100                1  other  MIBI  MALDI  NS
# Stanford-104                0  other  MIBI  MALDI  NS
#
# [2 rows x 54 columns]

# %% [markdown]
# ### Load a MIBI image

# %%
source_dict_bruce.keys()
# Out:
# dict_keys(['metadata', 'mibi_images'])

# %%
# Load the information on the image
mibi_immune = source_dict_bruce["mibi_images"]["immune"] # you can also choose "tumor"
mibi_immune.head(2)
# Out:
#                                                                    path  \
# sample_id
# Stanford_TA551_R10C4  /home/ec2-user/SageMaker/data/bruce_dataset/St...
# Stanford_TA551_R10C4  /home/ec2-user/SageMaker/data/bruce_dataset/St...
#
#                          marker
# sample_id
# Stanford_TA551_R10C4  Arginase1
# Stanford_TA551_R10C4         Au

# %%
# Display for one sample and one immune marker of interest
img_idx = 1
img = tifffile.imread(mibi_immune.path.values[img_idx])

# Normalize the image to the range [0, 1]
img_normalized = (img - img.min()) / (img.max() - img.min())

# Display the normalized image
plt.imshow(img_normalized)
plt.axis('off')
plt.show()
