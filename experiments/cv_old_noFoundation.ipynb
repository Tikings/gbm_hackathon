# %% [markdown]
# # Evaluation of the old framework

# %%
import sys
import os

project_path = "/home/sagemaker-user/gbm_hackathon"
if project_path not in sys.path:
    sys.path.append(project_path)
    print(sys.path)
# Out:
# ['/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python310.zip', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/lib-dynload', '', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/site-packages', '/home/sagemaker-user/gbm_hackathon']

# %%
# %load_ext autoreload
# %autoreload 2

from gbmhackathon.training.predictive import *
from gbmhackathon.models.mme import MultiModalEncoder, ClinicalLinkageModule, concat_modality_embeddings
from gbmhackathon.utils.loss_functions import InfoNCELoss, RegularizedInfoNCELoss, SmoothingFunction, RankMe, make_patient_map, RegularizationModule
from gbmhackathon.utils.module_functions import instantiate
from gbmhackathon.utils.model_saving import *
from gbmhackathon.training.loops import modality_wise_contrastive_learning, new_predictive_learning, build_run_name
from gbmhackathon.training.cv import *
from gbmhackathon.utils.analysis import *
from gbmhackathon.viz.viz_experiment import *
from gbmhackathon.s3_loader import load_s3

import os, time
from copy import deepcopy
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
# To investigate gradients
from torchviz import make_dot

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam

# %%
torch.set_num_threads(32)
torch.get_num_threads()
# Out:
# 32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %% [markdown]
# ## Dataset preparation

# %%
ALL_POSSIBLE_EMBS = ["025-03-22_12-27_phikon_emb_V1.pkl",
                    "2025-03-23_18-32_spatial_emb_V1.pkl",
                    "2025-03-30_14-23_clinical_emb_V1.pkl",
                    "2025-04-05_13-40_wes_emb_V1.pkl",
                    "2025-04-26_16-02_connectivities_spatial_V1.pkl",
                    "2025-05-03_10-15_bulk_emb_V1.pkl",
                    "2025-05-04_02-35_scRNA_emb_V1.pkl",
                    "2025-05-25_14-36_new_clinical_emb_V1.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_mds.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_pca.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_umap.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_mds.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_pca.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_umap.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_mds.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_pca.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_umap.pkl",
                    "2025-06-01_15-11_wes_emb_V1_mds.pkl",
                    "2025-06-01_15-11_wes_emb_V1_pca.pkl",
                    "2025-06-01_15-11_wes_emb_V1_umap.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_mds.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_pca.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_umap.pkl",
                    "2025-06-01_21-03_raw_spatial_emb_pca.pkl",
                    "2025-06-01_22-10_raw_spatial_emb_umap.pkl",
                    "2025-06-02_21-09_raw_scRNA_emb_pca.pkl",
                    "2025-06-02_22-50_raw_scRNA_emb_umap.pkl",
                    "embeddings_HnE_OptimusH0.pkl"]

# %% [markdown]
# ### You can choose any embedding from the above

# %%
name_emb_dict = {#"hne":"embeddings_HnE_OptimusH0.pkl",
# "spatial":"2025-06-01_22-10_raw_spatial_emb_umap.pkl",
"clinical":"2025-05-25_14-36_new_clinical_emb_V1.pkl",
"wes":"2025-04-05_13-40_wes_emb_V1.pkl",
"bulk":"2025-06-01_18-36_raw_bulk_emb_pca.pkl",
"scRNA":"2025-06-02_21-09_raw_scRNA_emb_pca.pkl"
                }
pkl_storage_folder = "embedding_V1"

# %%
dataset = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=1.0, normalize=True)
print(f"Dataset size: {len(dataset)}")
BATCH_SIZE = 742 #582
dataloader = DataLoader(dataset, BATCH_SIZE, shuffle=True, collate_fn=collate_predictive, generator=torch.Generator(device=dataset.device))
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# Normalization applied successfully
# By keeping 100.00% of dropout augmented samples we went from:
# 94 dropout samples (45.19% dropout in dataset) -- to --> 94 dropout samples (45.19% dropout in dataset)
# Dataset size: 208

# %% [markdown]
# ### To make a batch of True patient samples only (no dropout)

# %%
# Batch of all true samples (no dropout augmented samples)
batch_all = [dataset.__getitem__(idx) for idx in dataset.ind2patient if 'd' not in dataset.ind2patient[idx]]
batch_all = collate_predictive(batch_all)

# %% [markdown]
# ### Needed to know the size of the inputs (it is used later on to define model configurations)

# %%
raw_emb = next(iter(dataloader))[2]
inpute_size_dict = {}
for mod in raw_emb.keys():
    print(mod, raw_emb[mod].size())
    inpute_size_dict[mod] = raw_emb[mod].size(1)
# Out:
# clinical torch.Size([208, 20])
# wes torch.Size([208, 1790])
# bulk torch.Size([208, 60])
# scRNA torch.Size([208, 64])

# %% [markdown]
# ### Patient map is used by the contrastive loss to identify dropout and true samples which are from the same original patient

# %%
patient_map = make_patient_map(dataset)

# %% [markdown]
# ### Configuration of the MultiModalEncoder (see gbmhackathon/models/mme.py)

# %%
def adapt_base_config(base_cfg, input_size):
    base_copy = deepcopy(base_cfg)
    base_copy["layers"] = [input_size] + base_copy["layers"]
    return base_copy

# %%
out = 32
norm_fn = nn.BatchNorm1d
smoothing_fn = SmoothingFunction(bound=-50, slope=0.1, rate=-5)
dropout = 0.3
layers = [1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
base_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

hne_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

clinical_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

spatial_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

wes_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

rna_cfg = {"layers": [1024,256,out], #[1024,128,512,128,out],
        "dropout": dropout,
        "act_fn":act_fn, #[nn.GELU, nn.GELU, nn.GELU, nn.GELU, smoothing_fn],
        "norm_layer":norm_fn,
        "device":device}


# hne_cfg = adapt_base_config(hne_cfg, inpute_size_dict["hne"])
clinical_cfg = adapt_base_config(clinical_cfg, inpute_size_dict["clinical"])
# spatial_cfg = adapt_base_config(spatial_cfg, inpute_size_dict["spatial"])
wes_cfg = adapt_base_config(wes_cfg, inpute_size_dict["wes"])
bulk_cfg = adapt_base_config(rna_cfg, inpute_size_dict["bulk"])
sc_cfg = adapt_base_config(rna_cfg, inpute_size_dict["scRNA"])

# %%
mme_bulk_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": bulk_cfg}

mme_hne_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": hne_cfg}

mme_sc_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": sc_cfg}

mme_wes_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": wes_cfg}

mme_clinical_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": clinical_cfg}

mme_spatial_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": spatial_cfg}

# %%
mme_cfg = {#"hne_cfg":mme_hne_cfg, 
           "clinical_cfg":mme_clinical_cfg, 
           "wes_cfg":mme_wes_cfg, 
           # "spatial_cfg":mme_spatial_cfg,
           "bulk_cfg":mme_bulk_cfg,
          "sc_cfg":mme_sc_cfg}

# %% [markdown]
# ### Configuration of the Regularizer (see gbmhackathon/models/mme.py)

# %%
regularizer_cfg = {"reg_coeff":0.01,
        "use_variance":True,
        "var_coeff":1.0,
        "use_covariance":True,
        "cov_coeff":1.0,
        "var_gamma":1.0,
        "var_eps":1e-4,
}

# %% [markdown]
# ### Instantiation of training settings: model, optimizer, scheduler, epochs, learning rate.

# %%
mme = instantiate(mme_cfg,MultiModalEncoder)

EPOCHS_I = 50
base_lr_I = 1e-3
eta_min_coef = 0.05
scheduler_I_class = torch.optim.lr_scheduler.CosineAnnealingLR
scheduler_I_cfg = {"T_max":EPOCHS_I,
                  "eta_min":"dynamic"}

contrastive_loss_cfg = {"modalities":list(name_emb_dict.keys()),
                        "patient_map":patient_map,
                        'mode':'patient_scale', #
                        "temperature":0.05,
                        "similarity":'nt-xent',
                        "use_all_positives":False,
                        "alpha":0,
                        "bound":-50,
                        "slope":0.1,
                        "rate":-5,
                        "warn":False,
                       "smoothing_func":False}

# Optimization for Phase I
optimizer_I = Adam(mme.parameters(), lr=base_lr_I)
scheduler_I_cfg["optimizer"] = optimizer_I
if "eta_min" in scheduler_I_cfg.keys():
    if scheduler_I_cfg["eta_min"] == "dynamic":
        scheduler_I_cfg["eta_min"] = eta_min_coef * base_lr_I
scheduler_I = instantiate(scheduler_I_cfg, scheduler_I_class)

contrastive_loss_fn = instantiate(contrastive_loss_cfg, RegularizedInfoNCELoss)

modalities = next(iter(dataloader))[2].keys()
    
# A contrastive loss module per modality
modality_contrastive_loss_fn = {}
for modality in modalities:
    contrastive_loss_cfg_mod = contrastive_loss_cfg.copy()
    contrastive_loss_cfg_mod['modalities'] = [modality]
    modality_contrastive_loss_fn[modality] = instantiate(contrastive_loss_cfg_mod, RegularizedInfoNCELoss)

# An optimizer per modality
modality_optimizers = {modality:Adam(mme.modality_net_map[modality].parameters(), lr=base_lr_I) for modality in modalities}

# A scheduler per modality
modality_schedulers = {}
for modality in modalities:
    # Same schedule for all modalities for now, but it can be configurable
    scheduler_cfg = scheduler_I_cfg.copy()
    scheduler_cfg["optimizer"] = modality_optimizers[modality]
    if "eta_min" in scheduler_I_cfg.keys():
        if scheduler_cfg["eta_min"] == "dynamic":
            scheduler_cfg["eta_min"] = eta_min_coef * base_lr_I
    modality_schedulers[modality] = instantiate(scheduler_cfg, scheduler_I_class)

# A regularization method per modality
regularizer_dict = {}
for modality in modalities:
    regularizer_dict[modality] = instantiate(regularizer_cfg, RegularizationModule)
# Out:
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found

# %% [markdown]
# ### Training loop for contrastive phase

# %%
modality_wise_contrastive_learning(mme, 
                                   dataloader, 
                                   EPOCHS_I, 
                                   base_lr_I,
                                   modality_optimizers, 
                                   modality_contrastive_loss_fn, 
                                   modality_schedulers,
                                   regularizer_dict,
                                   batch_all=batch_all,
                                   make_gifs=False,
                                   analyze_emb=True)
# Out:
# EPOCH 1 AVERAGE TOTAL LOSS ACROSS MODALITIES: 7.1714
# EPOCH 2 AVERAGE TOTAL LOSS ACROSS MODALITIES: 6.2196
# EPOCH 3 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.7084
# EPOCH 4 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.4167
# EPOCH 5 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.2083
# EPOCH 6 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.0228
# EPOCH 7 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.8448
# EPOCH 8 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6934
# EPOCH 9 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5595
# EPOCH 10 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4513
# EPOCH 11 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.3610
# EPOCH 12 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.2806
# EPOCH 13 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.2071
# EPOCH 14 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.1426
# EPOCH 15 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.0797
# EPOCH 16 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.0242
# EPOCH 17 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.9731
# EPOCH 18 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.9247
# EPOCH 19 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.8810
# EPOCH 20 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.8406
# EPOCH 21 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.8042
# EPOCH 22 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7684
# EPOCH 23 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7363
# EPOCH 24 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7065
# EPOCH 25 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6781
# EPOCH 26 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6514
# EPOCH 27 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6268
# EPOCH 28 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6024
# EPOCH 29 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5806
# EPOCH 30 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5603
# EPOCH 31 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5397
# EPOCH 32 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5207
# EPOCH 33 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5023
# EPOCH 34 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4848
# EPOCH 35 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4687
# EPOCH 36 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4520
# EPOCH 37 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4367
# EPOCH 38 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4223
# EPOCH 39 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4080
# EPOCH 40 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3940
# EPOCH 41 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3811
# EPOCH 42 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3684
# EPOCH 43 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3557
# EPOCH 44 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3440
# EPOCH 45 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3328
# EPOCH 46 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3220
# EPOCH 47 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3121
# EPOCH 48 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3019
# EPOCH 49 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2928
# EPOCH 50 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2835

# %% [markdown]
# ## Save MultiModalEncoder

# %%
save_model(mme, '../saved_models/old_noFoundation_mme.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/old_noFoundation_mme.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_noFoundation_mme.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/old_noFoundation_mme.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_noFoundation_mme.ckpt'))

# %% [markdown]
# ## Use the trained MME to compute and save representations of true patient samples to use for the clinical linkage phase

# %%
run_name = build_run_name(
    model=mme,
    epochs=EPOCHS_I,
    base_lr=base_lr_I,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_I_class,
    scheduler_cfg=scheduler_I_cfg,
    contrastive_loss_cfg=contrastive_loss_cfg,
    modality_list=list(name_emb_dict.keys())
)

# %%
mme_emb_dict = mme(batch_all[2]) # Retrieves X_dict
folder = "mme_embeddings_old_noFoundation"
save_path = f"{folder}/{run_name}.pkl"
os.makedirs(folder, exist_ok=True)

with open(save_path, "wb") as f:
    pkl.dump(mme_emb_dict, f)

# %% [markdown]
# # Set everything up for clinical linkage phase
# We can choose to remove dropout or not by instantiating another dataset

# %%
dataset_II = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=0.0, normalize=True)
print(f"Dataset size: {len(dataset_II)}")
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# Normalization applied successfully
# Dataset size: 114

# %% [markdown]
# ### Configuration of the clinical linkage module

# %%
dropout = 0.3
layers = [out*len(mme_cfg),16]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
norm_fn = nn.BatchNorm1d
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
# ATTENTION !!!! MUST BE THIS EXACT ORDER FOR PREDICTIVE TASKS: 
# ['os_years', 'pfs_years', 'largest_diameter_of_the_primary_tumour_mm_duplicated_0', 'recurrent_sample']
# OR ['os_years', 'pfs_years', 'recurrent_sample', 'mgmt_promoter_methylation'] if using latest targets
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

clf_targets = ['recurrency', 'mgmt']
clf_targets_dict = {'recurrency':2, 'mgmt':3}

# %% [markdown]
# ### No RefinementBlock in this framework originally

# %%
# refinement_cfg = {"emb_size": out*len(mme_cfg),
#                 "cross_modality_heads": 1,
#                 "cross_mods_fc_size": 1024,
#                 "avail_mods_fc_size": 128,
#                 "avail_mods_len":len(mme_cfg),
#                 "avail_mods_dense_size": 32,
#                 "avail_mods_heads": 1,
#                 "act_fn": nn.GELU,
#                 "dropout": dropout,
#                 "device": device}
refinement_cfg = None

# %% [markdown]
# # Monte Carlo Cross Validation
# Instantiation must be done for each fold

# %%
n_splits = 30
test_size = 0.8
t_batch = 32 # training batch size
v_batch = 256 # evaluation batch size
random_state = 6262

# %%
cv_scores = {task:[] for task in predictive_cfg["heads_configs"].keys()}
t0 = time.time()
for train_loader, val_loader in get_mccv_loaders(dataset_II, 
                                                 collate_predictive,
                                                 n_splits=n_splits, 
                                                 test_size=test_size, 
                                                 train_batch_size=t_batch, 
                                                 val_batch_size=v_batch, 
                                                 device=device, 
                                                 random_state=random_state):
    EPOCHS_II = 150
    base_lr_II = 1e-4
    scheduler_II_class = torch.optim.lr_scheduler.CosineAnnealingLR
    scheduler_II_cfg = {"T_max":EPOCHS_II,
                        "eta_min":"dynamic"}
    clm = ClinicalLinkageModule(refinement_cfg=refinement_cfg,
                            predictive_cfg=predictive_cfg)
    # Optimization for Phase II
    optimizer_II = Adam(clm.parameters(), lr=base_lr_II)
    scheduler_II_cfg["optimizer"] = optimizer_II
    if "eta_min" in scheduler_II_cfg.keys():
        if scheduler_II_cfg["eta_min"] == "dynamic":
            scheduler_II_cfg["eta_min"] = eta_min_coef * base_lr_II
    scheduler_II = instantiate(scheduler_II_cfg, scheduler_II_class)

    # Training loop with validation at the end of each epoch on the validation set
    new_predictive_learning(mme, clm, 
                          train_loader,
                          EPOCHS_II, 
                          base_lr_II, 
                          optimizer_II,
                          scheduler_II,
                          clf_targets_dict,
                          v_dataloader=val_loader,
                          reg_loss_fn = nn.MSELoss(),
                          clf_loss_fn = nn.CrossEntropyLoss(),
                          batch_all=batch_all, # No worries, it is used in eval mode under the hood so not seen by model
                          make_gifs=False,
                          )
    # Evaluation metrics are computed on the validation set after training.
    clm.eval()
    all_val_predictions = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    all_val_targets = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    for batch in val_loader:
        patient_ids, modalities, X_dict, avail_mods, batch_targets, targets_names = batch
        
        contrastive_outputs = mme(X_dict)
        task_outputs, patient_embeddings = clm(contrastive_outputs, avail_mods)
        
        overall_loss = torch.tensor(0, device=device)
        # Regression losses
        for i, key in enumerate(task_outputs.keys()):
            if key not in clf_targets:
                all_val_predictions[key].append(task_outputs[key].squeeze())
                all_val_targets[key].append(batch_targets[:,i])
            
        # Classification losses
        for i, key in enumerate(clf_targets):
            if i == 0:
                start_idx = len(task_outputs.keys()) - len(clf_targets)
            else:
                start_idx = end_idx - 1 # last end_idx
            # clf_targets_dict is a dict that maps each clf target to the number of classes it holds
            end_idx = start_idx + clf_targets_dict[key]
            all_val_predictions[key].append(task_outputs[key])
            all_val_targets[key].append(batch_targets[:,start_idx:end_idx])
            
    for task in all_val_predictions.keys():
        all_task_pred = torch.cat(all_val_predictions[task], dim=0).to(dataset.device)
        all_task_true = torch.cat(all_val_targets[task], dim=0).to(dataset.device)
        if task not in clf_targets:
            score = torch.sqrt(nn.MSELoss()(all_task_pred, all_task_true)).item()
        else:
            score = f1_score(torch.argmax(all_task_true, dim=1).cpu().detach().numpy(), 
                             torch.argmax(all_task_pred, dim=1).cpu().detach().numpy(), 
                             average='weighted', zero_division=0)
        cv_scores[task].append(score)
reg_dict = {key:val for key, val in cv_scores.items() if key in ['os', 'pfs']}
clf_dict = {key:val for key, val in cv_scores.items() if key in clf_targets}
runtime = time.time() - t0
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.4948
# EPOCH 2 TOTAL TRAINING LOSS: 6.065302
# EPOCH 3 TOTAL TRAINING LOSS: 6.503557
# EPOCH 4 TOTAL TRAINING LOSS: 6.201038
# EPOCH 5 TOTAL TRAINING LOSS: 6.043238
# EPOCH 6 TOTAL TRAINING LOSS: 6.088053
# EPOCH 7 TOTAL TRAINING LOSS: 6.432082
# EPOCH 8 TOTAL TRAINING LOSS: 6.342132
# EPOCH 9 TOTAL TRAINING LOSS: 5.668884
# EPOCH 10 TOTAL TRAINING LOSS: 5.64089
# EPOCH 11 TOTAL TRAINING LOSS: 5.898132
# EPOCH 12 TOTAL TRAINING LOSS: 6.319727
# EPOCH 13 TOTAL TRAINING LOSS: 6.298933
# EPOCH 14 TOTAL TRAINING LOSS: 6.233450
# EPOCH 15 TOTAL TRAINING LOSS: 6.460064
# EPOCH 16 TOTAL TRAINING LOSS: 6.412394
# EPOCH 17 TOTAL TRAINING LOSS: 5.554534
# EPOCH 18 TOTAL TRAINING LOSS: 5.907787
# EPOCH 19 TOTAL TRAINING LOSS: 5.794463
# EPOCH 20 TOTAL TRAINING LOSS: 5.926638
# EPOCH 21 TOTAL TRAINING LOSS: 5.595935
# EPOCH 22 TOTAL TRAINING LOSS: 5.308607
# EPOCH 23 TOTAL TRAINING LOSS: 6.158308
# EPOCH 24 TOTAL TRAINING LOSS: 5.758349
# EPOCH 25 TOTAL TRAINING LOSS: 5.679387
# EPOCH 26 TOTAL TRAINING LOSS: 5.748462
# EPOCH 27 TOTAL TRAINING LOSS: 5.752229
# EPOCH 28 TOTAL TRAINING LOSS: 5.967504
# EPOCH 29 TOTAL TRAINING LOSS: 5.602799
# EPOCH 30 TOTAL TRAINING LOSS: 5.798592
# EPOCH 31 TOTAL TRAINING LOSS: 5.626006
# EPOCH 32 TOTAL TRAINING LOSS: 5.635115
# EPOCH 33 TOTAL TRAINING LOSS: 5.381883
# EPOCH 34 TOTAL TRAINING LOSS: 5.595914
# EPOCH 35 TOTAL TRAINING LOSS: 5.969618
# EPOCH 36 TOTAL TRAINING LOSS: 5.591696
# EPOCH 37 TOTAL TRAINING LOSS: 5.106857
# EPOCH 38 TOTAL TRAINING LOSS: 5.317567
# EPOCH 39 TOTAL TRAINING LOSS: 5.712579
# EPOCH 40 TOTAL TRAINING LOSS: 5.156138
# EPOCH 41 TOTAL TRAINING LOSS: 5.455104
# EPOCH 42 TOTAL TRAINING LOSS: 5.093656
# EPOCH 43 TOTAL TRAINING LOSS: 4.859048
# EPOCH 44 TOTAL TRAINING LOSS: 5.489556
# EPOCH 45 TOTAL TRAINING LOSS: 5.585405
# EPOCH 46 TOTAL TRAINING LOSS: 4.958603
# EPOCH 47 TOTAL TRAINING LOSS: 5.256645
# EPOCH 48 TOTAL TRAINING LOSS: 5.355530
# EPOCH 49 TOTAL TRAINING LOSS: 5.310296
# EPOCH 50 TOTAL TRAINING LOSS: 5.466542
# EPOCH 51 TOTAL TRAINING LOSS: 4.580533
# EPOCH 52 TOTAL TRAINING LOSS: 4.617077
# EPOCH 53 TOTAL TRAINING LOSS: 5.316043
# EPOCH 54 TOTAL TRAINING LOSS: 5.457996
# EPOCH 55 TOTAL TRAINING LOSS: 5.265463
# EPOCH 56 TOTAL TRAINING LOSS: 5.118246
# EPOCH 57 TOTAL TRAINING LOSS: 4.860833
# EPOCH 58 TOTAL TRAINING LOSS: 5.510061
# EPOCH 59 TOTAL TRAINING LOSS: 5.066048
# EPOCH 60 TOTAL TRAINING LOSS: 4.836169
# EPOCH 61 TOTAL TRAINING LOSS: 4.899828
# EPOCH 62 TOTAL TRAINING LOSS: 4.923033
# EPOCH 63 TOTAL TRAINING LOSS: 5.475952
# EPOCH 64 TOTAL TRAINING LOSS: 5.334561
# EPOCH 65 TOTAL TRAINING LOSS: 5.197303
# EPOCH 66 TOTAL TRAINING LOSS: 4.853202
# EPOCH 67 TOTAL TRAINING LOSS: 4.666177
# EPOCH 68 TOTAL TRAINING LOSS: 4.769982
# EPOCH 69 TOTAL TRAINING LOSS: 5.163203
# EPOCH 70 TOTAL TRAINING LOSS: 4.856118
# EPOCH 71 TOTAL TRAINING LOSS: 4.888206
# EPOCH 72 TOTAL TRAINING LOSS: 4.964662
# EPOCH 73 TOTAL TRAINING LOSS: 4.959521
# EPOCH 74 TOTAL TRAINING LOSS: 4.706197
# EPOCH 75 TOTAL TRAINING LOSS: 5.583333
# EPOCH 76 TOTAL TRAINING LOSS: 5.215724
# EPOCH 77 TOTAL TRAINING LOSS: 4.958328
# EPOCH 78 TOTAL TRAINING LOSS: 4.870156
# EPOCH 79 TOTAL TRAINING LOSS: 4.918561
# EPOCH 80 TOTAL TRAINING LOSS: 4.771949
# EPOCH 81 TOTAL TRAINING LOSS: 5.091574
# EPOCH 82 TOTAL TRAINING LOSS: 4.701892
# EPOCH 83 TOTAL TRAINING LOSS: 4.889100
# EPOCH 84 TOTAL TRAINING LOSS: 5.170489
# EPOCH 85 TOTAL TRAINING LOSS: 4.655715
# EPOCH 86 TOTAL TRAINING LOSS: 4.633510
# EPOCH 87 TOTAL TRAINING LOSS: 5.208970
# EPOCH 88 TOTAL TRAINING LOSS: 4.462246
# EPOCH 89 TOTAL TRAINING LOSS: 4.673811
# EPOCH 90 TOTAL TRAINING LOSS: 4.500756
# EPOCH 91 TOTAL TRAINING LOSS: 4.805039
# EPOCH 92 TOTAL TRAINING LOSS: 4.816745
# EPOCH 93 TOTAL TRAINING LOSS: 4.876634
# EPOCH 94 TOTAL TRAINING LOSS: 5.211136
# EPOCH 95 TOTAL TRAINING LOSS: 4.584226
# EPOCH 96 TOTAL TRAINING LOSS: 4.861865
# EPOCH 97 TOTAL TRAINING LOSS: 5.274888
# EPOCH 98 TOTAL TRAINING LOSS: 4.633702
# EPOCH 99 TOTAL TRAINING LOSS: 4.923511
# EPOCH 100 TOTAL TRAINING LOSS: 5.38343
# EPOCH 101 TOTAL TRAINING LOSS: 4.846991
# EPOCH 102 TOTAL TRAINING LOSS: 4.783349
# EPOCH 103 TOTAL TRAINING LOSS: 4.599727
# EPOCH 104 TOTAL TRAINING LOSS: 4.837333
# EPOCH 105 TOTAL TRAINING LOSS: 4.653503
# EPOCH 106 TOTAL TRAINING LOSS: 4.424019
# EPOCH 107 TOTAL TRAINING LOSS: 4.864013
# EPOCH 108 TOTAL TRAINING LOSS: 5.234234
# EPOCH 109 TOTAL TRAINING LOSS: 4.460263
# EPOCH 110 TOTAL TRAINING LOSS: 4.511551
# EPOCH 111 TOTAL TRAINING LOSS: 5.051795
# EPOCH 112 TOTAL TRAINING LOSS: 4.878625
# EPOCH 113 TOTAL TRAINING LOSS: 4.552125
# EPOCH 114 TOTAL TRAINING LOSS: 4.428299
# EPOCH 115 TOTAL TRAINING LOSS: 5.126017
# EPOCH 116 TOTAL TRAINING LOSS: 4.548349
# EPOCH 117 TOTAL TRAINING LOSS: 5.083617
# EPOCH 118 TOTAL TRAINING LOSS: 4.483987
# EPOCH 119 TOTAL TRAINING LOSS: 4.647129
# EPOCH 120 TOTAL TRAINING LOSS: 4.637506
# EPOCH 121 TOTAL TRAINING LOSS: 4.987908
# EPOCH 122 TOTAL TRAINING LOSS: 4.768437
# EPOCH 123 TOTAL TRAINING LOSS: 5.171383
# EPOCH 124 TOTAL TRAINING LOSS: 4.786866
# EPOCH 125 TOTAL TRAINING LOSS: 4.715504
# EPOCH 126 TOTAL TRAINING LOSS: 4.867896
# EPOCH 127 TOTAL TRAINING LOSS: 4.772309
# EPOCH 128 TOTAL TRAINING LOSS: 4.188497
# EPOCH 129 TOTAL TRAINING LOSS: 4.175786
# EPOCH 130 TOTAL TRAINING LOSS: 4.654293
# EPOCH 131 TOTAL TRAINING LOSS: 5.072929
# EPOCH 132 TOTAL TRAINING LOSS: 4.516816
# EPOCH 133 TOTAL TRAINING LOSS: 4.304433
# EPOCH 134 TOTAL TRAINING LOSS: 4.682728
# EPOCH 135 TOTAL TRAINING LOSS: 4.280385
# EPOCH 136 TOTAL TRAINING LOSS: 4.871671
# EPOCH 137 TOTAL TRAINING LOSS: 4.690750
# EPOCH 138 TOTAL TRAINING LOSS: 4.390536
# EPOCH 139 TOTAL TRAINING LOSS: 5.031036
# EPOCH 140 TOTAL TRAINING LOSS: 4.719388
# EPOCH 141 TOTAL TRAINING LOSS: 4.561145
# EPOCH 142 TOTAL TRAINING LOSS: 5.075157
# EPOCH 143 TOTAL TRAINING LOSS: 4.762139
# EPOCH 144 TOTAL TRAINING LOSS: 4.635809
# EPOCH 145 TOTAL TRAINING LOSS: 4.796777
# EPOCH 146 TOTAL TRAINING LOSS: 4.648019
# EPOCH 147 TOTAL TRAINING LOSS: 4.668787
# EPOCH 148 TOTAL TRAINING LOSS: 4.459016
# EPOCH 149 TOTAL TRAINING LOSS: 4.710689
# EPOCH 150 TOTAL TRAINING LOSS: 4.807561
# Using device(prediction head) : cuda176
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.3219
# EPOCH 2 TOTAL TRAINING LOSS: 6.377754
# EPOCH 3 TOTAL TRAINING LOSS: 6.507339
# EPOCH 4 TOTAL TRAINING LOSS: 6.915126
# EPOCH 5 TOTAL TRAINING LOSS: 6.433811
# EPOCH 6 TOTAL TRAINING LOSS: 5.850096
# EPOCH 7 TOTAL TRAINING LOSS: 5.740885
# EPOCH 8 TOTAL TRAINING LOSS: 5.557977
# EPOCH 9 TOTAL TRAINING LOSS: 5.876969
# EPOCH 10 TOTAL TRAINING LOSS: 5.92560
# EPOCH 11 TOTAL TRAINING LOSS: 5.851553
# EPOCH 12 TOTAL TRAINING LOSS: 6.409849
# EPOCH 13 TOTAL TRAINING LOSS: 5.480050
# EPOCH 14 TOTAL TRAINING LOSS: 5.543954
# EPOCH 15 TOTAL TRAINING LOSS: 5.221462
# EPOCH 16 TOTAL TRAINING LOSS: 6.212969
# EPOCH 17 TOTAL TRAINING LOSS: 6.692087
# EPOCH 18 TOTAL TRAINING LOSS: 5.384415
# EPOCH 19 TOTAL TRAINING LOSS: 6.298543
# EPOCH 20 TOTAL TRAINING LOSS: 5.467768
# EPOCH 21 TOTAL TRAINING LOSS: 7.180902
# EPOCH 22 TOTAL TRAINING LOSS: 5.024554
# EPOCH 23 TOTAL TRAINING LOSS: 5.681703
# EPOCH 24 TOTAL TRAINING LOSS: 5.867265
# EPOCH 25 TOTAL TRAINING LOSS: 5.563533
# EPOCH 26 TOTAL TRAINING LOSS: 6.359236
# EPOCH 27 TOTAL TRAINING LOSS: 5.924739
# EPOCH 28 TOTAL TRAINING LOSS: 6.048553
# EPOCH 29 TOTAL TRAINING LOSS: 6.322469
# EPOCH 30 TOTAL TRAINING LOSS: 5.391699
# EPOCH 31 TOTAL TRAINING LOSS: 5.637139
# EPOCH 32 TOTAL TRAINING LOSS: 5.040679
# EPOCH 33 TOTAL TRAINING LOSS: 6.268890
# EPOCH 34 TOTAL TRAINING LOSS: 5.738102
# EPOCH 35 TOTAL TRAINING LOSS: 5.970711
# EPOCH 36 TOTAL TRAINING LOSS: 4.634518
# EPOCH 37 TOTAL TRAINING LOSS: 5.734116
# EPOCH 38 TOTAL TRAINING LOSS: 5.321811
# EPOCH 39 TOTAL TRAINING LOSS: 5.067468
# EPOCH 40 TOTAL TRAINING LOSS: 5.315374
# EPOCH 41 TOTAL TRAINING LOSS: 5.562026
# EPOCH 42 TOTAL TRAINING LOSS: 5.283121
# EPOCH 43 TOTAL TRAINING LOSS: 5.669252
# EPOCH 44 TOTAL TRAINING LOSS: 5.029267
# EPOCH 45 TOTAL TRAINING LOSS: 4.958482
# EPOCH 46 TOTAL TRAINING LOSS: 4.907465
# EPOCH 47 TOTAL TRAINING LOSS: 5.404579
# EPOCH 48 TOTAL TRAINING LOSS: 5.336763
# EPOCH 49 TOTAL TRAINING LOSS: 4.765795
# EPOCH 50 TOTAL TRAINING LOSS: 4.602430
# EPOCH 51 TOTAL TRAINING LOSS: 5.234142
# EPOCH 52 TOTAL TRAINING LOSS: 4.700321
# EPOCH 53 TOTAL TRAINING LOSS: 4.573892
# EPOCH 54 TOTAL TRAINING LOSS: 5.085739
# EPOCH 55 TOTAL TRAINING LOSS: 5.120034
# EPOCH 56 TOTAL TRAINING LOSS: 5.495737
# EPOCH 57 TOTAL TRAINING LOSS: 5.076217
# EPOCH 58 TOTAL TRAINING LOSS: 5.039648
# EPOCH 59 TOTAL TRAINING LOSS: 4.073283
# EPOCH 60 TOTAL TRAINING LOSS: 6.186870
# EPOCH 61 TOTAL TRAINING LOSS: 5.683684
# EPOCH 62 TOTAL TRAINING LOSS: 5.221452
# EPOCH 63 TOTAL TRAINING LOSS: 4.606271
# EPOCH 64 TOTAL TRAINING LOSS: 6.095205
# EPOCH 65 TOTAL TRAINING LOSS: 4.728147
# EPOCH 66 TOTAL TRAINING LOSS: 4.437170
# EPOCH 67 TOTAL TRAINING LOSS: 5.380479
# EPOCH 68 TOTAL TRAINING LOSS: 4.484956
# EPOCH 69 TOTAL TRAINING LOSS: 4.747058
# EPOCH 70 TOTAL TRAINING LOSS: 4.500607
# EPOCH 71 TOTAL TRAINING LOSS: 5.206445
# EPOCH 72 TOTAL TRAINING LOSS: 4.403090
# EPOCH 73 TOTAL TRAINING LOSS: 4.368924
# EPOCH 74 TOTAL TRAINING LOSS: 4.903152
# EPOCH 75 TOTAL TRAINING LOSS: 5.128625
# EPOCH 76 TOTAL TRAINING LOSS: 5.157863
# EPOCH 77 TOTAL TRAINING LOSS: 4.491195
# EPOCH 78 TOTAL TRAINING LOSS: 4.697780
# EPOCH 79 TOTAL TRAINING LOSS: 4.694615
# EPOCH 80 TOTAL TRAINING LOSS: 4.625476
# EPOCH 81 TOTAL TRAINING LOSS: 4.892342
# EPOCH 82 TOTAL TRAINING LOSS: 4.958941
# EPOCH 83 TOTAL TRAINING LOSS: 4.480135
# EPOCH 84 TOTAL TRAINING LOSS: 4.681462
# EPOCH 85 TOTAL TRAINING LOSS: 5.028226
# EPOCH 86 TOTAL TRAINING LOSS: 3.921875
# EPOCH 87 TOTAL TRAINING LOSS: 4.439785
# EPOCH 88 TOTAL TRAINING LOSS: 5.335420
# EPOCH 89 TOTAL TRAINING LOSS: 4.476788
# EPOCH 90 TOTAL TRAINING LOSS: 4.814972
# EPOCH 91 TOTAL TRAINING LOSS: 4.110903
# EPOCH 92 TOTAL TRAINING LOSS: 4.790295
# EPOCH 93 TOTAL TRAINING LOSS: 5.316237
# EPOCH 94 TOTAL TRAINING LOSS: 4.587371
# EPOCH 95 TOTAL TRAINING LOSS: 5.381035
# EPOCH 96 TOTAL TRAINING LOSS: 5.082677
# EPOCH 97 TOTAL TRAINING LOSS: 4.222929
# EPOCH 98 TOTAL TRAINING LOSS: 4.630831
# EPOCH 99 TOTAL TRAINING LOSS: 3.974118
# EPOCH 100 TOTAL TRAINING LOSS: 4.46603
# EPOCH 101 TOTAL TRAINING LOSS: 4.924901
# EPOCH 102 TOTAL TRAINING LOSS: 4.082818
# EPOCH 103 TOTAL TRAINING LOSS: 4.405261
# EPOCH 104 TOTAL TRAINING LOSS: 4.703182
# EPOCH 105 TOTAL TRAINING LOSS: 4.920554
# EPOCH 106 TOTAL TRAINING LOSS: 4.303938
# EPOCH 107 TOTAL TRAINING LOSS: 4.438254
# EPOCH 108 TOTAL TRAINING LOSS: 4.464505
# EPOCH 109 TOTAL TRAINING LOSS: 4.575108
# EPOCH 110 TOTAL TRAINING LOSS: 4.110851
# EPOCH 111 TOTAL TRAINING LOSS: 5.142838
# EPOCH 112 TOTAL TRAINING LOSS: 5.098075
# EPOCH 113 TOTAL TRAINING LOSS: 4.804901
# EPOCH 114 TOTAL TRAINING LOSS: 4.426471
# EPOCH 115 TOTAL TRAINING LOSS: 4.480881
# EPOCH 116 TOTAL TRAINING LOSS: 3.924991
# EPOCH 117 TOTAL TRAINING LOSS: 4.576450
# EPOCH 118 TOTAL TRAINING LOSS: 4.195219
# EPOCH 119 TOTAL TRAINING LOSS: 3.949671
# EPOCH 120 TOTAL TRAINING LOSS: 4.342038
# EPOCH 121 TOTAL TRAINING LOSS: 5.373802
# EPOCH 122 TOTAL TRAINING LOSS: 4.939181
# EPOCH 123 TOTAL TRAINING LOSS: 4.083665
# EPOCH 124 TOTAL TRAINING LOSS: 5.296395
# EPOCH 125 TOTAL TRAINING LOSS: 4.427958
# EPOCH 126 TOTAL TRAINING LOSS: 4.296945
# EPOCH 127 TOTAL TRAINING LOSS: 3.597170
# EPOCH 128 TOTAL TRAINING LOSS: 4.508995
# EPOCH 129 TOTAL TRAINING LOSS: 4.266936
# EPOCH 130 TOTAL TRAINING LOSS: 4.726658
# EPOCH 131 TOTAL TRAINING LOSS: 4.554577
# EPOCH 132 TOTAL TRAINING LOSS: 4.448262
# EPOCH 133 TOTAL TRAINING LOSS: 3.947282
# EPOCH 134 TOTAL TRAINING LOSS: 4.691000
# EPOCH 135 TOTAL TRAINING LOSS: 4.774972
# EPOCH 136 TOTAL TRAINING LOSS: 4.526394
# EPOCH 137 TOTAL TRAINING LOSS: 4.197096
# EPOCH 138 TOTAL TRAINING LOSS: 4.853246
# EPOCH 139 TOTAL TRAINING LOSS: 3.596042
# EPOCH 140 TOTAL TRAINING LOSS: 3.931713
# EPOCH 141 TOTAL TRAINING LOSS: 4.070991
# EPOCH 142 TOTAL TRAINING LOSS: 3.904737
# EPOCH 143 TOTAL TRAINING LOSS: 3.550173
# EPOCH 144 TOTAL TRAINING LOSS: 4.411698
# EPOCH 145 TOTAL TRAINING LOSS: 4.883736
# EPOCH 146 TOTAL TRAINING LOSS: 5.215911
# EPOCH 147 TOTAL TRAINING LOSS: 4.152800
# EPOCH 148 TOTAL TRAINING LOSS: 3.985552
# EPOCH 149 TOTAL TRAINING LOSS: 5.014765
# EPOCH 150 TOTAL TRAINING LOSS: 4.527354
# Using device(prediction head) : cuda931
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 7.7573
# EPOCH 2 TOTAL TRAINING LOSS: 7.327417
# EPOCH 3 TOTAL TRAINING LOSS: 7.635244
# EPOCH 4 TOTAL TRAINING LOSS: 7.037762
# EPOCH 5 TOTAL TRAINING LOSS: 6.817306
# EPOCH 6 TOTAL TRAINING LOSS: 6.910288
# EPOCH 7 TOTAL TRAINING LOSS: 7.737872
# EPOCH 8 TOTAL TRAINING LOSS: 7.553462
# EPOCH 9 TOTAL TRAINING LOSS: 6.709542
# EPOCH 10 TOTAL TRAINING LOSS: 7.45825
# EPOCH 11 TOTAL TRAINING LOSS: 6.903779
# EPOCH 12 TOTAL TRAINING LOSS: 6.092705
# EPOCH 13 TOTAL TRAINING LOSS: 6.933437
# EPOCH 14 TOTAL TRAINING LOSS: 6.442293
# EPOCH 15 TOTAL TRAINING LOSS: 5.410957
# EPOCH 16 TOTAL TRAINING LOSS: 7.258321
# EPOCH 17 TOTAL TRAINING LOSS: 6.780177
# EPOCH 18 TOTAL TRAINING LOSS: 6.595461
# EPOCH 19 TOTAL TRAINING LOSS: 6.395830
# EPOCH 20 TOTAL TRAINING LOSS: 6.894432
# EPOCH 21 TOTAL TRAINING LOSS: 7.214954
# EPOCH 22 TOTAL TRAINING LOSS: 6.667570
# EPOCH 23 TOTAL TRAINING LOSS: 6.542855
# EPOCH 24 TOTAL TRAINING LOSS: 6.391021
# EPOCH 25 TOTAL TRAINING LOSS: 6.482032
# EPOCH 26 TOTAL TRAINING LOSS: 6.621068
# EPOCH 27 TOTAL TRAINING LOSS: 6.347937
# EPOCH 28 TOTAL TRAINING LOSS: 7.466363
# EPOCH 29 TOTAL TRAINING LOSS: 7.445749
# EPOCH 30 TOTAL TRAINING LOSS: 7.100483
# EPOCH 31 TOTAL TRAINING LOSS: 5.966343
# EPOCH 32 TOTAL TRAINING LOSS: 6.648318
# EPOCH 33 TOTAL TRAINING LOSS: 6.325420
# EPOCH 34 TOTAL TRAINING LOSS: 6.193074
# EPOCH 35 TOTAL TRAINING LOSS: 6.218864
# EPOCH 36 TOTAL TRAINING LOSS: 6.685052
# EPOCH 37 TOTAL TRAINING LOSS: 7.101919
# EPOCH 38 TOTAL TRAINING LOSS: 6.346964
# EPOCH 39 TOTAL TRAINING LOSS: 5.052940
# EPOCH 40 TOTAL TRAINING LOSS: 6.069189
# EPOCH 41 TOTAL TRAINING LOSS: 5.663228
# EPOCH 42 TOTAL TRAINING LOSS: 5.379292
# EPOCH 43 TOTAL TRAINING LOSS: 5.806977
# EPOCH 44 TOTAL TRAINING LOSS: 5.575465
# EPOCH 45 TOTAL TRAINING LOSS: 6.522004
# EPOCH 46 TOTAL TRAINING LOSS: 5.590936
# EPOCH 47 TOTAL TRAINING LOSS: 5.741294
# EPOCH 48 TOTAL TRAINING LOSS: 5.936671
# EPOCH 49 TOTAL TRAINING LOSS: 5.968991
# EPOCH 50 TOTAL TRAINING LOSS: 5.840156
# EPOCH 51 TOTAL TRAINING LOSS: 5.697779
# EPOCH 52 TOTAL TRAINING LOSS: 6.597391
# EPOCH 53 TOTAL TRAINING LOSS: 6.262117
# EPOCH 54 TOTAL TRAINING LOSS: 6.872712
# EPOCH 55 TOTAL TRAINING LOSS: 5.202063
# EPOCH 56 TOTAL TRAINING LOSS: 6.366894
# EPOCH 57 TOTAL TRAINING LOSS: 6.235664
# EPOCH 58 TOTAL TRAINING LOSS: 5.863790
# EPOCH 59 TOTAL TRAINING LOSS: 4.683910
# EPOCH 60 TOTAL TRAINING LOSS: 5.846647
# EPOCH 61 TOTAL TRAINING LOSS: 4.372117
# EPOCH 62 TOTAL TRAINING LOSS: 5.815242
# EPOCH 63 TOTAL TRAINING LOSS: 5.662463
# EPOCH 64 TOTAL TRAINING LOSS: 5.377489
# EPOCH 65 TOTAL TRAINING LOSS: 5.705089
# EPOCH 66 TOTAL TRAINING LOSS: 5.675817
# EPOCH 67 TOTAL TRAINING LOSS: 5.727341
# EPOCH 68 TOTAL TRAINING LOSS: 5.981792
# EPOCH 69 TOTAL TRAINING LOSS: 4.771275
# EPOCH 70 TOTAL TRAINING LOSS: 5.168806
# EPOCH 71 TOTAL TRAINING LOSS: 5.360889
# EPOCH 72 TOTAL TRAINING LOSS: 5.387035
# EPOCH 73 TOTAL TRAINING LOSS: 5.681286
# EPOCH 74 TOTAL TRAINING LOSS: 5.918521
# EPOCH 75 TOTAL TRAINING LOSS: 5.209874
# EPOCH 76 TOTAL TRAINING LOSS: 5.961777
# EPOCH 77 TOTAL TRAINING LOSS: 5.495817
# EPOCH 78 TOTAL TRAINING LOSS: 5.481659
# EPOCH 79 TOTAL TRAINING LOSS: 5.409088
# EPOCH 80 TOTAL TRAINING LOSS: 5.250030
# EPOCH 81 TOTAL TRAINING LOSS: 6.223623
# EPOCH 82 TOTAL TRAINING LOSS: 5.796473
# EPOCH 83 TOTAL TRAINING LOSS: 5.403724
# EPOCH 84 TOTAL TRAINING LOSS: 4.965831
# EPOCH 85 TOTAL TRAINING LOSS: 5.741252
# EPOCH 86 TOTAL TRAINING LOSS: 5.293980
# EPOCH 87 TOTAL TRAINING LOSS: 5.398104
# EPOCH 88 TOTAL TRAINING LOSS: 6.004209
# EPOCH 89 TOTAL TRAINING LOSS: 4.911244
# EPOCH 90 TOTAL TRAINING LOSS: 5.507005
# EPOCH 91 TOTAL TRAINING LOSS: 5.865807
# EPOCH 92 TOTAL TRAINING LOSS: 4.848425
# EPOCH 93 TOTAL TRAINING LOSS: 4.999871
# EPOCH 94 TOTAL TRAINING LOSS: 4.849792
# EPOCH 95 TOTAL TRAINING LOSS: 5.480700
# EPOCH 96 TOTAL TRAINING LOSS: 5.761739
# EPOCH 97 TOTAL TRAINING LOSS: 5.313874
# EPOCH 98 TOTAL TRAINING LOSS: 4.615792
# EPOCH 99 TOTAL TRAINING LOSS: 5.096701
# EPOCH 100 TOTAL TRAINING LOSS: 4.76493
# EPOCH 101 TOTAL TRAINING LOSS: 4.112365
# EPOCH 102 TOTAL TRAINING LOSS: 6.364613
# EPOCH 103 TOTAL TRAINING LOSS: 5.085667
# EPOCH 104 TOTAL TRAINING LOSS: 5.294011
# EPOCH 105 TOTAL TRAINING LOSS: 6.071899
# EPOCH 106 TOTAL TRAINING LOSS: 4.572804
# EPOCH 107 TOTAL TRAINING LOSS: 4.521235
# EPOCH 108 TOTAL TRAINING LOSS: 5.931593
# EPOCH 109 TOTAL TRAINING LOSS: 5.069788
# EPOCH 110 TOTAL TRAINING LOSS: 5.619953
# EPOCH 111 TOTAL TRAINING LOSS: 4.277064
# EPOCH 112 TOTAL TRAINING LOSS: 4.956431
# EPOCH 113 TOTAL TRAINING LOSS: 5.227003
# EPOCH 114 TOTAL TRAINING LOSS: 5.187871
# EPOCH 115 TOTAL TRAINING LOSS: 4.904717
# EPOCH 116 TOTAL TRAINING LOSS: 4.712693
# EPOCH 117 TOTAL TRAINING LOSS: 5.112886
# EPOCH 118 TOTAL TRAINING LOSS: 5.047018
# EPOCH 119 TOTAL TRAINING LOSS: 5.846165
# EPOCH 120 TOTAL TRAINING LOSS: 4.755108
# EPOCH 121 TOTAL TRAINING LOSS: 5.063154
# EPOCH 122 TOTAL TRAINING LOSS: 5.248392
# EPOCH 123 TOTAL TRAINING LOSS: 5.472712
# EPOCH 124 TOTAL TRAINING LOSS: 5.628666
# EPOCH 125 TOTAL TRAINING LOSS: 5.155292
# EPOCH 126 TOTAL TRAINING LOSS: 4.931189
# EPOCH 127 TOTAL TRAINING LOSS: 5.019643
# EPOCH 128 TOTAL TRAINING LOSS: 5.754072
# EPOCH 129 TOTAL TRAINING LOSS: 5.362878
# EPOCH 130 TOTAL TRAINING LOSS: 4.866249
# EPOCH 131 TOTAL TRAINING LOSS: 4.702134
# EPOCH 132 TOTAL TRAINING LOSS: 4.973212
# EPOCH 133 TOTAL TRAINING LOSS: 4.838378
# EPOCH 134 TOTAL TRAINING LOSS: 5.291838
# EPOCH 135 TOTAL TRAINING LOSS: 5.197153
# EPOCH 136 TOTAL TRAINING LOSS: 4.959537
# EPOCH 137 TOTAL TRAINING LOSS: 4.516867
# EPOCH 138 TOTAL TRAINING LOSS: 5.943762
# EPOCH 139 TOTAL TRAINING LOSS: 5.768268
# EPOCH 140 TOTAL TRAINING LOSS: 5.955583
# EPOCH 141 TOTAL TRAINING LOSS: 5.730150
# EPOCH 142 TOTAL TRAINING LOSS: 5.522706
# EPOCH 143 TOTAL TRAINING LOSS: 5.527956
# EPOCH 144 TOTAL TRAINING LOSS: 4.832578
# EPOCH 145 TOTAL TRAINING LOSS: 5.211708
# EPOCH 146 TOTAL TRAINING LOSS: 5.479034
# EPOCH 147 TOTAL TRAINING LOSS: 4.827856
# EPOCH 148 TOTAL TRAINING LOSS: 4.630326
# EPOCH 149 TOTAL TRAINING LOSS: 5.452154
# EPOCH 150 TOTAL TRAINING LOSS: 4.759364
# Using device(prediction head) : cuda769
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.8626
# EPOCH 2 TOTAL TRAINING LOSS: 7.056688
# EPOCH 3 TOTAL TRAINING LOSS: 6.953820
# EPOCH 4 TOTAL TRAINING LOSS: 6.896389
# EPOCH 5 TOTAL TRAINING LOSS: 7.306967
# EPOCH 6 TOTAL TRAINING LOSS: 7.016155
# EPOCH 7 TOTAL TRAINING LOSS: 6.301568
# EPOCH 8 TOTAL TRAINING LOSS: 7.063902
# EPOCH 9 TOTAL TRAINING LOSS: 7.025555
# EPOCH 10 TOTAL TRAINING LOSS: 6.71347
# EPOCH 11 TOTAL TRAINING LOSS: 6.724877
# EPOCH 12 TOTAL TRAINING LOSS: 6.505453
# EPOCH 13 TOTAL TRAINING LOSS: 7.170150
# EPOCH 14 TOTAL TRAINING LOSS: 7.454244
# EPOCH 15 TOTAL TRAINING LOSS: 7.055272
# EPOCH 16 TOTAL TRAINING LOSS: 6.768091
# EPOCH 17 TOTAL TRAINING LOSS: 6.936125
# EPOCH 18 TOTAL TRAINING LOSS: 6.080191
# EPOCH 19 TOTAL TRAINING LOSS: 7.178452
# EPOCH 20 TOTAL TRAINING LOSS: 6.340435
# EPOCH 21 TOTAL TRAINING LOSS: 6.218008
# EPOCH 22 TOTAL TRAINING LOSS: 6.943885
# EPOCH 23 TOTAL TRAINING LOSS: 6.185392
# EPOCH 24 TOTAL TRAINING LOSS: 6.211327
# EPOCH 25 TOTAL TRAINING LOSS: 6.321777
# EPOCH 26 TOTAL TRAINING LOSS: 6.724253
# EPOCH 27 TOTAL TRAINING LOSS: 6.671942
# EPOCH 28 TOTAL TRAINING LOSS: 6.808536
# EPOCH 29 TOTAL TRAINING LOSS: 6.263613
# EPOCH 30 TOTAL TRAINING LOSS: 6.214022
# EPOCH 31 TOTAL TRAINING LOSS: 6.798355
# EPOCH 32 TOTAL TRAINING LOSS: 6.093882
# EPOCH 33 TOTAL TRAINING LOSS: 6.107574
# EPOCH 34 TOTAL TRAINING LOSS: 6.355521
# EPOCH 35 TOTAL TRAINING LOSS: 6.299839
# EPOCH 36 TOTAL TRAINING LOSS: 6.771663
# EPOCH 37 TOTAL TRAINING LOSS: 6.437546
# EPOCH 38 TOTAL TRAINING LOSS: 6.690593
# EPOCH 39 TOTAL TRAINING LOSS: 6.029477
# EPOCH 40 TOTAL TRAINING LOSS: 5.901716
# EPOCH 41 TOTAL TRAINING LOSS: 6.654420
# EPOCH 42 TOTAL TRAINING LOSS: 6.581642
# EPOCH 43 TOTAL TRAINING LOSS: 5.774431
# EPOCH 44 TOTAL TRAINING LOSS: 6.203294
# EPOCH 45 TOTAL TRAINING LOSS: 6.227960
# EPOCH 46 TOTAL TRAINING LOSS: 6.671172
# EPOCH 47 TOTAL TRAINING LOSS: 5.896711
# EPOCH 48 TOTAL TRAINING LOSS: 5.876509
# EPOCH 49 TOTAL TRAINING LOSS: 6.102961
# EPOCH 50 TOTAL TRAINING LOSS: 6.091788
# EPOCH 51 TOTAL TRAINING LOSS: 6.088032
# EPOCH 52 TOTAL TRAINING LOSS: 6.445732
# EPOCH 53 TOTAL TRAINING LOSS: 5.937017
# EPOCH 54 TOTAL TRAINING LOSS: 5.559617
# EPOCH 55 TOTAL TRAINING LOSS: 5.838081
# EPOCH 56 TOTAL TRAINING LOSS: 6.250477
# EPOCH 57 TOTAL TRAINING LOSS: 6.355166
# EPOCH 58 TOTAL TRAINING LOSS: 5.578939
# EPOCH 59 TOTAL TRAINING LOSS: 6.458445
# EPOCH 60 TOTAL TRAINING LOSS: 5.599601
# EPOCH 61 TOTAL TRAINING LOSS: 6.056732
# EPOCH 62 TOTAL TRAINING LOSS: 6.060501
# EPOCH 63 TOTAL TRAINING LOSS: 6.299161
# EPOCH 64 TOTAL TRAINING LOSS: 5.703243
# EPOCH 65 TOTAL TRAINING LOSS: 6.024867
# EPOCH 66 TOTAL TRAINING LOSS: 5.201965
# EPOCH 67 TOTAL TRAINING LOSS: 5.778488
# EPOCH 68 TOTAL TRAINING LOSS: 5.920946
# EPOCH 69 TOTAL TRAINING LOSS: 5.688176
# EPOCH 70 TOTAL TRAINING LOSS: 5.541224
# EPOCH 71 TOTAL TRAINING LOSS: 6.374247
# EPOCH 72 TOTAL TRAINING LOSS: 5.365522
# EPOCH 73 TOTAL TRAINING LOSS: 5.591763
# EPOCH 74 TOTAL TRAINING LOSS: 5.667136
# EPOCH 75 TOTAL TRAINING LOSS: 5.654122
# EPOCH 76 TOTAL TRAINING LOSS: 5.284341
# EPOCH 77 TOTAL TRAINING LOSS: 5.589404
# EPOCH 78 TOTAL TRAINING LOSS: 6.532682
# EPOCH 79 TOTAL TRAINING LOSS: 5.265963
# EPOCH 80 TOTAL TRAINING LOSS: 5.264616
# EPOCH 81 TOTAL TRAINING LOSS: 5.900171
# EPOCH 82 TOTAL TRAINING LOSS: 5.963687
# EPOCH 83 TOTAL TRAINING LOSS: 5.599074
# EPOCH 84 TOTAL TRAINING LOSS: 5.715828
# EPOCH 85 TOTAL TRAINING LOSS: 6.113020
# EPOCH 86 TOTAL TRAINING LOSS: 5.335953
# EPOCH 87 TOTAL TRAINING LOSS: 6.198314
# EPOCH 88 TOTAL TRAINING LOSS: 5.496004
# EPOCH 89 TOTAL TRAINING LOSS: 5.545762
# EPOCH 90 TOTAL TRAINING LOSS: 5.517409
# EPOCH 91 TOTAL TRAINING LOSS: 5.695637
# EPOCH 92 TOTAL TRAINING LOSS: 5.199833
# EPOCH 93 TOTAL TRAINING LOSS: 5.104024
# EPOCH 94 TOTAL TRAINING LOSS: 5.815134
# EPOCH 95 TOTAL TRAINING LOSS: 5.534076
# EPOCH 96 TOTAL TRAINING LOSS: 5.213197
# EPOCH 97 TOTAL TRAINING LOSS: 5.011665
# EPOCH 98 TOTAL TRAINING LOSS: 4.938693
# EPOCH 99 TOTAL TRAINING LOSS: 5.586831
# EPOCH 100 TOTAL TRAINING LOSS: 5.48118
# EPOCH 101 TOTAL TRAINING LOSS: 5.248853
# EPOCH 102 TOTAL TRAINING LOSS: 5.485739
# EPOCH 103 TOTAL TRAINING LOSS: 5.479017
# EPOCH 104 TOTAL TRAINING LOSS: 5.637784
# EPOCH 105 TOTAL TRAINING LOSS: 5.240793
# EPOCH 106 TOTAL TRAINING LOSS: 5.602577
# EPOCH 107 TOTAL TRAINING LOSS: 6.082951
# EPOCH 108 TOTAL TRAINING LOSS: 5.833794
# EPOCH 109 TOTAL TRAINING LOSS: 5.746399
# EPOCH 110 TOTAL TRAINING LOSS: 5.132883
# EPOCH 111 TOTAL TRAINING LOSS: 5.734409
# EPOCH 112 TOTAL TRAINING LOSS: 5.359118
# EPOCH 113 TOTAL TRAINING LOSS: 4.903758
# EPOCH 114 TOTAL TRAINING LOSS: 5.368692
# EPOCH 115 TOTAL TRAINING LOSS: 5.540195
# EPOCH 116 TOTAL TRAINING LOSS: 6.114064
# EPOCH 117 TOTAL TRAINING LOSS: 6.555198
# EPOCH 118 TOTAL TRAINING LOSS: 4.885929
# EPOCH 119 TOTAL TRAINING LOSS: 5.522945
# EPOCH 120 TOTAL TRAINING LOSS: 5.928166
# EPOCH 121 TOTAL TRAINING LOSS: 5.336719
# EPOCH 122 TOTAL TRAINING LOSS: 5.351672
# EPOCH 123 TOTAL TRAINING LOSS: 5.535712
# EPOCH 124 TOTAL TRAINING LOSS: 5.058072
# EPOCH 125 TOTAL TRAINING LOSS: 5.314456
# EPOCH 126 TOTAL TRAINING LOSS: 4.957220
# EPOCH 127 TOTAL TRAINING LOSS: 6.014115
# EPOCH 128 TOTAL TRAINING LOSS: 5.282566
# EPOCH 129 TOTAL TRAINING LOSS: 5.547270
# EPOCH 130 TOTAL TRAINING LOSS: 4.930158
# EPOCH 131 TOTAL TRAINING LOSS: 5.822441
# EPOCH 132 TOTAL TRAINING LOSS: 5.798634
# EPOCH 133 TOTAL TRAINING LOSS: 5.413262
# EPOCH 134 TOTAL TRAINING LOSS: 5.650279
# EPOCH 135 TOTAL TRAINING LOSS: 5.440422
# EPOCH 136 TOTAL TRAINING LOSS: 4.875417
# EPOCH 137 TOTAL TRAINING LOSS: 5.191876
# EPOCH 138 TOTAL TRAINING LOSS: 5.572772
# EPOCH 139 TOTAL TRAINING LOSS: 5.527070
# EPOCH 140 TOTAL TRAINING LOSS: 4.603492
# EPOCH 141 TOTAL TRAINING LOSS: 5.243491
# EPOCH 142 TOTAL TRAINING LOSS: 5.392324
# EPOCH 143 TOTAL TRAINING LOSS: 5.096218
# EPOCH 144 TOTAL TRAINING LOSS: 5.691595
# EPOCH 145 TOTAL TRAINING LOSS: 5.389220
# EPOCH 146 TOTAL TRAINING LOSS: 5.126670
# EPOCH 147 TOTAL TRAINING LOSS: 5.320550
# EPOCH 148 TOTAL TRAINING LOSS: 5.947839
# EPOCH 149 TOTAL TRAINING LOSS: 5.651665
# EPOCH 150 TOTAL TRAINING LOSS: 5.490859
# Using device(prediction head) : cuda443
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.2342
# EPOCH 2 TOTAL TRAINING LOSS: 6.495234
# EPOCH 3 TOTAL TRAINING LOSS: 6.213022
# EPOCH 4 TOTAL TRAINING LOSS: 6.340322
# EPOCH 5 TOTAL TRAINING LOSS: 6.052026
# EPOCH 6 TOTAL TRAINING LOSS: 6.226234
# EPOCH 7 TOTAL TRAINING LOSS: 5.893749
# EPOCH 8 TOTAL TRAINING LOSS: 5.765373
# EPOCH 9 TOTAL TRAINING LOSS: 6.742901
# EPOCH 10 TOTAL TRAINING LOSS: 5.53887
# EPOCH 11 TOTAL TRAINING LOSS: 6.212277
# EPOCH 12 TOTAL TRAINING LOSS: 6.658116
# EPOCH 13 TOTAL TRAINING LOSS: 6.248663
# EPOCH 14 TOTAL TRAINING LOSS: 6.493401
# EPOCH 15 TOTAL TRAINING LOSS: 6.192456
# EPOCH 16 TOTAL TRAINING LOSS: 5.547905
# EPOCH 17 TOTAL TRAINING LOSS: 6.103666
# EPOCH 18 TOTAL TRAINING LOSS: 6.318138
# EPOCH 19 TOTAL TRAINING LOSS: 5.881324
# EPOCH 20 TOTAL TRAINING LOSS: 6.045818
# EPOCH 21 TOTAL TRAINING LOSS: 6.008019
# EPOCH 22 TOTAL TRAINING LOSS: 6.203935
# EPOCH 23 TOTAL TRAINING LOSS: 5.465856
# EPOCH 24 TOTAL TRAINING LOSS: 5.689101
# EPOCH 25 TOTAL TRAINING LOSS: 5.408137
# EPOCH 26 TOTAL TRAINING LOSS: 5.640084
# EPOCH 27 TOTAL TRAINING LOSS: 5.842441
# EPOCH 28 TOTAL TRAINING LOSS: 5.980816
# EPOCH 29 TOTAL TRAINING LOSS: 5.308066
# EPOCH 30 TOTAL TRAINING LOSS: 5.526140
# EPOCH 31 TOTAL TRAINING LOSS: 5.440696
# EPOCH 32 TOTAL TRAINING LOSS: 5.542593
# EPOCH 33 TOTAL TRAINING LOSS: 5.870969
# EPOCH 34 TOTAL TRAINING LOSS: 5.893341
# EPOCH 35 TOTAL TRAINING LOSS: 5.625058
# EPOCH 36 TOTAL TRAINING LOSS: 6.271816
# EPOCH 37 TOTAL TRAINING LOSS: 5.396798
# EPOCH 38 TOTAL TRAINING LOSS: 6.018709
# EPOCH 39 TOTAL TRAINING LOSS: 5.635615
# EPOCH 40 TOTAL TRAINING LOSS: 5.295774
# EPOCH 41 TOTAL TRAINING LOSS: 5.280150
# EPOCH 42 TOTAL TRAINING LOSS: 5.783678
# EPOCH 43 TOTAL TRAINING LOSS: 5.325991
# EPOCH 44 TOTAL TRAINING LOSS: 5.179208
# EPOCH 45 TOTAL TRAINING LOSS: 5.342029
# EPOCH 46 TOTAL TRAINING LOSS: 6.066002
# EPOCH 47 TOTAL TRAINING LOSS: 5.783127
# EPOCH 48 TOTAL TRAINING LOSS: 5.565988
# EPOCH 49 TOTAL TRAINING LOSS: 5.200463
# EPOCH 50 TOTAL TRAINING LOSS: 5.608881
# EPOCH 51 TOTAL TRAINING LOSS: 5.407942
# EPOCH 52 TOTAL TRAINING LOSS: 5.328289
# EPOCH 53 TOTAL TRAINING LOSS: 5.172468
# EPOCH 54 TOTAL TRAINING LOSS: 4.895601
# EPOCH 55 TOTAL TRAINING LOSS: 4.529838
# EPOCH 56 TOTAL TRAINING LOSS: 5.174632
# EPOCH 57 TOTAL TRAINING LOSS: 5.337477
# EPOCH 58 TOTAL TRAINING LOSS: 5.162806
# EPOCH 59 TOTAL TRAINING LOSS: 5.070817
# EPOCH 60 TOTAL TRAINING LOSS: 5.616464
# EPOCH 61 TOTAL TRAINING LOSS: 5.976201
# EPOCH 62 TOTAL TRAINING LOSS: 5.666494
# EPOCH 63 TOTAL TRAINING LOSS: 4.779462
# EPOCH 64 TOTAL TRAINING LOSS: 5.386290
# EPOCH 65 TOTAL TRAINING LOSS: 4.726660
# EPOCH 66 TOTAL TRAINING LOSS: 4.903585
# EPOCH 67 TOTAL TRAINING LOSS: 5.311129
# EPOCH 68 TOTAL TRAINING LOSS: 5.413281
# EPOCH 69 TOTAL TRAINING LOSS: 5.261569
# EPOCH 70 TOTAL TRAINING LOSS: 5.592384
# EPOCH 71 TOTAL TRAINING LOSS: 5.723835
# EPOCH 72 TOTAL TRAINING LOSS: 5.101110
# EPOCH 73 TOTAL TRAINING LOSS: 5.080374
# EPOCH 74 TOTAL TRAINING LOSS: 5.725986
# EPOCH 75 TOTAL TRAINING LOSS: 5.289816
# EPOCH 76 TOTAL TRAINING LOSS: 5.379580
# EPOCH 77 TOTAL TRAINING LOSS: 4.207552
# EPOCH 78 TOTAL TRAINING LOSS: 5.595724
# EPOCH 79 TOTAL TRAINING LOSS: 5.424253
# EPOCH 80 TOTAL TRAINING LOSS: 4.636565
# EPOCH 81 TOTAL TRAINING LOSS: 4.679362
# EPOCH 82 TOTAL TRAINING LOSS: 5.390784
# EPOCH 83 TOTAL TRAINING LOSS: 4.726983
# EPOCH 84 TOTAL TRAINING LOSS: 4.230323
# EPOCH 85 TOTAL TRAINING LOSS: 5.514892
# EPOCH 86 TOTAL TRAINING LOSS: 4.811668
# EPOCH 87 TOTAL TRAINING LOSS: 4.888671
# EPOCH 88 TOTAL TRAINING LOSS: 4.499500
# EPOCH 89 TOTAL TRAINING LOSS: 4.596689
# EPOCH 90 TOTAL TRAINING LOSS: 4.903724
# EPOCH 91 TOTAL TRAINING LOSS: 4.893250
# EPOCH 92 TOTAL TRAINING LOSS: 4.833226
# EPOCH 93 TOTAL TRAINING LOSS: 4.713508
# EPOCH 94 TOTAL TRAINING LOSS: 4.813136
# EPOCH 95 TOTAL TRAINING LOSS: 4.765957
# EPOCH 96 TOTAL TRAINING LOSS: 4.441524
# EPOCH 97 TOTAL TRAINING LOSS: 4.642173
# EPOCH 98 TOTAL TRAINING LOSS: 4.621901
# EPOCH 99 TOTAL TRAINING LOSS: 4.683442
# EPOCH 100 TOTAL TRAINING LOSS: 4.22305
# EPOCH 101 TOTAL TRAINING LOSS: 4.906448
# EPOCH 102 TOTAL TRAINING LOSS: 4.641444
# EPOCH 103 TOTAL TRAINING LOSS: 5.503004
# EPOCH 104 TOTAL TRAINING LOSS: 4.863098
# EPOCH 105 TOTAL TRAINING LOSS: 4.598295
# EPOCH 106 TOTAL TRAINING LOSS: 5.169617
# EPOCH 107 TOTAL TRAINING LOSS: 4.491346
# EPOCH 108 TOTAL TRAINING LOSS: 4.799531
# EPOCH 109 TOTAL TRAINING LOSS: 4.277827
# EPOCH 110 TOTAL TRAINING LOSS: 4.833441
# EPOCH 111 TOTAL TRAINING LOSS: 4.855804
# EPOCH 112 TOTAL TRAINING LOSS: 4.539539
# EPOCH 113 TOTAL TRAINING LOSS: 4.661269
# EPOCH 114 TOTAL TRAINING LOSS: 4.461964
# EPOCH 115 TOTAL TRAINING LOSS: 4.702421
# EPOCH 116 TOTAL TRAINING LOSS: 5.058840
# EPOCH 117 TOTAL TRAINING LOSS: 4.747619
# EPOCH 118 TOTAL TRAINING LOSS: 4.653109
# EPOCH 119 TOTAL TRAINING LOSS: 4.250422
# EPOCH 120 TOTAL TRAINING LOSS: 4.527122
# EPOCH 121 TOTAL TRAINING LOSS: 4.784529
# EPOCH 122 TOTAL TRAINING LOSS: 4.852557
# EPOCH 123 TOTAL TRAINING LOSS: 4.888283
# EPOCH 124 TOTAL TRAINING LOSS: 4.875038
# EPOCH 125 TOTAL TRAINING LOSS: 4.454619
# EPOCH 126 TOTAL TRAINING LOSS: 4.583008
# EPOCH 127 TOTAL TRAINING LOSS: 4.773352
# EPOCH 128 TOTAL TRAINING LOSS: 4.219582
# EPOCH 129 TOTAL TRAINING LOSS: 4.646303
# EPOCH 130 TOTAL TRAINING LOSS: 4.442299
# EPOCH 131 TOTAL TRAINING LOSS: 5.030090
# EPOCH 132 TOTAL TRAINING LOSS: 5.140379
# EPOCH 133 TOTAL TRAINING LOSS: 4.792701
# EPOCH 134 TOTAL TRAINING LOSS: 4.960865
# EPOCH 135 TOTAL TRAINING LOSS: 4.593240
# EPOCH 136 TOTAL TRAINING LOSS: 5.056445
# EPOCH 137 TOTAL TRAINING LOSS: 4.466592
# EPOCH 138 TOTAL TRAINING LOSS: 5.325986
# EPOCH 139 TOTAL TRAINING LOSS: 4.834158
# EPOCH 140 TOTAL TRAINING LOSS: 4.727457
# EPOCH 141 TOTAL TRAINING LOSS: 5.206819
# EPOCH 142 TOTAL TRAINING LOSS: 4.394232
# EPOCH 143 TOTAL TRAINING LOSS: 5.142732
# EPOCH 144 TOTAL TRAINING LOSS: 4.752353
# EPOCH 145 TOTAL TRAINING LOSS: 4.569943
# EPOCH 146 TOTAL TRAINING LOSS: 5.139294
# EPOCH 147 TOTAL TRAINING LOSS: 4.948250
# EPOCH 148 TOTAL TRAINING LOSS: 4.824690
# EPOCH 149 TOTAL TRAINING LOSS: 4.317508
# EPOCH 150 TOTAL TRAINING LOSS: 4.863722
# Using device(prediction head) : cuda610
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.0163
# EPOCH 2 TOTAL TRAINING LOSS: 5.110058
# EPOCH 3 TOTAL TRAINING LOSS: 6.092097
# EPOCH 4 TOTAL TRAINING LOSS: 5.548651
# EPOCH 5 TOTAL TRAINING LOSS: 5.594805
# EPOCH 6 TOTAL TRAINING LOSS: 5.875871
# EPOCH 7 TOTAL TRAINING LOSS: 5.297542
# EPOCH 8 TOTAL TRAINING LOSS: 5.270223
# EPOCH 9 TOTAL TRAINING LOSS: 5.192913
# EPOCH 10 TOTAL TRAINING LOSS: 4.94287
# EPOCH 11 TOTAL TRAINING LOSS: 6.155909
# EPOCH 12 TOTAL TRAINING LOSS: 5.093002
# EPOCH 13 TOTAL TRAINING LOSS: 5.771707
# EPOCH 14 TOTAL TRAINING LOSS: 4.721120
# EPOCH 15 TOTAL TRAINING LOSS: 5.251249
# EPOCH 16 TOTAL TRAINING LOSS: 5.599186
# EPOCH 17 TOTAL TRAINING LOSS: 5.352010
# EPOCH 18 TOTAL TRAINING LOSS: 5.156954
# EPOCH 19 TOTAL TRAINING LOSS: 5.110599
# EPOCH 20 TOTAL TRAINING LOSS: 5.563853
# EPOCH 21 TOTAL TRAINING LOSS: 5.216310
# EPOCH 22 TOTAL TRAINING LOSS: 4.686379
# EPOCH 23 TOTAL TRAINING LOSS: 4.769039
# EPOCH 24 TOTAL TRAINING LOSS: 5.086735
# EPOCH 25 TOTAL TRAINING LOSS: 4.881439
# EPOCH 26 TOTAL TRAINING LOSS: 4.671428
# EPOCH 27 TOTAL TRAINING LOSS: 5.210653
# EPOCH 28 TOTAL TRAINING LOSS: 4.815647
# EPOCH 29 TOTAL TRAINING LOSS: 4.887859
# EPOCH 30 TOTAL TRAINING LOSS: 5.616408
# EPOCH 31 TOTAL TRAINING LOSS: 4.571473
# EPOCH 32 TOTAL TRAINING LOSS: 5.264316
# EPOCH 33 TOTAL TRAINING LOSS: 6.001902
# EPOCH 34 TOTAL TRAINING LOSS: 5.023586
# EPOCH 35 TOTAL TRAINING LOSS: 4.774007
# EPOCH 36 TOTAL TRAINING LOSS: 4.621365
# EPOCH 37 TOTAL TRAINING LOSS: 4.276794
# EPOCH 38 TOTAL TRAINING LOSS: 4.930865
# EPOCH 39 TOTAL TRAINING LOSS: 4.827291
# EPOCH 40 TOTAL TRAINING LOSS: 4.928773
# EPOCH 41 TOTAL TRAINING LOSS: 4.509509
# EPOCH 42 TOTAL TRAINING LOSS: 5.511995
# EPOCH 43 TOTAL TRAINING LOSS: 4.772205
# EPOCH 44 TOTAL TRAINING LOSS: 4.256294
# EPOCH 45 TOTAL TRAINING LOSS: 4.770183
# EPOCH 46 TOTAL TRAINING LOSS: 4.746780
# EPOCH 47 TOTAL TRAINING LOSS: 4.666829
# EPOCH 48 TOTAL TRAINING LOSS: 4.646399
# EPOCH 49 TOTAL TRAINING LOSS: 4.922620
# EPOCH 50 TOTAL TRAINING LOSS: 5.053014
# EPOCH 51 TOTAL TRAINING LOSS: 4.613080
# EPOCH 52 TOTAL TRAINING LOSS: 5.020998
# EPOCH 53 TOTAL TRAINING LOSS: 4.191963
# EPOCH 54 TOTAL TRAINING LOSS: 4.470756
# EPOCH 55 TOTAL TRAINING LOSS: 4.377145
# EPOCH 56 TOTAL TRAINING LOSS: 4.587250
# EPOCH 57 TOTAL TRAINING LOSS: 4.248586
# EPOCH 58 TOTAL TRAINING LOSS: 4.596705
# EPOCH 59 TOTAL TRAINING LOSS: 4.353257
# EPOCH 60 TOTAL TRAINING LOSS: 4.583113
# EPOCH 61 TOTAL TRAINING LOSS: 4.223168
# EPOCH 62 TOTAL TRAINING LOSS: 4.791059
# EPOCH 63 TOTAL TRAINING LOSS: 4.566832
# EPOCH 64 TOTAL TRAINING LOSS: 4.603140
# EPOCH 65 TOTAL TRAINING LOSS: 4.300920
# EPOCH 66 TOTAL TRAINING LOSS: 4.354548
# EPOCH 67 TOTAL TRAINING LOSS: 4.591233
# EPOCH 68 TOTAL TRAINING LOSS: 4.553490
# EPOCH 69 TOTAL TRAINING LOSS: 4.069663
# EPOCH 70 TOTAL TRAINING LOSS: 5.454013
# EPOCH 71 TOTAL TRAINING LOSS: 4.814254
# EPOCH 72 TOTAL TRAINING LOSS: 4.581807
# EPOCH 73 TOTAL TRAINING LOSS: 4.136333
# EPOCH 74 TOTAL TRAINING LOSS: 4.239645
# EPOCH 75 TOTAL TRAINING LOSS: 4.639172
# EPOCH 76 TOTAL TRAINING LOSS: 4.750310
# EPOCH 77 TOTAL TRAINING LOSS: 4.039970
# EPOCH 78 TOTAL TRAINING LOSS: 4.506901
# EPOCH 79 TOTAL TRAINING LOSS: 4.861491
# EPOCH 80 TOTAL TRAINING LOSS: 3.999997
# EPOCH 81 TOTAL TRAINING LOSS: 4.095739
# EPOCH 82 TOTAL TRAINING LOSS: 4.756758
# EPOCH 83 TOTAL TRAINING LOSS: 4.752505
# EPOCH 84 TOTAL TRAINING LOSS: 4.523010
# EPOCH 85 TOTAL TRAINING LOSS: 4.231111
# EPOCH 86 TOTAL TRAINING LOSS: 4.295325
# EPOCH 87 TOTAL TRAINING LOSS: 4.108550
# EPOCH 88 TOTAL TRAINING LOSS: 4.136214
# EPOCH 89 TOTAL TRAINING LOSS: 4.508229
# EPOCH 90 TOTAL TRAINING LOSS: 4.335835
# EPOCH 91 TOTAL TRAINING LOSS: 4.245643
# EPOCH 92 TOTAL TRAINING LOSS: 3.971616
# EPOCH 93 TOTAL TRAINING LOSS: 3.950203
# EPOCH 94 TOTAL TRAINING LOSS: 4.399878
# EPOCH 95 TOTAL TRAINING LOSS: 4.090826
# EPOCH 96 TOTAL TRAINING LOSS: 4.395541
# EPOCH 97 TOTAL TRAINING LOSS: 4.055692
# EPOCH 98 TOTAL TRAINING LOSS: 4.022620
# EPOCH 99 TOTAL TRAINING LOSS: 4.284624
# EPOCH 100 TOTAL TRAINING LOSS: 4.60741
# EPOCH 101 TOTAL TRAINING LOSS: 4.057674
# EPOCH 102 TOTAL TRAINING LOSS: 4.389587
# EPOCH 103 TOTAL TRAINING LOSS: 4.319095
# EPOCH 104 TOTAL TRAINING LOSS: 4.659785
# EPOCH 105 TOTAL TRAINING LOSS: 4.141062
# EPOCH 106 TOTAL TRAINING LOSS: 4.135005
# EPOCH 107 TOTAL TRAINING LOSS: 4.185832
# EPOCH 108 TOTAL TRAINING LOSS: 4.047152
# EPOCH 109 TOTAL TRAINING LOSS: 3.394435
# EPOCH 110 TOTAL TRAINING LOSS: 3.771331
# EPOCH 111 TOTAL TRAINING LOSS: 3.834296
# EPOCH 112 TOTAL TRAINING LOSS: 4.419729
# EPOCH 113 TOTAL TRAINING LOSS: 4.120713
# EPOCH 114 TOTAL TRAINING LOSS: 4.256996
# EPOCH 115 TOTAL TRAINING LOSS: 3.793366
# EPOCH 116 TOTAL TRAINING LOSS: 3.882328
# EPOCH 117 TOTAL TRAINING LOSS: 3.926373
# EPOCH 118 TOTAL TRAINING LOSS: 3.685387
# EPOCH 119 TOTAL TRAINING LOSS: 4.523704
# EPOCH 120 TOTAL TRAINING LOSS: 3.687466
# EPOCH 121 TOTAL TRAINING LOSS: 3.729966
# EPOCH 122 TOTAL TRAINING LOSS: 4.683664
# EPOCH 123 TOTAL TRAINING LOSS: 4.018161
# EPOCH 124 TOTAL TRAINING LOSS: 4.251180
# EPOCH 125 TOTAL TRAINING LOSS: 4.009193
# EPOCH 126 TOTAL TRAINING LOSS: 4.012362
# EPOCH 127 TOTAL TRAINING LOSS: 4.105759
# EPOCH 128 TOTAL TRAINING LOSS: 4.411664
# EPOCH 129 TOTAL TRAINING LOSS: 3.575827
# EPOCH 130 TOTAL TRAINING LOSS: 4.558465
# EPOCH 131 TOTAL TRAINING LOSS: 3.863011
# EPOCH 132 TOTAL TRAINING LOSS: 4.181938
# EPOCH 133 TOTAL TRAINING LOSS: 4.271300
# EPOCH 134 TOTAL TRAINING LOSS: 4.087547
# EPOCH 135 TOTAL TRAINING LOSS: 4.243032
# EPOCH 136 TOTAL TRAINING LOSS: 3.794991
# EPOCH 137 TOTAL TRAINING LOSS: 3.714675
# EPOCH 138 TOTAL TRAINING LOSS: 4.037387
# EPOCH 139 TOTAL TRAINING LOSS: 4.393680
# EPOCH 140 TOTAL TRAINING LOSS: 3.881132
# EPOCH 141 TOTAL TRAINING LOSS: 4.284871
# EPOCH 142 TOTAL TRAINING LOSS: 4.413675
# EPOCH 143 TOTAL TRAINING LOSS: 3.863709
# EPOCH 144 TOTAL TRAINING LOSS: 4.191901
# EPOCH 145 TOTAL TRAINING LOSS: 4.242390
# EPOCH 146 TOTAL TRAINING LOSS: 4.145018
# EPOCH 147 TOTAL TRAINING LOSS: 4.117751
# EPOCH 148 TOTAL TRAINING LOSS: 4.124619
# EPOCH 149 TOTAL TRAINING LOSS: 4.070149
# EPOCH 150 TOTAL TRAINING LOSS: 4.114066
# Using device(prediction head) : cuda562
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 9.1312
# EPOCH 2 TOTAL TRAINING LOSS: 8.181077
# EPOCH 3 TOTAL TRAINING LOSS: 8.795945
# EPOCH 4 TOTAL TRAINING LOSS: 8.385706
# EPOCH 5 TOTAL TRAINING LOSS: 8.896394
# EPOCH 6 TOTAL TRAINING LOSS: 9.145288
# EPOCH 7 TOTAL TRAINING LOSS: 8.264888
# EPOCH 8 TOTAL TRAINING LOSS: 8.737611
# EPOCH 9 TOTAL TRAINING LOSS: 7.991446
# EPOCH 10 TOTAL TRAINING LOSS: 8.29311
# EPOCH 11 TOTAL TRAINING LOSS: 8.555840
# EPOCH 12 TOTAL TRAINING LOSS: 8.166297
# EPOCH 13 TOTAL TRAINING LOSS: 8.133264
# EPOCH 14 TOTAL TRAINING LOSS: 8.659243
# EPOCH 15 TOTAL TRAINING LOSS: 7.670229
# EPOCH 16 TOTAL TRAINING LOSS: 8.442808
# EPOCH 17 TOTAL TRAINING LOSS: 8.691512
# EPOCH 18 TOTAL TRAINING LOSS: 7.645408
# EPOCH 19 TOTAL TRAINING LOSS: 7.530230
# EPOCH 20 TOTAL TRAINING LOSS: 8.280271
# EPOCH 21 TOTAL TRAINING LOSS: 7.728405
# EPOCH 22 TOTAL TRAINING LOSS: 6.910737
# EPOCH 23 TOTAL TRAINING LOSS: 8.201281
# EPOCH 24 TOTAL TRAINING LOSS: 8.025327
# EPOCH 25 TOTAL TRAINING LOSS: 7.863088
# EPOCH 26 TOTAL TRAINING LOSS: 8.100775
# EPOCH 27 TOTAL TRAINING LOSS: 7.545277
# EPOCH 28 TOTAL TRAINING LOSS: 7.270984
# EPOCH 29 TOTAL TRAINING LOSS: 7.854086
# EPOCH 30 TOTAL TRAINING LOSS: 8.215254
# EPOCH 31 TOTAL TRAINING LOSS: 7.904712
# EPOCH 32 TOTAL TRAINING LOSS: 7.831882
# EPOCH 33 TOTAL TRAINING LOSS: 7.149860
# EPOCH 34 TOTAL TRAINING LOSS: 7.607127
# EPOCH 35 TOTAL TRAINING LOSS: 7.025582
# EPOCH 36 TOTAL TRAINING LOSS: 7.150737
# EPOCH 37 TOTAL TRAINING LOSS: 7.235409
# EPOCH 38 TOTAL TRAINING LOSS: 7.304310
# EPOCH 39 TOTAL TRAINING LOSS: 7.395934
# EPOCH 40 TOTAL TRAINING LOSS: 7.569848
# EPOCH 41 TOTAL TRAINING LOSS: 7.284699
# EPOCH 42 TOTAL TRAINING LOSS: 7.806485
# EPOCH 43 TOTAL TRAINING LOSS: 7.532616
# EPOCH 44 TOTAL TRAINING LOSS: 8.038861
# EPOCH 45 TOTAL TRAINING LOSS: 7.725551
# EPOCH 46 TOTAL TRAINING LOSS: 7.948412
# EPOCH 47 TOTAL TRAINING LOSS: 7.379930
# EPOCH 48 TOTAL TRAINING LOSS: 6.949537
# EPOCH 49 TOTAL TRAINING LOSS: 7.076169
# EPOCH 50 TOTAL TRAINING LOSS: 7.667551
# EPOCH 51 TOTAL TRAINING LOSS: 6.905278
# EPOCH 52 TOTAL TRAINING LOSS: 7.308607
# EPOCH 53 TOTAL TRAINING LOSS: 7.332465
# EPOCH 54 TOTAL TRAINING LOSS: 7.350188
# EPOCH 55 TOTAL TRAINING LOSS: 6.798465
# EPOCH 56 TOTAL TRAINING LOSS: 7.594588
# EPOCH 57 TOTAL TRAINING LOSS: 7.011299
# EPOCH 58 TOTAL TRAINING LOSS: 7.918439
# EPOCH 59 TOTAL TRAINING LOSS: 6.929099
# EPOCH 60 TOTAL TRAINING LOSS: 6.602846
# EPOCH 61 TOTAL TRAINING LOSS: 7.185708
# EPOCH 62 TOTAL TRAINING LOSS: 6.086795
# EPOCH 63 TOTAL TRAINING LOSS: 6.514813
# EPOCH 64 TOTAL TRAINING LOSS: 6.913209
# EPOCH 65 TOTAL TRAINING LOSS: 7.215334
# EPOCH 66 TOTAL TRAINING LOSS: 7.106966
# EPOCH 67 TOTAL TRAINING LOSS: 6.480849
# EPOCH 68 TOTAL TRAINING LOSS: 7.358305
# EPOCH 69 TOTAL TRAINING LOSS: 7.886677
# EPOCH 70 TOTAL TRAINING LOSS: 6.952264
# EPOCH 71 TOTAL TRAINING LOSS: 6.416727
# EPOCH 72 TOTAL TRAINING LOSS: 7.759457
# EPOCH 73 TOTAL TRAINING LOSS: 6.563637
# EPOCH 74 TOTAL TRAINING LOSS: 6.737970
# EPOCH 75 TOTAL TRAINING LOSS: 6.656349
# EPOCH 76 TOTAL TRAINING LOSS: 6.384756
# EPOCH 77 TOTAL TRAINING LOSS: 6.483110
# EPOCH 78 TOTAL TRAINING LOSS: 7.065096
# EPOCH 79 TOTAL TRAINING LOSS: 6.942571
# EPOCH 80 TOTAL TRAINING LOSS: 5.957033
# EPOCH 81 TOTAL TRAINING LOSS: 6.582926
# EPOCH 82 TOTAL TRAINING LOSS: 7.039579
# EPOCH 83 TOTAL TRAINING LOSS: 6.011584
# EPOCH 84 TOTAL TRAINING LOSS: 6.975216
# EPOCH 85 TOTAL TRAINING LOSS: 7.226360
# EPOCH 86 TOTAL TRAINING LOSS: 6.931375
# EPOCH 87 TOTAL TRAINING LOSS: 6.675296
# EPOCH 88 TOTAL TRAINING LOSS: 6.577840
# EPOCH 89 TOTAL TRAINING LOSS: 6.983843
# EPOCH 90 TOTAL TRAINING LOSS: 7.270113
# EPOCH 91 TOTAL TRAINING LOSS: 6.588909
# EPOCH 92 TOTAL TRAINING LOSS: 7.075183
# EPOCH 93 TOTAL TRAINING LOSS: 6.130353
# EPOCH 94 TOTAL TRAINING LOSS: 6.927945
# EPOCH 95 TOTAL TRAINING LOSS: 6.796373
# EPOCH 96 TOTAL TRAINING LOSS: 7.392870
# EPOCH 97 TOTAL TRAINING LOSS: 6.777614
# EPOCH 98 TOTAL TRAINING LOSS: 5.506473
# EPOCH 99 TOTAL TRAINING LOSS: 6.288780
# EPOCH 100 TOTAL TRAINING LOSS: 7.08369
# EPOCH 101 TOTAL TRAINING LOSS: 6.675473
# EPOCH 102 TOTAL TRAINING LOSS: 6.960468
# EPOCH 103 TOTAL TRAINING LOSS: 6.250531
# EPOCH 104 TOTAL TRAINING LOSS: 5.917026
# EPOCH 105 TOTAL TRAINING LOSS: 6.378284
# EPOCH 106 TOTAL TRAINING LOSS: 6.032583
# EPOCH 107 TOTAL TRAINING LOSS: 6.649716
# EPOCH 108 TOTAL TRAINING LOSS: 7.175894
# EPOCH 109 TOTAL TRAINING LOSS: 6.343890
# EPOCH 110 TOTAL TRAINING LOSS: 5.992209
# EPOCH 111 TOTAL TRAINING LOSS: 7.107491
# EPOCH 112 TOTAL TRAINING LOSS: 6.384318
# EPOCH 113 TOTAL TRAINING LOSS: 6.357853
# EPOCH 114 TOTAL TRAINING LOSS: 6.511483
# EPOCH 115 TOTAL TRAINING LOSS: 6.516250
# EPOCH 116 TOTAL TRAINING LOSS: 5.799396
# EPOCH 117 TOTAL TRAINING LOSS: 6.280255
# EPOCH 118 TOTAL TRAINING LOSS: 6.308285
# EPOCH 119 TOTAL TRAINING LOSS: 6.350723
# EPOCH 120 TOTAL TRAINING LOSS: 7.175451
# EPOCH 121 TOTAL TRAINING LOSS: 6.494496
# EPOCH 122 TOTAL TRAINING LOSS: 6.342012
# EPOCH 123 TOTAL TRAINING LOSS: 7.319926
# EPOCH 124 TOTAL TRAINING LOSS: 7.218024
# EPOCH 125 TOTAL TRAINING LOSS: 6.419171
# EPOCH 126 TOTAL TRAINING LOSS: 5.995585
# EPOCH 127 TOTAL TRAINING LOSS: 6.140282
# EPOCH 128 TOTAL TRAINING LOSS: 7.090085
# EPOCH 129 TOTAL TRAINING LOSS: 6.170156
# EPOCH 130 TOTAL TRAINING LOSS: 6.667785
# EPOCH 131 TOTAL TRAINING LOSS: 5.997115
# EPOCH 132 TOTAL TRAINING LOSS: 6.314572
# EPOCH 133 TOTAL TRAINING LOSS: 6.267394
# EPOCH 134 TOTAL TRAINING LOSS: 5.786550
# EPOCH 135 TOTAL TRAINING LOSS: 5.819045
# EPOCH 136 TOTAL TRAINING LOSS: 6.309710
# EPOCH 137 TOTAL TRAINING LOSS: 6.703546
# EPOCH 138 TOTAL TRAINING LOSS: 5.794288
# EPOCH 139 TOTAL TRAINING LOSS: 6.529192
# EPOCH 140 TOTAL TRAINING LOSS: 6.320351
# EPOCH 141 TOTAL TRAINING LOSS: 5.475913
# EPOCH 142 TOTAL TRAINING LOSS: 6.291260
# EPOCH 143 TOTAL TRAINING LOSS: 6.499038
# EPOCH 144 TOTAL TRAINING LOSS: 6.769070
# EPOCH 145 TOTAL TRAINING LOSS: 6.642234
# EPOCH 146 TOTAL TRAINING LOSS: 6.668002
# EPOCH 147 TOTAL TRAINING LOSS: 6.470498
# EPOCH 148 TOTAL TRAINING LOSS: 5.890944
# EPOCH 149 TOTAL TRAINING LOSS: 7.573924
# EPOCH 150 TOTAL TRAINING LOSS: 7.130339
# Using device(prediction head) : cuda772
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.8929
# EPOCH 2 TOTAL TRAINING LOSS: 6.722166
# EPOCH 3 TOTAL TRAINING LOSS: 6.474714
# EPOCH 4 TOTAL TRAINING LOSS: 6.218962
# EPOCH 5 TOTAL TRAINING LOSS: 5.863415
# EPOCH 6 TOTAL TRAINING LOSS: 6.832679
# EPOCH 7 TOTAL TRAINING LOSS: 6.152261
# EPOCH 8 TOTAL TRAINING LOSS: 6.369044
# EPOCH 9 TOTAL TRAINING LOSS: 6.493432
# EPOCH 10 TOTAL TRAINING LOSS: 6.31990
# EPOCH 11 TOTAL TRAINING LOSS: 6.076731
# EPOCH 12 TOTAL TRAINING LOSS: 6.270050
# EPOCH 13 TOTAL TRAINING LOSS: 6.267762
# EPOCH 14 TOTAL TRAINING LOSS: 6.690282
# EPOCH 15 TOTAL TRAINING LOSS: 5.656213
# EPOCH 16 TOTAL TRAINING LOSS: 6.529842
# EPOCH 17 TOTAL TRAINING LOSS: 6.039690
# EPOCH 18 TOTAL TRAINING LOSS: 5.722135
# EPOCH 19 TOTAL TRAINING LOSS: 6.562286
# EPOCH 20 TOTAL TRAINING LOSS: 6.288556
# EPOCH 21 TOTAL TRAINING LOSS: 5.428917
# EPOCH 22 TOTAL TRAINING LOSS: 7.015893
# EPOCH 23 TOTAL TRAINING LOSS: 6.450109
# EPOCH 24 TOTAL TRAINING LOSS: 6.082017
# EPOCH 25 TOTAL TRAINING LOSS: 5.909426
# EPOCH 26 TOTAL TRAINING LOSS: 6.440768
# EPOCH 27 TOTAL TRAINING LOSS: 6.394713
# EPOCH 28 TOTAL TRAINING LOSS: 5.879281
# EPOCH 29 TOTAL TRAINING LOSS: 5.209056
# EPOCH 30 TOTAL TRAINING LOSS: 5.188778
# EPOCH 31 TOTAL TRAINING LOSS: 5.609685
# EPOCH 32 TOTAL TRAINING LOSS: 5.594826
# EPOCH 33 TOTAL TRAINING LOSS: 5.557608
# EPOCH 34 TOTAL TRAINING LOSS: 5.718565
# EPOCH 35 TOTAL TRAINING LOSS: 5.470233
# EPOCH 36 TOTAL TRAINING LOSS: 4.352922
# EPOCH 37 TOTAL TRAINING LOSS: 4.828910
# EPOCH 38 TOTAL TRAINING LOSS: 4.501296
# EPOCH 39 TOTAL TRAINING LOSS: 4.788706
# EPOCH 40 TOTAL TRAINING LOSS: 4.766466
# EPOCH 41 TOTAL TRAINING LOSS: 6.395420
# EPOCH 42 TOTAL TRAINING LOSS: 5.841580
# EPOCH 43 TOTAL TRAINING LOSS: 5.491348
# EPOCH 44 TOTAL TRAINING LOSS: 5.150488
# EPOCH 45 TOTAL TRAINING LOSS: 5.122467
# EPOCH 46 TOTAL TRAINING LOSS: 4.282645
# EPOCH 47 TOTAL TRAINING LOSS: 6.022995
# EPOCH 48 TOTAL TRAINING LOSS: 4.549036
# EPOCH 49 TOTAL TRAINING LOSS: 5.006379
# EPOCH 50 TOTAL TRAINING LOSS: 5.102841
# EPOCH 51 TOTAL TRAINING LOSS: 4.270705
# EPOCH 52 TOTAL TRAINING LOSS: 4.782770
# EPOCH 53 TOTAL TRAINING LOSS: 5.408496
# EPOCH 54 TOTAL TRAINING LOSS: 5.294634
# EPOCH 55 TOTAL TRAINING LOSS: 4.920165
# EPOCH 56 TOTAL TRAINING LOSS: 4.200619
# EPOCH 57 TOTAL TRAINING LOSS: 5.192687
# EPOCH 58 TOTAL TRAINING LOSS: 4.810965
# EPOCH 59 TOTAL TRAINING LOSS: 5.496874
# EPOCH 60 TOTAL TRAINING LOSS: 4.831548
# EPOCH 61 TOTAL TRAINING LOSS: 4.748887
# EPOCH 62 TOTAL TRAINING LOSS: 4.948421
# EPOCH 63 TOTAL TRAINING LOSS: 4.950829
# EPOCH 64 TOTAL TRAINING LOSS: 4.595655
# EPOCH 65 TOTAL TRAINING LOSS: 4.629091
# EPOCH 66 TOTAL TRAINING LOSS: 4.954369
# EPOCH 67 TOTAL TRAINING LOSS: 4.462566
# EPOCH 68 TOTAL TRAINING LOSS: 5.318233
# EPOCH 69 TOTAL TRAINING LOSS: 4.140274
# EPOCH 70 TOTAL TRAINING LOSS: 3.591340
# EPOCH 71 TOTAL TRAINING LOSS: 5.008923
# EPOCH 72 TOTAL TRAINING LOSS: 5.499017
# EPOCH 73 TOTAL TRAINING LOSS: 4.881369
# EPOCH 74 TOTAL TRAINING LOSS: 4.752689
# EPOCH 75 TOTAL TRAINING LOSS: 4.430679
# EPOCH 76 TOTAL TRAINING LOSS: 3.840027
# EPOCH 77 TOTAL TRAINING LOSS: 4.866742
# EPOCH 78 TOTAL TRAINING LOSS: 4.122488
# EPOCH 79 TOTAL TRAINING LOSS: 4.501863
# EPOCH 80 TOTAL TRAINING LOSS: 4.766284
# EPOCH 81 TOTAL TRAINING LOSS: 3.534060
# EPOCH 82 TOTAL TRAINING LOSS: 4.902749
# EPOCH 83 TOTAL TRAINING LOSS: 4.439543
# EPOCH 84 TOTAL TRAINING LOSS: 4.471288
# EPOCH 85 TOTAL TRAINING LOSS: 4.238460
# EPOCH 86 TOTAL TRAINING LOSS: 4.697439
# EPOCH 87 TOTAL TRAINING LOSS: 4.413696
# EPOCH 88 TOTAL TRAINING LOSS: 3.706659
# EPOCH 89 TOTAL TRAINING LOSS: 4.630077
# EPOCH 90 TOTAL TRAINING LOSS: 4.366364
# EPOCH 91 TOTAL TRAINING LOSS: 4.997501
# EPOCH 92 TOTAL TRAINING LOSS: 4.047368
# EPOCH 93 TOTAL TRAINING LOSS: 5.009293
# EPOCH 94 TOTAL TRAINING LOSS: 4.200877
# EPOCH 95 TOTAL TRAINING LOSS: 4.243196
# EPOCH 96 TOTAL TRAINING LOSS: 3.936553
# EPOCH 97 TOTAL TRAINING LOSS: 4.255149
# EPOCH 98 TOTAL TRAINING LOSS: 4.196423
# EPOCH 99 TOTAL TRAINING LOSS: 4.723087
# EPOCH 100 TOTAL TRAINING LOSS: 4.66779
# EPOCH 101 TOTAL TRAINING LOSS: 4.425522
# EPOCH 102 TOTAL TRAINING LOSS: 4.487561
# EPOCH 103 TOTAL TRAINING LOSS: 4.910502
# EPOCH 104 TOTAL TRAINING LOSS: 4.805748
# EPOCH 105 TOTAL TRAINING LOSS: 3.823805
# EPOCH 106 TOTAL TRAINING LOSS: 4.102483
# EPOCH 107 TOTAL TRAINING LOSS: 4.780782
# EPOCH 108 TOTAL TRAINING LOSS: 4.064849
# EPOCH 109 TOTAL TRAINING LOSS: 3.538207
# EPOCH 110 TOTAL TRAINING LOSS: 4.452301
# ...
# EPOCH 61 TOTAL TRAINING LOSS: 4.306783
# EPOCH 62 TOTAL TRAINING LOSS: 4.337612
# EPOCH 63 TOTAL TRAINING LOSS: 5.047483
# EPOCH 64 TOTAL TRAINING LOSS: 5.001437
# EPOCH 65 TOTAL TRAINING LOSS: 5.090842
# EPOCH 66 TOTAL TRAINING LOSS: 4.482413
# EPOCH 67 TOTAL TRAINING LOSS: 5.134135
# EPOCH 68 TOTAL TRAINING LOSS: 5.204749
# EPOCH 69 TOTAL TRAINING LOSS: 4.601847
# EPOCH 70 TOTAL TRAINING LOSS: 5.326795
# EPOCH 71 TOTAL TRAINING LOSS: 4.625163
# EPOCH 72 TOTAL TRAINING LOSS: 5.040242
# EPOCH 73 TOTAL TRAINING LOSS: 4.452256
# EPOCH 74 TOTAL TRAINING LOSS: 5.249089
# EPOCH 75 TOTAL TRAINING LOSS: 4.543275
# EPOCH 76 TOTAL TRAINING LOSS: 5.046545
# EPOCH 77 TOTAL TRAINING LOSS: 5.527704
# EPOCH 78 TOTAL TRAINING LOSS: 4.934181
# EPOCH 79 TOTAL TRAINING LOSS: 4.276189
# EPOCH 80 TOTAL TRAINING LOSS: 4.759562
# EPOCH 81 TOTAL TRAINING LOSS: 5.113969
# EPOCH 82 TOTAL TRAINING LOSS: 4.231740
# EPOCH 83 TOTAL TRAINING LOSS: 4.958341
# EPOCH 84 TOTAL TRAINING LOSS: 4.917197
# EPOCH 85 TOTAL TRAINING LOSS: 4.307711
# EPOCH 86 TOTAL TRAINING LOSS: 4.485537
# EPOCH 87 TOTAL TRAINING LOSS: 4.213769
# EPOCH 88 TOTAL TRAINING LOSS: 4.486317
# EPOCH 89 TOTAL TRAINING LOSS: 4.673792
# EPOCH 90 TOTAL TRAINING LOSS: 4.315897
# EPOCH 91 TOTAL TRAINING LOSS: 4.177990
# EPOCH 92 TOTAL TRAINING LOSS: 4.881708
# EPOCH 93 TOTAL TRAINING LOSS: 4.261633
# EPOCH 94 TOTAL TRAINING LOSS: 4.027897
# EPOCH 95 TOTAL TRAINING LOSS: 4.797324
# EPOCH 96 TOTAL TRAINING LOSS: 3.974609
# EPOCH 97 TOTAL TRAINING LOSS: 3.975856
# EPOCH 98 TOTAL TRAINING LOSS: 4.461412
# EPOCH 99 TOTAL TRAINING LOSS: 4.253434
# EPOCH 100 TOTAL TRAINING LOSS: 4.18514
# EPOCH 101 TOTAL TRAINING LOSS: 4.006619
# EPOCH 102 TOTAL TRAINING LOSS: 4.550457
# EPOCH 103 TOTAL TRAINING LOSS: 3.936031
# EPOCH 104 TOTAL TRAINING LOSS: 4.092135
# EPOCH 105 TOTAL TRAINING LOSS: 4.210277
# EPOCH 106 TOTAL TRAINING LOSS: 4.639953
# EPOCH 107 TOTAL TRAINING LOSS: 3.946760
# EPOCH 108 TOTAL TRAINING LOSS: 4.014230
# EPOCH 109 TOTAL TRAINING LOSS: 4.438581
# EPOCH 110 TOTAL TRAINING LOSS: 4.475621
# EPOCH 111 TOTAL TRAINING LOSS: 4.303286
# EPOCH 112 TOTAL TRAINING LOSS: 3.897157
# EPOCH 113 TOTAL TRAINING LOSS: 4.582593
# EPOCH 114 TOTAL TRAINING LOSS: 4.933717
# EPOCH 115 TOTAL TRAINING LOSS: 3.914197
# EPOCH 116 TOTAL TRAINING LOSS: 4.278842
# EPOCH 117 TOTAL TRAINING LOSS: 4.576419
# EPOCH 118 TOTAL TRAINING LOSS: 4.471821
# EPOCH 119 TOTAL TRAINING LOSS: 4.284024
# EPOCH 120 TOTAL TRAINING LOSS: 4.868558
# EPOCH 121 TOTAL TRAINING LOSS: 3.873961
# EPOCH 122 TOTAL TRAINING LOSS: 4.342392
# EPOCH 123 TOTAL TRAINING LOSS: 4.730081
# EPOCH 124 TOTAL TRAINING LOSS: 4.617355
# EPOCH 125 TOTAL TRAINING LOSS: 4.497910
# EPOCH 126 TOTAL TRAINING LOSS: 4.034450
# EPOCH 127 TOTAL TRAINING LOSS: 4.857178
# EPOCH 128 TOTAL TRAINING LOSS: 4.404640
# EPOCH 129 TOTAL TRAINING LOSS: 4.484401
# EPOCH 130 TOTAL TRAINING LOSS: 4.026101
# EPOCH 131 TOTAL TRAINING LOSS: 4.431738
# EPOCH 132 TOTAL TRAINING LOSS: 3.996128
# EPOCH 133 TOTAL TRAINING LOSS: 4.676103
# EPOCH 134 TOTAL TRAINING LOSS: 4.652564
# EPOCH 135 TOTAL TRAINING LOSS: 3.902253
# EPOCH 136 TOTAL TRAINING LOSS: 4.209411
# EPOCH 137 TOTAL TRAINING LOSS: 4.029175
# EPOCH 138 TOTAL TRAINING LOSS: 4.447799
# EPOCH 139 TOTAL TRAINING LOSS: 3.546117
# EPOCH 140 TOTAL TRAINING LOSS: 4.408980
# EPOCH 141 TOTAL TRAINING LOSS: 4.496148
# EPOCH 142 TOTAL TRAINING LOSS: 4.368904
# EPOCH 143 TOTAL TRAINING LOSS: 4.043624
# EPOCH 144 TOTAL TRAINING LOSS: 4.022614
# EPOCH 145 TOTAL TRAINING LOSS: 4.212332
# EPOCH 146 TOTAL TRAINING LOSS: 4.580135
# EPOCH 147 TOTAL TRAINING LOSS: 3.996496
# EPOCH 148 TOTAL TRAINING LOSS: 4.426358
# EPOCH 149 TOTAL TRAINING LOSS: 4.489356
# EPOCH 150 TOTAL TRAINING LOSS: 4.275865
# Using device(prediction head) : cuda506
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.8958
# EPOCH 2 TOTAL TRAINING LOSS: 6.233885
# EPOCH 3 TOTAL TRAINING LOSS: 5.580180
# EPOCH 4 TOTAL TRAINING LOSS: 5.539497
# EPOCH 5 TOTAL TRAINING LOSS: 6.505223
# EPOCH 6 TOTAL TRAINING LOSS: 6.075768
# EPOCH 7 TOTAL TRAINING LOSS: 6.214308
# EPOCH 8 TOTAL TRAINING LOSS: 6.103681
# EPOCH 9 TOTAL TRAINING LOSS: 6.285660
# EPOCH 10 TOTAL TRAINING LOSS: 5.92921
# EPOCH 11 TOTAL TRAINING LOSS: 5.137430
# EPOCH 12 TOTAL TRAINING LOSS: 6.426044
# EPOCH 13 TOTAL TRAINING LOSS: 6.211071
# EPOCH 14 TOTAL TRAINING LOSS: 6.337093
# EPOCH 15 TOTAL TRAINING LOSS: 6.171130
# EPOCH 16 TOTAL TRAINING LOSS: 6.692772
# EPOCH 17 TOTAL TRAINING LOSS: 6.852321
# EPOCH 18 TOTAL TRAINING LOSS: 5.867269
# EPOCH 19 TOTAL TRAINING LOSS: 5.656363
# EPOCH 20 TOTAL TRAINING LOSS: 5.840626
# EPOCH 21 TOTAL TRAINING LOSS: 6.439124
# EPOCH 22 TOTAL TRAINING LOSS: 5.287451
# EPOCH 23 TOTAL TRAINING LOSS: 6.472952
# EPOCH 24 TOTAL TRAINING LOSS: 5.480799
# EPOCH 25 TOTAL TRAINING LOSS: 5.965520
# EPOCH 26 TOTAL TRAINING LOSS: 4.765051
# EPOCH 27 TOTAL TRAINING LOSS: 4.919904
# EPOCH 28 TOTAL TRAINING LOSS: 5.744701
# EPOCH 29 TOTAL TRAINING LOSS: 5.950633
# EPOCH 30 TOTAL TRAINING LOSS: 5.701028
# EPOCH 31 TOTAL TRAINING LOSS: 5.693724
# EPOCH 32 TOTAL TRAINING LOSS: 5.664667
# EPOCH 33 TOTAL TRAINING LOSS: 5.853378
# EPOCH 34 TOTAL TRAINING LOSS: 4.851249
# EPOCH 35 TOTAL TRAINING LOSS: 4.960695
# EPOCH 36 TOTAL TRAINING LOSS: 5.144526
# EPOCH 37 TOTAL TRAINING LOSS: 6.180290
# EPOCH 38 TOTAL TRAINING LOSS: 5.639175
# EPOCH 39 TOTAL TRAINING LOSS: 5.278134
# EPOCH 40 TOTAL TRAINING LOSS: 6.048240
# EPOCH 41 TOTAL TRAINING LOSS: 4.434732
# EPOCH 42 TOTAL TRAINING LOSS: 5.050452
# EPOCH 43 TOTAL TRAINING LOSS: 5.004144
# EPOCH 44 TOTAL TRAINING LOSS: 5.326051
# EPOCH 45 TOTAL TRAINING LOSS: 5.974396
# EPOCH 46 TOTAL TRAINING LOSS: 4.711346
# EPOCH 47 TOTAL TRAINING LOSS: 4.996221
# EPOCH 48 TOTAL TRAINING LOSS: 5.837414
# EPOCH 49 TOTAL TRAINING LOSS: 5.410321
# EPOCH 50 TOTAL TRAINING LOSS: 4.918514
# EPOCH 51 TOTAL TRAINING LOSS: 5.227446
# EPOCH 52 TOTAL TRAINING LOSS: 4.784315
# EPOCH 53 TOTAL TRAINING LOSS: 5.386763
# EPOCH 54 TOTAL TRAINING LOSS: 5.424017
# EPOCH 55 TOTAL TRAINING LOSS: 5.646707
# EPOCH 56 TOTAL TRAINING LOSS: 4.873274
# EPOCH 57 TOTAL TRAINING LOSS: 5.499356
# EPOCH 58 TOTAL TRAINING LOSS: 4.404172
# EPOCH 59 TOTAL TRAINING LOSS: 5.204883
# EPOCH 60 TOTAL TRAINING LOSS: 4.791303
# EPOCH 61 TOTAL TRAINING LOSS: 4.105070
# EPOCH 62 TOTAL TRAINING LOSS: 6.058536
# EPOCH 63 TOTAL TRAINING LOSS: 4.405001
# EPOCH 64 TOTAL TRAINING LOSS: 4.398009
# EPOCH 65 TOTAL TRAINING LOSS: 4.679021
# EPOCH 66 TOTAL TRAINING LOSS: 5.428851
# EPOCH 67 TOTAL TRAINING LOSS: 4.572293
# EPOCH 68 TOTAL TRAINING LOSS: 4.377931
# EPOCH 69 TOTAL TRAINING LOSS: 4.719730
# EPOCH 70 TOTAL TRAINING LOSS: 4.431450
# EPOCH 71 TOTAL TRAINING LOSS: 4.608221
# EPOCH 72 TOTAL TRAINING LOSS: 4.888391
# EPOCH 73 TOTAL TRAINING LOSS: 4.506195
# EPOCH 74 TOTAL TRAINING LOSS: 5.242583
# EPOCH 75 TOTAL TRAINING LOSS: 4.679406
# EPOCH 76 TOTAL TRAINING LOSS: 4.485931
# EPOCH 77 TOTAL TRAINING LOSS: 5.188309
# EPOCH 78 TOTAL TRAINING LOSS: 4.475207
# EPOCH 79 TOTAL TRAINING LOSS: 4.688397
# EPOCH 80 TOTAL TRAINING LOSS: 4.589021
# EPOCH 81 TOTAL TRAINING LOSS: 4.909621
# EPOCH 82 TOTAL TRAINING LOSS: 5.059423
# EPOCH 83 TOTAL TRAINING LOSS: 5.258962
# EPOCH 84 TOTAL TRAINING LOSS: 5.749354
# EPOCH 85 TOTAL TRAINING LOSS: 4.446581
# EPOCH 86 TOTAL TRAINING LOSS: 4.233472
# EPOCH 87 TOTAL TRAINING LOSS: 4.402438
# EPOCH 88 TOTAL TRAINING LOSS: 4.546864
# EPOCH 89 TOTAL TRAINING LOSS: 4.730740
# EPOCH 90 TOTAL TRAINING LOSS: 4.766626
# EPOCH 91 TOTAL TRAINING LOSS: 4.747113
# EPOCH 92 TOTAL TRAINING LOSS: 4.086234
# EPOCH 93 TOTAL TRAINING LOSS: 3.748691
# EPOCH 94 TOTAL TRAINING LOSS: 4.869958
# EPOCH 95 TOTAL TRAINING LOSS: 4.055231
# EPOCH 96 TOTAL TRAINING LOSS: 4.263544
# EPOCH 97 TOTAL TRAINING LOSS: 3.909497
# EPOCH 98 TOTAL TRAINING LOSS: 4.944018
# EPOCH 99 TOTAL TRAINING LOSS: 4.474174
# EPOCH 100 TOTAL TRAINING LOSS: 4.83684
# EPOCH 101 TOTAL TRAINING LOSS: 4.198900
# EPOCH 102 TOTAL TRAINING LOSS: 4.167513
# EPOCH 103 TOTAL TRAINING LOSS: 4.569267
# EPOCH 104 TOTAL TRAINING LOSS: 4.830391
# EPOCH 105 TOTAL TRAINING LOSS: 4.465661
# EPOCH 106 TOTAL TRAINING LOSS: 4.512992
# EPOCH 107 TOTAL TRAINING LOSS: 4.356336
# EPOCH 108 TOTAL TRAINING LOSS: 4.983901
# EPOCH 109 TOTAL TRAINING LOSS: 4.229492
# EPOCH 110 TOTAL TRAINING LOSS: 4.119794
# EPOCH 111 TOTAL TRAINING LOSS: 4.494966
# EPOCH 112 TOTAL TRAINING LOSS: 4.177461
# EPOCH 113 TOTAL TRAINING LOSS: 4.743919
# EPOCH 114 TOTAL TRAINING LOSS: 3.921649
# EPOCH 115 TOTAL TRAINING LOSS: 4.239597
# EPOCH 116 TOTAL TRAINING LOSS: 4.299031
# EPOCH 117 TOTAL TRAINING LOSS: 4.568989
# EPOCH 118 TOTAL TRAINING LOSS: 4.401124
# EPOCH 119 TOTAL TRAINING LOSS: 4.081511
# EPOCH 120 TOTAL TRAINING LOSS: 5.054420
# EPOCH 121 TOTAL TRAINING LOSS: 4.585133
# EPOCH 122 TOTAL TRAINING LOSS: 4.069716
# EPOCH 123 TOTAL TRAINING LOSS: 4.330582
# EPOCH 124 TOTAL TRAINING LOSS: 3.951637
# EPOCH 125 TOTAL TRAINING LOSS: 4.099035
# EPOCH 126 TOTAL TRAINING LOSS: 3.878414
# EPOCH 127 TOTAL TRAINING LOSS: 4.507245
# EPOCH 128 TOTAL TRAINING LOSS: 4.060301
# EPOCH 129 TOTAL TRAINING LOSS: 4.415370
# EPOCH 130 TOTAL TRAINING LOSS: 4.284811
# EPOCH 131 TOTAL TRAINING LOSS: 3.791941
# EPOCH 132 TOTAL TRAINING LOSS: 4.145682
# EPOCH 133 TOTAL TRAINING LOSS: 3.798744
# EPOCH 134 TOTAL TRAINING LOSS: 4.533217
# EPOCH 135 TOTAL TRAINING LOSS: 4.724481
# EPOCH 136 TOTAL TRAINING LOSS: 4.322840
# EPOCH 137 TOTAL TRAINING LOSS: 3.938362
# EPOCH 138 TOTAL TRAINING LOSS: 4.450461
# EPOCH 139 TOTAL TRAINING LOSS: 4.718966
# EPOCH 140 TOTAL TRAINING LOSS: 3.800447
# EPOCH 141 TOTAL TRAINING LOSS: 4.534404
# EPOCH 142 TOTAL TRAINING LOSS: 4.872932
# EPOCH 143 TOTAL TRAINING LOSS: 4.699111
# EPOCH 144 TOTAL TRAINING LOSS: 3.641488
# EPOCH 145 TOTAL TRAINING LOSS: 4.443422
# EPOCH 146 TOTAL TRAINING LOSS: 4.892851
# EPOCH 147 TOTAL TRAINING LOSS: 4.130991
# EPOCH 148 TOTAL TRAINING LOSS: 3.744040
# EPOCH 149 TOTAL TRAINING LOSS: 4.581587
# EPOCH 150 TOTAL TRAINING LOSS: 4.686031
# Using device(prediction head) : cuda813
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.0266
# EPOCH 2 TOTAL TRAINING LOSS: 6.041380
# EPOCH 3 TOTAL TRAINING LOSS: 6.098293
# EPOCH 4 TOTAL TRAINING LOSS: 5.841200
# EPOCH 5 TOTAL TRAINING LOSS: 6.206712
# EPOCH 6 TOTAL TRAINING LOSS: 6.498755
# EPOCH 7 TOTAL TRAINING LOSS: 5.901801
# EPOCH 8 TOTAL TRAINING LOSS: 5.909565
# EPOCH 9 TOTAL TRAINING LOSS: 5.649536
# EPOCH 10 TOTAL TRAINING LOSS: 5.92131
# EPOCH 11 TOTAL TRAINING LOSS: 6.267205
# EPOCH 12 TOTAL TRAINING LOSS: 5.969303
# EPOCH 13 TOTAL TRAINING LOSS: 5.691219
# EPOCH 14 TOTAL TRAINING LOSS: 5.474924
# EPOCH 15 TOTAL TRAINING LOSS: 5.523750
# EPOCH 16 TOTAL TRAINING LOSS: 5.493385
# EPOCH 17 TOTAL TRAINING LOSS: 5.625232
# EPOCH 18 TOTAL TRAINING LOSS: 5.546294
# EPOCH 19 TOTAL TRAINING LOSS: 5.892261
# EPOCH 20 TOTAL TRAINING LOSS: 5.932025
# EPOCH 21 TOTAL TRAINING LOSS: 5.626787
# EPOCH 22 TOTAL TRAINING LOSS: 5.370958
# EPOCH 23 TOTAL TRAINING LOSS: 5.747254
# EPOCH 24 TOTAL TRAINING LOSS: 5.082146
# EPOCH 25 TOTAL TRAINING LOSS: 4.992938
# EPOCH 26 TOTAL TRAINING LOSS: 5.964283
# EPOCH 27 TOTAL TRAINING LOSS: 4.955125
# EPOCH 28 TOTAL TRAINING LOSS: 5.057981
# EPOCH 29 TOTAL TRAINING LOSS: 5.564500
# EPOCH 30 TOTAL TRAINING LOSS: 5.221732
# EPOCH 31 TOTAL TRAINING LOSS: 5.419927
# EPOCH 32 TOTAL TRAINING LOSS: 5.292725
# EPOCH 33 TOTAL TRAINING LOSS: 5.091817
# EPOCH 34 TOTAL TRAINING LOSS: 4.845609
# EPOCH 35 TOTAL TRAINING LOSS: 5.294711
# EPOCH 36 TOTAL TRAINING LOSS: 4.980258
# EPOCH 37 TOTAL TRAINING LOSS: 5.743505
# EPOCH 38 TOTAL TRAINING LOSS: 4.867552
# EPOCH 39 TOTAL TRAINING LOSS: 5.163356
# EPOCH 40 TOTAL TRAINING LOSS: 5.855397
# EPOCH 41 TOTAL TRAINING LOSS: 5.110853
# EPOCH 42 TOTAL TRAINING LOSS: 4.863018
# EPOCH 43 TOTAL TRAINING LOSS: 4.692362
# EPOCH 44 TOTAL TRAINING LOSS: 4.720336
# EPOCH 45 TOTAL TRAINING LOSS: 5.227772
# EPOCH 46 TOTAL TRAINING LOSS: 5.034263
# EPOCH 47 TOTAL TRAINING LOSS: 5.209518
# EPOCH 48 TOTAL TRAINING LOSS: 5.102689
# EPOCH 49 TOTAL TRAINING LOSS: 4.691268
# EPOCH 50 TOTAL TRAINING LOSS: 5.241729
# EPOCH 51 TOTAL TRAINING LOSS: 5.394065
# EPOCH 52 TOTAL TRAINING LOSS: 4.650525
# EPOCH 53 TOTAL TRAINING LOSS: 5.196774
# EPOCH 54 TOTAL TRAINING LOSS: 5.029403
# EPOCH 55 TOTAL TRAINING LOSS: 4.683924
# EPOCH 56 TOTAL TRAINING LOSS: 4.702929
# EPOCH 57 TOTAL TRAINING LOSS: 4.704359
# EPOCH 58 TOTAL TRAINING LOSS: 4.992829
# EPOCH 59 TOTAL TRAINING LOSS: 5.311026
# EPOCH 60 TOTAL TRAINING LOSS: 5.050098
# EPOCH 61 TOTAL TRAINING LOSS: 4.484537
# EPOCH 62 TOTAL TRAINING LOSS: 4.265566
# EPOCH 63 TOTAL TRAINING LOSS: 4.813010
# EPOCH 64 TOTAL TRAINING LOSS: 4.498364
# EPOCH 65 TOTAL TRAINING LOSS: 4.316538
# EPOCH 66 TOTAL TRAINING LOSS: 4.797737
# EPOCH 67 TOTAL TRAINING LOSS: 4.654773
# EPOCH 68 TOTAL TRAINING LOSS: 4.759837
# EPOCH 69 TOTAL TRAINING LOSS: 4.657483
# EPOCH 70 TOTAL TRAINING LOSS: 4.879526
# EPOCH 71 TOTAL TRAINING LOSS: 4.728481
# EPOCH 72 TOTAL TRAINING LOSS: 4.792204
# EPOCH 73 TOTAL TRAINING LOSS: 4.626693
# EPOCH 74 TOTAL TRAINING LOSS: 4.528616
# EPOCH 75 TOTAL TRAINING LOSS: 5.091727
# EPOCH 76 TOTAL TRAINING LOSS: 4.671016
# EPOCH 77 TOTAL TRAINING LOSS: 4.621160
# EPOCH 78 TOTAL TRAINING LOSS: 4.658020
# EPOCH 79 TOTAL TRAINING LOSS: 5.172480
# EPOCH 80 TOTAL TRAINING LOSS: 5.047607
# EPOCH 81 TOTAL TRAINING LOSS: 4.186696
# EPOCH 82 TOTAL TRAINING LOSS: 4.499500
# EPOCH 83 TOTAL TRAINING LOSS: 4.512029
# EPOCH 84 TOTAL TRAINING LOSS: 4.821466
# EPOCH 85 TOTAL TRAINING LOSS: 4.588920
# EPOCH 86 TOTAL TRAINING LOSS: 4.995851
# EPOCH 87 TOTAL TRAINING LOSS: 4.484634
# EPOCH 88 TOTAL TRAINING LOSS: 4.256729
# EPOCH 89 TOTAL TRAINING LOSS: 4.326362
# EPOCH 90 TOTAL TRAINING LOSS: 4.492225
# EPOCH 91 TOTAL TRAINING LOSS: 4.457099
# EPOCH 92 TOTAL TRAINING LOSS: 4.248242
# EPOCH 93 TOTAL TRAINING LOSS: 4.268421
# EPOCH 94 TOTAL TRAINING LOSS: 3.937610
# EPOCH 95 TOTAL TRAINING LOSS: 4.411489
# EPOCH 96 TOTAL TRAINING LOSS: 3.573597
# EPOCH 97 TOTAL TRAINING LOSS: 4.751286
# EPOCH 98 TOTAL TRAINING LOSS: 4.506847
# EPOCH 99 TOTAL TRAINING LOSS: 3.710837
# EPOCH 100 TOTAL TRAINING LOSS: 3.91819
# EPOCH 101 TOTAL TRAINING LOSS: 4.078185
# EPOCH 102 TOTAL TRAINING LOSS: 4.691065
# EPOCH 103 TOTAL TRAINING LOSS: 4.763146
# EPOCH 104 TOTAL TRAINING LOSS: 4.060583
# EPOCH 105 TOTAL TRAINING LOSS: 4.835152
# EPOCH 106 TOTAL TRAINING LOSS: 4.501466
# EPOCH 107 TOTAL TRAINING LOSS: 4.798341
# EPOCH 108 TOTAL TRAINING LOSS: 4.760299
# EPOCH 109 TOTAL TRAINING LOSS: 4.151582
# EPOCH 110 TOTAL TRAINING LOSS: 4.715034
# EPOCH 111 TOTAL TRAINING LOSS: 4.059803
# EPOCH 112 TOTAL TRAINING LOSS: 4.850429
# EPOCH 113 TOTAL TRAINING LOSS: 4.672574
# EPOCH 114 TOTAL TRAINING LOSS: 3.925517
# EPOCH 115 TOTAL TRAINING LOSS: 3.995438
# EPOCH 116 TOTAL TRAINING LOSS: 4.304690
# EPOCH 117 TOTAL TRAINING LOSS: 4.290391
# EPOCH 118 TOTAL TRAINING LOSS: 4.009590
# EPOCH 119 TOTAL TRAINING LOSS: 4.494030
# EPOCH 120 TOTAL TRAINING LOSS: 4.909777
# EPOCH 121 TOTAL TRAINING LOSS: 4.670163
# EPOCH 122 TOTAL TRAINING LOSS: 4.390109
# EPOCH 123 TOTAL TRAINING LOSS: 5.035102
# EPOCH 124 TOTAL TRAINING LOSS: 4.392254
# EPOCH 125 TOTAL TRAINING LOSS: 5.058948
# EPOCH 126 TOTAL TRAINING LOSS: 3.930241
# EPOCH 127 TOTAL TRAINING LOSS: 4.749751
# EPOCH 128 TOTAL TRAINING LOSS: 4.326221
# EPOCH 129 TOTAL TRAINING LOSS: 4.915534
# EPOCH 130 TOTAL TRAINING LOSS: 4.357163
# EPOCH 131 TOTAL TRAINING LOSS: 4.115075
# EPOCH 132 TOTAL TRAINING LOSS: 4.644681
# EPOCH 133 TOTAL TRAINING LOSS: 4.436353
# EPOCH 134 TOTAL TRAINING LOSS: 4.351447
# EPOCH 135 TOTAL TRAINING LOSS: 4.107771
# EPOCH 136 TOTAL TRAINING LOSS: 4.443731
# EPOCH 137 TOTAL TRAINING LOSS: 4.333225
# EPOCH 138 TOTAL TRAINING LOSS: 4.651220
# EPOCH 139 TOTAL TRAINING LOSS: 3.828824
# EPOCH 140 TOTAL TRAINING LOSS: 4.185559
# EPOCH 141 TOTAL TRAINING LOSS: 4.091596
# EPOCH 142 TOTAL TRAINING LOSS: 4.173582
# EPOCH 143 TOTAL TRAINING LOSS: 4.777068
# EPOCH 144 TOTAL TRAINING LOSS: 4.653100
# EPOCH 145 TOTAL TRAINING LOSS: 3.904725
# EPOCH 146 TOTAL TRAINING LOSS: 4.161021
# EPOCH 147 TOTAL TRAINING LOSS: 4.131245
# EPOCH 148 TOTAL TRAINING LOSS: 4.049463
# EPOCH 149 TOTAL TRAINING LOSS: 5.106592
# EPOCH 150 TOTAL TRAINING LOSS: 4.235633
# EPOCH 150 TOTAL VALIDATION LOSS: 5.7648

# %%
run_name = build_run_name(
    model=clm,
    epochs=EPOCHS_II,
    base_lr=base_lr_II,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_II_class,
    scheduler_cfg=scheduler_II_cfg,
    contrastive_loss_cfg=None,
    modality_list=list(name_emb_dict.keys())
)

# %%
get_cv_results(reg_dict, clf_dict, 'old_noFoundation_' + run_name, time=runtime, save=True)
# Out:
#                                                  run  n_folds        time  \
# 0  old_noFoundation_ClinicalLinkageModule_E150_lr...       30  279.297293
#
#    low_rmse_os  avg_rmse_os  up_rmse_os  low_rmse_pfs  avg_rmse_pfs  \
# 0     1.279292     1.325066    1.377163      1.196924      1.240193
#
#    up_rmse_pfs  low_f1_recurrency  avg_f1_recurrency  up_f1_recurrency  \
# 0     1.284832            0.50105           0.518253          0.535274
#
#    low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  sum_reg_avg  sum_clf_avg  \
# 0     0.357322     0.389514    0.416228     2.565259     0.907767
#
#    sum_reg_ci_relative_width  sum_clf_ci_relative_width
# 0                   0.144744                   0.217266

# %% [markdown]
# ## **Results**

# %%
evaluations = {}
for task in cv_scores.keys():
    evaluations[task] = np.mean(cv_scores[task])
    print(f"MCCV score on task {task}: {evaluations[task]}")
# Out:
# MCCV score on task os: 1.3250661651293436
# MCCV score on task pfs: 1.240192969640096
# MCCV score on task recurrency: 0.5182529940225069
# MCCV score on task mgmt: 0.38951444322746914

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf")

# %% [markdown]
# ## Save ClinicalLinkageModule

# %%
save_model(clm, '../saved_models/old_noFoundation_clm.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/old_noFoundation_clm.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_noFoundation_clm.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/old_noFoundation_clm.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_noFoundation_clm.ckpt'))
