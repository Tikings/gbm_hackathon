# %% [markdown]
# # Evaluation of the old framework

# %%
import sys
import os

project_path = "/home/sagemaker-user/gbm_hackathon"
if project_path not in sys.path:
    sys.path.append(project_path)
    print(sys.path)
# Out:
# ['/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python310.zip', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/lib-dynload', '', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/site-packages', '/home/sagemaker-user/gbm_hackathon']

# %%
# %load_ext autoreload
# %autoreload 2

from gbmhackathon.training.predictive import *
from gbmhackathon.models.mme import MultiModalEncoder, ClinicalLinkageModule, concat_modality_embeddings
from gbmhackathon.utils.loss_functions import InfoNCELoss, RegularizedInfoNCELoss, SmoothingFunction, RankMe, make_patient_map, RegularizationModule
from gbmhackathon.utils.module_functions import instantiate
from gbmhackathon.utils.model_saving import *
from gbmhackathon.training.loops import modality_wise_contrastive_learning, new_predictive_learning, build_run_name
from gbmhackathon.training.cv import *
from gbmhackathon.utils.analysis import *
from gbmhackathon.viz.viz_experiment import *
from gbmhackathon.s3_loader import load_s3

import os, time
from copy import deepcopy
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
# To investigate gradients
from torchviz import make_dot

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
torch.set_num_threads(32)
torch.get_num_threads()
# Out:
# 32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %% [markdown]
# ## Dataset preparation

# %%
ALL_POSSIBLE_EMBS = ["025-03-22_12-27_phikon_emb_V1.pkl",
                    "2025-03-23_18-32_spatial_emb_V1.pkl",
                    "2025-03-30_14-23_clinical_emb_V1.pkl",
                    "2025-04-05_13-40_wes_emb_V1.pkl",
                    "2025-04-26_16-02_connectivities_spatial_V1.pkl",
                    "2025-05-03_10-15_bulk_emb_V1.pkl",
                    "2025-05-04_02-35_scRNA_emb_V1.pkl",
                    "2025-05-25_14-36_new_clinical_emb_V1.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_mds.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_pca.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_umap.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_mds.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_pca.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_umap.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_mds.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_pca.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_umap.pkl",
                    "2025-06-01_15-11_wes_emb_V1_mds.pkl",
                    "2025-06-01_15-11_wes_emb_V1_pca.pkl",
                    "2025-06-01_15-11_wes_emb_V1_umap.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_mds.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_pca.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_umap.pkl",
                    "2025-06-01_21-03_raw_spatial_emb_pca.pkl",
                    "2025-06-01_22-10_raw_spatial_emb_umap.pkl",
                    "2025-06-02_21-09_raw_scRNA_emb_pca.pkl",
                    "2025-06-02_22-50_raw_scRNA_emb_umap.pkl",
                    "embeddings_HnE_OptimusH0.pkl"]

# %% [markdown]
# ### You can choose any embedding from the above

# %%
name_emb_dict = {"hne":"embeddings_HnE_OptimusH0.pkl",
"spatial":"2025-03-23_18-32_spatial_emb_V1.pkl",
"clinical":"2025-05-25_14-36_new_clinical_emb_V1.pkl",
"wes":"2025-04-05_13-40_wes_emb_V1.pkl",
"bulk":"2025-05-03_10-15_bulk_emb_V1.pkl",
"scRNA":"2025-05-04_02-35_scRNA_emb_V1.pkl"
                }
pkl_storage_folder = "embedding_V1"

# %%
dataset = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=1.0, normalize=True)
print(f"Dataset size: {len(dataset)}")
BATCH_SIZE = 742 #582
dataloader = DataLoader(dataset, BATCH_SIZE, shuffle=True, collate_fn=collate_predictive, generator=torch.Generator(device=dataset.device))
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# Normalization applied successfully
# By keeping 100.00% of dropout augmented samples we went from:
# 628 dropout samples (84.64% dropout in dataset) -- to --> 628 dropout samples (84.64% dropout in dataset)
# Dataset size: 742

# %% [markdown]
# ### To make a batch of True patient samples only (no dropout)

# %%
# Batch of all true samples (no dropout augmented samples)
batch_all = [dataset.__getitem__(idx) for idx in dataset.ind2patient if 'd' not in dataset.ind2patient[idx]]
batch_all = collate_predictive(batch_all)

# %% [markdown]
# ### Needed to know the size of the inputs (it is used later on to define model configurations)

# %%
raw_emb = next(iter(dataloader))[2]
inpute_size_dict = {}
for mod in raw_emb.keys():
    print(mod, raw_emb[mod].size())
    inpute_size_dict[mod] = raw_emb[mod].size(1)
# Out:
# hne torch.Size([742, 1536])
# spatial torch.Size([742, 64])
# clinical torch.Size([742, 20])
# wes torch.Size([742, 1790])
# bulk torch.Size([742, 3072])
# scRNA torch.Size([742, 3072])

# %% [markdown]
# ### Patient map is used by the contrastive loss to identify dropout and true samples which are from the same original patient

# %%
patient_map = make_patient_map(dataset)

# %% [markdown]
# ### Configuration of the MultiModalEncoder (see gbmhackathon/models/mme.py)

# %%
def adapt_base_config(base_cfg, input_size):
    base_copy = deepcopy(base_cfg)
    base_copy["layers"] = [input_size] + base_copy["layers"]
    return base_copy

# %%
out = 32
norm_fn = nn.BatchNorm1d
smoothing_fn = SmoothingFunction(bound=-50, slope=0.1, rate=-5)
dropout = 0.3
layers = [1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
base_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

hne_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

clinical_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

spatial_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

wes_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

rna_cfg = {"layers": [1024,256,out], #[1024,128,512,128,out],
        "dropout": dropout,
        "act_fn":act_fn, #[nn.GELU, nn.GELU, nn.GELU, nn.GELU, smoothing_fn],
        "norm_layer":norm_fn,
        "device":device}


hne_cfg = adapt_base_config(hne_cfg, inpute_size_dict["hne"])
clinical_cfg = adapt_base_config(clinical_cfg, inpute_size_dict["clinical"])
spatial_cfg = adapt_base_config(spatial_cfg, inpute_size_dict["spatial"])
wes_cfg = adapt_base_config(wes_cfg, inpute_size_dict["wes"])
bulk_cfg = adapt_base_config(rna_cfg, inpute_size_dict["bulk"])
sc_cfg = adapt_base_config(rna_cfg, inpute_size_dict["scRNA"])

# %%
mme_bulk_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": bulk_cfg}

mme_hne_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": hne_cfg}

mme_sc_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": sc_cfg}

mme_wes_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": wes_cfg}

mme_clinical_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": clinical_cfg}

mme_spatial_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": spatial_cfg}

# %%
mme_cfg = {"hne_cfg":mme_hne_cfg, 
           "clinical_cfg":mme_clinical_cfg, 
           "wes_cfg":mme_wes_cfg, 
           "spatial_cfg":mme_spatial_cfg,
           "bulk_cfg":mme_bulk_cfg,
          "sc_cfg":mme_sc_cfg}

# %% [markdown]
# ### Configuration of the Regularizer (see gbmhackathon/models/mme.py)

# %%
regularizer_cfg = {"reg_coeff":0.01,
        "use_variance":True,
        "var_coeff":1.0,
        "use_covariance":True,
        "cov_coeff":1.0,
        "var_gamma":1.0,
        "var_eps":1e-4,
}

# %% [markdown]
# ### Instantiation of training settings: model, optimizer, scheduler, epochs, learning rate.

# %%
mme = instantiate(mme_cfg,MultiModalEncoder)

EPOCHS_I = 50
base_lr_I = 1e-3
eta_min_coef = 0.05
scheduler_I_class = torch.optim.lr_scheduler.CosineAnnealingLR
scheduler_I_cfg = {"T_max":EPOCHS_I,
                  "eta_min":"dynamic"}

contrastive_loss_cfg = {"modalities":list(name_emb_dict.keys()),
                        "patient_map":patient_map,
                        'mode':'patient_scale', #
                        "temperature":0.05,
                        "similarity":'nt-xent',
                        "use_all_positives":False,
                        "alpha":0,
                        "bound":-50,
                        "slope":0.1,
                        "rate":-5,
                        "warn":False,
                       "smoothing_func":False}

# Optimization for Phase I
optimizer_I = Adam(mme.parameters(), lr=base_lr_I)
scheduler_I_cfg["optimizer"] = optimizer_I
if "eta_min" in scheduler_I_cfg.keys():
    if scheduler_I_cfg["eta_min"] == "dynamic":
        scheduler_I_cfg["eta_min"] = eta_min_coef * base_lr_I
scheduler_I = instantiate(scheduler_I_cfg, scheduler_I_class)

contrastive_loss_fn = instantiate(contrastive_loss_cfg, RegularizedInfoNCELoss)

modalities = next(iter(dataloader))[2].keys()
    
# A contrastive loss module per modality
modality_contrastive_loss_fn = {}
for modality in modalities:
    contrastive_loss_cfg_mod = contrastive_loss_cfg.copy()
    contrastive_loss_cfg_mod['modalities'] = [modality]
    modality_contrastive_loss_fn[modality] = instantiate(contrastive_loss_cfg_mod, RegularizedInfoNCELoss)

# An optimizer per modality
modality_optimizers = {modality:Adam(mme.modality_net_map[modality].parameters(), lr=base_lr_I) for modality in modalities}

# A scheduler per modality
modality_schedulers = {}
for modality in modalities:
    # Same schedule for all modalities for now, but it can be configurable
    scheduler_cfg = scheduler_I_cfg.copy()
    scheduler_cfg["optimizer"] = modality_optimizers[modality]
    if "eta_min" in scheduler_I_cfg.keys():
        if scheduler_cfg["eta_min"] == "dynamic":
            scheduler_cfg["eta_min"] = eta_min_coef * base_lr_I
    modality_schedulers[modality] = instantiate(scheduler_cfg, scheduler_I_class)

# A regularization method per modality
regularizer_dict = {}
for modality in modalities:
    regularizer_dict[modality] = instantiate(regularizer_cfg, RegularizationModule)
# Out:
# {'net_type': 'mlp', 'device': 'cuda', 'net_config': {'layers': [1536, 512, 128, 32], 'dropout': 0.3, 'act_fn': [<class 'torch.nn.modules.activation.GELU'>, <class 'torch.nn.modules.activation.GELU'>, None], 'norm_layer': <class 'torch.nn.modules.batchnorm.BatchNorm1d'>, 'device': 'cuda'}}
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found

# %% [markdown]
# ### Training loop for contrastive phase

# %%
modality_wise_contrastive_learning(mme, 
                                   dataloader, 
                                   EPOCHS_I, 
                                   base_lr_I,
                                   modality_optimizers, 
                                   modality_contrastive_loss_fn, 
                                   modality_schedulers,
                                   regularizer_dict,
                                   batch_all=batch_all,
                                   make_gifs=False,
                                   analyze_emb=True)
# Out:
# EPOCH 1 AVERAGE TOTAL LOSS ACROSS MODALITIES: 9.8095
# EPOCH 2 AVERAGE TOTAL LOSS ACROSS MODALITIES: 8.5011
# EPOCH 3 AVERAGE TOTAL LOSS ACROSS MODALITIES: 7.3013
# EPOCH 4 AVERAGE TOTAL LOSS ACROSS MODALITIES: 6.6154
# EPOCH 5 AVERAGE TOTAL LOSS ACROSS MODALITIES: 6.1859
# EPOCH 6 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.8908
# EPOCH 7 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.6794
# EPOCH 8 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.5217
# EPOCH 9 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.3994
# EPOCH 10 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.3010
# EPOCH 11 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.2198
# EPOCH 12 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.1509
# EPOCH 13 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.0906
# EPOCH 14 AVERAGE TOTAL LOSS ACROSS MODALITIES: 5.0373
# EPOCH 15 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.9898
# EPOCH 16 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.9471
# EPOCH 17 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.9084
# EPOCH 18 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.8734
# EPOCH 19 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.8411
# EPOCH 20 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.8112
# EPOCH 21 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.7835
# EPOCH 22 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.7578
# EPOCH 23 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.7339
# EPOCH 24 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.7118
# EPOCH 25 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6907
# EPOCH 26 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6710
# EPOCH 27 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6525
# EPOCH 28 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6362
# EPOCH 29 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6225
# EPOCH 30 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.6087
# EPOCH 31 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5952
# EPOCH 32 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5818
# EPOCH 33 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5698
# EPOCH 34 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5578
# EPOCH 35 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5462
# EPOCH 36 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5353
# EPOCH 37 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5248
# EPOCH 38 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5146
# EPOCH 39 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5048
# EPOCH 40 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4958
# EPOCH 41 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4868
# EPOCH 42 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4782
# EPOCH 43 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4701
# EPOCH 44 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4624
# EPOCH 45 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4547
# EPOCH 46 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4475
# EPOCH 47 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4406
# EPOCH 48 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4339
# EPOCH 49 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4274
# EPOCH 50 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4212

# %% [markdown]
# ## Save MultiModalEncoder

# %%
save_model(mme, '../saved_models/old_framework_mme.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/old_framework_mme.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_framework_mme.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/old_framework_mme.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_framework_mme.ckpt'))

# %% [markdown]
# ## Use the trained MME to compute and save representations of true patient samples to use for the clinical linkage phase

# %%
run_name = build_run_name(
    model=mme,
    epochs=EPOCHS_I,
    base_lr=base_lr_I,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_I_class,
    scheduler_cfg=scheduler_I_cfg,
    contrastive_loss_cfg=contrastive_loss_cfg,
    modality_list=list(name_emb_dict.keys())
)

# %%
mme_emb_dict = mme(batch_all[2]) # Retrieves X_dict
folder = "mme_embeddings_old_framework"
save_path = f"{folder}/{run_name}.pkl"
os.makedirs(folder, exist_ok=True)

with open(save_path, "wb") as f:
    pkl.dump(mme_emb_dict, f)

# %% [markdown]
# # Set everything up for clinical linkage phase
# We can choose to remove dropout or not by instantiating another dataset

# %%
dataset_II = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=0.0, normalize=True)
print(f"Dataset size: {len(dataset_II)}")
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# Normalization applied successfully
# Dataset size: 114

# %% [markdown]
# ### Configuration of the clinical linkage module

# %%
dropout = 0.3
layers = [out*len(mme_cfg),16]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
norm_fn = nn.BatchNorm1d
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
# ATTENTION !!!! MUST BE THIS EXACT ORDER FOR PREDICTIVE TASKS: 
# ['os_years', 'pfs_years', 'largest_diameter_of_the_primary_tumour_mm_duplicated_0', 'recurrent_sample']
# OR ['os_years', 'pfs_years', 'recurrent_sample', 'mgmt_promoter_methylation'] if using latest targets
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

clf_targets = ['recurrency', 'mgmt']
clf_targets_dict = {'recurrency':2, 'mgmt':3}

# %% [markdown]
# ### No RefinementBlock in this framework originally

# %%
# refinement_cfg = {"emb_size": out*len(mme_cfg),
#                 "cross_modality_heads": 1,
#                 "cross_mods_fc_size": 1024,
#                 "avail_mods_fc_size": 128,
#                 "avail_mods_len":len(mme_cfg),
#                 "avail_mods_dense_size": 32,
#                 "avail_mods_heads": 1,
#                 "act_fn": nn.GELU,
#                 "dropout": dropout,
#                 "device": device}
refinement_cfg = None

# %% [markdown]
# # Monte Carlo Cross Validation
# Instantiation must be done for each fold

# %%
n_splits = 30
test_size = 0.8
t_batch = 32 # training batch size
v_batch = 256 # evaluation batch size
random_state = 6262

# %%
cv_scores = {task:[] for task in predictive_cfg["heads_configs"].keys()}
t0 = time.time()
for train_loader, val_loader in get_mccv_loaders(dataset_II, 
                                                 collate_predictive,
                                                 n_splits=n_splits, 
                                                 test_size=test_size, 
                                                 train_batch_size=t_batch, 
                                                 val_batch_size=v_batch, 
                                                 device=device, 
                                                 random_state=random_state):
    EPOCHS_II = 150
    base_lr_II = 1e-4
    scheduler_II_class = torch.optim.lr_scheduler.CosineAnnealingLR
    scheduler_II_cfg = {"T_max":EPOCHS_II,
                        "eta_min":"dynamic"}
    clm = ClinicalLinkageModule(refinement_cfg=refinement_cfg,
                            predictive_cfg=predictive_cfg)
    # Optimization for Phase II
    optimizer_II = Adam(clm.parameters(), lr=base_lr_II)
    scheduler_II_cfg["optimizer"] = optimizer_II
    if "eta_min" in scheduler_II_cfg.keys():
        if scheduler_II_cfg["eta_min"] == "dynamic":
            scheduler_II_cfg["eta_min"] = eta_min_coef * base_lr_II
    scheduler_II = instantiate(scheduler_II_cfg, scheduler_II_class)

    # Training loop with validation at the end of each epoch on the validation set
    new_predictive_learning(mme, clm, 
                          train_loader,
                          EPOCHS_II, 
                          base_lr_II, 
                          optimizer_II,
                          scheduler_II,
                          clf_targets_dict,
                          v_dataloader=val_loader,
                          reg_loss_fn = nn.MSELoss(),
                          clf_loss_fn = nn.CrossEntropyLoss(),
                          batch_all=batch_all, # No worries, it is used in eval mode under the hood so not seen by model
                          make_gifs=False,
                          )
    # Evaluation metrics are computed on the validation set after training.
    clm.eval()
    all_val_predictions = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    all_val_targets = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    for batch in val_loader:
        patient_ids, modalities, X_dict, avail_mods, batch_targets, targets_names = batch
        
        contrastive_outputs = mme(X_dict)
        task_outputs, patient_embeddings = clm(contrastive_outputs, avail_mods)
        
        overall_loss = torch.tensor(0, device=device)
        # Regression losses
        for i, key in enumerate(task_outputs.keys()):
            if key not in clf_targets:
                all_val_predictions[key].append(task_outputs[key].squeeze())
                all_val_targets[key].append(batch_targets[:,i])
            
        # Classification losses
        for i, key in enumerate(clf_targets):
            if i == 0:
                start_idx = len(task_outputs.keys()) - len(clf_targets)
            else:
                start_idx = end_idx - 1 # last end_idx
            # clf_targets_dict is a dict that maps each clf target to the number of classes it holds
            end_idx = start_idx + clf_targets_dict[key]
            all_val_predictions[key].append(task_outputs[key])
            all_val_targets[key].append(batch_targets[:,start_idx:end_idx])
            
    for task in all_val_predictions.keys():
        all_task_pred = torch.cat(all_val_predictions[task], dim=0).to(dataset.device)
        all_task_true = torch.cat(all_val_targets[task], dim=0).to(dataset.device)
        if task not in clf_targets:
            score = torch.sqrt(nn.MSELoss()(all_task_pred, all_task_true)).item()
        else:
            score = f1_score(torch.argmax(all_task_true, dim=1).cpu().detach().numpy(), 
                             torch.argmax(all_task_pred, dim=1).cpu().detach().numpy(), 
                             average='weighted', zero_division=0)
        cv_scores[task].append(score)
reg_dict = {key:val for key, val in cv_scores.items() if key in ['os', 'pfs']}
clf_dict = {key:val for key, val in cv_scores.items() if key in clf_targets}
runtime = time.time() - t0
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.9803
# EPOCH 2 TOTAL TRAINING LOSS: 6.128773
# EPOCH 3 TOTAL TRAINING LOSS: 5.651278
# EPOCH 4 TOTAL TRAINING LOSS: 5.486963
# EPOCH 5 TOTAL TRAINING LOSS: 5.491268
# EPOCH 6 TOTAL TRAINING LOSS: 5.673586
# EPOCH 7 TOTAL TRAINING LOSS: 5.751283
# EPOCH 8 TOTAL TRAINING LOSS: 5.556713
# EPOCH 9 TOTAL TRAINING LOSS: 5.063918
# EPOCH 10 TOTAL TRAINING LOSS: 5.35001
# EPOCH 11 TOTAL TRAINING LOSS: 4.964272
# EPOCH 12 TOTAL TRAINING LOSS: 5.247193
# EPOCH 13 TOTAL TRAINING LOSS: 5.055637
# EPOCH 14 TOTAL TRAINING LOSS: 5.267474
# EPOCH 15 TOTAL TRAINING LOSS: 5.506199
# EPOCH 16 TOTAL TRAINING LOSS: 4.660654
# EPOCH 17 TOTAL TRAINING LOSS: 5.352924
# EPOCH 18 TOTAL TRAINING LOSS: 5.064087
# EPOCH 19 TOTAL TRAINING LOSS: 4.965573
# EPOCH 20 TOTAL TRAINING LOSS: 4.932475
# EPOCH 21 TOTAL TRAINING LOSS: 4.789559
# EPOCH 22 TOTAL TRAINING LOSS: 4.918575
# EPOCH 23 TOTAL TRAINING LOSS: 5.382926
# EPOCH 24 TOTAL TRAINING LOSS: 5.002988
# EPOCH 25 TOTAL TRAINING LOSS: 4.830223
# EPOCH 26 TOTAL TRAINING LOSS: 4.693787
# EPOCH 27 TOTAL TRAINING LOSS: 4.870569
# EPOCH 28 TOTAL TRAINING LOSS: 4.805047
# EPOCH 29 TOTAL TRAINING LOSS: 4.919053
# EPOCH 30 TOTAL TRAINING LOSS: 4.903419
# EPOCH 31 TOTAL TRAINING LOSS: 4.426773
# EPOCH 32 TOTAL TRAINING LOSS: 5.025262
# EPOCH 33 TOTAL TRAINING LOSS: 4.917174
# EPOCH 34 TOTAL TRAINING LOSS: 4.931991
# EPOCH 35 TOTAL TRAINING LOSS: 4.969350
# EPOCH 36 TOTAL TRAINING LOSS: 4.905563
# EPOCH 37 TOTAL TRAINING LOSS: 4.815746
# EPOCH 38 TOTAL TRAINING LOSS: 4.657361
# EPOCH 39 TOTAL TRAINING LOSS: 4.927744
# EPOCH 40 TOTAL TRAINING LOSS: 5.072119
# EPOCH 41 TOTAL TRAINING LOSS: 4.384340
# EPOCH 42 TOTAL TRAINING LOSS: 4.432103
# EPOCH 43 TOTAL TRAINING LOSS: 4.311357
# EPOCH 44 TOTAL TRAINING LOSS: 4.830945
# EPOCH 45 TOTAL TRAINING LOSS: 4.830003
# EPOCH 46 TOTAL TRAINING LOSS: 4.780967
# EPOCH 47 TOTAL TRAINING LOSS: 4.926674
# EPOCH 48 TOTAL TRAINING LOSS: 4.862517
# EPOCH 49 TOTAL TRAINING LOSS: 4.597530
# EPOCH 50 TOTAL TRAINING LOSS: 4.903984
# EPOCH 51 TOTAL TRAINING LOSS: 4.535744
# EPOCH 52 TOTAL TRAINING LOSS: 3.791713
# EPOCH 53 TOTAL TRAINING LOSS: 4.237591
# EPOCH 54 TOTAL TRAINING LOSS: 4.366886
# EPOCH 55 TOTAL TRAINING LOSS: 4.110501
# EPOCH 56 TOTAL TRAINING LOSS: 4.341610
# EPOCH 57 TOTAL TRAINING LOSS: 4.650116
# EPOCH 58 TOTAL TRAINING LOSS: 4.334764
# EPOCH 59 TOTAL TRAINING LOSS: 4.085903
# EPOCH 60 TOTAL TRAINING LOSS: 4.058242
# EPOCH 61 TOTAL TRAINING LOSS: 4.203906
# EPOCH 62 TOTAL TRAINING LOSS: 4.086932
# EPOCH 63 TOTAL TRAINING LOSS: 3.994662
# EPOCH 64 TOTAL TRAINING LOSS: 3.873294
# EPOCH 65 TOTAL TRAINING LOSS: 3.994194
# EPOCH 66 TOTAL TRAINING LOSS: 4.031166
# EPOCH 67 TOTAL TRAINING LOSS: 4.181503
# EPOCH 68 TOTAL TRAINING LOSS: 4.020836
# EPOCH 69 TOTAL TRAINING LOSS: 4.175027
# EPOCH 70 TOTAL TRAINING LOSS: 4.339164
# EPOCH 71 TOTAL TRAINING LOSS: 4.203908
# EPOCH 72 TOTAL TRAINING LOSS: 4.240718
# EPOCH 73 TOTAL TRAINING LOSS: 4.345779
# EPOCH 74 TOTAL TRAINING LOSS: 4.147405
# EPOCH 75 TOTAL TRAINING LOSS: 4.366225
# EPOCH 76 TOTAL TRAINING LOSS: 4.379460
# EPOCH 77 TOTAL TRAINING LOSS: 4.355751
# EPOCH 78 TOTAL TRAINING LOSS: 3.974571
# EPOCH 79 TOTAL TRAINING LOSS: 4.109838
# EPOCH 80 TOTAL TRAINING LOSS: 4.142023
# EPOCH 81 TOTAL TRAINING LOSS: 4.002095
# EPOCH 82 TOTAL TRAINING LOSS: 4.311282
# EPOCH 83 TOTAL TRAINING LOSS: 4.325376
# EPOCH 84 TOTAL TRAINING LOSS: 4.152818
# EPOCH 85 TOTAL TRAINING LOSS: 3.777053
# EPOCH 86 TOTAL TRAINING LOSS: 4.202854
# EPOCH 87 TOTAL TRAINING LOSS: 3.590172
# EPOCH 88 TOTAL TRAINING LOSS: 3.942612
# EPOCH 89 TOTAL TRAINING LOSS: 4.259431
# EPOCH 90 TOTAL TRAINING LOSS: 4.297651
# EPOCH 91 TOTAL TRAINING LOSS: 4.094345
# EPOCH 92 TOTAL TRAINING LOSS: 3.699501
# EPOCH 93 TOTAL TRAINING LOSS: 3.898335
# EPOCH 94 TOTAL TRAINING LOSS: 3.780600
# EPOCH 95 TOTAL TRAINING LOSS: 3.825490
# EPOCH 96 TOTAL TRAINING LOSS: 3.962202
# EPOCH 97 TOTAL TRAINING LOSS: 3.577768
# EPOCH 98 TOTAL TRAINING LOSS: 4.446597
# EPOCH 99 TOTAL TRAINING LOSS: 4.041884
# EPOCH 100 TOTAL TRAINING LOSS: 4.44401
# EPOCH 101 TOTAL TRAINING LOSS: 4.261750
# EPOCH 102 TOTAL TRAINING LOSS: 4.091291
# EPOCH 103 TOTAL TRAINING LOSS: 4.113393
# EPOCH 104 TOTAL TRAINING LOSS: 4.077906
# EPOCH 105 TOTAL TRAINING LOSS: 3.750232
# EPOCH 106 TOTAL TRAINING LOSS: 3.948955
# EPOCH 107 TOTAL TRAINING LOSS: 3.855982
# EPOCH 108 TOTAL TRAINING LOSS: 3.509334
# EPOCH 109 TOTAL TRAINING LOSS: 4.325382
# EPOCH 110 TOTAL TRAINING LOSS: 3.170082
# EPOCH 111 TOTAL TRAINING LOSS: 4.188848
# EPOCH 112 TOTAL TRAINING LOSS: 3.772691
# EPOCH 113 TOTAL TRAINING LOSS: 3.551380
# EPOCH 114 TOTAL TRAINING LOSS: 4.024194
# EPOCH 115 TOTAL TRAINING LOSS: 3.961379
# EPOCH 116 TOTAL TRAINING LOSS: 3.936097
# EPOCH 117 TOTAL TRAINING LOSS: 3.492069
# EPOCH 118 TOTAL TRAINING LOSS: 4.071392
# EPOCH 119 TOTAL TRAINING LOSS: 3.412434
# EPOCH 120 TOTAL TRAINING LOSS: 3.707462
# EPOCH 121 TOTAL TRAINING LOSS: 3.997550
# EPOCH 122 TOTAL TRAINING LOSS: 4.187865
# EPOCH 123 TOTAL TRAINING LOSS: 3.648726
# EPOCH 124 TOTAL TRAINING LOSS: 3.611896
# EPOCH 125 TOTAL TRAINING LOSS: 4.149296
# EPOCH 126 TOTAL TRAINING LOSS: 4.118283
# EPOCH 127 TOTAL TRAINING LOSS: 3.481858
# EPOCH 128 TOTAL TRAINING LOSS: 3.587584
# EPOCH 129 TOTAL TRAINING LOSS: 4.486386
# EPOCH 130 TOTAL TRAINING LOSS: 3.839844
# EPOCH 131 TOTAL TRAINING LOSS: 3.961872
# EPOCH 132 TOTAL TRAINING LOSS: 4.064155
# EPOCH 133 TOTAL TRAINING LOSS: 3.840487
# EPOCH 134 TOTAL TRAINING LOSS: 3.536503
# EPOCH 135 TOTAL TRAINING LOSS: 3.463233
# EPOCH 136 TOTAL TRAINING LOSS: 3.954984
# EPOCH 137 TOTAL TRAINING LOSS: 3.416995
# EPOCH 138 TOTAL TRAINING LOSS: 4.049801
# EPOCH 139 TOTAL TRAINING LOSS: 4.098500
# EPOCH 140 TOTAL TRAINING LOSS: 4.053222
# EPOCH 141 TOTAL TRAINING LOSS: 3.884550
# EPOCH 142 TOTAL TRAINING LOSS: 3.790843
# EPOCH 143 TOTAL TRAINING LOSS: 4.072528
# EPOCH 144 TOTAL TRAINING LOSS: 3.737237
# EPOCH 145 TOTAL TRAINING LOSS: 4.069355
# EPOCH 146 TOTAL TRAINING LOSS: 3.918437
# EPOCH 147 TOTAL TRAINING LOSS: 4.062863
# EPOCH 148 TOTAL TRAINING LOSS: 3.535107
# EPOCH 149 TOTAL TRAINING LOSS: 3.718231
# EPOCH 150 TOTAL TRAINING LOSS: 3.700027
# Using device(prediction head) : cuda608
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.2351
# EPOCH 2 TOTAL TRAINING LOSS: 5.117407
# EPOCH 3 TOTAL TRAINING LOSS: 4.568743
# EPOCH 4 TOTAL TRAINING LOSS: 5.287784
# EPOCH 5 TOTAL TRAINING LOSS: 4.857873
# EPOCH 6 TOTAL TRAINING LOSS: 5.509776
# EPOCH 7 TOTAL TRAINING LOSS: 5.708922
# EPOCH 8 TOTAL TRAINING LOSS: 5.338639
# EPOCH 9 TOTAL TRAINING LOSS: 4.502584
# EPOCH 10 TOTAL TRAINING LOSS: 4.51691
# EPOCH 11 TOTAL TRAINING LOSS: 4.286893
# EPOCH 12 TOTAL TRAINING LOSS: 4.292191
# EPOCH 13 TOTAL TRAINING LOSS: 4.528191
# EPOCH 14 TOTAL TRAINING LOSS: 4.981931
# EPOCH 15 TOTAL TRAINING LOSS: 4.394152
# EPOCH 16 TOTAL TRAINING LOSS: 4.139571
# EPOCH 17 TOTAL TRAINING LOSS: 5.087134
# EPOCH 18 TOTAL TRAINING LOSS: 4.688311
# EPOCH 19 TOTAL TRAINING LOSS: 4.047133
# EPOCH 20 TOTAL TRAINING LOSS: 4.889728
# EPOCH 21 TOTAL TRAINING LOSS: 3.986234
# EPOCH 22 TOTAL TRAINING LOSS: 3.989771
# EPOCH 23 TOTAL TRAINING LOSS: 4.080773
# EPOCH 24 TOTAL TRAINING LOSS: 4.330557
# EPOCH 25 TOTAL TRAINING LOSS: 4.075019
# EPOCH 26 TOTAL TRAINING LOSS: 4.113710
# EPOCH 27 TOTAL TRAINING LOSS: 3.543043
# EPOCH 28 TOTAL TRAINING LOSS: 3.727635
# EPOCH 29 TOTAL TRAINING LOSS: 4.199503
# EPOCH 30 TOTAL TRAINING LOSS: 4.326683
# EPOCH 31 TOTAL TRAINING LOSS: 3.939981
# EPOCH 32 TOTAL TRAINING LOSS: 4.347731
# EPOCH 33 TOTAL TRAINING LOSS: 3.925575
# EPOCH 34 TOTAL TRAINING LOSS: 4.544569
# EPOCH 35 TOTAL TRAINING LOSS: 3.494014
# EPOCH 36 TOTAL TRAINING LOSS: 4.450929
# EPOCH 37 TOTAL TRAINING LOSS: 4.328123
# EPOCH 38 TOTAL TRAINING LOSS: 3.472880
# EPOCH 39 TOTAL TRAINING LOSS: 3.971219
# EPOCH 40 TOTAL TRAINING LOSS: 3.507560
# EPOCH 41 TOTAL TRAINING LOSS: 4.083545
# EPOCH 42 TOTAL TRAINING LOSS: 3.710752
# EPOCH 43 TOTAL TRAINING LOSS: 3.984621
# EPOCH 44 TOTAL TRAINING LOSS: 3.341476
# EPOCH 45 TOTAL TRAINING LOSS: 3.532380
# EPOCH 46 TOTAL TRAINING LOSS: 3.329415
# EPOCH 47 TOTAL TRAINING LOSS: 3.427143
# EPOCH 48 TOTAL TRAINING LOSS: 3.582656
# EPOCH 49 TOTAL TRAINING LOSS: 3.284548
# EPOCH 50 TOTAL TRAINING LOSS: 3.625612
# EPOCH 51 TOTAL TRAINING LOSS: 3.545788
# EPOCH 52 TOTAL TRAINING LOSS: 3.257670
# EPOCH 53 TOTAL TRAINING LOSS: 3.450928
# EPOCH 54 TOTAL TRAINING LOSS: 4.172711
# EPOCH 55 TOTAL TRAINING LOSS: 4.239347
# EPOCH 56 TOTAL TRAINING LOSS: 3.021805
# EPOCH 57 TOTAL TRAINING LOSS: 3.286946
# EPOCH 58 TOTAL TRAINING LOSS: 2.949648
# EPOCH 59 TOTAL TRAINING LOSS: 4.067519
# EPOCH 60 TOTAL TRAINING LOSS: 3.128524
# EPOCH 61 TOTAL TRAINING LOSS: 3.621553
# EPOCH 62 TOTAL TRAINING LOSS: 3.002423
# EPOCH 63 TOTAL TRAINING LOSS: 3.516870
# EPOCH 64 TOTAL TRAINING LOSS: 3.595722
# EPOCH 65 TOTAL TRAINING LOSS: 3.280153
# EPOCH 66 TOTAL TRAINING LOSS: 3.478746
# EPOCH 67 TOTAL TRAINING LOSS: 3.394102
# EPOCH 68 TOTAL TRAINING LOSS: 3.297720
# EPOCH 69 TOTAL TRAINING LOSS: 3.355601
# EPOCH 70 TOTAL TRAINING LOSS: 3.177140
# EPOCH 71 TOTAL TRAINING LOSS: 3.045151
# EPOCH 72 TOTAL TRAINING LOSS: 3.326916
# EPOCH 73 TOTAL TRAINING LOSS: 2.932677
# EPOCH 74 TOTAL TRAINING LOSS: 3.380613
# EPOCH 75 TOTAL TRAINING LOSS: 3.331969
# EPOCH 76 TOTAL TRAINING LOSS: 3.621292
# EPOCH 77 TOTAL TRAINING LOSS: 3.048930
# EPOCH 78 TOTAL TRAINING LOSS: 3.161053
# EPOCH 79 TOTAL TRAINING LOSS: 3.090224
# EPOCH 80 TOTAL TRAINING LOSS: 3.473328
# EPOCH 81 TOTAL TRAINING LOSS: 3.212465
# EPOCH 82 TOTAL TRAINING LOSS: 3.183902
# EPOCH 83 TOTAL TRAINING LOSS: 3.632752
# EPOCH 84 TOTAL TRAINING LOSS: 3.184432
# EPOCH 85 TOTAL TRAINING LOSS: 2.952328
# EPOCH 86 TOTAL TRAINING LOSS: 3.543674
# EPOCH 87 TOTAL TRAINING LOSS: 3.098987
# EPOCH 88 TOTAL TRAINING LOSS: 3.418784
# EPOCH 89 TOTAL TRAINING LOSS: 2.906696
# EPOCH 90 TOTAL TRAINING LOSS: 2.939061
# EPOCH 91 TOTAL TRAINING LOSS: 3.226852
# EPOCH 92 TOTAL TRAINING LOSS: 2.867075
# EPOCH 93 TOTAL TRAINING LOSS: 3.184411
# EPOCH 94 TOTAL TRAINING LOSS: 3.257495
# EPOCH 95 TOTAL TRAINING LOSS: 3.378444
# EPOCH 96 TOTAL TRAINING LOSS: 2.851189
# EPOCH 97 TOTAL TRAINING LOSS: 3.504225
# EPOCH 98 TOTAL TRAINING LOSS: 2.741731
# EPOCH 99 TOTAL TRAINING LOSS: 2.751997
# EPOCH 100 TOTAL TRAINING LOSS: 2.76205
# EPOCH 101 TOTAL TRAINING LOSS: 3.384440
# EPOCH 102 TOTAL TRAINING LOSS: 3.274721
# EPOCH 103 TOTAL TRAINING LOSS: 2.865550
# EPOCH 104 TOTAL TRAINING LOSS: 3.504320
# EPOCH 105 TOTAL TRAINING LOSS: 3.359439
# EPOCH 106 TOTAL TRAINING LOSS: 3.212619
# EPOCH 107 TOTAL TRAINING LOSS: 3.071226
# EPOCH 108 TOTAL TRAINING LOSS: 3.017083
# EPOCH 109 TOTAL TRAINING LOSS: 3.235122
# EPOCH 110 TOTAL TRAINING LOSS: 3.022759
# EPOCH 111 TOTAL TRAINING LOSS: 2.949706
# EPOCH 112 TOTAL TRAINING LOSS: 3.079903
# EPOCH 113 TOTAL TRAINING LOSS: 3.135598
# EPOCH 114 TOTAL TRAINING LOSS: 2.997635
# EPOCH 115 TOTAL TRAINING LOSS: 2.887592
# EPOCH 116 TOTAL TRAINING LOSS: 2.943090
# EPOCH 117 TOTAL TRAINING LOSS: 2.898454
# EPOCH 118 TOTAL TRAINING LOSS: 3.000457
# EPOCH 119 TOTAL TRAINING LOSS: 3.075407
# EPOCH 120 TOTAL TRAINING LOSS: 2.579455
# EPOCH 121 TOTAL TRAINING LOSS: 3.260581
# EPOCH 122 TOTAL TRAINING LOSS: 2.926766
# EPOCH 123 TOTAL TRAINING LOSS: 2.859619
# EPOCH 124 TOTAL TRAINING LOSS: 2.682899
# EPOCH 125 TOTAL TRAINING LOSS: 2.870017
# EPOCH 126 TOTAL TRAINING LOSS: 3.036102
# EPOCH 127 TOTAL TRAINING LOSS: 3.178788
# EPOCH 128 TOTAL TRAINING LOSS: 3.026318
# EPOCH 129 TOTAL TRAINING LOSS: 3.163350
# EPOCH 130 TOTAL TRAINING LOSS: 2.874346
# EPOCH 131 TOTAL TRAINING LOSS: 3.658663
# EPOCH 132 TOTAL TRAINING LOSS: 2.710932
# EPOCH 133 TOTAL TRAINING LOSS: 3.122763
# EPOCH 134 TOTAL TRAINING LOSS: 3.237283
# EPOCH 135 TOTAL TRAINING LOSS: 3.108150
# EPOCH 136 TOTAL TRAINING LOSS: 3.118417
# EPOCH 137 TOTAL TRAINING LOSS: 3.352777
# EPOCH 138 TOTAL TRAINING LOSS: 2.642443
# EPOCH 139 TOTAL TRAINING LOSS: 2.842007
# EPOCH 140 TOTAL TRAINING LOSS: 3.709274
# EPOCH 141 TOTAL TRAINING LOSS: 2.813110
# EPOCH 142 TOTAL TRAINING LOSS: 3.191609
# EPOCH 143 TOTAL TRAINING LOSS: 3.297914
# EPOCH 144 TOTAL TRAINING LOSS: 3.052630
# EPOCH 145 TOTAL TRAINING LOSS: 3.138706
# EPOCH 146 TOTAL TRAINING LOSS: 3.242622
# EPOCH 147 TOTAL TRAINING LOSS: 2.784882
# EPOCH 148 TOTAL TRAINING LOSS: 2.440221
# EPOCH 149 TOTAL TRAINING LOSS: 3.083778
# EPOCH 150 TOTAL TRAINING LOSS: 3.131169
# Using device(prediction head) : cuda935
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.7324
# EPOCH 2 TOTAL TRAINING LOSS: 5.902962
# EPOCH 3 TOTAL TRAINING LOSS: 5.427500
# EPOCH 4 TOTAL TRAINING LOSS: 6.106868
# EPOCH 5 TOTAL TRAINING LOSS: 6.783539
# EPOCH 6 TOTAL TRAINING LOSS: 5.039124
# EPOCH 7 TOTAL TRAINING LOSS: 4.636318
# EPOCH 8 TOTAL TRAINING LOSS: 5.901335
# EPOCH 9 TOTAL TRAINING LOSS: 6.184843
# EPOCH 10 TOTAL TRAINING LOSS: 4.61522
# EPOCH 11 TOTAL TRAINING LOSS: 4.876525
# EPOCH 12 TOTAL TRAINING LOSS: 4.616097
# EPOCH 13 TOTAL TRAINING LOSS: 5.061990
# EPOCH 14 TOTAL TRAINING LOSS: 5.572561
# EPOCH 15 TOTAL TRAINING LOSS: 5.136857
# EPOCH 16 TOTAL TRAINING LOSS: 5.008062
# EPOCH 17 TOTAL TRAINING LOSS: 5.635290
# EPOCH 18 TOTAL TRAINING LOSS: 6.064025
# EPOCH 19 TOTAL TRAINING LOSS: 5.519897
# EPOCH 20 TOTAL TRAINING LOSS: 5.072717
# EPOCH 21 TOTAL TRAINING LOSS: 6.081916
# EPOCH 22 TOTAL TRAINING LOSS: 5.255752
# EPOCH 23 TOTAL TRAINING LOSS: 4.762038
# EPOCH 24 TOTAL TRAINING LOSS: 4.741961
# EPOCH 25 TOTAL TRAINING LOSS: 4.034230
# EPOCH 26 TOTAL TRAINING LOSS: 5.006318
# EPOCH 27 TOTAL TRAINING LOSS: 4.230231
# EPOCH 28 TOTAL TRAINING LOSS: 5.421597
# EPOCH 29 TOTAL TRAINING LOSS: 3.916617
# EPOCH 30 TOTAL TRAINING LOSS: 4.818950
# EPOCH 31 TOTAL TRAINING LOSS: 4.591749
# EPOCH 32 TOTAL TRAINING LOSS: 3.828826
# EPOCH 33 TOTAL TRAINING LOSS: 4.605391
# EPOCH 34 TOTAL TRAINING LOSS: 4.827501
# EPOCH 35 TOTAL TRAINING LOSS: 4.166739
# EPOCH 36 TOTAL TRAINING LOSS: 4.493123
# EPOCH 37 TOTAL TRAINING LOSS: 4.052936
# EPOCH 38 TOTAL TRAINING LOSS: 4.643522
# EPOCH 39 TOTAL TRAINING LOSS: 4.284178
# EPOCH 40 TOTAL TRAINING LOSS: 4.544735
# EPOCH 41 TOTAL TRAINING LOSS: 4.378255
# EPOCH 42 TOTAL TRAINING LOSS: 3.953798
# EPOCH 43 TOTAL TRAINING LOSS: 3.884746
# EPOCH 44 TOTAL TRAINING LOSS: 4.071128
# EPOCH 45 TOTAL TRAINING LOSS: 4.610303
# EPOCH 46 TOTAL TRAINING LOSS: 4.240096
# EPOCH 47 TOTAL TRAINING LOSS: 4.514634
# EPOCH 48 TOTAL TRAINING LOSS: 4.193354
# EPOCH 49 TOTAL TRAINING LOSS: 4.119401
# EPOCH 50 TOTAL TRAINING LOSS: 4.028691
# EPOCH 51 TOTAL TRAINING LOSS: 3.993690
# EPOCH 52 TOTAL TRAINING LOSS: 3.738534
# EPOCH 53 TOTAL TRAINING LOSS: 4.407865
# EPOCH 54 TOTAL TRAINING LOSS: 3.370647
# EPOCH 55 TOTAL TRAINING LOSS: 3.854190
# EPOCH 56 TOTAL TRAINING LOSS: 4.185953
# EPOCH 57 TOTAL TRAINING LOSS: 4.154496
# EPOCH 58 TOTAL TRAINING LOSS: 3.945861
# EPOCH 59 TOTAL TRAINING LOSS: 4.353764
# EPOCH 60 TOTAL TRAINING LOSS: 4.243246
# EPOCH 61 TOTAL TRAINING LOSS: 4.246823
# EPOCH 62 TOTAL TRAINING LOSS: 4.018710
# EPOCH 63 TOTAL TRAINING LOSS: 4.027105
# EPOCH 64 TOTAL TRAINING LOSS: 4.268355
# EPOCH 65 TOTAL TRAINING LOSS: 3.561991
# EPOCH 66 TOTAL TRAINING LOSS: 3.673437
# EPOCH 67 TOTAL TRAINING LOSS: 4.221004
# EPOCH 68 TOTAL TRAINING LOSS: 4.238407
# EPOCH 69 TOTAL TRAINING LOSS: 3.861777
# EPOCH 70 TOTAL TRAINING LOSS: 3.657810
# EPOCH 71 TOTAL TRAINING LOSS: 3.374226
# EPOCH 72 TOTAL TRAINING LOSS: 3.603558
# EPOCH 73 TOTAL TRAINING LOSS: 3.649373
# EPOCH 74 TOTAL TRAINING LOSS: 4.323846
# EPOCH 75 TOTAL TRAINING LOSS: 3.841023
# EPOCH 76 TOTAL TRAINING LOSS: 3.922525
# EPOCH 77 TOTAL TRAINING LOSS: 3.849950
# EPOCH 78 TOTAL TRAINING LOSS: 3.831449
# EPOCH 79 TOTAL TRAINING LOSS: 4.079370
# EPOCH 80 TOTAL TRAINING LOSS: 3.265959
# EPOCH 81 TOTAL TRAINING LOSS: 3.984500
# EPOCH 82 TOTAL TRAINING LOSS: 3.462759
# EPOCH 83 TOTAL TRAINING LOSS: 3.834125
# EPOCH 84 TOTAL TRAINING LOSS: 3.859977
# EPOCH 85 TOTAL TRAINING LOSS: 3.616426
# EPOCH 86 TOTAL TRAINING LOSS: 3.644018
# EPOCH 87 TOTAL TRAINING LOSS: 3.593716
# EPOCH 88 TOTAL TRAINING LOSS: 3.611214
# EPOCH 89 TOTAL TRAINING LOSS: 3.638267
# EPOCH 90 TOTAL TRAINING LOSS: 3.491502
# EPOCH 91 TOTAL TRAINING LOSS: 3.722763
# EPOCH 92 TOTAL TRAINING LOSS: 3.317471
# EPOCH 93 TOTAL TRAINING LOSS: 3.463092
# EPOCH 94 TOTAL TRAINING LOSS: 3.740886
# EPOCH 95 TOTAL TRAINING LOSS: 3.893086
# EPOCH 96 TOTAL TRAINING LOSS: 3.436946
# EPOCH 97 TOTAL TRAINING LOSS: 3.351115
# EPOCH 98 TOTAL TRAINING LOSS: 3.257350
# EPOCH 99 TOTAL TRAINING LOSS: 3.914933
# EPOCH 100 TOTAL TRAINING LOSS: 3.56519
# EPOCH 101 TOTAL TRAINING LOSS: 3.691697
# EPOCH 102 TOTAL TRAINING LOSS: 3.669472
# EPOCH 103 TOTAL TRAINING LOSS: 3.735327
# EPOCH 104 TOTAL TRAINING LOSS: 3.729233
# EPOCH 105 TOTAL TRAINING LOSS: 3.352758
# EPOCH 106 TOTAL TRAINING LOSS: 3.249721
# EPOCH 107 TOTAL TRAINING LOSS: 3.835268
# EPOCH 108 TOTAL TRAINING LOSS: 3.181760
# EPOCH 109 TOTAL TRAINING LOSS: 3.923153
# EPOCH 110 TOTAL TRAINING LOSS: 3.491538
# EPOCH 111 TOTAL TRAINING LOSS: 3.746233
# EPOCH 112 TOTAL TRAINING LOSS: 3.790565
# EPOCH 113 TOTAL TRAINING LOSS: 3.957648
# EPOCH 114 TOTAL TRAINING LOSS: 3.410706
# EPOCH 115 TOTAL TRAINING LOSS: 4.082225
# EPOCH 116 TOTAL TRAINING LOSS: 3.240070
# EPOCH 117 TOTAL TRAINING LOSS: 3.412830
# EPOCH 118 TOTAL TRAINING LOSS: 3.007289
# EPOCH 119 TOTAL TRAINING LOSS: 3.517866
# EPOCH 120 TOTAL TRAINING LOSS: 3.719496
# EPOCH 121 TOTAL TRAINING LOSS: 3.459459
# EPOCH 122 TOTAL TRAINING LOSS: 4.359595
# EPOCH 123 TOTAL TRAINING LOSS: 4.026208
# EPOCH 124 TOTAL TRAINING LOSS: 3.970930
# EPOCH 125 TOTAL TRAINING LOSS: 2.978464
# EPOCH 126 TOTAL TRAINING LOSS: 3.320003
# EPOCH 127 TOTAL TRAINING LOSS: 3.729863
# EPOCH 128 TOTAL TRAINING LOSS: 4.004039
# EPOCH 129 TOTAL TRAINING LOSS: 3.705258
# EPOCH 130 TOTAL TRAINING LOSS: 3.852113
# EPOCH 131 TOTAL TRAINING LOSS: 3.629180
# EPOCH 132 TOTAL TRAINING LOSS: 3.555435
# EPOCH 133 TOTAL TRAINING LOSS: 3.480424
# EPOCH 134 TOTAL TRAINING LOSS: 3.518939
# EPOCH 135 TOTAL TRAINING LOSS: 3.298885
# EPOCH 136 TOTAL TRAINING LOSS: 3.516343
# EPOCH 137 TOTAL TRAINING LOSS: 3.634368
# EPOCH 138 TOTAL TRAINING LOSS: 3.364414
# EPOCH 139 TOTAL TRAINING LOSS: 3.708251
# EPOCH 140 TOTAL TRAINING LOSS: 2.880444
# EPOCH 141 TOTAL TRAINING LOSS: 3.699783
# EPOCH 142 TOTAL TRAINING LOSS: 3.408617
# EPOCH 143 TOTAL TRAINING LOSS: 3.614601
# EPOCH 144 TOTAL TRAINING LOSS: 3.886787
# EPOCH 145 TOTAL TRAINING LOSS: 3.654648
# EPOCH 146 TOTAL TRAINING LOSS: 3.213663
# EPOCH 147 TOTAL TRAINING LOSS: 3.150315
# EPOCH 148 TOTAL TRAINING LOSS: 3.566648
# EPOCH 149 TOTAL TRAINING LOSS: 3.758678
# EPOCH 150 TOTAL TRAINING LOSS: 3.341322
# Using device(prediction head) : cuda533
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.2083
# EPOCH 2 TOTAL TRAINING LOSS: 6.266936
# EPOCH 3 TOTAL TRAINING LOSS: 5.899797
# EPOCH 4 TOTAL TRAINING LOSS: 5.875589
# EPOCH 5 TOTAL TRAINING LOSS: 6.014980
# EPOCH 6 TOTAL TRAINING LOSS: 5.625373
# EPOCH 7 TOTAL TRAINING LOSS: 5.832582
# EPOCH 8 TOTAL TRAINING LOSS: 5.922982
# EPOCH 9 TOTAL TRAINING LOSS: 6.389990
# EPOCH 10 TOTAL TRAINING LOSS: 6.35054
# EPOCH 11 TOTAL TRAINING LOSS: 5.930999
# EPOCH 12 TOTAL TRAINING LOSS: 5.760023
# EPOCH 13 TOTAL TRAINING LOSS: 5.450133
# EPOCH 14 TOTAL TRAINING LOSS: 5.886454
# EPOCH 15 TOTAL TRAINING LOSS: 6.265097
# EPOCH 16 TOTAL TRAINING LOSS: 6.343031
# EPOCH 17 TOTAL TRAINING LOSS: 5.163505
# EPOCH 18 TOTAL TRAINING LOSS: 5.070756
# EPOCH 19 TOTAL TRAINING LOSS: 5.594300
# EPOCH 20 TOTAL TRAINING LOSS: 5.314177
# EPOCH 21 TOTAL TRAINING LOSS: 5.806439
# EPOCH 22 TOTAL TRAINING LOSS: 5.462845
# EPOCH 23 TOTAL TRAINING LOSS: 5.496548
# EPOCH 24 TOTAL TRAINING LOSS: 5.052682
# EPOCH 25 TOTAL TRAINING LOSS: 4.429113
# EPOCH 26 TOTAL TRAINING LOSS: 4.863826
# EPOCH 27 TOTAL TRAINING LOSS: 5.671581
# EPOCH 28 TOTAL TRAINING LOSS: 5.618742
# EPOCH 29 TOTAL TRAINING LOSS: 5.531825
# EPOCH 30 TOTAL TRAINING LOSS: 5.794219
# EPOCH 31 TOTAL TRAINING LOSS: 5.011164
# EPOCH 32 TOTAL TRAINING LOSS: 4.978131
# EPOCH 33 TOTAL TRAINING LOSS: 5.474140
# EPOCH 34 TOTAL TRAINING LOSS: 5.765206
# EPOCH 35 TOTAL TRAINING LOSS: 5.563450
# EPOCH 36 TOTAL TRAINING LOSS: 4.932665
# EPOCH 37 TOTAL TRAINING LOSS: 4.775426
# EPOCH 38 TOTAL TRAINING LOSS: 5.308566
# EPOCH 39 TOTAL TRAINING LOSS: 4.937276
# EPOCH 40 TOTAL TRAINING LOSS: 4.950296
# EPOCH 41 TOTAL TRAINING LOSS: 5.280039
# EPOCH 42 TOTAL TRAINING LOSS: 4.594194
# EPOCH 43 TOTAL TRAINING LOSS: 4.981363
# EPOCH 44 TOTAL TRAINING LOSS: 5.099698
# EPOCH 45 TOTAL TRAINING LOSS: 4.809740
# EPOCH 46 TOTAL TRAINING LOSS: 5.331700
# EPOCH 47 TOTAL TRAINING LOSS: 4.925482
# EPOCH 48 TOTAL TRAINING LOSS: 4.457637
# EPOCH 49 TOTAL TRAINING LOSS: 4.893825
# EPOCH 50 TOTAL TRAINING LOSS: 4.390054
# EPOCH 51 TOTAL TRAINING LOSS: 4.748907
# EPOCH 52 TOTAL TRAINING LOSS: 4.802768
# EPOCH 53 TOTAL TRAINING LOSS: 4.524184
# EPOCH 54 TOTAL TRAINING LOSS: 4.836740
# EPOCH 55 TOTAL TRAINING LOSS: 5.201512
# EPOCH 56 TOTAL TRAINING LOSS: 4.584763
# EPOCH 57 TOTAL TRAINING LOSS: 4.446771
# EPOCH 58 TOTAL TRAINING LOSS: 4.789652
# EPOCH 59 TOTAL TRAINING LOSS: 4.403103
# EPOCH 60 TOTAL TRAINING LOSS: 4.508653
# EPOCH 61 TOTAL TRAINING LOSS: 4.561282
# EPOCH 62 TOTAL TRAINING LOSS: 4.001518
# EPOCH 63 TOTAL TRAINING LOSS: 5.123601
# EPOCH 64 TOTAL TRAINING LOSS: 4.338119
# EPOCH 65 TOTAL TRAINING LOSS: 4.476001
# EPOCH 66 TOTAL TRAINING LOSS: 4.476399
# EPOCH 67 TOTAL TRAINING LOSS: 5.459117
# EPOCH 68 TOTAL TRAINING LOSS: 4.199454
# EPOCH 69 TOTAL TRAINING LOSS: 4.204529
# EPOCH 70 TOTAL TRAINING LOSS: 4.578946
# EPOCH 71 TOTAL TRAINING LOSS: 4.397995
# EPOCH 72 TOTAL TRAINING LOSS: 4.976081
# EPOCH 73 TOTAL TRAINING LOSS: 4.342162
# EPOCH 74 TOTAL TRAINING LOSS: 5.172170
# EPOCH 75 TOTAL TRAINING LOSS: 4.621837
# EPOCH 76 TOTAL TRAINING LOSS: 5.510591
# EPOCH 77 TOTAL TRAINING LOSS: 4.693345
# EPOCH 78 TOTAL TRAINING LOSS: 4.176503
# EPOCH 79 TOTAL TRAINING LOSS: 4.154731
# EPOCH 80 TOTAL TRAINING LOSS: 4.763588
# EPOCH 81 TOTAL TRAINING LOSS: 4.231582
# EPOCH 82 TOTAL TRAINING LOSS: 4.749302
# EPOCH 83 TOTAL TRAINING LOSS: 4.769620
# EPOCH 84 TOTAL TRAINING LOSS: 4.104604
# EPOCH 85 TOTAL TRAINING LOSS: 4.179073
# EPOCH 86 TOTAL TRAINING LOSS: 4.113964
# EPOCH 87 TOTAL TRAINING LOSS: 3.760930
# EPOCH 88 TOTAL TRAINING LOSS: 4.207389
# EPOCH 89 TOTAL TRAINING LOSS: 4.044067
# EPOCH 90 TOTAL TRAINING LOSS: 3.499174
# EPOCH 91 TOTAL TRAINING LOSS: 4.663478
# EPOCH 92 TOTAL TRAINING LOSS: 4.548377
# EPOCH 93 TOTAL TRAINING LOSS: 4.057377
# EPOCH 94 TOTAL TRAINING LOSS: 4.434033
# EPOCH 95 TOTAL TRAINING LOSS: 4.404565
# EPOCH 96 TOTAL TRAINING LOSS: 4.240478
# EPOCH 97 TOTAL TRAINING LOSS: 4.620080
# EPOCH 98 TOTAL TRAINING LOSS: 4.095823
# EPOCH 99 TOTAL TRAINING LOSS: 4.238871
# EPOCH 100 TOTAL TRAINING LOSS: 4.87450
# EPOCH 101 TOTAL TRAINING LOSS: 3.660470
# EPOCH 102 TOTAL TRAINING LOSS: 4.991677
# EPOCH 103 TOTAL TRAINING LOSS: 4.207791
# EPOCH 104 TOTAL TRAINING LOSS: 5.049768
# EPOCH 105 TOTAL TRAINING LOSS: 4.148160
# EPOCH 106 TOTAL TRAINING LOSS: 3.771088
# EPOCH 107 TOTAL TRAINING LOSS: 4.269211
# EPOCH 108 TOTAL TRAINING LOSS: 3.705097
# EPOCH 109 TOTAL TRAINING LOSS: 4.409103
# EPOCH 110 TOTAL TRAINING LOSS: 3.495227
# EPOCH 111 TOTAL TRAINING LOSS: 4.316927
# EPOCH 112 TOTAL TRAINING LOSS: 3.808989
# EPOCH 113 TOTAL TRAINING LOSS: 3.827146
# EPOCH 114 TOTAL TRAINING LOSS: 4.281182
# EPOCH 115 TOTAL TRAINING LOSS: 3.412968
# EPOCH 116 TOTAL TRAINING LOSS: 4.136636
# EPOCH 117 TOTAL TRAINING LOSS: 3.908340
# EPOCH 118 TOTAL TRAINING LOSS: 3.112832
# EPOCH 119 TOTAL TRAINING LOSS: 3.926742
# EPOCH 120 TOTAL TRAINING LOSS: 4.096573
# EPOCH 121 TOTAL TRAINING LOSS: 3.851531
# EPOCH 122 TOTAL TRAINING LOSS: 4.109142
# EPOCH 123 TOTAL TRAINING LOSS: 4.144466
# EPOCH 124 TOTAL TRAINING LOSS: 3.912575
# EPOCH 125 TOTAL TRAINING LOSS: 3.936198
# EPOCH 126 TOTAL TRAINING LOSS: 4.396442
# EPOCH 127 TOTAL TRAINING LOSS: 4.460173
# EPOCH 128 TOTAL TRAINING LOSS: 3.952938
# EPOCH 129 TOTAL TRAINING LOSS: 4.570348
# EPOCH 130 TOTAL TRAINING LOSS: 4.592392
# EPOCH 131 TOTAL TRAINING LOSS: 3.794503
# EPOCH 132 TOTAL TRAINING LOSS: 3.953059
# EPOCH 133 TOTAL TRAINING LOSS: 3.999534
# EPOCH 134 TOTAL TRAINING LOSS: 4.074512
# EPOCH 135 TOTAL TRAINING LOSS: 4.418491
# EPOCH 136 TOTAL TRAINING LOSS: 4.033881
# EPOCH 137 TOTAL TRAINING LOSS: 4.869216
# EPOCH 138 TOTAL TRAINING LOSS: 4.122427
# EPOCH 139 TOTAL TRAINING LOSS: 3.727218
# EPOCH 140 TOTAL TRAINING LOSS: 4.643416
# EPOCH 141 TOTAL TRAINING LOSS: 3.631359
# EPOCH 142 TOTAL TRAINING LOSS: 3.945939
# EPOCH 143 TOTAL TRAINING LOSS: 4.010487
# EPOCH 144 TOTAL TRAINING LOSS: 4.211207
# EPOCH 145 TOTAL TRAINING LOSS: 4.789968
# EPOCH 146 TOTAL TRAINING LOSS: 3.773144
# EPOCH 147 TOTAL TRAINING LOSS: 4.411558
# EPOCH 148 TOTAL TRAINING LOSS: 4.326948
# EPOCH 149 TOTAL TRAINING LOSS: 3.808247
# EPOCH 150 TOTAL TRAINING LOSS: 4.368664
# Using device(prediction head) : cuda154
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.3659
# EPOCH 2 TOTAL TRAINING LOSS: 5.490019
# EPOCH 3 TOTAL TRAINING LOSS: 4.077938
# EPOCH 4 TOTAL TRAINING LOSS: 5.139157
# EPOCH 5 TOTAL TRAINING LOSS: 4.798218
# EPOCH 6 TOTAL TRAINING LOSS: 5.471521
# EPOCH 7 TOTAL TRAINING LOSS: 5.744135
# EPOCH 8 TOTAL TRAINING LOSS: 4.658325
# EPOCH 9 TOTAL TRAINING LOSS: 4.479443
# EPOCH 10 TOTAL TRAINING LOSS: 4.82133
# EPOCH 11 TOTAL TRAINING LOSS: 5.491983
# EPOCH 12 TOTAL TRAINING LOSS: 5.482035
# EPOCH 13 TOTAL TRAINING LOSS: 4.218509
# EPOCH 14 TOTAL TRAINING LOSS: 5.746236
# EPOCH 15 TOTAL TRAINING LOSS: 4.411127
# EPOCH 16 TOTAL TRAINING LOSS: 4.897414
# EPOCH 17 TOTAL TRAINING LOSS: 5.214676
# EPOCH 18 TOTAL TRAINING LOSS: 4.388604
# EPOCH 19 TOTAL TRAINING LOSS: 4.528510
# EPOCH 20 TOTAL TRAINING LOSS: 4.823228
# EPOCH 21 TOTAL TRAINING LOSS: 4.385762
# EPOCH 22 TOTAL TRAINING LOSS: 4.143096
# EPOCH 23 TOTAL TRAINING LOSS: 4.175738
# EPOCH 24 TOTAL TRAINING LOSS: 4.103997
# EPOCH 25 TOTAL TRAINING LOSS: 4.484958
# EPOCH 26 TOTAL TRAINING LOSS: 4.348250
# EPOCH 27 TOTAL TRAINING LOSS: 4.270631
# EPOCH 28 TOTAL TRAINING LOSS: 3.904715
# EPOCH 29 TOTAL TRAINING LOSS: 4.539865
# EPOCH 30 TOTAL TRAINING LOSS: 4.453275
# EPOCH 31 TOTAL TRAINING LOSS: 3.753666
# EPOCH 32 TOTAL TRAINING LOSS: 3.938110
# EPOCH 33 TOTAL TRAINING LOSS: 3.741715
# EPOCH 34 TOTAL TRAINING LOSS: 4.272142
# EPOCH 35 TOTAL TRAINING LOSS: 4.614314
# EPOCH 36 TOTAL TRAINING LOSS: 4.057467
# EPOCH 37 TOTAL TRAINING LOSS: 4.557802
# EPOCH 38 TOTAL TRAINING LOSS: 3.511852
# EPOCH 39 TOTAL TRAINING LOSS: 3.917660
# EPOCH 40 TOTAL TRAINING LOSS: 3.399970
# EPOCH 41 TOTAL TRAINING LOSS: 4.377973
# EPOCH 42 TOTAL TRAINING LOSS: 4.039964
# EPOCH 43 TOTAL TRAINING LOSS: 3.750241
# EPOCH 44 TOTAL TRAINING LOSS: 3.802337
# EPOCH 45 TOTAL TRAINING LOSS: 4.314721
# EPOCH 46 TOTAL TRAINING LOSS: 3.745044
# EPOCH 47 TOTAL TRAINING LOSS: 3.563352
# EPOCH 48 TOTAL TRAINING LOSS: 4.185371
# EPOCH 49 TOTAL TRAINING LOSS: 4.070329
# EPOCH 50 TOTAL TRAINING LOSS: 3.895096
# EPOCH 51 TOTAL TRAINING LOSS: 3.490047
# EPOCH 52 TOTAL TRAINING LOSS: 3.870931
# EPOCH 53 TOTAL TRAINING LOSS: 3.411804
# EPOCH 54 TOTAL TRAINING LOSS: 3.318668
# EPOCH 55 TOTAL TRAINING LOSS: 3.664971
# EPOCH 56 TOTAL TRAINING LOSS: 3.628767
# EPOCH 57 TOTAL TRAINING LOSS: 3.829537
# EPOCH 58 TOTAL TRAINING LOSS: 3.631984
# EPOCH 59 TOTAL TRAINING LOSS: 3.516592
# EPOCH 60 TOTAL TRAINING LOSS: 3.481867
# EPOCH 61 TOTAL TRAINING LOSS: 3.662984
# EPOCH 62 TOTAL TRAINING LOSS: 3.586840
# EPOCH 63 TOTAL TRAINING LOSS: 3.191067
# EPOCH 64 TOTAL TRAINING LOSS: 3.646126
# EPOCH 65 TOTAL TRAINING LOSS: 3.588568
# EPOCH 66 TOTAL TRAINING LOSS: 3.841169
# EPOCH 67 TOTAL TRAINING LOSS: 3.537903
# EPOCH 68 TOTAL TRAINING LOSS: 3.284036
# EPOCH 69 TOTAL TRAINING LOSS: 3.432257
# EPOCH 70 TOTAL TRAINING LOSS: 3.491029
# EPOCH 71 TOTAL TRAINING LOSS: 3.676243
# EPOCH 72 TOTAL TRAINING LOSS: 3.394542
# EPOCH 73 TOTAL TRAINING LOSS: 2.943625
# EPOCH 74 TOTAL TRAINING LOSS: 3.372832
# EPOCH 75 TOTAL TRAINING LOSS: 3.631679
# EPOCH 76 TOTAL TRAINING LOSS: 3.180507
# EPOCH 77 TOTAL TRAINING LOSS: 3.372730
# EPOCH 78 TOTAL TRAINING LOSS: 3.412876
# EPOCH 79 TOTAL TRAINING LOSS: 3.250125
# EPOCH 80 TOTAL TRAINING LOSS: 3.837877
# EPOCH 81 TOTAL TRAINING LOSS: 3.628337
# EPOCH 82 TOTAL TRAINING LOSS: 3.221399
# EPOCH 83 TOTAL TRAINING LOSS: 3.881413
# EPOCH 84 TOTAL TRAINING LOSS: 2.930729
# EPOCH 85 TOTAL TRAINING LOSS: 3.459723
# EPOCH 86 TOTAL TRAINING LOSS: 3.756479
# EPOCH 87 TOTAL TRAINING LOSS: 3.320761
# EPOCH 88 TOTAL TRAINING LOSS: 3.700695
# EPOCH 89 TOTAL TRAINING LOSS: 3.298863
# EPOCH 90 TOTAL TRAINING LOSS: 2.900181
# EPOCH 91 TOTAL TRAINING LOSS: 3.392607
# EPOCH 92 TOTAL TRAINING LOSS: 3.331097
# EPOCH 93 TOTAL TRAINING LOSS: 3.346036
# EPOCH 94 TOTAL TRAINING LOSS: 3.020071
# EPOCH 95 TOTAL TRAINING LOSS: 3.357090
# EPOCH 96 TOTAL TRAINING LOSS: 3.302660
# EPOCH 97 TOTAL TRAINING LOSS: 3.294982
# EPOCH 98 TOTAL TRAINING LOSS: 3.253749
# EPOCH 99 TOTAL TRAINING LOSS: 3.836312
# EPOCH 100 TOTAL TRAINING LOSS: 2.96025
# EPOCH 101 TOTAL TRAINING LOSS: 3.129659
# EPOCH 102 TOTAL TRAINING LOSS: 3.168055
# EPOCH 103 TOTAL TRAINING LOSS: 3.295383
# EPOCH 104 TOTAL TRAINING LOSS: 3.138519
# EPOCH 105 TOTAL TRAINING LOSS: 3.361088
# EPOCH 106 TOTAL TRAINING LOSS: 3.076778
# EPOCH 107 TOTAL TRAINING LOSS: 3.157775
# EPOCH 108 TOTAL TRAINING LOSS: 3.383564
# EPOCH 109 TOTAL TRAINING LOSS: 3.250435
# EPOCH 110 TOTAL TRAINING LOSS: 2.812865
# EPOCH 111 TOTAL TRAINING LOSS: 2.613463
# EPOCH 112 TOTAL TRAINING LOSS: 3.158953
# EPOCH 113 TOTAL TRAINING LOSS: 3.606933
# EPOCH 114 TOTAL TRAINING LOSS: 3.095120
# EPOCH 115 TOTAL TRAINING LOSS: 3.040571
# EPOCH 116 TOTAL TRAINING LOSS: 2.889192
# EPOCH 117 TOTAL TRAINING LOSS: 3.444774
# EPOCH 118 TOTAL TRAINING LOSS: 3.008167
# EPOCH 119 TOTAL TRAINING LOSS: 3.180918
# EPOCH 120 TOTAL TRAINING LOSS: 3.151860
# EPOCH 121 TOTAL TRAINING LOSS: 3.144535
# EPOCH 122 TOTAL TRAINING LOSS: 3.360410
# EPOCH 123 TOTAL TRAINING LOSS: 3.112088
# EPOCH 124 TOTAL TRAINING LOSS: 3.203278
# EPOCH 125 TOTAL TRAINING LOSS: 3.193663
# EPOCH 126 TOTAL TRAINING LOSS: 2.975820
# EPOCH 127 TOTAL TRAINING LOSS: 3.285742
# EPOCH 128 TOTAL TRAINING LOSS: 3.028040
# EPOCH 129 TOTAL TRAINING LOSS: 3.002235
# EPOCH 130 TOTAL TRAINING LOSS: 3.167345
# EPOCH 131 TOTAL TRAINING LOSS: 2.776521
# EPOCH 132 TOTAL TRAINING LOSS: 2.918405
# EPOCH 133 TOTAL TRAINING LOSS: 2.853981
# EPOCH 134 TOTAL TRAINING LOSS: 2.945181
# EPOCH 135 TOTAL TRAINING LOSS: 2.851740
# EPOCH 136 TOTAL TRAINING LOSS: 2.955483
# EPOCH 137 TOTAL TRAINING LOSS: 2.929064
# EPOCH 138 TOTAL TRAINING LOSS: 2.999427
# EPOCH 139 TOTAL TRAINING LOSS: 3.359129
# EPOCH 140 TOTAL TRAINING LOSS: 3.040034
# EPOCH 141 TOTAL TRAINING LOSS: 3.100198
# EPOCH 142 TOTAL TRAINING LOSS: 2.939944
# EPOCH 143 TOTAL TRAINING LOSS: 3.026894
# EPOCH 144 TOTAL TRAINING LOSS: 3.252504
# EPOCH 145 TOTAL TRAINING LOSS: 3.123673
# EPOCH 146 TOTAL TRAINING LOSS: 3.303844
# EPOCH 147 TOTAL TRAINING LOSS: 3.184100
# EPOCH 148 TOTAL TRAINING LOSS: 3.192286
# EPOCH 149 TOTAL TRAINING LOSS: 2.729501
# EPOCH 150 TOTAL TRAINING LOSS: 3.033063
# Using device(prediction head) : cuda598
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.0699
# EPOCH 2 TOTAL TRAINING LOSS: 6.422757
# EPOCH 3 TOTAL TRAINING LOSS: 6.235366
# EPOCH 4 TOTAL TRAINING LOSS: 6.386084
# EPOCH 5 TOTAL TRAINING LOSS: 5.533806
# EPOCH 6 TOTAL TRAINING LOSS: 6.467224
# EPOCH 7 TOTAL TRAINING LOSS: 5.441054
# EPOCH 8 TOTAL TRAINING LOSS: 6.235295
# EPOCH 9 TOTAL TRAINING LOSS: 5.854042
# EPOCH 10 TOTAL TRAINING LOSS: 5.19057
# EPOCH 11 TOTAL TRAINING LOSS: 6.393038
# EPOCH 12 TOTAL TRAINING LOSS: 6.047797
# EPOCH 13 TOTAL TRAINING LOSS: 6.232054
# EPOCH 14 TOTAL TRAINING LOSS: 6.026201
# EPOCH 15 TOTAL TRAINING LOSS: 6.090249
# EPOCH 16 TOTAL TRAINING LOSS: 5.413211
# EPOCH 17 TOTAL TRAINING LOSS: 5.192473
# EPOCH 18 TOTAL TRAINING LOSS: 5.765854
# EPOCH 19 TOTAL TRAINING LOSS: 5.091890
# EPOCH 20 TOTAL TRAINING LOSS: 5.706773
# EPOCH 21 TOTAL TRAINING LOSS: 5.487743
# EPOCH 22 TOTAL TRAINING LOSS: 4.382720
# EPOCH 23 TOTAL TRAINING LOSS: 4.845088
# EPOCH 24 TOTAL TRAINING LOSS: 5.311076
# EPOCH 25 TOTAL TRAINING LOSS: 5.816579
# EPOCH 26 TOTAL TRAINING LOSS: 5.641691
# EPOCH 27 TOTAL TRAINING LOSS: 5.367791
# EPOCH 28 TOTAL TRAINING LOSS: 4.933321
# EPOCH 29 TOTAL TRAINING LOSS: 3.836415
# EPOCH 30 TOTAL TRAINING LOSS: 4.949524
# EPOCH 31 TOTAL TRAINING LOSS: 4.559750
# EPOCH 32 TOTAL TRAINING LOSS: 5.262794
# EPOCH 33 TOTAL TRAINING LOSS: 4.690112
# EPOCH 34 TOTAL TRAINING LOSS: 4.863543
# EPOCH 35 TOTAL TRAINING LOSS: 4.942748
# EPOCH 36 TOTAL TRAINING LOSS: 5.103377
# EPOCH 37 TOTAL TRAINING LOSS: 4.247695
# EPOCH 38 TOTAL TRAINING LOSS: 5.768638
# EPOCH 39 TOTAL TRAINING LOSS: 4.408419
# EPOCH 40 TOTAL TRAINING LOSS: 4.672859
# EPOCH 41 TOTAL TRAINING LOSS: 4.485985
# EPOCH 42 TOTAL TRAINING LOSS: 4.887737
# EPOCH 43 TOTAL TRAINING LOSS: 4.531326
# EPOCH 44 TOTAL TRAINING LOSS: 4.467599
# EPOCH 45 TOTAL TRAINING LOSS: 4.462531
# EPOCH 46 TOTAL TRAINING LOSS: 3.554633
# EPOCH 47 TOTAL TRAINING LOSS: 3.901132
# EPOCH 48 TOTAL TRAINING LOSS: 4.521083
# EPOCH 49 TOTAL TRAINING LOSS: 4.043368
# EPOCH 50 TOTAL TRAINING LOSS: 4.491595
# EPOCH 51 TOTAL TRAINING LOSS: 4.500675
# EPOCH 52 TOTAL TRAINING LOSS: 4.395392
# EPOCH 53 TOTAL TRAINING LOSS: 4.069719
# EPOCH 54 TOTAL TRAINING LOSS: 4.954037
# EPOCH 55 TOTAL TRAINING LOSS: 3.777268
# EPOCH 56 TOTAL TRAINING LOSS: 4.414534
# EPOCH 57 TOTAL TRAINING LOSS: 4.335088
# EPOCH 58 TOTAL TRAINING LOSS: 3.937019
# EPOCH 59 TOTAL TRAINING LOSS: 4.205648
# EPOCH 60 TOTAL TRAINING LOSS: 4.670773
# EPOCH 61 TOTAL TRAINING LOSS: 3.765607
# EPOCH 62 TOTAL TRAINING LOSS: 4.229319
# EPOCH 63 TOTAL TRAINING LOSS: 4.979358
# EPOCH 64 TOTAL TRAINING LOSS: 3.942920
# EPOCH 65 TOTAL TRAINING LOSS: 4.018938
# EPOCH 66 TOTAL TRAINING LOSS: 3.961584
# EPOCH 67 TOTAL TRAINING LOSS: 3.415120
# EPOCH 68 TOTAL TRAINING LOSS: 3.212865
# EPOCH 69 TOTAL TRAINING LOSS: 4.246256
# EPOCH 70 TOTAL TRAINING LOSS: 3.803544
# EPOCH 71 TOTAL TRAINING LOSS: 4.132396
# EPOCH 72 TOTAL TRAINING LOSS: 4.177688
# EPOCH 73 TOTAL TRAINING LOSS: 3.740591
# EPOCH 74 TOTAL TRAINING LOSS: 3.923261
# EPOCH 75 TOTAL TRAINING LOSS: 4.527967
# EPOCH 76 TOTAL TRAINING LOSS: 3.472297
# EPOCH 77 TOTAL TRAINING LOSS: 3.473986
# EPOCH 78 TOTAL TRAINING LOSS: 4.110799
# EPOCH 79 TOTAL TRAINING LOSS: 3.519060
# EPOCH 80 TOTAL TRAINING LOSS: 3.236396
# EPOCH 81 TOTAL TRAINING LOSS: 4.141472
# EPOCH 82 TOTAL TRAINING LOSS: 3.757950
# EPOCH 83 TOTAL TRAINING LOSS: 3.420663
# EPOCH 84 TOTAL TRAINING LOSS: 4.162041
# EPOCH 85 TOTAL TRAINING LOSS: 4.585454
# EPOCH 86 TOTAL TRAINING LOSS: 4.333056
# EPOCH 87 TOTAL TRAINING LOSS: 3.671421
# EPOCH 88 TOTAL TRAINING LOSS: 4.179284
# EPOCH 89 TOTAL TRAINING LOSS: 4.803451
# EPOCH 90 TOTAL TRAINING LOSS: 3.864166
# EPOCH 91 TOTAL TRAINING LOSS: 3.399135
# EPOCH 92 TOTAL TRAINING LOSS: 4.263009
# EPOCH 93 TOTAL TRAINING LOSS: 3.557491
# EPOCH 94 TOTAL TRAINING LOSS: 4.183172
# EPOCH 95 TOTAL TRAINING LOSS: 3.894145
# EPOCH 96 TOTAL TRAINING LOSS: 3.573664
# EPOCH 97 TOTAL TRAINING LOSS: 3.454420
# EPOCH 98 TOTAL TRAINING LOSS: 4.191835
# EPOCH 99 TOTAL TRAINING LOSS: 3.574066
# EPOCH 100 TOTAL TRAINING LOSS: 3.80442
# EPOCH 101 TOTAL TRAINING LOSS: 3.366275
# EPOCH 102 TOTAL TRAINING LOSS: 5.017923
# EPOCH 103 TOTAL TRAINING LOSS: 3.802449
# EPOCH 104 TOTAL TRAINING LOSS: 3.365385
# EPOCH 105 TOTAL TRAINING LOSS: 3.773586
# EPOCH 106 TOTAL TRAINING LOSS: 4.286658
# EPOCH 107 TOTAL TRAINING LOSS: 3.630248
# EPOCH 108 TOTAL TRAINING LOSS: 4.083302
# EPOCH 109 TOTAL TRAINING LOSS: 4.261403
# EPOCH 110 TOTAL TRAINING LOSS: 4.120901
# EPOCH 111 TOTAL TRAINING LOSS: 3.739174
# EPOCH 112 TOTAL TRAINING LOSS: 3.969582
# EPOCH 113 TOTAL TRAINING LOSS: 3.658541
# EPOCH 114 TOTAL TRAINING LOSS: 3.934632
# EPOCH 115 TOTAL TRAINING LOSS: 3.543739
# EPOCH 116 TOTAL TRAINING LOSS: 3.240167
# EPOCH 117 TOTAL TRAINING LOSS: 3.812860
# EPOCH 118 TOTAL TRAINING LOSS: 3.900436
# EPOCH 119 TOTAL TRAINING LOSS: 3.841096
# EPOCH 120 TOTAL TRAINING LOSS: 3.710319
# EPOCH 121 TOTAL TRAINING LOSS: 3.656981
# EPOCH 122 TOTAL TRAINING LOSS: 3.826967
# EPOCH 123 TOTAL TRAINING LOSS: 3.612053
# EPOCH 124 TOTAL TRAINING LOSS: 3.793498
# EPOCH 125 TOTAL TRAINING LOSS: 3.355899
# EPOCH 126 TOTAL TRAINING LOSS: 3.835951
# EPOCH 127 TOTAL TRAINING LOSS: 4.228086
# EPOCH 128 TOTAL TRAINING LOSS: 3.676775
# EPOCH 129 TOTAL TRAINING LOSS: 3.597100
# EPOCH 130 TOTAL TRAINING LOSS: 3.712345
# EPOCH 131 TOTAL TRAINING LOSS: 4.077723
# EPOCH 132 TOTAL TRAINING LOSS: 3.827311
# EPOCH 133 TOTAL TRAINING LOSS: 3.708695
# EPOCH 134 TOTAL TRAINING LOSS: 3.120569
# EPOCH 135 TOTAL TRAINING LOSS: 3.803850
# EPOCH 136 TOTAL TRAINING LOSS: 4.105912
# EPOCH 137 TOTAL TRAINING LOSS: 3.502165
# EPOCH 138 TOTAL TRAINING LOSS: 3.859034
# EPOCH 139 TOTAL TRAINING LOSS: 3.791060
# EPOCH 140 TOTAL TRAINING LOSS: 3.297457
# EPOCH 141 TOTAL TRAINING LOSS: 3.773981
# EPOCH 142 TOTAL TRAINING LOSS: 3.908230
# EPOCH 143 TOTAL TRAINING LOSS: 3.871438
# EPOCH 144 TOTAL TRAINING LOSS: 3.698958
# EPOCH 145 TOTAL TRAINING LOSS: 3.836242
# EPOCH 146 TOTAL TRAINING LOSS: 4.082775
# EPOCH 147 TOTAL TRAINING LOSS: 3.542006
# EPOCH 148 TOTAL TRAINING LOSS: 3.795702
# EPOCH 149 TOTAL TRAINING LOSS: 3.856712
# EPOCH 150 TOTAL TRAINING LOSS: 4.050369
# Using device(prediction head) : cuda822
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.1317
# EPOCH 2 TOTAL TRAINING LOSS: 5.136324
# EPOCH 3 TOTAL TRAINING LOSS: 5.472595
# EPOCH 4 TOTAL TRAINING LOSS: 5.004871
# EPOCH 5 TOTAL TRAINING LOSS: 5.357852
# EPOCH 6 TOTAL TRAINING LOSS: 5.160215
# EPOCH 7 TOTAL TRAINING LOSS: 5.860808
# EPOCH 8 TOTAL TRAINING LOSS: 4.856702
# EPOCH 9 TOTAL TRAINING LOSS: 5.491420
# EPOCH 10 TOTAL TRAINING LOSS: 4.88736
# EPOCH 11 TOTAL TRAINING LOSS: 4.858567
# EPOCH 12 TOTAL TRAINING LOSS: 5.037774
# EPOCH 13 TOTAL TRAINING LOSS: 5.090510
# EPOCH 14 TOTAL TRAINING LOSS: 5.436941
# EPOCH 15 TOTAL TRAINING LOSS: 5.216506
# EPOCH 16 TOTAL TRAINING LOSS: 5.518243
# EPOCH 17 TOTAL TRAINING LOSS: 4.881115
# EPOCH 18 TOTAL TRAINING LOSS: 5.078503
# EPOCH 19 TOTAL TRAINING LOSS: 4.401994
# EPOCH 20 TOTAL TRAINING LOSS: 4.612713
# EPOCH 21 TOTAL TRAINING LOSS: 4.948438
# EPOCH 22 TOTAL TRAINING LOSS: 4.380643
# EPOCH 23 TOTAL TRAINING LOSS: 4.581275
# EPOCH 24 TOTAL TRAINING LOSS: 4.848558
# EPOCH 25 TOTAL TRAINING LOSS: 4.808129
# EPOCH 26 TOTAL TRAINING LOSS: 4.706553
# EPOCH 27 TOTAL TRAINING LOSS: 4.392203
# EPOCH 28 TOTAL TRAINING LOSS: 4.711040
# EPOCH 29 TOTAL TRAINING LOSS: 4.791931
# EPOCH 30 TOTAL TRAINING LOSS: 4.352415
# EPOCH 31 TOTAL TRAINING LOSS: 4.027456
# EPOCH 32 TOTAL TRAINING LOSS: 4.876704
# EPOCH 33 TOTAL TRAINING LOSS: 4.471656
# EPOCH 34 TOTAL TRAINING LOSS: 4.602519
# EPOCH 35 TOTAL TRAINING LOSS: 4.633360
# EPOCH 36 TOTAL TRAINING LOSS: 4.524075
# EPOCH 37 TOTAL TRAINING LOSS: 4.226658
# EPOCH 38 TOTAL TRAINING LOSS: 4.175804
# EPOCH 39 TOTAL TRAINING LOSS: 4.658935
# EPOCH 40 TOTAL TRAINING LOSS: 4.067740
# EPOCH 41 TOTAL TRAINING LOSS: 4.109035
# EPOCH 42 TOTAL TRAINING LOSS: 4.381104
# EPOCH 43 TOTAL TRAINING LOSS: 3.692028
# EPOCH 44 TOTAL TRAINING LOSS: 4.347285
# EPOCH 45 TOTAL TRAINING LOSS: 4.172526
# EPOCH 46 TOTAL TRAINING LOSS: 4.209989
# EPOCH 47 TOTAL TRAINING LOSS: 4.110885
# EPOCH 48 TOTAL TRAINING LOSS: 4.000657
# EPOCH 49 TOTAL TRAINING LOSS: 4.050125
# EPOCH 50 TOTAL TRAINING LOSS: 3.944876
# EPOCH 51 TOTAL TRAINING LOSS: 4.494471
# EPOCH 52 TOTAL TRAINING LOSS: 3.788603
# EPOCH 53 TOTAL TRAINING LOSS: 4.266849
# EPOCH 54 TOTAL TRAINING LOSS: 4.259147
# EPOCH 55 TOTAL TRAINING LOSS: 3.680824
# EPOCH 56 TOTAL TRAINING LOSS: 4.467447
# EPOCH 57 TOTAL TRAINING LOSS: 4.525264
# EPOCH 58 TOTAL TRAINING LOSS: 3.986774
# EPOCH 59 TOTAL TRAINING LOSS: 4.220684
# EPOCH 60 TOTAL TRAINING LOSS: 4.456701
# EPOCH 61 TOTAL TRAINING LOSS: 4.388929
# EPOCH 62 TOTAL TRAINING LOSS: 3.383833
# EPOCH 63 TOTAL TRAINING LOSS: 4.030547
# EPOCH 64 TOTAL TRAINING LOSS: 4.165749
# EPOCH 65 TOTAL TRAINING LOSS: 4.172783
# EPOCH 66 TOTAL TRAINING LOSS: 4.119686
# EPOCH 67 TOTAL TRAINING LOSS: 3.904222
# EPOCH 68 TOTAL TRAINING LOSS: 3.458074
# EPOCH 69 TOTAL TRAINING LOSS: 3.599719
# EPOCH 70 TOTAL TRAINING LOSS: 3.581805
# EPOCH 71 TOTAL TRAINING LOSS: 4.104635
# EPOCH 72 TOTAL TRAINING LOSS: 3.865275
# EPOCH 73 TOTAL TRAINING LOSS: 3.941459
# EPOCH 74 TOTAL TRAINING LOSS: 3.619303
# EPOCH 75 TOTAL TRAINING LOSS: 3.852949
# EPOCH 76 TOTAL TRAINING LOSS: 4.220083
# EPOCH 77 TOTAL TRAINING LOSS: 3.711920
# EPOCH 78 TOTAL TRAINING LOSS: 3.536229
# EPOCH 79 TOTAL TRAINING LOSS: 3.516722
# EPOCH 80 TOTAL TRAINING LOSS: 3.434028
# EPOCH 81 TOTAL TRAINING LOSS: 3.860280
# EPOCH 82 TOTAL TRAINING LOSS: 3.987888
# EPOCH 83 TOTAL TRAINING LOSS: 3.589634
# EPOCH 84 TOTAL TRAINING LOSS: 3.577414
# EPOCH 85 TOTAL TRAINING LOSS: 3.396818
# EPOCH 86 TOTAL TRAINING LOSS: 4.046514
# EPOCH 87 TOTAL TRAINING LOSS: 3.168519
# EPOCH 88 TOTAL TRAINING LOSS: 3.534925
# EPOCH 89 TOTAL TRAINING LOSS: 3.326331
# EPOCH 90 TOTAL TRAINING LOSS: 3.496915
# EPOCH 91 TOTAL TRAINING LOSS: 4.051158
# EPOCH 92 TOTAL TRAINING LOSS: 3.430202
# EPOCH 93 TOTAL TRAINING LOSS: 3.469314
# EPOCH 94 TOTAL TRAINING LOSS: 3.201161
# EPOCH 95 TOTAL TRAINING LOSS: 3.335494
# EPOCH 96 TOTAL TRAINING LOSS: 3.220055
# EPOCH 97 TOTAL TRAINING LOSS: 3.268292
# EPOCH 98 TOTAL TRAINING LOSS: 3.625841
# EPOCH 99 TOTAL TRAINING LOSS: 3.635533
# EPOCH 100 TOTAL TRAINING LOSS: 3.46103
# EPOCH 101 TOTAL TRAINING LOSS: 4.023380
# EPOCH 102 TOTAL TRAINING LOSS: 3.305112
# EPOCH 103 TOTAL TRAINING LOSS: 3.346959
# EPOCH 104 TOTAL TRAINING LOSS: 3.337480
# EPOCH 105 TOTAL TRAINING LOSS: 3.724529
# EPOCH 106 TOTAL TRAINING LOSS: 3.230393
# EPOCH 107 TOTAL TRAINING LOSS: 3.311843
# EPOCH 108 TOTAL TRAINING LOSS: 3.221490
# EPOCH 109 TOTAL TRAINING LOSS: 3.178622
# EPOCH 110 TOTAL TRAINING LOSS: 3.824797
# EPOCH 111 TOTAL TRAINING LOSS: 3.262501
# EPOCH 112 TOTAL TRAINING LOSS: 3.726080
# EPOCH 113 TOTAL TRAINING LOSS: 3.849883
# EPOCH 114 TOTAL TRAINING LOSS: 3.186483
# EPOCH 115 TOTAL TRAINING LOSS: 3.049840
# EPOCH 116 TOTAL TRAINING LOSS: 3.751387
# EPOCH 117 TOTAL TRAINING LOSS: 3.682016
# EPOCH 118 TOTAL TRAINING LOSS: 4.079914
# EPOCH 119 TOTAL TRAINING LOSS: 3.184417
# EPOCH 120 TOTAL TRAINING LOSS: 3.712682
# EPOCH 121 TOTAL TRAINING LOSS: 3.243910
# EPOCH 122 TOTAL TRAINING LOSS: 3.530012
# EPOCH 123 TOTAL TRAINING LOSS: 3.248539
# EPOCH 124 TOTAL TRAINING LOSS: 2.598191
# EPOCH 125 TOTAL TRAINING LOSS: 3.559478
# EPOCH 126 TOTAL TRAINING LOSS: 3.483643
# EPOCH 127 TOTAL TRAINING LOSS: 3.236240
# EPOCH 128 TOTAL TRAINING LOSS: 3.443904
# EPOCH 129 TOTAL TRAINING LOSS: 3.428877
# EPOCH 130 TOTAL TRAINING LOSS: 3.490263
# EPOCH 131 TOTAL TRAINING LOSS: 2.989715
# EPOCH 132 TOTAL TRAINING LOSS: 3.272377
# EPOCH 133 TOTAL TRAINING LOSS: 3.432113
# EPOCH 134 TOTAL TRAINING LOSS: 3.477512
# EPOCH 135 TOTAL TRAINING LOSS: 3.500290
# EPOCH 136 TOTAL TRAINING LOSS: 3.794236
# EPOCH 137 TOTAL TRAINING LOSS: 3.589597
# EPOCH 138 TOTAL TRAINING LOSS: 3.905892
# EPOCH 139 TOTAL TRAINING LOSS: 3.479186
# EPOCH 140 TOTAL TRAINING LOSS: 3.506867
# EPOCH 141 TOTAL TRAINING LOSS: 3.373990
# EPOCH 142 TOTAL TRAINING LOSS: 3.297469
# EPOCH 143 TOTAL TRAINING LOSS: 3.275162
# EPOCH 144 TOTAL TRAINING LOSS: 3.412243
# EPOCH 145 TOTAL TRAINING LOSS: 3.398178
# EPOCH 146 TOTAL TRAINING LOSS: 3.934051
# EPOCH 147 TOTAL TRAINING LOSS: 3.854287
# EPOCH 148 TOTAL TRAINING LOSS: 3.158451
# EPOCH 149 TOTAL TRAINING LOSS: 3.842812
# EPOCH 150 TOTAL TRAINING LOSS: 3.485088
# Using device(prediction head) : cuda289
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.0349
# EPOCH 2 TOTAL TRAINING LOSS: 6.533412
# EPOCH 3 TOTAL TRAINING LOSS: 5.207237
# EPOCH 4 TOTAL TRAINING LOSS: 6.113283
# EPOCH 5 TOTAL TRAINING LOSS: 6.295643
# EPOCH 6 TOTAL TRAINING LOSS: 5.512702
# EPOCH 7 TOTAL TRAINING LOSS: 6.156294
# EPOCH 8 TOTAL TRAINING LOSS: 5.483686
# EPOCH 9 TOTAL TRAINING LOSS: 5.635683
# EPOCH 10 TOTAL TRAINING LOSS: 5.25834
# EPOCH 11 TOTAL TRAINING LOSS: 6.099784
# EPOCH 12 TOTAL TRAINING LOSS: 5.877187
# EPOCH 13 TOTAL TRAINING LOSS: 5.297613
# EPOCH 14 TOTAL TRAINING LOSS: 5.376949
# EPOCH 15 TOTAL TRAINING LOSS: 5.274883
# EPOCH 16 TOTAL TRAINING LOSS: 6.141239
# EPOCH 17 TOTAL TRAINING LOSS: 5.589813
# EPOCH 18 TOTAL TRAINING LOSS: 5.945595
# EPOCH 19 TOTAL TRAINING LOSS: 5.747543
# EPOCH 20 TOTAL TRAINING LOSS: 5.195707
# EPOCH 21 TOTAL TRAINING LOSS: 5.356467
# EPOCH 22 TOTAL TRAINING LOSS: 4.904669
# EPOCH 23 TOTAL TRAINING LOSS: 5.134488
# EPOCH 24 TOTAL TRAINING LOSS: 4.609209
# EPOCH 25 TOTAL TRAINING LOSS: 4.480935
# EPOCH 26 TOTAL TRAINING LOSS: 4.307866
# EPOCH 27 TOTAL TRAINING LOSS: 5.248066
# EPOCH 28 TOTAL TRAINING LOSS: 4.707657
# EPOCH 29 TOTAL TRAINING LOSS: 4.832896
# EPOCH 30 TOTAL TRAINING LOSS: 4.624576
# EPOCH 31 TOTAL TRAINING LOSS: 5.249018
# EPOCH 32 TOTAL TRAINING LOSS: 5.198571
# EPOCH 33 TOTAL TRAINING LOSS: 5.559913
# EPOCH 34 TOTAL TRAINING LOSS: 4.465468
# EPOCH 35 TOTAL TRAINING LOSS: 5.212866
# EPOCH 36 TOTAL TRAINING LOSS: 4.334714
# EPOCH 37 TOTAL TRAINING LOSS: 5.029787
# EPOCH 38 TOTAL TRAINING LOSS: 4.166488
# EPOCH 39 TOTAL TRAINING LOSS: 4.654165
# EPOCH 40 TOTAL TRAINING LOSS: 4.598998
# EPOCH 41 TOTAL TRAINING LOSS: 4.469370
# EPOCH 42 TOTAL TRAINING LOSS: 5.230452
# EPOCH 43 TOTAL TRAINING LOSS: 4.403947
# EPOCH 44 TOTAL TRAINING LOSS: 5.425230
# EPOCH 45 TOTAL TRAINING LOSS: 5.033194
# EPOCH 46 TOTAL TRAINING LOSS: 4.139839
# EPOCH 47 TOTAL TRAINING LOSS: 4.073684
# EPOCH 48 TOTAL TRAINING LOSS: 4.695259
# EPOCH 49 TOTAL TRAINING LOSS: 4.665361
# EPOCH 50 TOTAL TRAINING LOSS: 3.697012
# EPOCH 51 TOTAL TRAINING LOSS: 4.269077
# EPOCH 52 TOTAL TRAINING LOSS: 3.963551
# EPOCH 53 TOTAL TRAINING LOSS: 4.367272
# EPOCH 54 TOTAL TRAINING LOSS: 3.497671
# EPOCH 55 TOTAL TRAINING LOSS: 4.622564
# EPOCH 56 TOTAL TRAINING LOSS: 3.880891
# EPOCH 57 TOTAL TRAINING LOSS: 4.065986
# EPOCH 58 TOTAL TRAINING LOSS: 3.373971
# EPOCH 59 TOTAL TRAINING LOSS: 4.222689
# EPOCH 60 TOTAL TRAINING LOSS: 4.202783
# EPOCH 61 TOTAL TRAINING LOSS: 4.105589
# EPOCH 62 TOTAL TRAINING LOSS: 3.889984
# EPOCH 63 TOTAL TRAINING LOSS: 4.284071
# EPOCH 64 TOTAL TRAINING LOSS: 3.506249
# EPOCH 65 TOTAL TRAINING LOSS: 4.577198
# EPOCH 66 TOTAL TRAINING LOSS: 3.642028
# EPOCH 67 TOTAL TRAINING LOSS: 3.338754
# EPOCH 68 TOTAL TRAINING LOSS: 4.583844
# EPOCH 69 TOTAL TRAINING LOSS: 3.278943
# EPOCH 70 TOTAL TRAINING LOSS: 3.793917
# EPOCH 71 TOTAL TRAINING LOSS: 4.684764
# EPOCH 72 TOTAL TRAINING LOSS: 4.270420
# EPOCH 73 TOTAL TRAINING LOSS: 4.035087
# EPOCH 74 TOTAL TRAINING LOSS: 3.393469
# EPOCH 75 TOTAL TRAINING LOSS: 3.584559
# EPOCH 76 TOTAL TRAINING LOSS: 3.621871
# EPOCH 77 TOTAL TRAINING LOSS: 3.863339
# EPOCH 78 TOTAL TRAINING LOSS: 3.840690
# EPOCH 79 TOTAL TRAINING LOSS: 4.118446
# EPOCH 80 TOTAL TRAINING LOSS: 4.050459
# EPOCH 81 TOTAL TRAINING LOSS: 3.589044
# EPOCH 82 TOTAL TRAINING LOSS: 3.871943
# EPOCH 83 TOTAL TRAINING LOSS: 4.363320
# EPOCH 84 TOTAL TRAINING LOSS: 3.771564
# EPOCH 85 TOTAL TRAINING LOSS: 3.417542
# EPOCH 86 TOTAL TRAINING LOSS: 3.760473
# EPOCH 87 TOTAL TRAINING LOSS: 3.764827
# EPOCH 88 TOTAL TRAINING LOSS: 4.042420
# EPOCH 89 TOTAL TRAINING LOSS: 4.289997
# EPOCH 90 TOTAL TRAINING LOSS: 3.779123
# EPOCH 91 TOTAL TRAINING LOSS: 3.518457
# EPOCH 92 TOTAL TRAINING LOSS: 3.587669
# EPOCH 93 TOTAL TRAINING LOSS: 3.976295
# EPOCH 94 TOTAL TRAINING LOSS: 4.349180
# EPOCH 95 TOTAL TRAINING LOSS: 3.885311
# EPOCH 96 TOTAL TRAINING LOSS: 3.636861
# EPOCH 97 TOTAL TRAINING LOSS: 3.673796
# EPOCH 98 TOTAL TRAINING LOSS: 3.521812
# EPOCH 99 TOTAL TRAINING LOSS: 4.011496
# EPOCH 100 TOTAL TRAINING LOSS: 4.23075
# EPOCH 101 TOTAL TRAINING LOSS: 3.567607
# EPOCH 102 TOTAL TRAINING LOSS: 3.007006
# EPOCH 103 TOTAL TRAINING LOSS: 3.456325
# EPOCH 104 TOTAL TRAINING LOSS: 3.900682
# EPOCH 105 TOTAL TRAINING LOSS: 4.109934
# EPOCH 106 TOTAL TRAINING LOSS: 3.524312
# EPOCH 107 TOTAL TRAINING LOSS: 3.401623
# EPOCH 108 TOTAL TRAINING LOSS: 3.743716
# EPOCH 109 TOTAL TRAINING LOSS: 3.800199
# EPOCH 110 TOTAL TRAINING LOSS: 3.481955
# ...
# EPOCH 61 TOTAL TRAINING LOSS: 3.344662
# EPOCH 62 TOTAL TRAINING LOSS: 3.709051
# EPOCH 63 TOTAL TRAINING LOSS: 3.849302
# EPOCH 64 TOTAL TRAINING LOSS: 3.489678
# EPOCH 65 TOTAL TRAINING LOSS: 3.973288
# EPOCH 66 TOTAL TRAINING LOSS: 4.215513
# EPOCH 67 TOTAL TRAINING LOSS: 3.529426
# EPOCH 68 TOTAL TRAINING LOSS: 4.226982
# EPOCH 69 TOTAL TRAINING LOSS: 3.572706
# EPOCH 70 TOTAL TRAINING LOSS: 3.509988
# EPOCH 71 TOTAL TRAINING LOSS: 2.961104
# EPOCH 72 TOTAL TRAINING LOSS: 3.808424
# EPOCH 73 TOTAL TRAINING LOSS: 3.763976
# EPOCH 74 TOTAL TRAINING LOSS: 3.238908
# EPOCH 75 TOTAL TRAINING LOSS: 3.953908
# EPOCH 76 TOTAL TRAINING LOSS: 4.173271
# EPOCH 77 TOTAL TRAINING LOSS: 3.800729
# EPOCH 78 TOTAL TRAINING LOSS: 3.420190
# EPOCH 79 TOTAL TRAINING LOSS: 3.201916
# EPOCH 80 TOTAL TRAINING LOSS: 3.489292
# EPOCH 81 TOTAL TRAINING LOSS: 3.355974
# EPOCH 82 TOTAL TRAINING LOSS: 3.395887
# EPOCH 83 TOTAL TRAINING LOSS: 3.685998
# EPOCH 84 TOTAL TRAINING LOSS: 3.553424
# EPOCH 85 TOTAL TRAINING LOSS: 3.358444
# EPOCH 86 TOTAL TRAINING LOSS: 3.427836
# EPOCH 87 TOTAL TRAINING LOSS: 3.050254
# EPOCH 88 TOTAL TRAINING LOSS: 3.207672
# EPOCH 89 TOTAL TRAINING LOSS: 3.817769
# EPOCH 90 TOTAL TRAINING LOSS: 3.065726
# EPOCH 91 TOTAL TRAINING LOSS: 3.483459
# EPOCH 92 TOTAL TRAINING LOSS: 4.293719
# EPOCH 93 TOTAL TRAINING LOSS: 4.122742
# EPOCH 94 TOTAL TRAINING LOSS: 3.682200
# EPOCH 95 TOTAL TRAINING LOSS: 3.382810
# EPOCH 96 TOTAL TRAINING LOSS: 3.387591
# EPOCH 97 TOTAL TRAINING LOSS: 3.110628
# EPOCH 98 TOTAL TRAINING LOSS: 3.433968
# EPOCH 99 TOTAL TRAINING LOSS: 3.094945
# EPOCH 100 TOTAL TRAINING LOSS: 2.94915
# EPOCH 101 TOTAL TRAINING LOSS: 2.883378
# EPOCH 102 TOTAL TRAINING LOSS: 2.918656
# EPOCH 103 TOTAL TRAINING LOSS: 3.293610
# EPOCH 104 TOTAL TRAINING LOSS: 3.258707
# EPOCH 105 TOTAL TRAINING LOSS: 3.512105
# EPOCH 106 TOTAL TRAINING LOSS: 2.982256
# EPOCH 107 TOTAL TRAINING LOSS: 3.147699
# EPOCH 108 TOTAL TRAINING LOSS: 3.213845
# EPOCH 109 TOTAL TRAINING LOSS: 3.869466
# EPOCH 110 TOTAL TRAINING LOSS: 3.235670
# EPOCH 111 TOTAL TRAINING LOSS: 3.361623
# EPOCH 112 TOTAL TRAINING LOSS: 3.419755
# EPOCH 113 TOTAL TRAINING LOSS: 3.213822
# EPOCH 114 TOTAL TRAINING LOSS: 2.811415
# EPOCH 115 TOTAL TRAINING LOSS: 3.159446
# EPOCH 116 TOTAL TRAINING LOSS: 3.322958
# EPOCH 117 TOTAL TRAINING LOSS: 3.216327
# EPOCH 118 TOTAL TRAINING LOSS: 3.174347
# EPOCH 119 TOTAL TRAINING LOSS: 3.455953
# EPOCH 120 TOTAL TRAINING LOSS: 2.965514
# EPOCH 121 TOTAL TRAINING LOSS: 3.262032
# EPOCH 122 TOTAL TRAINING LOSS: 3.073438
# EPOCH 123 TOTAL TRAINING LOSS: 3.224652
# EPOCH 124 TOTAL TRAINING LOSS: 3.386911
# EPOCH 125 TOTAL TRAINING LOSS: 3.800954
# EPOCH 126 TOTAL TRAINING LOSS: 3.499997
# EPOCH 127 TOTAL TRAINING LOSS: 2.800153
# EPOCH 128 TOTAL TRAINING LOSS: 3.313545
# EPOCH 129 TOTAL TRAINING LOSS: 4.104730
# EPOCH 130 TOTAL TRAINING LOSS: 4.367068
# EPOCH 131 TOTAL TRAINING LOSS: 3.544783
# EPOCH 132 TOTAL TRAINING LOSS: 3.789033
# EPOCH 133 TOTAL TRAINING LOSS: 3.325117
# EPOCH 134 TOTAL TRAINING LOSS: 3.647768
# EPOCH 135 TOTAL TRAINING LOSS: 3.730040
# EPOCH 136 TOTAL TRAINING LOSS: 3.450600
# EPOCH 137 TOTAL TRAINING LOSS: 3.142849
# EPOCH 138 TOTAL TRAINING LOSS: 4.027543
# EPOCH 139 TOTAL TRAINING LOSS: 2.879336
# EPOCH 140 TOTAL TRAINING LOSS: 3.134205
# EPOCH 141 TOTAL TRAINING LOSS: 3.732503
# EPOCH 142 TOTAL TRAINING LOSS: 3.288542
# EPOCH 143 TOTAL TRAINING LOSS: 3.115812
# EPOCH 144 TOTAL TRAINING LOSS: 3.794596
# EPOCH 145 TOTAL TRAINING LOSS: 3.544232
# EPOCH 146 TOTAL TRAINING LOSS: 2.968664
# EPOCH 147 TOTAL TRAINING LOSS: 3.173125
# EPOCH 148 TOTAL TRAINING LOSS: 3.141724
# EPOCH 149 TOTAL TRAINING LOSS: 3.790252
# EPOCH 150 TOTAL TRAINING LOSS: 3.437009
# Using device(prediction head) : cuda495
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 4.8552
# EPOCH 2 TOTAL TRAINING LOSS: 5.318986
# EPOCH 3 TOTAL TRAINING LOSS: 5.013284
# EPOCH 4 TOTAL TRAINING LOSS: 5.338573
# EPOCH 5 TOTAL TRAINING LOSS: 6.074066
# EPOCH 6 TOTAL TRAINING LOSS: 5.756875
# EPOCH 7 TOTAL TRAINING LOSS: 5.624875
# EPOCH 8 TOTAL TRAINING LOSS: 6.030077
# EPOCH 9 TOTAL TRAINING LOSS: 5.122896
# EPOCH 10 TOTAL TRAINING LOSS: 6.02491
# EPOCH 11 TOTAL TRAINING LOSS: 5.760320
# EPOCH 12 TOTAL TRAINING LOSS: 5.666643
# EPOCH 13 TOTAL TRAINING LOSS: 5.709356
# EPOCH 14 TOTAL TRAINING LOSS: 5.386291
# EPOCH 15 TOTAL TRAINING LOSS: 4.925005
# EPOCH 16 TOTAL TRAINING LOSS: 4.840732
# EPOCH 17 TOTAL TRAINING LOSS: 5.382166
# EPOCH 18 TOTAL TRAINING LOSS: 4.915307
# EPOCH 19 TOTAL TRAINING LOSS: 5.303032
# EPOCH 20 TOTAL TRAINING LOSS: 5.074961
# EPOCH 21 TOTAL TRAINING LOSS: 5.526388
# EPOCH 22 TOTAL TRAINING LOSS: 5.328717
# EPOCH 23 TOTAL TRAINING LOSS: 5.123268
# EPOCH 24 TOTAL TRAINING LOSS: 4.209616
# EPOCH 25 TOTAL TRAINING LOSS: 4.462310
# EPOCH 26 TOTAL TRAINING LOSS: 4.150159
# EPOCH 27 TOTAL TRAINING LOSS: 4.693354
# EPOCH 28 TOTAL TRAINING LOSS: 4.628861
# EPOCH 29 TOTAL TRAINING LOSS: 4.404891
# EPOCH 30 TOTAL TRAINING LOSS: 4.552109
# EPOCH 31 TOTAL TRAINING LOSS: 4.588194
# EPOCH 32 TOTAL TRAINING LOSS: 4.243972
# EPOCH 33 TOTAL TRAINING LOSS: 4.550251
# EPOCH 34 TOTAL TRAINING LOSS: 4.518908
# EPOCH 35 TOTAL TRAINING LOSS: 4.178442
# EPOCH 36 TOTAL TRAINING LOSS: 4.317663
# EPOCH 37 TOTAL TRAINING LOSS: 4.191163
# EPOCH 38 TOTAL TRAINING LOSS: 4.434487
# EPOCH 39 TOTAL TRAINING LOSS: 4.246916
# EPOCH 40 TOTAL TRAINING LOSS: 4.151947
# EPOCH 41 TOTAL TRAINING LOSS: 4.615794
# EPOCH 42 TOTAL TRAINING LOSS: 4.812698
# EPOCH 43 TOTAL TRAINING LOSS: 3.877505
# EPOCH 44 TOTAL TRAINING LOSS: 4.570933
# EPOCH 45 TOTAL TRAINING LOSS: 3.992390
# EPOCH 46 TOTAL TRAINING LOSS: 3.865572
# EPOCH 47 TOTAL TRAINING LOSS: 4.218668
# EPOCH 48 TOTAL TRAINING LOSS: 4.017392
# EPOCH 49 TOTAL TRAINING LOSS: 4.039186
# EPOCH 50 TOTAL TRAINING LOSS: 4.627146
# EPOCH 51 TOTAL TRAINING LOSS: 4.042653
# EPOCH 52 TOTAL TRAINING LOSS: 4.415342
# EPOCH 53 TOTAL TRAINING LOSS: 4.047439
# EPOCH 54 TOTAL TRAINING LOSS: 3.962411
# EPOCH 55 TOTAL TRAINING LOSS: 4.252286
# EPOCH 56 TOTAL TRAINING LOSS: 4.532974
# EPOCH 57 TOTAL TRAINING LOSS: 4.329345
# EPOCH 58 TOTAL TRAINING LOSS: 4.348523
# EPOCH 59 TOTAL TRAINING LOSS: 3.386096
# EPOCH 60 TOTAL TRAINING LOSS: 3.952462
# EPOCH 61 TOTAL TRAINING LOSS: 3.934137
# EPOCH 62 TOTAL TRAINING LOSS: 3.839583
# EPOCH 63 TOTAL TRAINING LOSS: 3.564446
# EPOCH 64 TOTAL TRAINING LOSS: 4.528383
# EPOCH 65 TOTAL TRAINING LOSS: 3.813996
# EPOCH 66 TOTAL TRAINING LOSS: 3.949371
# EPOCH 67 TOTAL TRAINING LOSS: 4.184238
# EPOCH 68 TOTAL TRAINING LOSS: 4.409510
# EPOCH 69 TOTAL TRAINING LOSS: 4.368368
# EPOCH 70 TOTAL TRAINING LOSS: 4.069207
# EPOCH 71 TOTAL TRAINING LOSS: 4.335538
# EPOCH 72 TOTAL TRAINING LOSS: 3.402611
# EPOCH 73 TOTAL TRAINING LOSS: 4.207889
# EPOCH 74 TOTAL TRAINING LOSS: 3.737882
# EPOCH 75 TOTAL TRAINING LOSS: 4.649174
# EPOCH 76 TOTAL TRAINING LOSS: 4.157122
# EPOCH 77 TOTAL TRAINING LOSS: 3.966560
# EPOCH 78 TOTAL TRAINING LOSS: 4.065326
# EPOCH 79 TOTAL TRAINING LOSS: 3.651464
# EPOCH 80 TOTAL TRAINING LOSS: 4.639303
# EPOCH 81 TOTAL TRAINING LOSS: 4.000022
# EPOCH 82 TOTAL TRAINING LOSS: 3.860684
# EPOCH 83 TOTAL TRAINING LOSS: 3.756506
# EPOCH 84 TOTAL TRAINING LOSS: 3.973520
# EPOCH 85 TOTAL TRAINING LOSS: 3.891984
# EPOCH 86 TOTAL TRAINING LOSS: 4.417126
# EPOCH 87 TOTAL TRAINING LOSS: 3.329478
# EPOCH 88 TOTAL TRAINING LOSS: 3.599082
# EPOCH 89 TOTAL TRAINING LOSS: 3.438633
# EPOCH 90 TOTAL TRAINING LOSS: 3.735562
# EPOCH 91 TOTAL TRAINING LOSS: 3.202180
# EPOCH 92 TOTAL TRAINING LOSS: 3.321755
# EPOCH 93 TOTAL TRAINING LOSS: 4.523624
# EPOCH 94 TOTAL TRAINING LOSS: 3.569606
# EPOCH 95 TOTAL TRAINING LOSS: 3.500525
# EPOCH 96 TOTAL TRAINING LOSS: 3.604424
# EPOCH 97 TOTAL TRAINING LOSS: 3.903452
# EPOCH 98 TOTAL TRAINING LOSS: 3.460599
# EPOCH 99 TOTAL TRAINING LOSS: 3.758629
# EPOCH 100 TOTAL TRAINING LOSS: 3.48058
# EPOCH 101 TOTAL TRAINING LOSS: 3.794725
# EPOCH 102 TOTAL TRAINING LOSS: 3.719309
# EPOCH 103 TOTAL TRAINING LOSS: 3.616203
# EPOCH 104 TOTAL TRAINING LOSS: 3.426288
# EPOCH 105 TOTAL TRAINING LOSS: 3.748745
# EPOCH 106 TOTAL TRAINING LOSS: 3.358465
# EPOCH 107 TOTAL TRAINING LOSS: 3.594148
# EPOCH 108 TOTAL TRAINING LOSS: 3.582483
# EPOCH 109 TOTAL TRAINING LOSS: 3.440756
# EPOCH 110 TOTAL TRAINING LOSS: 3.641461
# EPOCH 111 TOTAL TRAINING LOSS: 3.201929
# EPOCH 112 TOTAL TRAINING LOSS: 3.520186
# EPOCH 113 TOTAL TRAINING LOSS: 3.606862
# EPOCH 114 TOTAL TRAINING LOSS: 3.765107
# EPOCH 115 TOTAL TRAINING LOSS: 3.422154
# EPOCH 116 TOTAL TRAINING LOSS: 3.071927
# EPOCH 117 TOTAL TRAINING LOSS: 3.696533
# EPOCH 118 TOTAL TRAINING LOSS: 3.625253
# EPOCH 119 TOTAL TRAINING LOSS: 3.634735
# EPOCH 120 TOTAL TRAINING LOSS: 3.462725
# EPOCH 121 TOTAL TRAINING LOSS: 3.255364
# EPOCH 122 TOTAL TRAINING LOSS: 3.409925
# EPOCH 123 TOTAL TRAINING LOSS: 3.613025
# EPOCH 124 TOTAL TRAINING LOSS: 3.476084
# EPOCH 125 TOTAL TRAINING LOSS: 3.518669
# EPOCH 126 TOTAL TRAINING LOSS: 3.504229
# EPOCH 127 TOTAL TRAINING LOSS: 3.501241
# EPOCH 128 TOTAL TRAINING LOSS: 3.792479
# EPOCH 129 TOTAL TRAINING LOSS: 3.563908
# EPOCH 130 TOTAL TRAINING LOSS: 3.392698
# EPOCH 131 TOTAL TRAINING LOSS: 4.150366
# EPOCH 132 TOTAL TRAINING LOSS: 3.319912
# EPOCH 133 TOTAL TRAINING LOSS: 4.027922
# EPOCH 134 TOTAL TRAINING LOSS: 3.418046
# EPOCH 135 TOTAL TRAINING LOSS: 3.921482
# EPOCH 136 TOTAL TRAINING LOSS: 3.417632
# EPOCH 137 TOTAL TRAINING LOSS: 3.845523
# EPOCH 138 TOTAL TRAINING LOSS: 3.147130
# EPOCH 139 TOTAL TRAINING LOSS: 3.248620
# EPOCH 140 TOTAL TRAINING LOSS: 3.858652
# EPOCH 141 TOTAL TRAINING LOSS: 4.063879
# EPOCH 142 TOTAL TRAINING LOSS: 4.411132
# EPOCH 143 TOTAL TRAINING LOSS: 3.692634
# EPOCH 144 TOTAL TRAINING LOSS: 3.728202
# EPOCH 145 TOTAL TRAINING LOSS: 3.364413
# EPOCH 146 TOTAL TRAINING LOSS: 3.712606
# EPOCH 147 TOTAL TRAINING LOSS: 3.910668
# EPOCH 148 TOTAL TRAINING LOSS: 3.811491
# EPOCH 149 TOTAL TRAINING LOSS: 3.277645
# EPOCH 150 TOTAL TRAINING LOSS: 3.882288
# Using device(prediction head) : cuda189
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.9591
# EPOCH 2 TOTAL TRAINING LOSS: 6.007792
# EPOCH 3 TOTAL TRAINING LOSS: 6.203133
# EPOCH 4 TOTAL TRAINING LOSS: 6.410886
# EPOCH 5 TOTAL TRAINING LOSS: 6.178051
# EPOCH 6 TOTAL TRAINING LOSS: 5.634429
# EPOCH 7 TOTAL TRAINING LOSS: 5.552095
# EPOCH 8 TOTAL TRAINING LOSS: 6.167183
# EPOCH 9 TOTAL TRAINING LOSS: 5.747597
# EPOCH 10 TOTAL TRAINING LOSS: 5.98484
# EPOCH 11 TOTAL TRAINING LOSS: 6.494878
# EPOCH 12 TOTAL TRAINING LOSS: 5.399214
# EPOCH 13 TOTAL TRAINING LOSS: 6.290073
# EPOCH 14 TOTAL TRAINING LOSS: 5.895330
# EPOCH 15 TOTAL TRAINING LOSS: 6.297208
# EPOCH 16 TOTAL TRAINING LOSS: 4.913390
# EPOCH 17 TOTAL TRAINING LOSS: 6.396642
# EPOCH 18 TOTAL TRAINING LOSS: 5.325447
# EPOCH 19 TOTAL TRAINING LOSS: 5.341751
# EPOCH 20 TOTAL TRAINING LOSS: 5.533616
# EPOCH 21 TOTAL TRAINING LOSS: 5.531357
# EPOCH 22 TOTAL TRAINING LOSS: 4.894298
# EPOCH 23 TOTAL TRAINING LOSS: 5.328351
# EPOCH 24 TOTAL TRAINING LOSS: 4.898612
# EPOCH 25 TOTAL TRAINING LOSS: 4.926770
# EPOCH 26 TOTAL TRAINING LOSS: 5.146399
# EPOCH 27 TOTAL TRAINING LOSS: 5.222202
# EPOCH 28 TOTAL TRAINING LOSS: 4.959085
# EPOCH 29 TOTAL TRAINING LOSS: 4.577645
# EPOCH 30 TOTAL TRAINING LOSS: 4.793100
# EPOCH 31 TOTAL TRAINING LOSS: 5.118595
# EPOCH 32 TOTAL TRAINING LOSS: 5.361214
# EPOCH 33 TOTAL TRAINING LOSS: 4.305044
# EPOCH 34 TOTAL TRAINING LOSS: 4.197171
# EPOCH 35 TOTAL TRAINING LOSS: 5.020263
# EPOCH 36 TOTAL TRAINING LOSS: 4.884555
# EPOCH 37 TOTAL TRAINING LOSS: 4.714908
# EPOCH 38 TOTAL TRAINING LOSS: 5.567174
# EPOCH 39 TOTAL TRAINING LOSS: 5.422496
# EPOCH 40 TOTAL TRAINING LOSS: 5.570088
# EPOCH 41 TOTAL TRAINING LOSS: 4.693164
# EPOCH 42 TOTAL TRAINING LOSS: 4.601026
# EPOCH 43 TOTAL TRAINING LOSS: 5.698411
# EPOCH 44 TOTAL TRAINING LOSS: 4.260204
# EPOCH 45 TOTAL TRAINING LOSS: 4.682068
# EPOCH 46 TOTAL TRAINING LOSS: 4.165487
# EPOCH 47 TOTAL TRAINING LOSS: 4.248203
# EPOCH 48 TOTAL TRAINING LOSS: 4.648560
# EPOCH 49 TOTAL TRAINING LOSS: 4.488727
# EPOCH 50 TOTAL TRAINING LOSS: 5.309338
# EPOCH 51 TOTAL TRAINING LOSS: 3.988711
# EPOCH 52 TOTAL TRAINING LOSS: 5.152135
# EPOCH 53 TOTAL TRAINING LOSS: 4.123709
# EPOCH 54 TOTAL TRAINING LOSS: 4.282842
# EPOCH 55 TOTAL TRAINING LOSS: 3.722996
# EPOCH 56 TOTAL TRAINING LOSS: 4.539711
# EPOCH 57 TOTAL TRAINING LOSS: 4.672571
# EPOCH 58 TOTAL TRAINING LOSS: 3.947257
# EPOCH 59 TOTAL TRAINING LOSS: 4.281771
# EPOCH 60 TOTAL TRAINING LOSS: 5.127018
# EPOCH 61 TOTAL TRAINING LOSS: 4.008041
# EPOCH 62 TOTAL TRAINING LOSS: 4.227321
# EPOCH 63 TOTAL TRAINING LOSS: 4.304532
# EPOCH 64 TOTAL TRAINING LOSS: 4.827798
# EPOCH 65 TOTAL TRAINING LOSS: 3.697200
# EPOCH 66 TOTAL TRAINING LOSS: 4.353969
# EPOCH 67 TOTAL TRAINING LOSS: 4.649363
# EPOCH 68 TOTAL TRAINING LOSS: 4.029607
# EPOCH 69 TOTAL TRAINING LOSS: 4.692565
# EPOCH 70 TOTAL TRAINING LOSS: 3.733144
# EPOCH 71 TOTAL TRAINING LOSS: 4.668964
# EPOCH 72 TOTAL TRAINING LOSS: 4.259310
# EPOCH 73 TOTAL TRAINING LOSS: 4.621148
# EPOCH 74 TOTAL TRAINING LOSS: 4.009109
# EPOCH 75 TOTAL TRAINING LOSS: 4.420495
# EPOCH 76 TOTAL TRAINING LOSS: 3.983350
# EPOCH 77 TOTAL TRAINING LOSS: 4.081225
# EPOCH 78 TOTAL TRAINING LOSS: 3.691812
# EPOCH 79 TOTAL TRAINING LOSS: 4.158992
# EPOCH 80 TOTAL TRAINING LOSS: 3.919701
# EPOCH 81 TOTAL TRAINING LOSS: 4.282401
# EPOCH 82 TOTAL TRAINING LOSS: 4.626025
# EPOCH 83 TOTAL TRAINING LOSS: 3.902656
# EPOCH 84 TOTAL TRAINING LOSS: 3.957933
# EPOCH 85 TOTAL TRAINING LOSS: 4.174959
# EPOCH 86 TOTAL TRAINING LOSS: 4.152309
# EPOCH 87 TOTAL TRAINING LOSS: 3.549637
# EPOCH 88 TOTAL TRAINING LOSS: 3.651751
# EPOCH 89 TOTAL TRAINING LOSS: 4.279572
# EPOCH 90 TOTAL TRAINING LOSS: 4.084749
# EPOCH 91 TOTAL TRAINING LOSS: 4.117678
# EPOCH 92 TOTAL TRAINING LOSS: 4.550984
# EPOCH 93 TOTAL TRAINING LOSS: 3.439725
# EPOCH 94 TOTAL TRAINING LOSS: 3.921166
# EPOCH 95 TOTAL TRAINING LOSS: 3.969312
# EPOCH 96 TOTAL TRAINING LOSS: 3.220932
# EPOCH 97 TOTAL TRAINING LOSS: 3.506422
# EPOCH 98 TOTAL TRAINING LOSS: 3.780994
# EPOCH 99 TOTAL TRAINING LOSS: 3.590649
# EPOCH 100 TOTAL TRAINING LOSS: 4.15599
# EPOCH 101 TOTAL TRAINING LOSS: 3.851299
# EPOCH 102 TOTAL TRAINING LOSS: 4.163986
# EPOCH 103 TOTAL TRAINING LOSS: 4.162885
# EPOCH 104 TOTAL TRAINING LOSS: 3.460514
# EPOCH 105 TOTAL TRAINING LOSS: 3.498585
# EPOCH 106 TOTAL TRAINING LOSS: 3.859278
# EPOCH 107 TOTAL TRAINING LOSS: 3.877874
# EPOCH 108 TOTAL TRAINING LOSS: 3.461320
# EPOCH 109 TOTAL TRAINING LOSS: 3.731518
# EPOCH 110 TOTAL TRAINING LOSS: 3.380288
# EPOCH 111 TOTAL TRAINING LOSS: 3.471579
# EPOCH 112 TOTAL TRAINING LOSS: 3.297532
# EPOCH 113 TOTAL TRAINING LOSS: 3.451561
# EPOCH 114 TOTAL TRAINING LOSS: 3.835152
# EPOCH 115 TOTAL TRAINING LOSS: 4.248679
# EPOCH 116 TOTAL TRAINING LOSS: 3.728944
# EPOCH 117 TOTAL TRAINING LOSS: 3.873930
# EPOCH 118 TOTAL TRAINING LOSS: 3.948257
# EPOCH 119 TOTAL TRAINING LOSS: 3.858638
# EPOCH 120 TOTAL TRAINING LOSS: 3.357152
# EPOCH 121 TOTAL TRAINING LOSS: 3.917084
# EPOCH 122 TOTAL TRAINING LOSS: 3.570344
# EPOCH 123 TOTAL TRAINING LOSS: 3.333696
# EPOCH 124 TOTAL TRAINING LOSS: 4.321538
# EPOCH 125 TOTAL TRAINING LOSS: 3.528432
# EPOCH 126 TOTAL TRAINING LOSS: 3.551923
# EPOCH 127 TOTAL TRAINING LOSS: 4.448812
# EPOCH 128 TOTAL TRAINING LOSS: 3.829022
# EPOCH 129 TOTAL TRAINING LOSS: 2.816248
# EPOCH 130 TOTAL TRAINING LOSS: 3.488559
# EPOCH 131 TOTAL TRAINING LOSS: 3.873666
# EPOCH 132 TOTAL TRAINING LOSS: 3.709254
# EPOCH 133 TOTAL TRAINING LOSS: 3.694463
# EPOCH 134 TOTAL TRAINING LOSS: 3.570585
# EPOCH 135 TOTAL TRAINING LOSS: 3.672959
# EPOCH 136 TOTAL TRAINING LOSS: 4.235114
# EPOCH 137 TOTAL TRAINING LOSS: 3.875369
# EPOCH 138 TOTAL TRAINING LOSS: 3.527797
# EPOCH 139 TOTAL TRAINING LOSS: 3.271572
# EPOCH 140 TOTAL TRAINING LOSS: 3.226824
# EPOCH 141 TOTAL TRAINING LOSS: 4.638546
# EPOCH 142 TOTAL TRAINING LOSS: 2.890524
# EPOCH 143 TOTAL TRAINING LOSS: 3.780455
# EPOCH 144 TOTAL TRAINING LOSS: 3.518870
# EPOCH 145 TOTAL TRAINING LOSS: 3.327566
# EPOCH 146 TOTAL TRAINING LOSS: 3.755784
# EPOCH 147 TOTAL TRAINING LOSS: 3.723079
# EPOCH 148 TOTAL TRAINING LOSS: 3.250991
# EPOCH 149 TOTAL TRAINING LOSS: 3.207869
# EPOCH 150 TOTAL TRAINING LOSS: 4.433734
# EPOCH 150 TOTAL VALIDATION LOSS: 4.9555

# %%
run_name = build_run_name(
    model=clm,
    epochs=EPOCHS_II,
    base_lr=base_lr_II,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_II_class,
    scheduler_cfg=scheduler_II_cfg,
    contrastive_loss_cfg=None,
    modality_list=list(name_emb_dict.keys())
)

# %%
get_cv_results(reg_dict, clf_dict, 'old_' + run_name, time=runtime, save=True)
# Out:
#                                                  run  n_folds        time  \
# 0  old_ClinicalLinkageModule_E150_lr1e-04_CosineA...       30  341.097006
#
#    low_rmse_os  avg_rmse_os  up_rmse_os  low_rmse_pfs  avg_rmse_pfs  \
# 0     1.192986     1.229372    1.276038      1.200548      1.241086
#
#    up_rmse_pfs  low_f1_recurrency  avg_f1_recurrency  up_f1_recurrency  \
# 0     1.282301           0.497562           0.515335          0.532844
#
#    low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  sum_reg_avg  sum_clf_avg  \
# 0     0.366828     0.388021    0.403591     2.470458     0.903356
#
#    sum_reg_ci_relative_width  sum_clf_ci_relative_width
# 0                   0.133428                   0.163208

# %% [markdown]
# ## **Results**

# %%
evaluations = {}
for task in cv_scores.keys():
    evaluations[task] = np.mean(cv_scores[task])
    print(f"MCCV score on task {task}: {evaluations[task]}")
# Out:
# MCCV score on task os: 1.2293719132741292
# MCCV score on task pfs: 1.2410860260327656
# MCCV score on task recurrency: 0.5153353229194326
# MCCV score on task mgmt: 0.38802117023654775

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf")

# %% [markdown]
# ## Save ClinicalLinkageModule

# %%
save_model(clm, '../saved_models/old_framework_clm.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/old_framework_clm.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_framework_clm.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/old_framework_clm.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_old_framework_clm.ckpt'))
