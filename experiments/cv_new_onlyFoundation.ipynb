# %% [markdown]
# # Evaluation of the new framework (only foundation models)

# %%
import sys
import os

project_path = "/home/sagemaker-user/gbm_hackathon"
if project_path not in sys.path:
    sys.path.append(project_path)
    print(sys.path)
# Out:
# ['/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python310.zip', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/lib-dynload', '', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/site-packages', '/home/sagemaker-user/gbm_hackathon']

# %%
# %load_ext autoreload
# %autoreload 2

from gbmhackathon.training.predictive import *
from gbmhackathon.models.mme import MultiModalEncoder, ClinicalLinkageModule, concat_modality_embeddings
from gbmhackathon.utils.loss_functions import InfoNCELoss, RegularizedInfoNCELoss, SmoothingFunction, RankMe, make_patient_map, RegularizationModule
from gbmhackathon.utils.module_functions import instantiate
from gbmhackathon.utils.model_saving import *
from gbmhackathon.training.loops import modality_wise_contrastive_learning, new_predictive_learning, build_run_name
from gbmhackathon.training.cv import *
from gbmhackathon.utils.analysis import *
from gbmhackathon.viz.viz_experiment import *
from gbmhackathon.s3_loader import load_s3

import os, time
from copy import deepcopy
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
# To investigate gradients


import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam

# %%
torch.set_num_threads(32)
torch.get_num_threads()
# Out:
# 32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %% [markdown]
# ## Dataset preparation

# %%
ALL_POSSIBLE_EMBS = ["025-03-22_12-27_phikon_emb_V1.pkl",
                    "2025-03-23_18-32_spatial_emb_V1.pkl",
                    "2025-03-30_14-23_clinical_emb_V1.pkl",
                    "2025-04-05_13-40_wes_emb_V1.pkl",
                    "2025-04-26_16-02_connectivities_spatial_V1.pkl",
                    "2025-05-03_10-15_bulk_emb_V1.pkl",
                    "2025-05-04_02-35_scRNA_emb_V1.pkl",
                    "2025-05-25_14-36_new_clinical_emb_V1.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_mds.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_pca.pkl",
                    "2025-06-01_15-11_bulk_emb_V1_umap.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_mds.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_pca.pkl",
                    "2025-06-01_15-11_embeddings_HnE_OptimusH0_umap.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_mds.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_pca.pkl",
                    "2025-06-01_15-11_scRNA_emb_V1_umap.pkl",
                    "2025-06-01_15-11_wes_emb_V1_mds.pkl",
                    "2025-06-01_15-11_wes_emb_V1_pca.pkl",
                    "2025-06-01_15-11_wes_emb_V1_umap.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_mds.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_pca.pkl",
                    "2025-06-01_18-36_raw_bulk_emb_umap.pkl",
                    "2025-06-01_21-03_raw_spatial_emb_pca.pkl",
                    "2025-06-01_22-10_raw_spatial_emb_umap.pkl",
                    "2025-06-02_21-09_raw_scRNA_emb_pca.pkl",
                    "2025-06-02_22-50_raw_scRNA_emb_umap.pkl",
                    "embeddings_HnE_OptimusH0.pkl"]

# %% [markdown]
# ### You can choose any embedding from the above

# %%
name_emb_dict = {"hne":"embeddings_HnE_OptimusH0.pkl",
"spatial":"2025-03-23_18-32_spatial_emb_V1.pkl",
"clinical":"2025-05-25_14-36_new_clinical_emb_V1.pkl", # Needed to retrieve targets, will be removed afterwards
"bulk":"2025-05-03_10-15_bulk_emb_V1.pkl",
"scRNA":"2025-05-04_02-35_scRNA_emb_V1.pkl"
                }
pkl_storage_folder = "embedding_V1"

# %%
dataset = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, 
                                    device=device, 
                                    dropout=1.0, 
                                    normalize=True, 
                                    remove_clinical=True)
print(f"Dataset size: {len(dataset)}")
BATCH_SIZE = 742 #582
dataloader = DataLoader(dataset, BATCH_SIZE, shuffle=True, collate_fn=collate_predictive, generator=torch.Generator(device=dataset.device))
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# dict_keys(['hne', 'spatial', 'bulk', 'scRNA'])
# Clinical successfully removed
# spatial tensor([-1.2553, -1.1431, -1.0777, -1.2676, -0.8982, -1.1545, -0.8487, -1.2577,
#         -0.9547, -1.1874, -1.0252, -1.2998, -1.3097, -1.2077, -1.3141, -1.2162,
#         -1.0057, -1.2872, -0.9572, -1.0273, -1.0509, -1.0739, -0.9225, -1.1718,
#         -1.1085, -1.2474, -1.2076, -1.3897, -1.0923, -1.1740, -1.0682, -1.4825,
#         -1.2190, -1.1134, -0.9512, -1.2223, -0.9888, -1.1704, -0.9840, -1.0893,
#         -1.2488, -1.1461, -1.0863, -1.0485, -1.1140, -0.9333, -1.0830, -1.0695,
#         -1.1005, -0.9239, -1.3218, -0.9554, -1.0725, -1.1427, -1.0236, -1.1748,
#         -0.9028, -1.0569, -1.0684, -1.0735, -0.9262, -1.0439, -0.9128, -1.0088,
#         -1.0696, -1.1391, -0.8199, -0.8497, -1.4329, -1.0332, -0.8422, -1.0564,
#         -1.0540, -0.9929, -0.9593, -1.2920, -1.2158, -1.0403, -0.9243, -1.1929,
#         -0.9487, -1.1276, -1.3280, -0.8531, -1.1883, -1.0247], device='cuda:0')
# Normalization applied successfully
# By keeping 100.00% of dropout augmented samples we went from:
# 88 dropout samples (43.78% dropout in dataset) -- to --> 88 dropout samples (43.78% dropout in dataset)
# Dataset size: 201

# %% [markdown]
# ### To make a batch of True patient samples only (no dropout)

# %%
# Batch of all true samples (no dropout augmented samples)
batch_all = [dataset.__getitem__(idx) for idx in dataset.ind2patient if 'd' not in dataset.ind2patient[idx]]
batch_all = collate_predictive(batch_all)

# %% [markdown]
# ### Needed to know the size of the inputs (it is used later on to define model configurations)

# %%
raw_emb = next(iter(dataloader))[2]
inpute_size_dict = {}
for mod in raw_emb.keys():
    print(mod, raw_emb[mod].size())
    inpute_size_dict[mod] = raw_emb[mod].size(1)
# Out:
# hne torch.Size([201, 1536])
# spatial torch.Size([201, 64])
# bulk torch.Size([201, 3072])
# scRNA torch.Size([201, 3072])

# %% [markdown]
# ### Patient map is used by the contrastive loss to identify dropout and true samples which are from the same original patient

# %%
patient_map = make_patient_map(dataset)

# %% [markdown]
# ### Configuration of the MultiModalEncoder (see gbmhackathon/models/mme.py)

# %%
def adapt_base_config(base_cfg, input_size):
    base_copy = deepcopy(base_cfg)
    base_copy["layers"] = [input_size] + base_copy["layers"]
    return base_copy

# %%
out = 32
norm_fn = nn.BatchNorm1d
smoothing_fn = SmoothingFunction(bound=-50, slope=0.1, rate=-5)
dropout = 0.3
layers = [1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
base_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

hne_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

clinical_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

spatial_cfg = {"layers": [256,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

wes_cfg = {"layers": [512,128,out],
        "dropout": dropout,
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

rna_cfg = {"layers": [1024,256,out], #[1024,128,512,128,out],
        "dropout": dropout,
        "act_fn":act_fn, #[nn.GELU, nn.GELU, nn.GELU, nn.GELU, smoothing_fn],
        "norm_layer":norm_fn,
        "device":device}


hne_cfg = adapt_base_config(hne_cfg, inpute_size_dict["hne"])
# clinical_cfg = adapt_base_config(clinical_cfg, inpute_size_dict["clinical"])
spatial_cfg = adapt_base_config(spatial_cfg, inpute_size_dict["spatial"])
# wes_cfg = adapt_base_config(wes_cfg, inpute_size_dict["wes"])
bulk_cfg = adapt_base_config(rna_cfg, inpute_size_dict["bulk"])
sc_cfg = adapt_base_config(rna_cfg, inpute_size_dict["scRNA"])

# %%
mme_bulk_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": bulk_cfg}

mme_hne_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": hne_cfg}

mme_sc_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": sc_cfg}

mme_wes_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": wes_cfg}

mme_clinical_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": clinical_cfg}

mme_spatial_cfg = {"net_type": "mlp",
                "device": device,
                "net_config": spatial_cfg}

# %%
mme_cfg = {"hne_cfg":mme_hne_cfg, 
           # "clinical_cfg":mme_clinical_cfg, 
           # "wes_cfg":mme_wes_cfg, 
           "spatial_cfg":mme_spatial_cfg,
           "bulk_cfg":mme_bulk_cfg,
          "sc_cfg":mme_sc_cfg}

# %% [markdown]
# ### Configuration of the Regularizer (see gbmhackathon/models/mme.py)

# %%
regularizer_cfg = {"reg_coeff":0.01,
        "use_variance":True,
        "var_coeff":1.0,
        "use_covariance":True,
        "cov_coeff":1.0,
        "var_gamma":1.0,
        "var_eps":1e-4,
}

# %% [markdown]
# ### Instantiation of training settings: model, optimizer, scheduler, epochs, learning rate.

# %%
mme = instantiate(mme_cfg,MultiModalEncoder)

EPOCHS_I = 50
base_lr_I = 1e-3
eta_min_coef = 0.05
scheduler_I_class = torch.optim.lr_scheduler.CosineAnnealingLR
scheduler_I_cfg = {"T_max":EPOCHS_I,
                  "eta_min":"dynamic"}

contrastive_loss_cfg = {"modalities":list(name_emb_dict.keys()),
                        "patient_map":patient_map,
                        'mode':'modality_scale',
                        "temperature":0.05,
                        "similarity":'nt-xent',
                        "use_all_positives":False,
                        "alpha":0,
                        "bound":-50,
                        "slope":0.1,
                        "rate":-5,
                        "warn":False,
                       "smoothing_func":False}

# Optimization for Phase I
optimizer_I = Adam(mme.parameters(), lr=base_lr_I)
scheduler_I_cfg["optimizer"] = optimizer_I
if "eta_min" in scheduler_I_cfg.keys():
    if scheduler_I_cfg["eta_min"] == "dynamic":
        scheduler_I_cfg["eta_min"] = eta_min_coef * base_lr_I
scheduler_I = instantiate(scheduler_I_cfg, scheduler_I_class)

contrastive_loss_fn = instantiate(contrastive_loss_cfg, RegularizedInfoNCELoss)

modalities = next(iter(dataloader))[2].keys()
    
# A contrastive loss module per modality
modality_contrastive_loss_fn = {}
for modality in modalities:
    contrastive_loss_cfg_mod = contrastive_loss_cfg.copy()
    contrastive_loss_cfg_mod['modalities'] = [modality]
    modality_contrastive_loss_fn[modality] = instantiate(contrastive_loss_cfg_mod, RegularizedInfoNCELoss)

# An optimizer per modality
modality_optimizers = {modality:Adam(mme.modality_net_map[modality].parameters(), lr=base_lr_I) for modality in modalities}

# A scheduler per modality
modality_schedulers = {}
for modality in modalities:
    # Same schedule for all modalities for now, but it can be configurable
    scheduler_cfg = scheduler_I_cfg.copy()
    scheduler_cfg["optimizer"] = modality_optimizers[modality]
    if "eta_min" in scheduler_I_cfg.keys():
        if scheduler_cfg["eta_min"] == "dynamic":
            scheduler_cfg["eta_min"] = eta_min_coef * base_lr_I
    modality_schedulers[modality] = instantiate(scheduler_cfg, scheduler_I_class)

# A regularization method per modality
regularizer_dict = {}
for modality in modalities:
    regularizer_dict[modality] = instantiate(regularizer_cfg, RegularizationModule)
# Out:
# {'net_type': 'mlp', 'device': 'cuda', 'net_config': {'layers': [1536, 512, 128, 32], 'dropout': 0.3, 'act_fn': [<class 'torch.nn.modules.activation.GELU'>, <class 'torch.nn.modules.activation.GELU'>, None], 'norm_layer': <class 'torch.nn.modules.batchnorm.BatchNorm1d'>, 'device': 'cuda'}}
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found
# Using device: cuda
# No potential residual connections found

# %% [markdown]
# ### Training loop for contrastive phase

# %%
modality_wise_contrastive_learning(mme, 
                                   dataloader, 
                                   EPOCHS_I, 
                                   base_lr_I,
                                   modality_optimizers, 
                                   modality_contrastive_loss_fn, 
                                   modality_schedulers,
                                   regularizer_dict,
                                   batch_all=batch_all,
                                   make_gifs=False,
                                   analyze_emb=True)
# Out:
# EPOCH 1 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.5325
# EPOCH 2 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.7250
# EPOCH 3 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.4052
# EPOCH 4 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.2182
# EPOCH 5 AVERAGE TOTAL LOSS ACROSS MODALITIES: 4.0896
# EPOCH 6 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.9916
# EPOCH 7 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.9177
# EPOCH 8 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.8599
# EPOCH 9 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.8123
# EPOCH 10 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7741
# EPOCH 11 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7421
# EPOCH 12 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.7157
# EPOCH 13 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6894
# EPOCH 14 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6666
# EPOCH 15 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6444
# EPOCH 16 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6231
# EPOCH 17 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.6038
# EPOCH 18 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5846
# EPOCH 19 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5650
# EPOCH 20 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5465
# EPOCH 21 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5291
# EPOCH 22 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.5113
# EPOCH 23 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4952
# EPOCH 24 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4797
# EPOCH 25 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4654
# EPOCH 26 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4503
# EPOCH 27 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4370
# EPOCH 28 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4256
# EPOCH 29 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4141
# EPOCH 30 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.4023
# EPOCH 31 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3924
# EPOCH 32 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3812
# EPOCH 33 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3703
# EPOCH 34 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3606
# EPOCH 35 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3511
# EPOCH 36 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3417
# EPOCH 37 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3324
# EPOCH 38 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3247
# EPOCH 39 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3174
# EPOCH 40 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3100
# EPOCH 41 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.3021
# EPOCH 42 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2946
# EPOCH 43 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2879
# EPOCH 44 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2810
# EPOCH 45 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2740
# EPOCH 46 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2679
# EPOCH 47 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2616
# EPOCH 48 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2552
# EPOCH 49 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2492
# EPOCH 50 AVERAGE TOTAL LOSS ACROSS MODALITIES: 3.2440

# %% [markdown]
# ## Save MultiModalEncoder

# %%
save_model(mme, '../saved_models/new_onlyFoundation_mme.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/new_onlyFoundation_mme.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_new_onlyFoundation_mme.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/new_onlyFoundation_mme.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_new_onlyFoundation_mme.ckpt'))

# %% [markdown]
# ## Use the trained MME to compute and save representations of true patient samples to use for the clinical linkage phase

# %%
run_name = build_run_name(
    model=mme,
    epochs=EPOCHS_I,
    base_lr=base_lr_I,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_I_class,
    scheduler_cfg=scheduler_I_cfg,
    contrastive_loss_cfg=contrastive_loss_cfg,
    modality_list=list(name_emb_dict.keys())
)

# %%
mme_emb_dict = mme(batch_all[2]) # Retrieves X_dict
folder = "mme_embeddings_only_foundation"
save_path = f"{folder}/{run_name}.pkl"
os.makedirs(folder, exist_ok=True)

with open(save_path, "wb") as f:
    pkl.dump(mme_emb_dict, f)

# %% [markdown]
# # Set everything up for clinical linkage phase
# We can choose to remove dropout or not by instantiating another dataset

# %%
dataset_II = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, 
                                    device=device, 
                                    dropout=0.0, 
                                    normalize=True, 
                                    remove_clinical=True)
print(f"Dataset size: {len(dataset_II)}")
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# dict_keys(['hne', 'spatial', 'bulk', 'scRNA'])
# Clinical successfully removed
# spatial tensor([-1.2553, -1.1431, -1.0777, -1.2676, -0.8982, -1.1545, -0.8487, -1.2577,
#         -0.9547, -1.1874, -1.0252, -1.2998, -1.3097, -1.2077, -1.3141, -1.2162,
#         -1.0057, -1.2872, -0.9572, -1.0273, -1.0509, -1.0739, -0.9225, -1.1718,
#         -1.1085, -1.2474, -1.2076, -1.3897, -1.0923, -1.1740, -1.0682, -1.4825,
#         -1.2190, -1.1134, -0.9512, -1.2223, -0.9888, -1.1704, -0.9840, -1.0893,
#         -1.2488, -1.1461, -1.0863, -1.0485, -1.1140, -0.9333, -1.0830, -1.0695,
#         -1.1005, -0.9239, -1.3218, -0.9554, -1.0725, -1.1427, -1.0236, -1.1748,
#         -0.9028, -1.0569, -1.0684, -1.0735, -0.9262, -1.0439, -0.9128, -1.0088,
#         -1.0696, -1.1391, -0.8199, -0.8497, -1.4329, -1.0332, -0.8422, -1.0564,
#         -1.0540, -0.9929, -0.9593, -1.2920, -1.2158, -1.0403, -0.9243, -1.1929,
#         -0.9487, -1.1276, -1.3280, -0.8531, -1.1883, -1.0247], device='cuda:0')
# Normalization applied successfully
# Dataset size: 113

# %% [markdown]
# ### Configuration of the clinical linkage module

# %%
dropout = 0.3
layers = [out*len(mme_cfg),16]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
norm_fn = nn.BatchNorm1d
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn":act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
# ATTENTION !!!! MUST BE THIS EXACT ORDER FOR PREDICTIVE TASKS: 
# ['os_years', 'pfs_years', 'largest_diameter_of_the_primary_tumour_mm_duplicated_0', 'recurrent_sample']
# OR ['os_years', 'pfs_years', 'recurrent_sample', 'mgmt_promoter_methylation'] if using latest targets
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}
refinement_cfg = {"emb_size": out*len(mme_cfg),
                "cross_modality_heads": 1,
                "cross_mods_fc_size": 1024,
                "avail_mods_fc_size": 128,
                "avail_mods_len":len(mme_cfg),
                "avail_mods_dense_size": 32,
                "avail_mods_heads": 1,
                "act_fn": nn.GELU,
                "dropout": dropout,
                "device": device}
clf_targets = ['recurrency', 'mgmt']
clf_targets_dict = {'recurrency':2, 'mgmt':3}

# %% [markdown]
# # Monte Carlo Cross Validation
# Instantiation must be done for each fold

# %%
n_splits = 30
test_size = 0.8
t_batch = 32 # training batch size
v_batch = 256 # evaluation batch size
random_state = 6262

# %%
cv_scores = {task:[] for task in predictive_cfg["heads_configs"].keys()}
t0 = time.time()
for train_loader, val_loader in get_mccv_loaders(dataset_II, 
                                                 collate_predictive,
                                                 n_splits=n_splits, 
                                                 test_size=test_size, 
                                                 train_batch_size=t_batch, 
                                                 val_batch_size=v_batch, 
                                                 device=device, 
                                                 random_state=random_state):
    EPOCHS_II = 150
    base_lr_II = 1e-4
    scheduler_II_class = torch.optim.lr_scheduler.CosineAnnealingLR
    scheduler_II_cfg = {"T_max":EPOCHS_II,
                        "eta_min":"dynamic"}
    clm = ClinicalLinkageModule(refinement_cfg=refinement_cfg,
                            predictive_cfg=predictive_cfg)
    # Optimization for Phase II
    optimizer_II = Adam(clm.parameters(), lr=base_lr_II)
    scheduler_II_cfg["optimizer"] = optimizer_II
    if "eta_min" in scheduler_II_cfg.keys():
        if scheduler_II_cfg["eta_min"] == "dynamic":
            scheduler_II_cfg["eta_min"] = eta_min_coef * base_lr_II
    scheduler_II = instantiate(scheduler_II_cfg, scheduler_II_class)

    # Training loop with validation at the end of each epoch on the validation set
    new_predictive_learning(mme, clm, 
                          train_loader,
                          EPOCHS_II, 
                          base_lr_II, 
                          optimizer_II,
                          scheduler_II,
                          clf_targets_dict,
                          v_dataloader=val_loader,
                          reg_loss_fn = nn.MSELoss(),
                          clf_loss_fn = nn.CrossEntropyLoss(),
                          batch_all=batch_all, # No worries, it is used in eval mode under the hood so not seen by model
                          make_gifs=False,
                          )
    # Evaluation metrics are computed on the validation set after training.
    clm.eval()
    all_val_predictions = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    all_val_targets = {task:[] for task in predictive_cfg["heads_configs"].keys()}
    for batch in val_loader:
        patient_ids, modalities, X_dict, avail_mods, batch_targets, targets_names = batch
        
        contrastive_outputs = mme(X_dict)
        task_outputs, patient_embeddings = clm(contrastive_outputs, avail_mods)
        
        overall_loss = torch.tensor(0, device=device)
        # Regression losses
        for i, key in enumerate(task_outputs.keys()):
            if key not in clf_targets:
                all_val_predictions[key].append(task_outputs[key].squeeze())
                all_val_targets[key].append(batch_targets[:,i])
            
        # Classification losses
        for i, key in enumerate(clf_targets):
            if i == 0:
                start_idx = len(task_outputs.keys()) - len(clf_targets)
            else:
                start_idx = end_idx - 1 # last end_idx
            # clf_targets_dict is a dict that maps each clf target to the number of classes it holds
            end_idx = start_idx + clf_targets_dict[key]
            all_val_predictions[key].append(task_outputs[key])
            all_val_targets[key].append(batch_targets[:,start_idx:end_idx])
            
    for task in all_val_predictions.keys():
        all_task_pred = torch.cat(all_val_predictions[task], dim=0).to(dataset.device)
        all_task_true = torch.cat(all_val_targets[task], dim=0).to(dataset.device)
        if task not in clf_targets:
            score = torch.sqrt(nn.MSELoss()(all_task_pred, all_task_true)).item()
        else:
            score = f1_score(torch.argmax(all_task_true, dim=1).cpu().detach().numpy(), 
                             torch.argmax(all_task_pred, dim=1).cpu().detach().numpy(), 
                             average='weighted', zero_division=0)
        cv_scores[task].append(score)
reg_dict = {key:val for key, val in cv_scores.items() if key in ['os', 'pfs']}
clf_dict = {key:val for key, val in cv_scores.items() if key in clf_targets}
runtime = time.time() - t0
# Out:
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.4407
# EPOCH 2 TOTAL TRAINING LOSS: 4.769000
# EPOCH 3 TOTAL TRAINING LOSS: 3.890258
# EPOCH 4 TOTAL TRAINING LOSS: 3.861989
# EPOCH 5 TOTAL TRAINING LOSS: 3.756700
# EPOCH 6 TOTAL TRAINING LOSS: 4.505409
# EPOCH 7 TOTAL TRAINING LOSS: 4.148012
# EPOCH 8 TOTAL TRAINING LOSS: 4.249867
# EPOCH 9 TOTAL TRAINING LOSS: 3.292114
# EPOCH 10 TOTAL TRAINING LOSS: 3.14379
# EPOCH 11 TOTAL TRAINING LOSS: 4.179348
# EPOCH 12 TOTAL TRAINING LOSS: 3.397943
# EPOCH 13 TOTAL TRAINING LOSS: 4.215602
# EPOCH 14 TOTAL TRAINING LOSS: 3.848446
# EPOCH 15 TOTAL TRAINING LOSS: 4.004516
# EPOCH 16 TOTAL TRAINING LOSS: 4.411357
# EPOCH 17 TOTAL TRAINING LOSS: 3.126680
# EPOCH 18 TOTAL TRAINING LOSS: 3.662637
# EPOCH 19 TOTAL TRAINING LOSS: 3.339057
# EPOCH 20 TOTAL TRAINING LOSS: 3.321789
# EPOCH 21 TOTAL TRAINING LOSS: 3.128021
# EPOCH 22 TOTAL TRAINING LOSS: 3.496794
# EPOCH 23 TOTAL TRAINING LOSS: 2.955791
# EPOCH 24 TOTAL TRAINING LOSS: 2.725421
# EPOCH 25 TOTAL TRAINING LOSS: 2.907905
# EPOCH 26 TOTAL TRAINING LOSS: 3.232444
# EPOCH 27 TOTAL TRAINING LOSS: 3.387684
# EPOCH 28 TOTAL TRAINING LOSS: 3.039901
# EPOCH 29 TOTAL TRAINING LOSS: 3.133649
# EPOCH 30 TOTAL TRAINING LOSS: 3.073121
# EPOCH 31 TOTAL TRAINING LOSS: 3.383130
# EPOCH 32 TOTAL TRAINING LOSS: 3.404879
# EPOCH 33 TOTAL TRAINING LOSS: 3.780421
# EPOCH 34 TOTAL TRAINING LOSS: 3.148630
# EPOCH 35 TOTAL TRAINING LOSS: 3.448633
# EPOCH 36 TOTAL TRAINING LOSS: 2.772393
# EPOCH 37 TOTAL TRAINING LOSS: 3.161450
# EPOCH 38 TOTAL TRAINING LOSS: 3.287028
# EPOCH 39 TOTAL TRAINING LOSS: 3.102042
# EPOCH 40 TOTAL TRAINING LOSS: 2.973749
# EPOCH 41 TOTAL TRAINING LOSS: 2.718109
# EPOCH 42 TOTAL TRAINING LOSS: 3.174169
# EPOCH 43 TOTAL TRAINING LOSS: 2.473041
# EPOCH 44 TOTAL TRAINING LOSS: 2.965895
# EPOCH 45 TOTAL TRAINING LOSS: 2.707435
# EPOCH 46 TOTAL TRAINING LOSS: 2.670998
# EPOCH 47 TOTAL TRAINING LOSS: 3.632807
# EPOCH 48 TOTAL TRAINING LOSS: 2.884403
# EPOCH 49 TOTAL TRAINING LOSS: 2.830386
# EPOCH 50 TOTAL TRAINING LOSS: 2.450845
# EPOCH 51 TOTAL TRAINING LOSS: 3.285129
# EPOCH 52 TOTAL TRAINING LOSS: 2.539765
# EPOCH 53 TOTAL TRAINING LOSS: 2.617854
# EPOCH 54 TOTAL TRAINING LOSS: 3.357238
# EPOCH 55 TOTAL TRAINING LOSS: 2.681483
# EPOCH 56 TOTAL TRAINING LOSS: 2.297433
# EPOCH 57 TOTAL TRAINING LOSS: 3.005784
# EPOCH 58 TOTAL TRAINING LOSS: 2.975922
# EPOCH 59 TOTAL TRAINING LOSS: 2.390912
# EPOCH 60 TOTAL TRAINING LOSS: 3.394797
# EPOCH 61 TOTAL TRAINING LOSS: 2.843624
# EPOCH 62 TOTAL TRAINING LOSS: 2.342305
# EPOCH 63 TOTAL TRAINING LOSS: 2.625044
# EPOCH 64 TOTAL TRAINING LOSS: 2.955117
# EPOCH 65 TOTAL TRAINING LOSS: 2.854188
# EPOCH 66 TOTAL TRAINING LOSS: 2.926780
# EPOCH 67 TOTAL TRAINING LOSS: 2.232464
# EPOCH 68 TOTAL TRAINING LOSS: 2.090290
# EPOCH 69 TOTAL TRAINING LOSS: 3.084306
# EPOCH 70 TOTAL TRAINING LOSS: 2.274802
# EPOCH 71 TOTAL TRAINING LOSS: 2.082833
# EPOCH 72 TOTAL TRAINING LOSS: 2.108302
# EPOCH 73 TOTAL TRAINING LOSS: 2.714240
# EPOCH 74 TOTAL TRAINING LOSS: 2.393582
# EPOCH 75 TOTAL TRAINING LOSS: 2.185359
# EPOCH 76 TOTAL TRAINING LOSS: 2.448269
# EPOCH 77 TOTAL TRAINING LOSS: 2.462901
# EPOCH 78 TOTAL TRAINING LOSS: 2.424238
# EPOCH 79 TOTAL TRAINING LOSS: 2.622998
# EPOCH 80 TOTAL TRAINING LOSS: 2.777096
# EPOCH 81 TOTAL TRAINING LOSS: 2.718654
# EPOCH 82 TOTAL TRAINING LOSS: 2.051752
# EPOCH 83 TOTAL TRAINING LOSS: 2.665796
# EPOCH 84 TOTAL TRAINING LOSS: 2.253548
# EPOCH 85 TOTAL TRAINING LOSS: 3.067315
# EPOCH 86 TOTAL TRAINING LOSS: 2.713570
# EPOCH 87 TOTAL TRAINING LOSS: 2.322651
# EPOCH 88 TOTAL TRAINING LOSS: 2.513030
# EPOCH 89 TOTAL TRAINING LOSS: 2.552276
# EPOCH 90 TOTAL TRAINING LOSS: 3.703036
# EPOCH 91 TOTAL TRAINING LOSS: 2.819980
# EPOCH 92 TOTAL TRAINING LOSS: 2.908552
# EPOCH 93 TOTAL TRAINING LOSS: 2.090669
# EPOCH 94 TOTAL TRAINING LOSS: 2.053831
# EPOCH 95 TOTAL TRAINING LOSS: 2.431295
# EPOCH 96 TOTAL TRAINING LOSS: 2.328256
# EPOCH 97 TOTAL TRAINING LOSS: 2.626794
# EPOCH 98 TOTAL TRAINING LOSS: 2.358362
# EPOCH 99 TOTAL TRAINING LOSS: 2.084887
# EPOCH 100 TOTAL TRAINING LOSS: 2.34961
# EPOCH 101 TOTAL TRAINING LOSS: 2.792057
# EPOCH 102 TOTAL TRAINING LOSS: 3.582151
# EPOCH 103 TOTAL TRAINING LOSS: 2.390722
# EPOCH 104 TOTAL TRAINING LOSS: 3.074873
# EPOCH 105 TOTAL TRAINING LOSS: 2.486463
# EPOCH 106 TOTAL TRAINING LOSS: 2.028366
# EPOCH 107 TOTAL TRAINING LOSS: 2.293586
# EPOCH 108 TOTAL TRAINING LOSS: 2.401288
# EPOCH 109 TOTAL TRAINING LOSS: 2.618874
# EPOCH 110 TOTAL TRAINING LOSS: 3.252503
# EPOCH 111 TOTAL TRAINING LOSS: 3.085795
# EPOCH 112 TOTAL TRAINING LOSS: 1.983057
# EPOCH 113 TOTAL TRAINING LOSS: 1.907874
# EPOCH 114 TOTAL TRAINING LOSS: 2.575210
# EPOCH 115 TOTAL TRAINING LOSS: 1.594408
# EPOCH 116 TOTAL TRAINING LOSS: 2.836857
# EPOCH 117 TOTAL TRAINING LOSS: 2.344608
# EPOCH 118 TOTAL TRAINING LOSS: 2.170296
# EPOCH 119 TOTAL TRAINING LOSS: 1.742069
# EPOCH 120 TOTAL TRAINING LOSS: 2.913597
# EPOCH 121 TOTAL TRAINING LOSS: 2.022718
# EPOCH 122 TOTAL TRAINING LOSS: 2.207320
# EPOCH 123 TOTAL TRAINING LOSS: 2.592278
# EPOCH 124 TOTAL TRAINING LOSS: 1.980017
# EPOCH 125 TOTAL TRAINING LOSS: 1.877982
# EPOCH 126 TOTAL TRAINING LOSS: 2.284789
# EPOCH 127 TOTAL TRAINING LOSS: 2.281606
# EPOCH 128 TOTAL TRAINING LOSS: 2.812218
# EPOCH 129 TOTAL TRAINING LOSS: 2.371079
# EPOCH 130 TOTAL TRAINING LOSS: 2.704430
# EPOCH 131 TOTAL TRAINING LOSS: 2.032839
# EPOCH 132 TOTAL TRAINING LOSS: 3.159639
# EPOCH 133 TOTAL TRAINING LOSS: 3.105441
# EPOCH 134 TOTAL TRAINING LOSS: 2.134776
# EPOCH 135 TOTAL TRAINING LOSS: 1.986866
# EPOCH 136 TOTAL TRAINING LOSS: 2.705059
# EPOCH 137 TOTAL TRAINING LOSS: 2.000128
# EPOCH 138 TOTAL TRAINING LOSS: 2.158404
# EPOCH 139 TOTAL TRAINING LOSS: 2.891419
# EPOCH 140 TOTAL TRAINING LOSS: 2.391903
# EPOCH 141 TOTAL TRAINING LOSS: 2.960193
# EPOCH 142 TOTAL TRAINING LOSS: 1.722086
# EPOCH 143 TOTAL TRAINING LOSS: 2.027233
# EPOCH 144 TOTAL TRAINING LOSS: 2.043043
# EPOCH 145 TOTAL TRAINING LOSS: 2.456847
# EPOCH 146 TOTAL TRAINING LOSS: 2.581614
# EPOCH 147 TOTAL TRAINING LOSS: 2.258706
# EPOCH 148 TOTAL TRAINING LOSS: 2.450644
# EPOCH 149 TOTAL TRAINING LOSS: 3.008913
# EPOCH 150 TOTAL TRAINING LOSS: 2.071996
# Using device: cudaLIDATION LOSS: 4.6782
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 7.4021
# EPOCH 2 TOTAL TRAINING LOSS: 5.620913
# EPOCH 3 TOTAL TRAINING LOSS: 6.873531
# EPOCH 4 TOTAL TRAINING LOSS: 5.163370
# EPOCH 5 TOTAL TRAINING LOSS: 4.768218
# EPOCH 6 TOTAL TRAINING LOSS: 4.778669
# EPOCH 7 TOTAL TRAINING LOSS: 4.409211
# EPOCH 8 TOTAL TRAINING LOSS: 5.007232
# EPOCH 9 TOTAL TRAINING LOSS: 5.708231
# EPOCH 10 TOTAL TRAINING LOSS: 4.01317
# EPOCH 11 TOTAL TRAINING LOSS: 4.693197
# EPOCH 12 TOTAL TRAINING LOSS: 5.386670
# EPOCH 13 TOTAL TRAINING LOSS: 3.970783
# EPOCH 14 TOTAL TRAINING LOSS: 3.451874
# EPOCH 15 TOTAL TRAINING LOSS: 3.916248
# EPOCH 16 TOTAL TRAINING LOSS: 4.512388
# EPOCH 17 TOTAL TRAINING LOSS: 4.008211
# EPOCH 18 TOTAL TRAINING LOSS: 3.973299
# EPOCH 19 TOTAL TRAINING LOSS: 4.426068
# EPOCH 20 TOTAL TRAINING LOSS: 3.691788
# EPOCH 21 TOTAL TRAINING LOSS: 3.435283
# EPOCH 22 TOTAL TRAINING LOSS: 3.439023
# EPOCH 23 TOTAL TRAINING LOSS: 3.673328
# EPOCH 24 TOTAL TRAINING LOSS: 3.573515
# EPOCH 25 TOTAL TRAINING LOSS: 4.578113
# EPOCH 26 TOTAL TRAINING LOSS: 3.008735
# EPOCH 27 TOTAL TRAINING LOSS: 4.116194
# EPOCH 28 TOTAL TRAINING LOSS: 3.946683
# EPOCH 29 TOTAL TRAINING LOSS: 3.317594
# EPOCH 30 TOTAL TRAINING LOSS: 3.524455
# EPOCH 31 TOTAL TRAINING LOSS: 3.076138
# EPOCH 32 TOTAL TRAINING LOSS: 3.570625
# EPOCH 33 TOTAL TRAINING LOSS: 3.421176
# EPOCH 34 TOTAL TRAINING LOSS: 2.791711
# EPOCH 35 TOTAL TRAINING LOSS: 3.401459
# EPOCH 36 TOTAL TRAINING LOSS: 3.097260
# EPOCH 37 TOTAL TRAINING LOSS: 3.192239
# EPOCH 38 TOTAL TRAINING LOSS: 3.941435
# EPOCH 39 TOTAL TRAINING LOSS: 3.676847
# EPOCH 40 TOTAL TRAINING LOSS: 4.062883
# EPOCH 41 TOTAL TRAINING LOSS: 3.540139
# EPOCH 42 TOTAL TRAINING LOSS: 3.475231
# EPOCH 43 TOTAL TRAINING LOSS: 3.353832
# EPOCH 44 TOTAL TRAINING LOSS: 3.845953
# EPOCH 45 TOTAL TRAINING LOSS: 3.161451
# EPOCH 46 TOTAL TRAINING LOSS: 3.966937
# EPOCH 47 TOTAL TRAINING LOSS: 2.900441
# EPOCH 48 TOTAL TRAINING LOSS: 2.569993
# EPOCH 49 TOTAL TRAINING LOSS: 3.633756
# EPOCH 50 TOTAL TRAINING LOSS: 3.596552
# EPOCH 51 TOTAL TRAINING LOSS: 3.220982
# EPOCH 52 TOTAL TRAINING LOSS: 2.819308
# EPOCH 53 TOTAL TRAINING LOSS: 3.076128
# EPOCH 54 TOTAL TRAINING LOSS: 3.974686
# EPOCH 55 TOTAL TRAINING LOSS: 3.717707
# EPOCH 56 TOTAL TRAINING LOSS: 3.318218
# EPOCH 57 TOTAL TRAINING LOSS: 4.623548
# EPOCH 58 TOTAL TRAINING LOSS: 2.838654
# EPOCH 59 TOTAL TRAINING LOSS: 3.018339
# EPOCH 60 TOTAL TRAINING LOSS: 2.971309
# EPOCH 61 TOTAL TRAINING LOSS: 2.685863
# EPOCH 62 TOTAL TRAINING LOSS: 2.476774
# EPOCH 63 TOTAL TRAINING LOSS: 2.907201
# EPOCH 64 TOTAL TRAINING LOSS: 3.372554
# EPOCH 65 TOTAL TRAINING LOSS: 3.256673
# EPOCH 66 TOTAL TRAINING LOSS: 3.536024
# EPOCH 67 TOTAL TRAINING LOSS: 2.904142
# EPOCH 68 TOTAL TRAINING LOSS: 3.539189
# EPOCH 69 TOTAL TRAINING LOSS: 2.998616
# EPOCH 70 TOTAL TRAINING LOSS: 3.138954
# EPOCH 71 TOTAL TRAINING LOSS: 3.943821
# EPOCH 72 TOTAL TRAINING LOSS: 2.890007
# EPOCH 73 TOTAL TRAINING LOSS: 2.985128
# EPOCH 74 TOTAL TRAINING LOSS: 2.779081
# EPOCH 75 TOTAL TRAINING LOSS: 2.727218
# EPOCH 76 TOTAL TRAINING LOSS: 3.169270
# EPOCH 77 TOTAL TRAINING LOSS: 2.219949
# EPOCH 78 TOTAL TRAINING LOSS: 2.825830
# EPOCH 79 TOTAL TRAINING LOSS: 3.273512
# EPOCH 80 TOTAL TRAINING LOSS: 3.535904
# EPOCH 81 TOTAL TRAINING LOSS: 2.638760
# EPOCH 82 TOTAL TRAINING LOSS: 3.231015
# EPOCH 83 TOTAL TRAINING LOSS: 3.415802
# EPOCH 84 TOTAL TRAINING LOSS: 2.560709
# EPOCH 85 TOTAL TRAINING LOSS: 2.488620
# EPOCH 86 TOTAL TRAINING LOSS: 2.822458
# EPOCH 87 TOTAL TRAINING LOSS: 2.476566
# EPOCH 88 TOTAL TRAINING LOSS: 2.489519
# EPOCH 89 TOTAL TRAINING LOSS: 3.320667
# EPOCH 90 TOTAL TRAINING LOSS: 3.579257
# EPOCH 91 TOTAL TRAINING LOSS: 2.873126
# EPOCH 92 TOTAL TRAINING LOSS: 2.822506
# EPOCH 93 TOTAL TRAINING LOSS: 2.818800
# EPOCH 94 TOTAL TRAINING LOSS: 3.055141
# EPOCH 95 TOTAL TRAINING LOSS: 3.204412
# EPOCH 96 TOTAL TRAINING LOSS: 2.865984
# EPOCH 97 TOTAL TRAINING LOSS: 2.823811
# EPOCH 98 TOTAL TRAINING LOSS: 3.118574
# EPOCH 99 TOTAL TRAINING LOSS: 3.842208
# EPOCH 100 TOTAL TRAINING LOSS: 2.88192
# EPOCH 101 TOTAL TRAINING LOSS: 3.105285
# EPOCH 102 TOTAL TRAINING LOSS: 2.615199
# EPOCH 103 TOTAL TRAINING LOSS: 2.625385
# EPOCH 104 TOTAL TRAINING LOSS: 2.909066
# EPOCH 105 TOTAL TRAINING LOSS: 2.910844
# EPOCH 106 TOTAL TRAINING LOSS: 3.422223
# EPOCH 107 TOTAL TRAINING LOSS: 2.732649
# EPOCH 108 TOTAL TRAINING LOSS: 2.918174
# EPOCH 109 TOTAL TRAINING LOSS: 2.570433
# EPOCH 110 TOTAL TRAINING LOSS: 2.734893
# EPOCH 111 TOTAL TRAINING LOSS: 3.681327
# EPOCH 112 TOTAL TRAINING LOSS: 2.620566
# EPOCH 113 TOTAL TRAINING LOSS: 3.628176
# EPOCH 114 TOTAL TRAINING LOSS: 2.512256
# EPOCH 115 TOTAL TRAINING LOSS: 2.729984
# EPOCH 116 TOTAL TRAINING LOSS: 2.844088
# EPOCH 117 TOTAL TRAINING LOSS: 3.221174
# EPOCH 118 TOTAL TRAINING LOSS: 2.677541
# EPOCH 119 TOTAL TRAINING LOSS: 2.620427
# EPOCH 120 TOTAL TRAINING LOSS: 2.536597
# EPOCH 121 TOTAL TRAINING LOSS: 2.578736
# EPOCH 122 TOTAL TRAINING LOSS: 2.712726
# EPOCH 123 TOTAL TRAINING LOSS: 2.586593
# EPOCH 124 TOTAL TRAINING LOSS: 3.770405
# EPOCH 125 TOTAL TRAINING LOSS: 2.758651
# EPOCH 126 TOTAL TRAINING LOSS: 3.257508
# EPOCH 127 TOTAL TRAINING LOSS: 2.335511
# EPOCH 128 TOTAL TRAINING LOSS: 2.693110
# EPOCH 129 TOTAL TRAINING LOSS: 3.678083
# EPOCH 130 TOTAL TRAINING LOSS: 2.260624
# EPOCH 131 TOTAL TRAINING LOSS: 4.497331
# EPOCH 132 TOTAL TRAINING LOSS: 2.774559
# EPOCH 133 TOTAL TRAINING LOSS: 3.524154
# EPOCH 134 TOTAL TRAINING LOSS: 3.819144
# EPOCH 135 TOTAL TRAINING LOSS: 3.148182
# EPOCH 136 TOTAL TRAINING LOSS: 2.623022
# EPOCH 137 TOTAL TRAINING LOSS: 3.096724
# EPOCH 138 TOTAL TRAINING LOSS: 3.069278
# EPOCH 139 TOTAL TRAINING LOSS: 3.196458
# EPOCH 140 TOTAL TRAINING LOSS: 2.404710
# EPOCH 141 TOTAL TRAINING LOSS: 2.530413
# EPOCH 142 TOTAL TRAINING LOSS: 2.929486
# EPOCH 143 TOTAL TRAINING LOSS: 4.218995
# EPOCH 144 TOTAL TRAINING LOSS: 3.113641
# EPOCH 145 TOTAL TRAINING LOSS: 2.919868
# EPOCH 146 TOTAL TRAINING LOSS: 2.543820
# EPOCH 147 TOTAL TRAINING LOSS: 2.926987
# EPOCH 148 TOTAL TRAINING LOSS: 2.471463
# EPOCH 149 TOTAL TRAINING LOSS: 3.019130
# EPOCH 150 TOTAL TRAINING LOSS: 3.206604
# Using device: cudaLIDATION LOSS: 4.3682
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.1687
# EPOCH 2 TOTAL TRAINING LOSS: 4.749045
# EPOCH 3 TOTAL TRAINING LOSS: 3.420451
# EPOCH 4 TOTAL TRAINING LOSS: 3.274891
# EPOCH 5 TOTAL TRAINING LOSS: 3.435156
# EPOCH 6 TOTAL TRAINING LOSS: 4.164167
# EPOCH 7 TOTAL TRAINING LOSS: 3.638975
# EPOCH 8 TOTAL TRAINING LOSS: 3.088437
# EPOCH 9 TOTAL TRAINING LOSS: 3.337729
# EPOCH 10 TOTAL TRAINING LOSS: 2.71342
# EPOCH 11 TOTAL TRAINING LOSS: 2.467841
# EPOCH 12 TOTAL TRAINING LOSS: 3.608120
# EPOCH 13 TOTAL TRAINING LOSS: 3.728252
# EPOCH 14 TOTAL TRAINING LOSS: 3.030474
# EPOCH 15 TOTAL TRAINING LOSS: 2.997615
# EPOCH 16 TOTAL TRAINING LOSS: 3.512203
# EPOCH 17 TOTAL TRAINING LOSS: 3.274034
# EPOCH 18 TOTAL TRAINING LOSS: 2.555930
# EPOCH 19 TOTAL TRAINING LOSS: 2.748483
# EPOCH 20 TOTAL TRAINING LOSS: 2.328634
# EPOCH 21 TOTAL TRAINING LOSS: 2.289796
# EPOCH 22 TOTAL TRAINING LOSS: 3.012162
# EPOCH 23 TOTAL TRAINING LOSS: 3.616943
# EPOCH 24 TOTAL TRAINING LOSS: 2.499471
# EPOCH 25 TOTAL TRAINING LOSS: 2.718384
# EPOCH 26 TOTAL TRAINING LOSS: 2.495636
# EPOCH 27 TOTAL TRAINING LOSS: 2.846926
# EPOCH 28 TOTAL TRAINING LOSS: 1.980442
# EPOCH 29 TOTAL TRAINING LOSS: 2.136051
# EPOCH 30 TOTAL TRAINING LOSS: 2.231955
# EPOCH 31 TOTAL TRAINING LOSS: 2.410271
# EPOCH 32 TOTAL TRAINING LOSS: 1.791853
# EPOCH 33 TOTAL TRAINING LOSS: 2.603276
# EPOCH 34 TOTAL TRAINING LOSS: 2.077133
# EPOCH 35 TOTAL TRAINING LOSS: 2.161788
# EPOCH 36 TOTAL TRAINING LOSS: 1.845092
# EPOCH 37 TOTAL TRAINING LOSS: 2.542234
# EPOCH 38 TOTAL TRAINING LOSS: 2.485824
# EPOCH 39 TOTAL TRAINING LOSS: 2.512728
# EPOCH 40 TOTAL TRAINING LOSS: 2.392498
# EPOCH 41 TOTAL TRAINING LOSS: 2.840969
# EPOCH 42 TOTAL TRAINING LOSS: 2.511227
# EPOCH 43 TOTAL TRAINING LOSS: 2.751982
# EPOCH 44 TOTAL TRAINING LOSS: 1.766429
# EPOCH 45 TOTAL TRAINING LOSS: 2.050479
# EPOCH 46 TOTAL TRAINING LOSS: 1.902572
# EPOCH 47 TOTAL TRAINING LOSS: 2.867946
# EPOCH 48 TOTAL TRAINING LOSS: 2.482455
# EPOCH 49 TOTAL TRAINING LOSS: 2.282789
# EPOCH 50 TOTAL TRAINING LOSS: 2.740707
# EPOCH 51 TOTAL TRAINING LOSS: 2.312445
# EPOCH 52 TOTAL TRAINING LOSS: 2.630375
# EPOCH 53 TOTAL TRAINING LOSS: 2.011843
# EPOCH 54 TOTAL TRAINING LOSS: 2.357438
# EPOCH 55 TOTAL TRAINING LOSS: 2.110502
# EPOCH 56 TOTAL TRAINING LOSS: 2.387398
# EPOCH 57 TOTAL TRAINING LOSS: 1.698301
# EPOCH 58 TOTAL TRAINING LOSS: 2.477283
# EPOCH 59 TOTAL TRAINING LOSS: 1.890360
# EPOCH 60 TOTAL TRAINING LOSS: 2.749056
# EPOCH 61 TOTAL TRAINING LOSS: 2.867916
# EPOCH 62 TOTAL TRAINING LOSS: 2.759873
# EPOCH 63 TOTAL TRAINING LOSS: 2.415236
# EPOCH 64 TOTAL TRAINING LOSS: 1.875211
# EPOCH 65 TOTAL TRAINING LOSS: 2.633314
# EPOCH 66 TOTAL TRAINING LOSS: 2.436991
# EPOCH 67 TOTAL TRAINING LOSS: 2.158931
# EPOCH 68 TOTAL TRAINING LOSS: 2.297953
# EPOCH 69 TOTAL TRAINING LOSS: 2.334819
# EPOCH 70 TOTAL TRAINING LOSS: 3.150914
# EPOCH 71 TOTAL TRAINING LOSS: 3.512398
# EPOCH 72 TOTAL TRAINING LOSS: 2.425992
# EPOCH 73 TOTAL TRAINING LOSS: 2.002935
# EPOCH 74 TOTAL TRAINING LOSS: 2.870621
# EPOCH 75 TOTAL TRAINING LOSS: 1.791712
# EPOCH 76 TOTAL TRAINING LOSS: 1.451810
# EPOCH 77 TOTAL TRAINING LOSS: 1.957631
# EPOCH 78 TOTAL TRAINING LOSS: 2.153647
# EPOCH 79 TOTAL TRAINING LOSS: 1.969787
# EPOCH 80 TOTAL TRAINING LOSS: 1.574672
# EPOCH 81 TOTAL TRAINING LOSS: 2.064658
# EPOCH 82 TOTAL TRAINING LOSS: 1.702261
# EPOCH 83 TOTAL TRAINING LOSS: 1.849389
# EPOCH 84 TOTAL TRAINING LOSS: 1.785395
# EPOCH 85 TOTAL TRAINING LOSS: 2.323099
# EPOCH 86 TOTAL TRAINING LOSS: 2.135705
# EPOCH 87 TOTAL TRAINING LOSS: 2.455466
# EPOCH 88 TOTAL TRAINING LOSS: 1.850694
# EPOCH 89 TOTAL TRAINING LOSS: 2.649448
# EPOCH 90 TOTAL TRAINING LOSS: 2.106994
# EPOCH 91 TOTAL TRAINING LOSS: 2.236143
# EPOCH 92 TOTAL TRAINING LOSS: 1.968162
# EPOCH 93 TOTAL TRAINING LOSS: 1.624386
# EPOCH 94 TOTAL TRAINING LOSS: 1.641412
# EPOCH 95 TOTAL TRAINING LOSS: 1.674895
# EPOCH 96 TOTAL TRAINING LOSS: 1.936523
# EPOCH 97 TOTAL TRAINING LOSS: 2.941472
# EPOCH 98 TOTAL TRAINING LOSS: 2.449312
# EPOCH 99 TOTAL TRAINING LOSS: 2.239672
# EPOCH 100 TOTAL TRAINING LOSS: 1.95283
# EPOCH 101 TOTAL TRAINING LOSS: 2.410415
# EPOCH 102 TOTAL TRAINING LOSS: 2.727328
# EPOCH 103 TOTAL TRAINING LOSS: 1.433357
# EPOCH 104 TOTAL TRAINING LOSS: 1.848252
# EPOCH 105 TOTAL TRAINING LOSS: 2.461662
# EPOCH 106 TOTAL TRAINING LOSS: 1.594762
# EPOCH 107 TOTAL TRAINING LOSS: 1.909603
# EPOCH 108 TOTAL TRAINING LOSS: 1.685243
# EPOCH 109 TOTAL TRAINING LOSS: 2.304736
# EPOCH 110 TOTAL TRAINING LOSS: 1.897896
# EPOCH 111 TOTAL TRAINING LOSS: 2.590391
# EPOCH 112 TOTAL TRAINING LOSS: 2.074947
# EPOCH 113 TOTAL TRAINING LOSS: 2.202764
# EPOCH 114 TOTAL TRAINING LOSS: 2.040233
# EPOCH 115 TOTAL TRAINING LOSS: 2.314526
# EPOCH 116 TOTAL TRAINING LOSS: 1.954102
# EPOCH 117 TOTAL TRAINING LOSS: 1.867992
# EPOCH 118 TOTAL TRAINING LOSS: 1.777131
# EPOCH 119 TOTAL TRAINING LOSS: 1.806052
# EPOCH 120 TOTAL TRAINING LOSS: 1.855002
# EPOCH 121 TOTAL TRAINING LOSS: 2.298925
# EPOCH 122 TOTAL TRAINING LOSS: 1.814460
# EPOCH 123 TOTAL TRAINING LOSS: 1.440691
# EPOCH 124 TOTAL TRAINING LOSS: 1.375381
# EPOCH 125 TOTAL TRAINING LOSS: 1.664672
# EPOCH 126 TOTAL TRAINING LOSS: 2.492897
# EPOCH 127 TOTAL TRAINING LOSS: 2.354186
# EPOCH 128 TOTAL TRAINING LOSS: 2.378959
# EPOCH 129 TOTAL TRAINING LOSS: 2.367860
# EPOCH 130 TOTAL TRAINING LOSS: 1.789489
# EPOCH 131 TOTAL TRAINING LOSS: 1.724118
# EPOCH 132 TOTAL TRAINING LOSS: 1.999338
# EPOCH 133 TOTAL TRAINING LOSS: 1.717803
# EPOCH 134 TOTAL TRAINING LOSS: 2.656698
# EPOCH 135 TOTAL TRAINING LOSS: 2.733497
# EPOCH 136 TOTAL TRAINING LOSS: 3.222202
# EPOCH 137 TOTAL TRAINING LOSS: 1.573870
# EPOCH 138 TOTAL TRAINING LOSS: 1.642080
# EPOCH 139 TOTAL TRAINING LOSS: 2.357639
# EPOCH 140 TOTAL TRAINING LOSS: 1.913267
# EPOCH 141 TOTAL TRAINING LOSS: 1.572889
# EPOCH 142 TOTAL TRAINING LOSS: 2.858322
# EPOCH 143 TOTAL TRAINING LOSS: 2.116667
# EPOCH 144 TOTAL TRAINING LOSS: 2.647086
# EPOCH 145 TOTAL TRAINING LOSS: 2.684568
# EPOCH 146 TOTAL TRAINING LOSS: 2.358128
# EPOCH 147 TOTAL TRAINING LOSS: 1.439042
# EPOCH 148 TOTAL TRAINING LOSS: 2.458851
# EPOCH 149 TOTAL TRAINING LOSS: 1.803678
# EPOCH 150 TOTAL TRAINING LOSS: 1.455220
# Using device: cudaLIDATION LOSS: 4.5406
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.7836
# EPOCH 2 TOTAL TRAINING LOSS: 5.558453
# EPOCH 3 TOTAL TRAINING LOSS: 6.125715
# EPOCH 4 TOTAL TRAINING LOSS: 4.716711
# EPOCH 5 TOTAL TRAINING LOSS: 5.203278
# EPOCH 6 TOTAL TRAINING LOSS: 5.905131
# EPOCH 7 TOTAL TRAINING LOSS: 5.275189
# EPOCH 8 TOTAL TRAINING LOSS: 5.356546
# EPOCH 9 TOTAL TRAINING LOSS: 5.542347
# EPOCH 10 TOTAL TRAINING LOSS: 3.72965
# EPOCH 11 TOTAL TRAINING LOSS: 4.338000
# EPOCH 12 TOTAL TRAINING LOSS: 4.040592
# EPOCH 13 TOTAL TRAINING LOSS: 3.911979
# EPOCH 14 TOTAL TRAINING LOSS: 4.774648
# EPOCH 15 TOTAL TRAINING LOSS: 4.707104
# EPOCH 16 TOTAL TRAINING LOSS: 5.014728
# EPOCH 17 TOTAL TRAINING LOSS: 3.737402
# EPOCH 18 TOTAL TRAINING LOSS: 3.696217
# EPOCH 19 TOTAL TRAINING LOSS: 4.057492
# EPOCH 20 TOTAL TRAINING LOSS: 3.672241
# EPOCH 21 TOTAL TRAINING LOSS: 3.565001
# EPOCH 22 TOTAL TRAINING LOSS: 3.685829
# EPOCH 23 TOTAL TRAINING LOSS: 4.595810
# EPOCH 24 TOTAL TRAINING LOSS: 4.187660
# EPOCH 25 TOTAL TRAINING LOSS: 3.774693
# EPOCH 26 TOTAL TRAINING LOSS: 3.005967
# EPOCH 27 TOTAL TRAINING LOSS: 3.864327
# EPOCH 28 TOTAL TRAINING LOSS: 4.447324
# EPOCH 29 TOTAL TRAINING LOSS: 3.950496
# EPOCH 30 TOTAL TRAINING LOSS: 3.196942
# EPOCH 31 TOTAL TRAINING LOSS: 2.915143
# EPOCH 32 TOTAL TRAINING LOSS: 3.979126
# EPOCH 33 TOTAL TRAINING LOSS: 3.448533
# EPOCH 34 TOTAL TRAINING LOSS: 4.406478
# EPOCH 35 TOTAL TRAINING LOSS: 2.639729
# EPOCH 36 TOTAL TRAINING LOSS: 3.234631
# EPOCH 37 TOTAL TRAINING LOSS: 3.571172
# EPOCH 38 TOTAL TRAINING LOSS: 3.590289
# EPOCH 39 TOTAL TRAINING LOSS: 3.175777
# EPOCH 40 TOTAL TRAINING LOSS: 2.777347
# EPOCH 41 TOTAL TRAINING LOSS: 2.241408
# EPOCH 42 TOTAL TRAINING LOSS: 3.093709
# EPOCH 43 TOTAL TRAINING LOSS: 3.747140
# EPOCH 44 TOTAL TRAINING LOSS: 3.755669
# EPOCH 45 TOTAL TRAINING LOSS: 3.451796
# EPOCH 46 TOTAL TRAINING LOSS: 3.146497
# EPOCH 47 TOTAL TRAINING LOSS: 2.595269
# EPOCH 48 TOTAL TRAINING LOSS: 3.225815
# EPOCH 49 TOTAL TRAINING LOSS: 2.729584
# EPOCH 50 TOTAL TRAINING LOSS: 3.033957
# EPOCH 51 TOTAL TRAINING LOSS: 2.823264
# EPOCH 52 TOTAL TRAINING LOSS: 3.696310
# EPOCH 53 TOTAL TRAINING LOSS: 2.193437
# EPOCH 54 TOTAL TRAINING LOSS: 2.774423
# EPOCH 55 TOTAL TRAINING LOSS: 2.759753
# EPOCH 56 TOTAL TRAINING LOSS: 3.000782
# EPOCH 57 TOTAL TRAINING LOSS: 2.734954
# EPOCH 58 TOTAL TRAINING LOSS: 2.486262
# EPOCH 59 TOTAL TRAINING LOSS: 2.591129
# EPOCH 60 TOTAL TRAINING LOSS: 2.407306
# EPOCH 61 TOTAL TRAINING LOSS: 4.383217
# EPOCH 62 TOTAL TRAINING LOSS: 3.215804
# EPOCH 63 TOTAL TRAINING LOSS: 3.680720
# EPOCH 64 TOTAL TRAINING LOSS: 2.880756
# EPOCH 65 TOTAL TRAINING LOSS: 3.664205
# EPOCH 66 TOTAL TRAINING LOSS: 3.282179
# EPOCH 67 TOTAL TRAINING LOSS: 2.160073
# EPOCH 68 TOTAL TRAINING LOSS: 2.568092
# EPOCH 69 TOTAL TRAINING LOSS: 2.867364
# EPOCH 70 TOTAL TRAINING LOSS: 3.443313
# EPOCH 71 TOTAL TRAINING LOSS: 3.457459
# EPOCH 72 TOTAL TRAINING LOSS: 3.950956
# EPOCH 73 TOTAL TRAINING LOSS: 3.820503
# EPOCH 74 TOTAL TRAINING LOSS: 2.615124
# EPOCH 75 TOTAL TRAINING LOSS: 2.573413
# EPOCH 76 TOTAL TRAINING LOSS: 3.348563
# EPOCH 77 TOTAL TRAINING LOSS: 2.979488
# EPOCH 78 TOTAL TRAINING LOSS: 2.479159
# EPOCH 79 TOTAL TRAINING LOSS: 2.528934
# EPOCH 80 TOTAL TRAINING LOSS: 2.408674
# EPOCH 81 TOTAL TRAINING LOSS: 2.780833
# EPOCH 82 TOTAL TRAINING LOSS: 3.216692
# EPOCH 83 TOTAL TRAINING LOSS: 2.584837
# EPOCH 84 TOTAL TRAINING LOSS: 2.054098
# EPOCH 85 TOTAL TRAINING LOSS: 2.569819
# EPOCH 86 TOTAL TRAINING LOSS: 3.249289
# EPOCH 87 TOTAL TRAINING LOSS: 2.702369
# EPOCH 88 TOTAL TRAINING LOSS: 2.993974
# EPOCH 89 TOTAL TRAINING LOSS: 3.313799
# EPOCH 90 TOTAL TRAINING LOSS: 2.818949
# EPOCH 91 TOTAL TRAINING LOSS: 3.624014
# EPOCH 92 TOTAL TRAINING LOSS: 2.576112
# EPOCH 93 TOTAL TRAINING LOSS: 2.752918
# EPOCH 94 TOTAL TRAINING LOSS: 3.505244
# EPOCH 95 TOTAL TRAINING LOSS: 2.375802
# EPOCH 96 TOTAL TRAINING LOSS: 2.824014
# EPOCH 97 TOTAL TRAINING LOSS: 3.070979
# EPOCH 98 TOTAL TRAINING LOSS: 2.382559
# EPOCH 99 TOTAL TRAINING LOSS: 3.369375
# EPOCH 100 TOTAL TRAINING LOSS: 2.99614
# EPOCH 101 TOTAL TRAINING LOSS: 3.192303
# EPOCH 102 TOTAL TRAINING LOSS: 2.464439
# EPOCH 103 TOTAL TRAINING LOSS: 2.317849
# EPOCH 104 TOTAL TRAINING LOSS: 3.847151
# EPOCH 105 TOTAL TRAINING LOSS: 3.395766
# EPOCH 106 TOTAL TRAINING LOSS: 3.031226
# EPOCH 107 TOTAL TRAINING LOSS: 2.961252
# EPOCH 108 TOTAL TRAINING LOSS: 2.583211
# EPOCH 109 TOTAL TRAINING LOSS: 3.051270
# EPOCH 110 TOTAL TRAINING LOSS: 2.945502
# EPOCH 111 TOTAL TRAINING LOSS: 2.092558
# EPOCH 112 TOTAL TRAINING LOSS: 2.941164
# EPOCH 113 TOTAL TRAINING LOSS: 3.341499
# EPOCH 114 TOTAL TRAINING LOSS: 2.484939
# EPOCH 115 TOTAL TRAINING LOSS: 2.579594
# EPOCH 116 TOTAL TRAINING LOSS: 2.055919
# EPOCH 117 TOTAL TRAINING LOSS: 2.794752
# EPOCH 118 TOTAL TRAINING LOSS: 2.212016
# EPOCH 119 TOTAL TRAINING LOSS: 2.707821
# EPOCH 120 TOTAL TRAINING LOSS: 2.508854
# EPOCH 121 TOTAL TRAINING LOSS: 2.669392
# EPOCH 122 TOTAL TRAINING LOSS: 2.734973
# EPOCH 123 TOTAL TRAINING LOSS: 2.503049
# EPOCH 124 TOTAL TRAINING LOSS: 2.108663
# EPOCH 125 TOTAL TRAINING LOSS: 3.197664
# EPOCH 126 TOTAL TRAINING LOSS: 2.363862
# EPOCH 127 TOTAL TRAINING LOSS: 2.062427
# EPOCH 128 TOTAL TRAINING LOSS: 3.345989
# EPOCH 129 TOTAL TRAINING LOSS: 2.299848
# EPOCH 130 TOTAL TRAINING LOSS: 2.645337
# EPOCH 131 TOTAL TRAINING LOSS: 3.474145
# EPOCH 132 TOTAL TRAINING LOSS: 2.312863
# EPOCH 133 TOTAL TRAINING LOSS: 2.492347
# EPOCH 134 TOTAL TRAINING LOSS: 3.887235
# EPOCH 135 TOTAL TRAINING LOSS: 2.253856
# EPOCH 136 TOTAL TRAINING LOSS: 2.517689
# EPOCH 137 TOTAL TRAINING LOSS: 3.992546
# EPOCH 138 TOTAL TRAINING LOSS: 2.440773
# EPOCH 139 TOTAL TRAINING LOSS: 2.263625
# EPOCH 140 TOTAL TRAINING LOSS: 2.554086
# EPOCH 141 TOTAL TRAINING LOSS: 2.292561
# EPOCH 142 TOTAL TRAINING LOSS: 2.068952
# EPOCH 143 TOTAL TRAINING LOSS: 2.649030
# EPOCH 144 TOTAL TRAINING LOSS: 3.076420
# EPOCH 145 TOTAL TRAINING LOSS: 2.164072
# EPOCH 146 TOTAL TRAINING LOSS: 2.879222
# EPOCH 147 TOTAL TRAINING LOSS: 2.341568
# EPOCH 148 TOTAL TRAINING LOSS: 2.408354
# EPOCH 149 TOTAL TRAINING LOSS: 2.580386
# EPOCH 150 TOTAL TRAINING LOSS: 2.255227
# Using device: cudaLIDATION LOSS: 3.9944
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.0521
# EPOCH 2 TOTAL TRAINING LOSS: 3.915669
# EPOCH 3 TOTAL TRAINING LOSS: 4.041273
# EPOCH 4 TOTAL TRAINING LOSS: 5.475436
# EPOCH 5 TOTAL TRAINING LOSS: 4.376835
# EPOCH 6 TOTAL TRAINING LOSS: 4.576838
# EPOCH 7 TOTAL TRAINING LOSS: 4.105384
# EPOCH 8 TOTAL TRAINING LOSS: 3.567375
# EPOCH 9 TOTAL TRAINING LOSS: 3.596904
# EPOCH 10 TOTAL TRAINING LOSS: 3.28320
# EPOCH 11 TOTAL TRAINING LOSS: 3.098013
# EPOCH 12 TOTAL TRAINING LOSS: 3.283979
# EPOCH 13 TOTAL TRAINING LOSS: 2.932585
# EPOCH 14 TOTAL TRAINING LOSS: 3.419031
# EPOCH 15 TOTAL TRAINING LOSS: 3.573675
# EPOCH 16 TOTAL TRAINING LOSS: 3.242064
# EPOCH 17 TOTAL TRAINING LOSS: 2.543581
# EPOCH 18 TOTAL TRAINING LOSS: 3.179288
# EPOCH 19 TOTAL TRAINING LOSS: 3.157331
# EPOCH 20 TOTAL TRAINING LOSS: 3.237971
# EPOCH 21 TOTAL TRAINING LOSS: 3.550805
# EPOCH 22 TOTAL TRAINING LOSS: 3.231605
# EPOCH 23 TOTAL TRAINING LOSS: 3.121800
# EPOCH 24 TOTAL TRAINING LOSS: 3.098191
# EPOCH 25 TOTAL TRAINING LOSS: 2.978644
# EPOCH 26 TOTAL TRAINING LOSS: 2.877553
# EPOCH 27 TOTAL TRAINING LOSS: 3.281653
# EPOCH 28 TOTAL TRAINING LOSS: 2.407839
# EPOCH 29 TOTAL TRAINING LOSS: 2.496199
# EPOCH 30 TOTAL TRAINING LOSS: 2.367363
# EPOCH 31 TOTAL TRAINING LOSS: 2.887082
# EPOCH 32 TOTAL TRAINING LOSS: 3.259145
# EPOCH 33 TOTAL TRAINING LOSS: 2.967776
# EPOCH 34 TOTAL TRAINING LOSS: 2.912336
# EPOCH 35 TOTAL TRAINING LOSS: 2.531251
# EPOCH 36 TOTAL TRAINING LOSS: 2.489923
# EPOCH 37 TOTAL TRAINING LOSS: 2.592087
# EPOCH 38 TOTAL TRAINING LOSS: 3.214517
# EPOCH 39 TOTAL TRAINING LOSS: 3.008115
# EPOCH 40 TOTAL TRAINING LOSS: 1.747636
# EPOCH 41 TOTAL TRAINING LOSS: 2.620824
# EPOCH 42 TOTAL TRAINING LOSS: 2.887932
# EPOCH 43 TOTAL TRAINING LOSS: 3.155048
# EPOCH 44 TOTAL TRAINING LOSS: 2.181609
# EPOCH 45 TOTAL TRAINING LOSS: 2.327808
# EPOCH 46 TOTAL TRAINING LOSS: 2.759692
# EPOCH 47 TOTAL TRAINING LOSS: 2.408807
# EPOCH 48 TOTAL TRAINING LOSS: 2.441164
# EPOCH 49 TOTAL TRAINING LOSS: 2.387859
# EPOCH 50 TOTAL TRAINING LOSS: 3.769727
# EPOCH 51 TOTAL TRAINING LOSS: 2.953819
# EPOCH 52 TOTAL TRAINING LOSS: 3.097408
# EPOCH 53 TOTAL TRAINING LOSS: 2.700160
# EPOCH 54 TOTAL TRAINING LOSS: 2.019442
# EPOCH 55 TOTAL TRAINING LOSS: 2.469927
# EPOCH 56 TOTAL TRAINING LOSS: 2.699346
# EPOCH 57 TOTAL TRAINING LOSS: 2.928882
# EPOCH 58 TOTAL TRAINING LOSS: 2.587940
# EPOCH 59 TOTAL TRAINING LOSS: 2.725109
# EPOCH 60 TOTAL TRAINING LOSS: 2.153935
# EPOCH 61 TOTAL TRAINING LOSS: 2.749640
# EPOCH 62 TOTAL TRAINING LOSS: 2.137910
# EPOCH 63 TOTAL TRAINING LOSS: 2.566557
# EPOCH 64 TOTAL TRAINING LOSS: 2.152557
# EPOCH 65 TOTAL TRAINING LOSS: 3.461449
# EPOCH 66 TOTAL TRAINING LOSS: 2.042677
# EPOCH 67 TOTAL TRAINING LOSS: 2.975906
# EPOCH 68 TOTAL TRAINING LOSS: 3.113559
# EPOCH 69 TOTAL TRAINING LOSS: 2.275100
# EPOCH 70 TOTAL TRAINING LOSS: 2.624686
# EPOCH 71 TOTAL TRAINING LOSS: 2.762818
# EPOCH 72 TOTAL TRAINING LOSS: 2.579468
# EPOCH 73 TOTAL TRAINING LOSS: 2.486646
# EPOCH 74 TOTAL TRAINING LOSS: 3.246310
# EPOCH 75 TOTAL TRAINING LOSS: 2.262521
# EPOCH 76 TOTAL TRAINING LOSS: 2.263401
# EPOCH 77 TOTAL TRAINING LOSS: 2.585613
# EPOCH 78 TOTAL TRAINING LOSS: 2.678611
# EPOCH 79 TOTAL TRAINING LOSS: 2.644396
# EPOCH 80 TOTAL TRAINING LOSS: 2.956432
# EPOCH 81 TOTAL TRAINING LOSS: 1.840942
# EPOCH 82 TOTAL TRAINING LOSS: 2.056031
# EPOCH 83 TOTAL TRAINING LOSS: 1.872833
# EPOCH 84 TOTAL TRAINING LOSS: 2.275421
# EPOCH 85 TOTAL TRAINING LOSS: 1.828206
# EPOCH 86 TOTAL TRAINING LOSS: 1.967763
# EPOCH 87 TOTAL TRAINING LOSS: 2.225754
# EPOCH 88 TOTAL TRAINING LOSS: 1.732260
# EPOCH 89 TOTAL TRAINING LOSS: 1.665088
# EPOCH 90 TOTAL TRAINING LOSS: 2.236028
# EPOCH 91 TOTAL TRAINING LOSS: 2.807836
# EPOCH 92 TOTAL TRAINING LOSS: 2.245230
# EPOCH 93 TOTAL TRAINING LOSS: 2.491740
# EPOCH 94 TOTAL TRAINING LOSS: 2.003054
# EPOCH 95 TOTAL TRAINING LOSS: 1.961415
# EPOCH 96 TOTAL TRAINING LOSS: 2.068394
# EPOCH 97 TOTAL TRAINING LOSS: 1.610975
# EPOCH 98 TOTAL TRAINING LOSS: 3.584855
# EPOCH 99 TOTAL TRAINING LOSS: 1.998808
# EPOCH 100 TOTAL TRAINING LOSS: 1.68589
# EPOCH 101 TOTAL TRAINING LOSS: 1.903501
# EPOCH 102 TOTAL TRAINING LOSS: 1.867292
# EPOCH 103 TOTAL TRAINING LOSS: 1.807880
# EPOCH 104 TOTAL TRAINING LOSS: 1.671884
# EPOCH 105 TOTAL TRAINING LOSS: 2.303106
# EPOCH 106 TOTAL TRAINING LOSS: 2.177853
# EPOCH 107 TOTAL TRAINING LOSS: 2.399826
# EPOCH 108 TOTAL TRAINING LOSS: 2.383852
# EPOCH 109 TOTAL TRAINING LOSS: 2.242671
# EPOCH 110 TOTAL TRAINING LOSS: 1.907355
# EPOCH 111 TOTAL TRAINING LOSS: 2.697599
# EPOCH 112 TOTAL TRAINING LOSS: 2.353457
# EPOCH 113 TOTAL TRAINING LOSS: 1.970460
# EPOCH 114 TOTAL TRAINING LOSS: 2.253330
# EPOCH 115 TOTAL TRAINING LOSS: 2.574849
# EPOCH 116 TOTAL TRAINING LOSS: 2.457943
# EPOCH 117 TOTAL TRAINING LOSS: 2.306561
# EPOCH 118 TOTAL TRAINING LOSS: 1.840340
# EPOCH 119 TOTAL TRAINING LOSS: 2.498303
# EPOCH 120 TOTAL TRAINING LOSS: 1.787124
# EPOCH 121 TOTAL TRAINING LOSS: 1.514342
# EPOCH 122 TOTAL TRAINING LOSS: 1.865772
# EPOCH 123 TOTAL TRAINING LOSS: 3.432427
# EPOCH 124 TOTAL TRAINING LOSS: 2.051433
# EPOCH 125 TOTAL TRAINING LOSS: 2.430780
# EPOCH 126 TOTAL TRAINING LOSS: 2.501064
# EPOCH 127 TOTAL TRAINING LOSS: 2.206723
# EPOCH 128 TOTAL TRAINING LOSS: 2.874713
# EPOCH 129 TOTAL TRAINING LOSS: 1.916945
# EPOCH 130 TOTAL TRAINING LOSS: 1.926772
# EPOCH 131 TOTAL TRAINING LOSS: 1.798350
# EPOCH 132 TOTAL TRAINING LOSS: 1.720428
# EPOCH 133 TOTAL TRAINING LOSS: 2.702661
# EPOCH 134 TOTAL TRAINING LOSS: 2.254518
# EPOCH 135 TOTAL TRAINING LOSS: 2.126613
# EPOCH 136 TOTAL TRAINING LOSS: 2.111821
# EPOCH 137 TOTAL TRAINING LOSS: 1.864453
# EPOCH 138 TOTAL TRAINING LOSS: 1.878741
# EPOCH 139 TOTAL TRAINING LOSS: 1.983445
# EPOCH 140 TOTAL TRAINING LOSS: 1.973958
# EPOCH 141 TOTAL TRAINING LOSS: 1.983790
# EPOCH 142 TOTAL TRAINING LOSS: 1.808450
# EPOCH 143 TOTAL TRAINING LOSS: 1.666184
# EPOCH 144 TOTAL TRAINING LOSS: 1.681507
# EPOCH 145 TOTAL TRAINING LOSS: 1.982327
# EPOCH 146 TOTAL TRAINING LOSS: 2.564196
# EPOCH 147 TOTAL TRAINING LOSS: 2.331420
# EPOCH 148 TOTAL TRAINING LOSS: 2.474112
# EPOCH 149 TOTAL TRAINING LOSS: 2.475441
# EPOCH 150 TOTAL TRAINING LOSS: 2.372807
# Using device: cudaLIDATION LOSS: 4.9178
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.7167
# EPOCH 2 TOTAL TRAINING LOSS: 4.771888
# EPOCH 3 TOTAL TRAINING LOSS: 5.444976
# EPOCH 4 TOTAL TRAINING LOSS: 4.694983
# EPOCH 5 TOTAL TRAINING LOSS: 3.138027
# EPOCH 6 TOTAL TRAINING LOSS: 3.788625
# EPOCH 7 TOTAL TRAINING LOSS: 4.316658
# EPOCH 8 TOTAL TRAINING LOSS: 3.577955
# EPOCH 9 TOTAL TRAINING LOSS: 4.135755
# EPOCH 10 TOTAL TRAINING LOSS: 3.57075
# EPOCH 11 TOTAL TRAINING LOSS: 2.915906
# EPOCH 12 TOTAL TRAINING LOSS: 2.933029
# EPOCH 13 TOTAL TRAINING LOSS: 3.680236
# EPOCH 14 TOTAL TRAINING LOSS: 3.135300
# EPOCH 15 TOTAL TRAINING LOSS: 3.087872
# EPOCH 16 TOTAL TRAINING LOSS: 3.478516
# EPOCH 17 TOTAL TRAINING LOSS: 3.826293
# EPOCH 18 TOTAL TRAINING LOSS: 3.136222
# EPOCH 19 TOTAL TRAINING LOSS: 3.392582
# EPOCH 20 TOTAL TRAINING LOSS: 2.634747
# EPOCH 21 TOTAL TRAINING LOSS: 3.290745
# EPOCH 22 TOTAL TRAINING LOSS: 2.626653
# EPOCH 23 TOTAL TRAINING LOSS: 3.565217
# EPOCH 24 TOTAL TRAINING LOSS: 2.897643
# EPOCH 25 TOTAL TRAINING LOSS: 2.626069
# EPOCH 26 TOTAL TRAINING LOSS: 2.961781
# EPOCH 27 TOTAL TRAINING LOSS: 3.621020
# EPOCH 28 TOTAL TRAINING LOSS: 2.987835
# EPOCH 29 TOTAL TRAINING LOSS: 2.881307
# EPOCH 30 TOTAL TRAINING LOSS: 3.222875
# EPOCH 31 TOTAL TRAINING LOSS: 3.298114
# EPOCH 32 TOTAL TRAINING LOSS: 3.334632
# EPOCH 33 TOTAL TRAINING LOSS: 2.767020
# EPOCH 34 TOTAL TRAINING LOSS: 2.944519
# EPOCH 35 TOTAL TRAINING LOSS: 2.391733
# EPOCH 36 TOTAL TRAINING LOSS: 3.824260
# EPOCH 37 TOTAL TRAINING LOSS: 2.909612
# EPOCH 38 TOTAL TRAINING LOSS: 2.652313
# EPOCH 39 TOTAL TRAINING LOSS: 3.433881
# EPOCH 40 TOTAL TRAINING LOSS: 2.752426
# EPOCH 41 TOTAL TRAINING LOSS: 3.351705
# EPOCH 42 TOTAL TRAINING LOSS: 2.339192
# EPOCH 43 TOTAL TRAINING LOSS: 2.852788
# EPOCH 44 TOTAL TRAINING LOSS: 1.891249
# EPOCH 45 TOTAL TRAINING LOSS: 2.423934
# EPOCH 46 TOTAL TRAINING LOSS: 2.476627
# EPOCH 47 TOTAL TRAINING LOSS: 2.888406
# EPOCH 48 TOTAL TRAINING LOSS: 2.316896
# EPOCH 49 TOTAL TRAINING LOSS: 2.731959
# EPOCH 50 TOTAL TRAINING LOSS: 3.245445
# EPOCH 51 TOTAL TRAINING LOSS: 2.811675
# EPOCH 52 TOTAL TRAINING LOSS: 2.801616
# EPOCH 53 TOTAL TRAINING LOSS: 1.894772
# EPOCH 54 TOTAL TRAINING LOSS: 2.351221
# EPOCH 55 TOTAL TRAINING LOSS: 2.608025
# EPOCH 56 TOTAL TRAINING LOSS: 2.234354
# EPOCH 57 TOTAL TRAINING LOSS: 1.946197
# EPOCH 58 TOTAL TRAINING LOSS: 2.183407
# EPOCH 59 TOTAL TRAINING LOSS: 2.245500
# EPOCH 60 TOTAL TRAINING LOSS: 2.616188
# EPOCH 61 TOTAL TRAINING LOSS: 2.936427
# EPOCH 62 TOTAL TRAINING LOSS: 2.301807
# EPOCH 63 TOTAL TRAINING LOSS: 2.576060
# EPOCH 64 TOTAL TRAINING LOSS: 2.155530
# EPOCH 65 TOTAL TRAINING LOSS: 2.335793
# EPOCH 66 TOTAL TRAINING LOSS: 2.105109
# EPOCH 67 TOTAL TRAINING LOSS: 2.637155
# EPOCH 68 TOTAL TRAINING LOSS: 2.816853
# EPOCH 69 TOTAL TRAINING LOSS: 2.836334
# EPOCH 70 TOTAL TRAINING LOSS: 2.234136
# EPOCH 71 TOTAL TRAINING LOSS: 1.946728
# EPOCH 72 TOTAL TRAINING LOSS: 1.711242
# EPOCH 73 TOTAL TRAINING LOSS: 2.348225
# EPOCH 74 TOTAL TRAINING LOSS: 2.673948
# EPOCH 75 TOTAL TRAINING LOSS: 2.388576
# EPOCH 76 TOTAL TRAINING LOSS: 2.365171
# EPOCH 77 TOTAL TRAINING LOSS: 2.688397
# EPOCH 78 TOTAL TRAINING LOSS: 2.189459
# EPOCH 79 TOTAL TRAINING LOSS: 2.311553
# EPOCH 80 TOTAL TRAINING LOSS: 1.874787
# EPOCH 81 TOTAL TRAINING LOSS: 1.785434
# EPOCH 82 TOTAL TRAINING LOSS: 1.862340
# EPOCH 83 TOTAL TRAINING LOSS: 1.955086
# EPOCH 84 TOTAL TRAINING LOSS: 1.777882
# EPOCH 85 TOTAL TRAINING LOSS: 2.517911
# EPOCH 86 TOTAL TRAINING LOSS: 1.954496
# EPOCH 87 TOTAL TRAINING LOSS: 2.439813
# EPOCH 88 TOTAL TRAINING LOSS: 2.790693
# EPOCH 89 TOTAL TRAINING LOSS: 2.546060
# EPOCH 90 TOTAL TRAINING LOSS: 2.425901
# EPOCH 91 TOTAL TRAINING LOSS: 1.831464
# EPOCH 92 TOTAL TRAINING LOSS: 2.209408
# EPOCH 93 TOTAL TRAINING LOSS: 1.774635
# EPOCH 94 TOTAL TRAINING LOSS: 2.284815
# EPOCH 95 TOTAL TRAINING LOSS: 2.540903
# EPOCH 96 TOTAL TRAINING LOSS: 2.075164
# EPOCH 97 TOTAL TRAINING LOSS: 2.165489
# EPOCH 98 TOTAL TRAINING LOSS: 1.955511
# EPOCH 99 TOTAL TRAINING LOSS: 2.277902
# EPOCH 100 TOTAL TRAINING LOSS: 2.51265
# EPOCH 101 TOTAL TRAINING LOSS: 2.225970
# EPOCH 102 TOTAL TRAINING LOSS: 1.677413
# EPOCH 103 TOTAL TRAINING LOSS: 2.169388
# EPOCH 104 TOTAL TRAINING LOSS: 2.624577
# EPOCH 105 TOTAL TRAINING LOSS: 2.378717
# EPOCH 106 TOTAL TRAINING LOSS: 2.035745
# EPOCH 107 TOTAL TRAINING LOSS: 2.048698
# EPOCH 108 TOTAL TRAINING LOSS: 2.057637
# EPOCH 109 TOTAL TRAINING LOSS: 2.431769
# EPOCH 110 TOTAL TRAINING LOSS: 1.836326
# EPOCH 111 TOTAL TRAINING LOSS: 2.514306
# EPOCH 112 TOTAL TRAINING LOSS: 1.787304
# EPOCH 113 TOTAL TRAINING LOSS: 2.209293
# EPOCH 114 TOTAL TRAINING LOSS: 2.154273
# EPOCH 115 TOTAL TRAINING LOSS: 1.917864
# EPOCH 116 TOTAL TRAINING LOSS: 2.025234
# EPOCH 117 TOTAL TRAINING LOSS: 2.434040
# EPOCH 118 TOTAL TRAINING LOSS: 2.058108
# EPOCH 119 TOTAL TRAINING LOSS: 1.787859
# EPOCH 120 TOTAL TRAINING LOSS: 2.494486
# EPOCH 121 TOTAL TRAINING LOSS: 1.922626
# EPOCH 122 TOTAL TRAINING LOSS: 1.799029
# EPOCH 123 TOTAL TRAINING LOSS: 2.053976
# EPOCH 124 TOTAL TRAINING LOSS: 2.320061
# EPOCH 125 TOTAL TRAINING LOSS: 2.040434
# EPOCH 126 TOTAL TRAINING LOSS: 1.918093
# EPOCH 127 TOTAL TRAINING LOSS: 1.755013
# EPOCH 128 TOTAL TRAINING LOSS: 2.305049
# EPOCH 129 TOTAL TRAINING LOSS: 2.123149
# EPOCH 130 TOTAL TRAINING LOSS: 1.932129
# EPOCH 131 TOTAL TRAINING LOSS: 1.987377
# EPOCH 132 TOTAL TRAINING LOSS: 2.641464
# EPOCH 133 TOTAL TRAINING LOSS: 2.384214
# EPOCH 134 TOTAL TRAINING LOSS: 1.730332
# EPOCH 135 TOTAL TRAINING LOSS: 2.448707
# EPOCH 136 TOTAL TRAINING LOSS: 1.908032
# EPOCH 137 TOTAL TRAINING LOSS: 2.276484
# EPOCH 138 TOTAL TRAINING LOSS: 2.161341
# EPOCH 139 TOTAL TRAINING LOSS: 2.295988
# EPOCH 140 TOTAL TRAINING LOSS: 1.845464
# EPOCH 141 TOTAL TRAINING LOSS: 2.515949
# EPOCH 142 TOTAL TRAINING LOSS: 1.918036
# EPOCH 143 TOTAL TRAINING LOSS: 2.294888
# EPOCH 144 TOTAL TRAINING LOSS: 2.093099
# EPOCH 145 TOTAL TRAINING LOSS: 1.809828
# EPOCH 146 TOTAL TRAINING LOSS: 2.271220
# EPOCH 147 TOTAL TRAINING LOSS: 1.998811
# EPOCH 148 TOTAL TRAINING LOSS: 1.968359
# EPOCH 149 TOTAL TRAINING LOSS: 1.826319
# EPOCH 150 TOTAL TRAINING LOSS: 2.216367
# Using device: cudaLIDATION LOSS: 4.7900
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.3317
# EPOCH 2 TOTAL TRAINING LOSS: 4.019245
# EPOCH 3 TOTAL TRAINING LOSS: 4.157261
# EPOCH 4 TOTAL TRAINING LOSS: 4.667789
# EPOCH 5 TOTAL TRAINING LOSS: 4.133504
# EPOCH 6 TOTAL TRAINING LOSS: 3.585087
# EPOCH 7 TOTAL TRAINING LOSS: 3.800355
# EPOCH 8 TOTAL TRAINING LOSS: 4.581098
# EPOCH 9 TOTAL TRAINING LOSS: 4.168160
# EPOCH 10 TOTAL TRAINING LOSS: 2.39980
# EPOCH 11 TOTAL TRAINING LOSS: 3.452154
# EPOCH 12 TOTAL TRAINING LOSS: 3.698226
# EPOCH 13 TOTAL TRAINING LOSS: 2.744745
# EPOCH 14 TOTAL TRAINING LOSS: 2.928099
# EPOCH 15 TOTAL TRAINING LOSS: 2.897532
# EPOCH 16 TOTAL TRAINING LOSS: 3.142429
# EPOCH 17 TOTAL TRAINING LOSS: 3.279594
# EPOCH 18 TOTAL TRAINING LOSS: 2.765601
# EPOCH 19 TOTAL TRAINING LOSS: 3.719753
# EPOCH 20 TOTAL TRAINING LOSS: 2.582718
# EPOCH 21 TOTAL TRAINING LOSS: 2.932645
# EPOCH 22 TOTAL TRAINING LOSS: 2.286106
# EPOCH 23 TOTAL TRAINING LOSS: 2.998216
# EPOCH 24 TOTAL TRAINING LOSS: 2.051914
# EPOCH 25 TOTAL TRAINING LOSS: 2.375251
# EPOCH 26 TOTAL TRAINING LOSS: 2.438835
# EPOCH 27 TOTAL TRAINING LOSS: 3.417476
# EPOCH 28 TOTAL TRAINING LOSS: 2.081001
# EPOCH 29 TOTAL TRAINING LOSS: 3.453959
# EPOCH 30 TOTAL TRAINING LOSS: 2.655174
# EPOCH 31 TOTAL TRAINING LOSS: 5.551027
# EPOCH 32 TOTAL TRAINING LOSS: 2.335031
# EPOCH 33 TOTAL TRAINING LOSS: 1.982941
# EPOCH 34 TOTAL TRAINING LOSS: 2.293028
# EPOCH 35 TOTAL TRAINING LOSS: 2.085725
# EPOCH 36 TOTAL TRAINING LOSS: 2.026504
# EPOCH 37 TOTAL TRAINING LOSS: 2.383233
# EPOCH 38 TOTAL TRAINING LOSS: 2.165277
# EPOCH 39 TOTAL TRAINING LOSS: 3.475462
# EPOCH 40 TOTAL TRAINING LOSS: 2.466406
# EPOCH 41 TOTAL TRAINING LOSS: 2.900688
# EPOCH 42 TOTAL TRAINING LOSS: 1.684057
# EPOCH 43 TOTAL TRAINING LOSS: 2.189258
# EPOCH 44 TOTAL TRAINING LOSS: 3.351324
# EPOCH 45 TOTAL TRAINING LOSS: 1.600191
# EPOCH 46 TOTAL TRAINING LOSS: 2.204113
# EPOCH 47 TOTAL TRAINING LOSS: 2.568469
# EPOCH 48 TOTAL TRAINING LOSS: 1.962563
# EPOCH 49 TOTAL TRAINING LOSS: 2.482153
# EPOCH 50 TOTAL TRAINING LOSS: 1.900278
# EPOCH 51 TOTAL TRAINING LOSS: 2.179304
# EPOCH 52 TOTAL TRAINING LOSS: 2.381189
# EPOCH 53 TOTAL TRAINING LOSS: 3.347768
# EPOCH 54 TOTAL TRAINING LOSS: 1.931712
# EPOCH 55 TOTAL TRAINING LOSS: 1.721029
# EPOCH 56 TOTAL TRAINING LOSS: 2.625015
# EPOCH 57 TOTAL TRAINING LOSS: 1.811897
# EPOCH 58 TOTAL TRAINING LOSS: 1.753777
# EPOCH 59 TOTAL TRAINING LOSS: 2.347440
# EPOCH 60 TOTAL TRAINING LOSS: 1.854026
# EPOCH 61 TOTAL TRAINING LOSS: 1.631131
# EPOCH 62 TOTAL TRAINING LOSS: 1.652723
# EPOCH 63 TOTAL TRAINING LOSS: 3.268771
# EPOCH 64 TOTAL TRAINING LOSS: 1.999381
# EPOCH 65 TOTAL TRAINING LOSS: 2.964782
# EPOCH 66 TOTAL TRAINING LOSS: 2.038807
# EPOCH 67 TOTAL TRAINING LOSS: 1.927553
# EPOCH 68 TOTAL TRAINING LOSS: 2.459813
# EPOCH 69 TOTAL TRAINING LOSS: 2.519740
# EPOCH 70 TOTAL TRAINING LOSS: 1.798679
# EPOCH 71 TOTAL TRAINING LOSS: 2.025952
# EPOCH 72 TOTAL TRAINING LOSS: 2.831019
# EPOCH 73 TOTAL TRAINING LOSS: 1.702216
# EPOCH 74 TOTAL TRAINING LOSS: 2.046993
# EPOCH 75 TOTAL TRAINING LOSS: 2.440509
# EPOCH 76 TOTAL TRAINING LOSS: 2.238727
# EPOCH 77 TOTAL TRAINING LOSS: 2.002215
# EPOCH 78 TOTAL TRAINING LOSS: 3.561782
# EPOCH 79 TOTAL TRAINING LOSS: 2.547025
# EPOCH 80 TOTAL TRAINING LOSS: 1.830207
# EPOCH 81 TOTAL TRAINING LOSS: 1.764711
# EPOCH 82 TOTAL TRAINING LOSS: 2.786617
# EPOCH 83 TOTAL TRAINING LOSS: 2.026988
# EPOCH 84 TOTAL TRAINING LOSS: 3.619099
# EPOCH 85 TOTAL TRAINING LOSS: 1.685665
# EPOCH 86 TOTAL TRAINING LOSS: 1.877043
# EPOCH 87 TOTAL TRAINING LOSS: 1.872231
# EPOCH 88 TOTAL TRAINING LOSS: 2.599911
# EPOCH 89 TOTAL TRAINING LOSS: 1.691768
# EPOCH 90 TOTAL TRAINING LOSS: 1.929682
# EPOCH 91 TOTAL TRAINING LOSS: 1.829311
# EPOCH 92 TOTAL TRAINING LOSS: 1.450406
# EPOCH 93 TOTAL TRAINING LOSS: 2.476174
# EPOCH 94 TOTAL TRAINING LOSS: 3.212773
# EPOCH 95 TOTAL TRAINING LOSS: 1.749346
# EPOCH 96 TOTAL TRAINING LOSS: 1.627222
# EPOCH 97 TOTAL TRAINING LOSS: 1.928406
# EPOCH 98 TOTAL TRAINING LOSS: 2.573351
# EPOCH 99 TOTAL TRAINING LOSS: 1.787114
# EPOCH 100 TOTAL TRAINING LOSS: 1.66894
# EPOCH 101 TOTAL TRAINING LOSS: 2.951581
# EPOCH 102 TOTAL TRAINING LOSS: 1.623960
# EPOCH 103 TOTAL TRAINING LOSS: 2.009368
# EPOCH 104 TOTAL TRAINING LOSS: 1.653570
# EPOCH 105 TOTAL TRAINING LOSS: 1.741107
# EPOCH 106 TOTAL TRAINING LOSS: 1.376494
# EPOCH 107 TOTAL TRAINING LOSS: 2.059714
# EPOCH 108 TOTAL TRAINING LOSS: 2.036122
# EPOCH 109 TOTAL TRAINING LOSS: 2.140960
# EPOCH 110 TOTAL TRAINING LOSS: 1.701600
# EPOCH 111 TOTAL TRAINING LOSS: 2.867312
# EPOCH 112 TOTAL TRAINING LOSS: 1.825334
# EPOCH 113 TOTAL TRAINING LOSS: 1.952590
# EPOCH 114 TOTAL TRAINING LOSS: 1.780860
# EPOCH 115 TOTAL TRAINING LOSS: 2.044832
# EPOCH 116 TOTAL TRAINING LOSS: 1.641789
# EPOCH 117 TOTAL TRAINING LOSS: 2.140673
# EPOCH 118 TOTAL TRAINING LOSS: 1.970135
# EPOCH 119 TOTAL TRAINING LOSS: 1.823950
# EPOCH 120 TOTAL TRAINING LOSS: 1.630833
# EPOCH 121 TOTAL TRAINING LOSS: 2.528064
# EPOCH 122 TOTAL TRAINING LOSS: 1.555611
# EPOCH 123 TOTAL TRAINING LOSS: 1.551020
# EPOCH 124 TOTAL TRAINING LOSS: 2.298502
# EPOCH 125 TOTAL TRAINING LOSS: 2.728962
# EPOCH 126 TOTAL TRAINING LOSS: 2.713597
# EPOCH 127 TOTAL TRAINING LOSS: 1.764069
# EPOCH 128 TOTAL TRAINING LOSS: 2.420008
# EPOCH 129 TOTAL TRAINING LOSS: 2.671480
# EPOCH 130 TOTAL TRAINING LOSS: 2.158587
# EPOCH 131 TOTAL TRAINING LOSS: 2.146322
# EPOCH 132 TOTAL TRAINING LOSS: 2.182665
# EPOCH 133 TOTAL TRAINING LOSS: 1.971147
# EPOCH 134 TOTAL TRAINING LOSS: 1.739676
# EPOCH 135 TOTAL TRAINING LOSS: 1.450906
# EPOCH 136 TOTAL TRAINING LOSS: 1.819426
# EPOCH 137 TOTAL TRAINING LOSS: 3.617901
# EPOCH 138 TOTAL TRAINING LOSS: 1.198036
# EPOCH 139 TOTAL TRAINING LOSS: 1.875803
# EPOCH 140 TOTAL TRAINING LOSS: 1.901304
# EPOCH 141 TOTAL TRAINING LOSS: 2.345640
# EPOCH 142 TOTAL TRAINING LOSS: 1.845592
# EPOCH 143 TOTAL TRAINING LOSS: 2.302199
# EPOCH 144 TOTAL TRAINING LOSS: 1.446874
# EPOCH 145 TOTAL TRAINING LOSS: 1.729212
# EPOCH 146 TOTAL TRAINING LOSS: 1.598585
# EPOCH 147 TOTAL TRAINING LOSS: 2.509557
# EPOCH 148 TOTAL TRAINING LOSS: 1.353468
# EPOCH 149 TOTAL TRAINING LOSS: 1.961212
# EPOCH 150 TOTAL TRAINING LOSS: 1.460255
# Using device: cudaLIDATION LOSS: 4.4989
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.5672
# EPOCH 2 TOTAL TRAINING LOSS: 6.842285
# EPOCH 3 TOTAL TRAINING LOSS: 5.176187
# EPOCH 4 TOTAL TRAINING LOSS: 4.788494
# EPOCH 5 TOTAL TRAINING LOSS: 5.272826
# EPOCH 6 TOTAL TRAINING LOSS: 5.237377
# EPOCH 7 TOTAL TRAINING LOSS: 3.852316
# EPOCH 8 TOTAL TRAINING LOSS: 3.465579
# EPOCH 9 TOTAL TRAINING LOSS: 4.267456
# EPOCH 10 TOTAL TRAINING LOSS: 4.65311
# EPOCH 11 TOTAL TRAINING LOSS: 3.845714
# EPOCH 12 TOTAL TRAINING LOSS: 3.036279
# EPOCH 13 TOTAL TRAINING LOSS: 3.484154
# EPOCH 14 TOTAL TRAINING LOSS: 3.313507
# EPOCH 15 TOTAL TRAINING LOSS: 3.671280
# EPOCH 16 TOTAL TRAINING LOSS: 3.035479
# EPOCH 17 TOTAL TRAINING LOSS: 3.756581
# EPOCH 18 TOTAL TRAINING LOSS: 3.200918
# EPOCH 19 TOTAL TRAINING LOSS: 4.524931
# EPOCH 20 TOTAL TRAINING LOSS: 3.215484
# EPOCH 21 TOTAL TRAINING LOSS: 2.448288
# EPOCH 22 TOTAL TRAINING LOSS: 3.344420
# EPOCH 23 TOTAL TRAINING LOSS: 3.243015
# EPOCH 24 TOTAL TRAINING LOSS: 2.386282
# EPOCH 25 TOTAL TRAINING LOSS: 5.432498
# EPOCH 26 TOTAL TRAINING LOSS: 2.755731
# EPOCH 27 TOTAL TRAINING LOSS: 2.780793
# EPOCH 28 TOTAL TRAINING LOSS: 3.627313
# EPOCH 29 TOTAL TRAINING LOSS: 4.084477
# EPOCH 30 TOTAL TRAINING LOSS: 2.743581
# EPOCH 31 TOTAL TRAINING LOSS: 2.906218
# EPOCH 32 TOTAL TRAINING LOSS: 3.237093
# EPOCH 33 TOTAL TRAINING LOSS: 3.737150
# EPOCH 34 TOTAL TRAINING LOSS: 3.232978
# EPOCH 35 TOTAL TRAINING LOSS: 3.495324
# EPOCH 36 TOTAL TRAINING LOSS: 2.725684
# EPOCH 37 TOTAL TRAINING LOSS: 3.278599
# EPOCH 38 TOTAL TRAINING LOSS: 3.132618
# EPOCH 39 TOTAL TRAINING LOSS: 2.865041
# EPOCH 40 TOTAL TRAINING LOSS: 3.217592
# EPOCH 41 TOTAL TRAINING LOSS: 2.468366
# EPOCH 42 TOTAL TRAINING LOSS: 2.139249
# EPOCH 43 TOTAL TRAINING LOSS: 2.620202
# EPOCH 44 TOTAL TRAINING LOSS: 2.678195
# EPOCH 45 TOTAL TRAINING LOSS: 2.929132
# EPOCH 46 TOTAL TRAINING LOSS: 3.239582
# EPOCH 47 TOTAL TRAINING LOSS: 2.260218
# EPOCH 48 TOTAL TRAINING LOSS: 2.074052
# EPOCH 49 TOTAL TRAINING LOSS: 2.885145
# EPOCH 50 TOTAL TRAINING LOSS: 2.418474
# EPOCH 51 TOTAL TRAINING LOSS: 2.971160
# EPOCH 52 TOTAL TRAINING LOSS: 2.494244
# EPOCH 53 TOTAL TRAINING LOSS: 3.443234
# EPOCH 54 TOTAL TRAINING LOSS: 2.362920
# EPOCH 55 TOTAL TRAINING LOSS: 2.738721
# EPOCH 56 TOTAL TRAINING LOSS: 2.740725
# EPOCH 57 TOTAL TRAINING LOSS: 3.347155
# EPOCH 58 TOTAL TRAINING LOSS: 2.793819
# EPOCH 59 TOTAL TRAINING LOSS: 3.752856
# EPOCH 60 TOTAL TRAINING LOSS: 2.778863
# EPOCH 61 TOTAL TRAINING LOSS: 3.255383
# EPOCH 62 TOTAL TRAINING LOSS: 1.902282
# EPOCH 63 TOTAL TRAINING LOSS: 3.035407
# EPOCH 64 TOTAL TRAINING LOSS: 1.943000
# EPOCH 65 TOTAL TRAINING LOSS: 2.354429
# EPOCH 66 TOTAL TRAINING LOSS: 3.023104
# EPOCH 67 TOTAL TRAINING LOSS: 3.346829
# EPOCH 68 TOTAL TRAINING LOSS: 3.284804
# EPOCH 69 TOTAL TRAINING LOSS: 2.466032
# EPOCH 70 TOTAL TRAINING LOSS: 2.667126
# EPOCH 71 TOTAL TRAINING LOSS: 3.025233
# EPOCH 72 TOTAL TRAINING LOSS: 2.336960
# EPOCH 73 TOTAL TRAINING LOSS: 1.943904
# EPOCH 74 TOTAL TRAINING LOSS: 2.806992
# EPOCH 75 TOTAL TRAINING LOSS: 2.141200
# EPOCH 76 TOTAL TRAINING LOSS: 2.099875
# EPOCH 77 TOTAL TRAINING LOSS: 1.862291
# EPOCH 78 TOTAL TRAINING LOSS: 3.000122
# EPOCH 79 TOTAL TRAINING LOSS: 3.351187
# EPOCH 80 TOTAL TRAINING LOSS: 2.365219
# EPOCH 81 TOTAL TRAINING LOSS: 1.871485
# EPOCH 82 TOTAL TRAINING LOSS: 1.796090
# EPOCH 83 TOTAL TRAINING LOSS: 2.269874
# EPOCH 84 TOTAL TRAINING LOSS: 1.878908
# EPOCH 85 TOTAL TRAINING LOSS: 2.542293
# EPOCH 86 TOTAL TRAINING LOSS: 2.103347
# EPOCH 87 TOTAL TRAINING LOSS: 2.143836
# EPOCH 88 TOTAL TRAINING LOSS: 2.373582
# EPOCH 89 TOTAL TRAINING LOSS: 2.371641
# EPOCH 90 TOTAL TRAINING LOSS: 1.950903
# EPOCH 91 TOTAL TRAINING LOSS: 2.112303
# EPOCH 92 TOTAL TRAINING LOSS: 1.921289
# EPOCH 93 TOTAL TRAINING LOSS: 2.919362
# EPOCH 94 TOTAL TRAINING LOSS: 2.338715
# EPOCH 95 TOTAL TRAINING LOSS: 2.852649
# EPOCH 96 TOTAL TRAINING LOSS: 2.019472
# EPOCH 97 TOTAL TRAINING LOSS: 2.305042
# EPOCH 98 TOTAL TRAINING LOSS: 2.980516
# EPOCH 99 TOTAL TRAINING LOSS: 2.309421
# EPOCH 100 TOTAL TRAINING LOSS: 1.94458
# EPOCH 101 TOTAL TRAINING LOSS: 1.817231
# EPOCH 102 TOTAL TRAINING LOSS: 3.543758
# EPOCH 103 TOTAL TRAINING LOSS: 2.462074
# ...
# EPOCH 63 TOTAL TRAINING LOSS: 1.948839
# EPOCH 64 TOTAL TRAINING LOSS: 2.617715
# EPOCH 65 TOTAL TRAINING LOSS: 2.182356
# EPOCH 66 TOTAL TRAINING LOSS: 2.966364
# EPOCH 67 TOTAL TRAINING LOSS: 1.312989
# EPOCH 68 TOTAL TRAINING LOSS: 2.581727
# EPOCH 69 TOTAL TRAINING LOSS: 2.000049
# EPOCH 70 TOTAL TRAINING LOSS: 2.675392
# EPOCH 71 TOTAL TRAINING LOSS: 2.916627
# EPOCH 72 TOTAL TRAINING LOSS: 2.293882
# EPOCH 73 TOTAL TRAINING LOSS: 2.262154
# EPOCH 74 TOTAL TRAINING LOSS: 1.537421
# EPOCH 75 TOTAL TRAINING LOSS: 2.762139
# EPOCH 76 TOTAL TRAINING LOSS: 2.830049
# EPOCH 77 TOTAL TRAINING LOSS: 2.315251
# EPOCH 78 TOTAL TRAINING LOSS: 2.445945
# EPOCH 79 TOTAL TRAINING LOSS: 1.890819
# EPOCH 80 TOTAL TRAINING LOSS: 1.915358
# EPOCH 81 TOTAL TRAINING LOSS: 2.115880
# EPOCH 82 TOTAL TRAINING LOSS: 1.793828
# EPOCH 83 TOTAL TRAINING LOSS: 1.882882
# EPOCH 84 TOTAL TRAINING LOSS: 2.433867
# EPOCH 85 TOTAL TRAINING LOSS: 2.980629
# EPOCH 86 TOTAL TRAINING LOSS: 2.369509
# EPOCH 87 TOTAL TRAINING LOSS: 2.490162
# EPOCH 88 TOTAL TRAINING LOSS: 2.812422
# EPOCH 89 TOTAL TRAINING LOSS: 2.186927
# EPOCH 90 TOTAL TRAINING LOSS: 4.324946
# EPOCH 91 TOTAL TRAINING LOSS: 2.267516
# EPOCH 92 TOTAL TRAINING LOSS: 1.435925
# EPOCH 93 TOTAL TRAINING LOSS: 1.507100
# EPOCH 94 TOTAL TRAINING LOSS: 2.446863
# EPOCH 95 TOTAL TRAINING LOSS: 1.751554
# EPOCH 96 TOTAL TRAINING LOSS: 1.557828
# EPOCH 97 TOTAL TRAINING LOSS: 1.767850
# EPOCH 98 TOTAL TRAINING LOSS: 2.416773
# EPOCH 99 TOTAL TRAINING LOSS: 1.870830
# EPOCH 100 TOTAL TRAINING LOSS: 3.24829
# EPOCH 101 TOTAL TRAINING LOSS: 2.591856
# EPOCH 102 TOTAL TRAINING LOSS: 2.270682
# EPOCH 103 TOTAL TRAINING LOSS: 1.758136
# EPOCH 104 TOTAL TRAINING LOSS: 1.569863
# EPOCH 105 TOTAL TRAINING LOSS: 2.142825
# EPOCH 106 TOTAL TRAINING LOSS: 1.731077
# EPOCH 107 TOTAL TRAINING LOSS: 1.463895
# EPOCH 108 TOTAL TRAINING LOSS: 2.379077
# EPOCH 109 TOTAL TRAINING LOSS: 2.325271
# EPOCH 110 TOTAL TRAINING LOSS: 2.155049
# EPOCH 111 TOTAL TRAINING LOSS: 2.844519
# EPOCH 112 TOTAL TRAINING LOSS: 2.168573
# EPOCH 113 TOTAL TRAINING LOSS: 1.563123
# EPOCH 114 TOTAL TRAINING LOSS: 1.983057
# EPOCH 115 TOTAL TRAINING LOSS: 1.811335
# EPOCH 116 TOTAL TRAINING LOSS: 1.668929
# EPOCH 117 TOTAL TRAINING LOSS: 1.697320
# EPOCH 118 TOTAL TRAINING LOSS: 1.502710
# EPOCH 119 TOTAL TRAINING LOSS: 2.162750
# EPOCH 120 TOTAL TRAINING LOSS: 1.940661
# EPOCH 121 TOTAL TRAINING LOSS: 2.395802
# EPOCH 122 TOTAL TRAINING LOSS: 1.504196
# EPOCH 123 TOTAL TRAINING LOSS: 2.197276
# EPOCH 124 TOTAL TRAINING LOSS: 2.435972
# EPOCH 125 TOTAL TRAINING LOSS: 1.604286
# EPOCH 126 TOTAL TRAINING LOSS: 1.698133
# EPOCH 127 TOTAL TRAINING LOSS: 1.320414
# EPOCH 128 TOTAL TRAINING LOSS: 1.713861
# EPOCH 129 TOTAL TRAINING LOSS: 1.850551
# EPOCH 130 TOTAL TRAINING LOSS: 1.923475
# EPOCH 131 TOTAL TRAINING LOSS: 1.866425
# EPOCH 132 TOTAL TRAINING LOSS: 2.602206
# EPOCH 133 TOTAL TRAINING LOSS: 2.064017
# EPOCH 134 TOTAL TRAINING LOSS: 2.463935
# EPOCH 135 TOTAL TRAINING LOSS: 3.053837
# EPOCH 136 TOTAL TRAINING LOSS: 1.652137
# EPOCH 137 TOTAL TRAINING LOSS: 2.534813
# EPOCH 138 TOTAL TRAINING LOSS: 2.236777
# EPOCH 139 TOTAL TRAINING LOSS: 1.918336
# EPOCH 140 TOTAL TRAINING LOSS: 2.222846
# EPOCH 141 TOTAL TRAINING LOSS: 2.671720
# EPOCH 142 TOTAL TRAINING LOSS: 1.801725
# EPOCH 143 TOTAL TRAINING LOSS: 1.953392
# EPOCH 144 TOTAL TRAINING LOSS: 1.456656
# EPOCH 145 TOTAL TRAINING LOSS: 2.409542
# EPOCH 146 TOTAL TRAINING LOSS: 2.401998
# EPOCH 147 TOTAL TRAINING LOSS: 2.586635
# EPOCH 148 TOTAL TRAINING LOSS: 2.094058
# EPOCH 149 TOTAL TRAINING LOSS: 2.652883
# EPOCH 150 TOTAL TRAINING LOSS: 1.565588
# Using device: cudaLIDATION LOSS: 6.9814
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 6.1800
# EPOCH 2 TOTAL TRAINING LOSS: 6.568411
# EPOCH 3 TOTAL TRAINING LOSS: 5.601990
# EPOCH 4 TOTAL TRAINING LOSS: 4.580868
# EPOCH 5 TOTAL TRAINING LOSS: 4.188635
# EPOCH 6 TOTAL TRAINING LOSS: 4.824323
# EPOCH 7 TOTAL TRAINING LOSS: 4.532047
# EPOCH 8 TOTAL TRAINING LOSS: 4.209551
# EPOCH 9 TOTAL TRAINING LOSS: 3.960381
# EPOCH 10 TOTAL TRAINING LOSS: 3.80142
# EPOCH 11 TOTAL TRAINING LOSS: 3.281589
# EPOCH 12 TOTAL TRAINING LOSS: 3.649694
# EPOCH 13 TOTAL TRAINING LOSS: 3.752398
# EPOCH 14 TOTAL TRAINING LOSS: 3.856412
# EPOCH 15 TOTAL TRAINING LOSS: 3.041373
# EPOCH 16 TOTAL TRAINING LOSS: 3.064465
# EPOCH 17 TOTAL TRAINING LOSS: 5.232378
# EPOCH 18 TOTAL TRAINING LOSS: 3.229877
# EPOCH 19 TOTAL TRAINING LOSS: 3.177813
# EPOCH 20 TOTAL TRAINING LOSS: 3.840228
# EPOCH 21 TOTAL TRAINING LOSS: 2.689815
# EPOCH 22 TOTAL TRAINING LOSS: 2.820741
# EPOCH 23 TOTAL TRAINING LOSS: 2.567977
# EPOCH 24 TOTAL TRAINING LOSS: 2.783561
# EPOCH 25 TOTAL TRAINING LOSS: 2.871231
# EPOCH 26 TOTAL TRAINING LOSS: 2.702358
# EPOCH 27 TOTAL TRAINING LOSS: 2.666673
# EPOCH 28 TOTAL TRAINING LOSS: 3.734687
# EPOCH 29 TOTAL TRAINING LOSS: 3.085442
# EPOCH 30 TOTAL TRAINING LOSS: 2.663148
# EPOCH 31 TOTAL TRAINING LOSS: 2.354397
# EPOCH 32 TOTAL TRAINING LOSS: 3.030349
# EPOCH 33 TOTAL TRAINING LOSS: 2.137229
# EPOCH 34 TOTAL TRAINING LOSS: 3.894499
# EPOCH 35 TOTAL TRAINING LOSS: 2.341220
# EPOCH 36 TOTAL TRAINING LOSS: 2.561876
# EPOCH 37 TOTAL TRAINING LOSS: 2.697324
# EPOCH 38 TOTAL TRAINING LOSS: 2.594618
# EPOCH 39 TOTAL TRAINING LOSS: 4.054155
# EPOCH 40 TOTAL TRAINING LOSS: 2.399421
# EPOCH 41 TOTAL TRAINING LOSS: 2.959959
# EPOCH 42 TOTAL TRAINING LOSS: 1.882083
# EPOCH 43 TOTAL TRAINING LOSS: 2.479406
# EPOCH 44 TOTAL TRAINING LOSS: 3.833986
# EPOCH 45 TOTAL TRAINING LOSS: 3.649412
# EPOCH 46 TOTAL TRAINING LOSS: 3.444990
# EPOCH 47 TOTAL TRAINING LOSS: 3.624059
# EPOCH 48 TOTAL TRAINING LOSS: 2.467320
# EPOCH 49 TOTAL TRAINING LOSS: 2.167427
# EPOCH 50 TOTAL TRAINING LOSS: 2.280132
# EPOCH 51 TOTAL TRAINING LOSS: 1.708383
# EPOCH 52 TOTAL TRAINING LOSS: 3.109904
# EPOCH 53 TOTAL TRAINING LOSS: 3.125562
# EPOCH 54 TOTAL TRAINING LOSS: 2.905881
# EPOCH 55 TOTAL TRAINING LOSS: 2.021676
# EPOCH 56 TOTAL TRAINING LOSS: 2.735961
# EPOCH 57 TOTAL TRAINING LOSS: 2.609970
# EPOCH 58 TOTAL TRAINING LOSS: 2.470414
# EPOCH 59 TOTAL TRAINING LOSS: 2.376219
# EPOCH 60 TOTAL TRAINING LOSS: 1.774949
# EPOCH 61 TOTAL TRAINING LOSS: 3.171705
# EPOCH 62 TOTAL TRAINING LOSS: 1.852284
# EPOCH 63 TOTAL TRAINING LOSS: 2.291334
# EPOCH 64 TOTAL TRAINING LOSS: 2.250076
# EPOCH 65 TOTAL TRAINING LOSS: 2.442060
# EPOCH 66 TOTAL TRAINING LOSS: 1.743902
# EPOCH 67 TOTAL TRAINING LOSS: 3.002569
# EPOCH 68 TOTAL TRAINING LOSS: 1.939490
# EPOCH 69 TOTAL TRAINING LOSS: 2.132712
# EPOCH 70 TOTAL TRAINING LOSS: 1.940468
# EPOCH 71 TOTAL TRAINING LOSS: 2.767562
# EPOCH 72 TOTAL TRAINING LOSS: 2.519889
# EPOCH 73 TOTAL TRAINING LOSS: 3.088544
# EPOCH 74 TOTAL TRAINING LOSS: 3.236251
# EPOCH 75 TOTAL TRAINING LOSS: 3.083459
# EPOCH 76 TOTAL TRAINING LOSS: 3.005296
# EPOCH 77 TOTAL TRAINING LOSS: 2.702015
# EPOCH 78 TOTAL TRAINING LOSS: 1.851443
# EPOCH 79 TOTAL TRAINING LOSS: 2.645696
# EPOCH 80 TOTAL TRAINING LOSS: 2.310583
# EPOCH 81 TOTAL TRAINING LOSS: 2.537544
# EPOCH 82 TOTAL TRAINING LOSS: 2.379228
# EPOCH 83 TOTAL TRAINING LOSS: 2.217119
# EPOCH 84 TOTAL TRAINING LOSS: 2.224205
# EPOCH 85 TOTAL TRAINING LOSS: 1.669066
# EPOCH 86 TOTAL TRAINING LOSS: 2.040332
# EPOCH 87 TOTAL TRAINING LOSS: 2.175059
# EPOCH 88 TOTAL TRAINING LOSS: 2.499302
# EPOCH 89 TOTAL TRAINING LOSS: 1.686658
# EPOCH 90 TOTAL TRAINING LOSS: 1.806348
# EPOCH 91 TOTAL TRAINING LOSS: 2.293796
# EPOCH 92 TOTAL TRAINING LOSS: 2.676158
# EPOCH 93 TOTAL TRAINING LOSS: 2.969950
# EPOCH 94 TOTAL TRAINING LOSS: 2.073644
# EPOCH 95 TOTAL TRAINING LOSS: 1.561132
# EPOCH 96 TOTAL TRAINING LOSS: 2.225205
# EPOCH 97 TOTAL TRAINING LOSS: 1.687968
# EPOCH 98 TOTAL TRAINING LOSS: 3.748774
# EPOCH 99 TOTAL TRAINING LOSS: 1.956035
# EPOCH 100 TOTAL TRAINING LOSS: 1.73135
# EPOCH 101 TOTAL TRAINING LOSS: 2.009470
# EPOCH 102 TOTAL TRAINING LOSS: 2.332446
# EPOCH 103 TOTAL TRAINING LOSS: 1.594243
# EPOCH 104 TOTAL TRAINING LOSS: 3.127291
# EPOCH 105 TOTAL TRAINING LOSS: 1.903747
# EPOCH 106 TOTAL TRAINING LOSS: 1.819516
# EPOCH 107 TOTAL TRAINING LOSS: 2.127630
# EPOCH 108 TOTAL TRAINING LOSS: 2.098393
# EPOCH 109 TOTAL TRAINING LOSS: 2.448585
# EPOCH 110 TOTAL TRAINING LOSS: 2.354527
# EPOCH 111 TOTAL TRAINING LOSS: 2.011490
# EPOCH 112 TOTAL TRAINING LOSS: 2.042952
# EPOCH 113 TOTAL TRAINING LOSS: 1.911123
# EPOCH 114 TOTAL TRAINING LOSS: 1.374488
# EPOCH 115 TOTAL TRAINING LOSS: 2.311842
# EPOCH 116 TOTAL TRAINING LOSS: 2.063802
# EPOCH 117 TOTAL TRAINING LOSS: 3.172433
# EPOCH 118 TOTAL TRAINING LOSS: 2.130108
# EPOCH 119 TOTAL TRAINING LOSS: 2.304740
# EPOCH 120 TOTAL TRAINING LOSS: 2.808316
# EPOCH 121 TOTAL TRAINING LOSS: 1.592239
# EPOCH 122 TOTAL TRAINING LOSS: 1.902234
# EPOCH 123 TOTAL TRAINING LOSS: 1.643820
# EPOCH 124 TOTAL TRAINING LOSS: 3.049305
# EPOCH 125 TOTAL TRAINING LOSS: 2.548239
# EPOCH 126 TOTAL TRAINING LOSS: 2.085142
# EPOCH 127 TOTAL TRAINING LOSS: 2.578108
# EPOCH 128 TOTAL TRAINING LOSS: 2.428369
# EPOCH 129 TOTAL TRAINING LOSS: 1.904866
# EPOCH 130 TOTAL TRAINING LOSS: 2.947066
# EPOCH 131 TOTAL TRAINING LOSS: 2.246203
# EPOCH 132 TOTAL TRAINING LOSS: 1.658263
# EPOCH 133 TOTAL TRAINING LOSS: 1.991022
# EPOCH 134 TOTAL TRAINING LOSS: 1.631271
# EPOCH 135 TOTAL TRAINING LOSS: 2.135521
# EPOCH 136 TOTAL TRAINING LOSS: 1.609475
# EPOCH 137 TOTAL TRAINING LOSS: 2.417000
# EPOCH 138 TOTAL TRAINING LOSS: 1.512061
# EPOCH 139 TOTAL TRAINING LOSS: 2.252751
# EPOCH 140 TOTAL TRAINING LOSS: 2.613728
# EPOCH 141 TOTAL TRAINING LOSS: 2.130859
# EPOCH 142 TOTAL TRAINING LOSS: 2.089154
# EPOCH 143 TOTAL TRAINING LOSS: 2.365158
# EPOCH 144 TOTAL TRAINING LOSS: 2.293518
# EPOCH 145 TOTAL TRAINING LOSS: 1.974606
# EPOCH 146 TOTAL TRAINING LOSS: 2.952882
# EPOCH 147 TOTAL TRAINING LOSS: 2.741443
# EPOCH 148 TOTAL TRAINING LOSS: 2.434267
# EPOCH 149 TOTAL TRAINING LOSS: 1.246581
# EPOCH 150 TOTAL TRAINING LOSS: 1.652399
# Using device: cudaLIDATION LOSS: 4.2191
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# EPOCH 1 TOTAL TRAINING LOSS: 5.3534
# EPOCH 2 TOTAL TRAINING LOSS: 4.649235
# EPOCH 3 TOTAL TRAINING LOSS: 4.562326
# EPOCH 4 TOTAL TRAINING LOSS: 5.299675
# EPOCH 5 TOTAL TRAINING LOSS: 4.841192
# EPOCH 6 TOTAL TRAINING LOSS: 4.697168
# EPOCH 7 TOTAL TRAINING LOSS: 3.681401
# EPOCH 8 TOTAL TRAINING LOSS: 3.140879
# EPOCH 9 TOTAL TRAINING LOSS: 3.318753
# EPOCH 10 TOTAL TRAINING LOSS: 4.22930
# EPOCH 11 TOTAL TRAINING LOSS: 2.793476
# EPOCH 12 TOTAL TRAINING LOSS: 3.074998
# EPOCH 13 TOTAL TRAINING LOSS: 2.279282
# EPOCH 14 TOTAL TRAINING LOSS: 3.508966
# EPOCH 15 TOTAL TRAINING LOSS: 3.462609
# EPOCH 16 TOTAL TRAINING LOSS: 3.952012
# EPOCH 17 TOTAL TRAINING LOSS: 3.865199
# EPOCH 18 TOTAL TRAINING LOSS: 4.651129
# EPOCH 19 TOTAL TRAINING LOSS: 3.571610
# EPOCH 20 TOTAL TRAINING LOSS: 2.406668
# EPOCH 21 TOTAL TRAINING LOSS: 2.418308
# EPOCH 22 TOTAL TRAINING LOSS: 3.080365
# EPOCH 23 TOTAL TRAINING LOSS: 3.438903
# EPOCH 24 TOTAL TRAINING LOSS: 3.259206
# EPOCH 25 TOTAL TRAINING LOSS: 4.215614
# EPOCH 26 TOTAL TRAINING LOSS: 3.369947
# EPOCH 27 TOTAL TRAINING LOSS: 3.446011
# EPOCH 28 TOTAL TRAINING LOSS: 3.222614
# EPOCH 29 TOTAL TRAINING LOSS: 3.149355
# EPOCH 30 TOTAL TRAINING LOSS: 1.922364
# EPOCH 31 TOTAL TRAINING LOSS: 3.476980
# EPOCH 32 TOTAL TRAINING LOSS: 2.334772
# EPOCH 33 TOTAL TRAINING LOSS: 2.162474
# EPOCH 34 TOTAL TRAINING LOSS: 2.425508
# EPOCH 35 TOTAL TRAINING LOSS: 2.408735
# EPOCH 36 TOTAL TRAINING LOSS: 3.459844
# EPOCH 37 TOTAL TRAINING LOSS: 2.577115
# EPOCH 38 TOTAL TRAINING LOSS: 2.301999
# EPOCH 39 TOTAL TRAINING LOSS: 3.240574
# EPOCH 40 TOTAL TRAINING LOSS: 2.796530
# EPOCH 41 TOTAL TRAINING LOSS: 2.874245
# EPOCH 42 TOTAL TRAINING LOSS: 3.086556
# EPOCH 43 TOTAL TRAINING LOSS: 2.349171
# EPOCH 44 TOTAL TRAINING LOSS: 2.258499
# EPOCH 45 TOTAL TRAINING LOSS: 3.021932
# EPOCH 46 TOTAL TRAINING LOSS: 2.606790
# EPOCH 47 TOTAL TRAINING LOSS: 2.143190
# EPOCH 48 TOTAL TRAINING LOSS: 2.723258
# EPOCH 49 TOTAL TRAINING LOSS: 2.272413
# EPOCH 50 TOTAL TRAINING LOSS: 2.691781
# EPOCH 51 TOTAL TRAINING LOSS: 2.533509
# EPOCH 52 TOTAL TRAINING LOSS: 2.360699
# EPOCH 53 TOTAL TRAINING LOSS: 2.421997
# EPOCH 54 TOTAL TRAINING LOSS: 1.995230
# EPOCH 55 TOTAL TRAINING LOSS: 2.514338
# EPOCH 56 TOTAL TRAINING LOSS: 3.543190
# EPOCH 57 TOTAL TRAINING LOSS: 2.138425
# EPOCH 58 TOTAL TRAINING LOSS: 3.577128
# EPOCH 59 TOTAL TRAINING LOSS: 1.998357
# EPOCH 60 TOTAL TRAINING LOSS: 2.319769
# EPOCH 61 TOTAL TRAINING LOSS: 1.722704
# EPOCH 62 TOTAL TRAINING LOSS: 2.098835
# EPOCH 63 TOTAL TRAINING LOSS: 1.985513
# EPOCH 64 TOTAL TRAINING LOSS: 1.971552
# EPOCH 65 TOTAL TRAINING LOSS: 3.026432
# EPOCH 66 TOTAL TRAINING LOSS: 1.836567
# EPOCH 67 TOTAL TRAINING LOSS: 1.830898
# EPOCH 68 TOTAL TRAINING LOSS: 3.552859
# EPOCH 69 TOTAL TRAINING LOSS: 1.641654
# EPOCH 70 TOTAL TRAINING LOSS: 2.156315
# EPOCH 71 TOTAL TRAINING LOSS: 2.353231
# EPOCH 72 TOTAL TRAINING LOSS: 2.023913
# EPOCH 73 TOTAL TRAINING LOSS: 1.576115
# EPOCH 74 TOTAL TRAINING LOSS: 2.075353
# EPOCH 75 TOTAL TRAINING LOSS: 1.776321
# EPOCH 76 TOTAL TRAINING LOSS: 3.554782
# EPOCH 77 TOTAL TRAINING LOSS: 3.612743
# EPOCH 78 TOTAL TRAINING LOSS: 1.973966
# EPOCH 79 TOTAL TRAINING LOSS: 2.430345
# EPOCH 80 TOTAL TRAINING LOSS: 3.070800
# EPOCH 81 TOTAL TRAINING LOSS: 1.942554
# EPOCH 82 TOTAL TRAINING LOSS: 1.803675
# EPOCH 83 TOTAL TRAINING LOSS: 2.646466
# EPOCH 84 TOTAL TRAINING LOSS: 1.549178
# EPOCH 85 TOTAL TRAINING LOSS: 2.878280
# EPOCH 86 TOTAL TRAINING LOSS: 1.977996
# EPOCH 87 TOTAL TRAINING LOSS: 2.928692
# EPOCH 88 TOTAL TRAINING LOSS: 3.608284
# EPOCH 89 TOTAL TRAINING LOSS: 1.612868
# EPOCH 90 TOTAL TRAINING LOSS: 1.590732
# EPOCH 91 TOTAL TRAINING LOSS: 2.829429
# EPOCH 92 TOTAL TRAINING LOSS: 2.430842
# EPOCH 93 TOTAL TRAINING LOSS: 2.798323
# EPOCH 94 TOTAL TRAINING LOSS: 1.673233
# EPOCH 95 TOTAL TRAINING LOSS: 3.000250
# EPOCH 96 TOTAL TRAINING LOSS: 2.010010
# EPOCH 97 TOTAL TRAINING LOSS: 2.877795
# EPOCH 98 TOTAL TRAINING LOSS: 2.399142
# EPOCH 99 TOTAL TRAINING LOSS: 2.368362
# EPOCH 100 TOTAL TRAINING LOSS: 1.64533
# EPOCH 101 TOTAL TRAINING LOSS: 1.575958
# EPOCH 102 TOTAL TRAINING LOSS: 1.818587
# EPOCH 103 TOTAL TRAINING LOSS: 1.924022
# EPOCH 104 TOTAL TRAINING LOSS: 2.420436
# EPOCH 105 TOTAL TRAINING LOSS: 1.384523
# EPOCH 106 TOTAL TRAINING LOSS: 2.772583
# EPOCH 107 TOTAL TRAINING LOSS: 2.921116
# EPOCH 108 TOTAL TRAINING LOSS: 1.445601
# EPOCH 109 TOTAL TRAINING LOSS: 2.182178
# EPOCH 110 TOTAL TRAINING LOSS: 1.696188
# EPOCH 111 TOTAL TRAINING LOSS: 1.928376
# EPOCH 112 TOTAL TRAINING LOSS: 1.974304
# EPOCH 113 TOTAL TRAINING LOSS: 2.149826
# EPOCH 114 TOTAL TRAINING LOSS: 2.747422
# EPOCH 115 TOTAL TRAINING LOSS: 2.187303
# EPOCH 116 TOTAL TRAINING LOSS: 2.315812
# EPOCH 117 TOTAL TRAINING LOSS: 2.779205
# EPOCH 118 TOTAL TRAINING LOSS: 2.840963
# EPOCH 119 TOTAL TRAINING LOSS: 2.283729
# EPOCH 120 TOTAL TRAINING LOSS: 1.751868
# EPOCH 121 TOTAL TRAINING LOSS: 1.637884
# EPOCH 122 TOTAL TRAINING LOSS: 1.885317
# EPOCH 123 TOTAL TRAINING LOSS: 1.837127
# EPOCH 124 TOTAL TRAINING LOSS: 2.888666
# EPOCH 125 TOTAL TRAINING LOSS: 2.448611
# EPOCH 126 TOTAL TRAINING LOSS: 2.869823
# EPOCH 127 TOTAL TRAINING LOSS: 2.734308
# EPOCH 128 TOTAL TRAINING LOSS: 1.730639
# EPOCH 129 TOTAL TRAINING LOSS: 1.756129
# EPOCH 130 TOTAL TRAINING LOSS: 1.786858
# EPOCH 131 TOTAL TRAINING LOSS: 2.174324
# EPOCH 132 TOTAL TRAINING LOSS: 2.565723
# EPOCH 133 TOTAL TRAINING LOSS: 2.963425
# EPOCH 134 TOTAL TRAINING LOSS: 1.689675
# EPOCH 135 TOTAL TRAINING LOSS: 3.348084
# EPOCH 136 TOTAL TRAINING LOSS: 1.385746
# EPOCH 137 TOTAL TRAINING LOSS: 1.478070
# EPOCH 138 TOTAL TRAINING LOSS: 2.500203
# EPOCH 139 TOTAL TRAINING LOSS: 2.750265
# EPOCH 140 TOTAL TRAINING LOSS: 2.209290
# EPOCH 141 TOTAL TRAINING LOSS: 1.926903
# EPOCH 142 TOTAL TRAINING LOSS: 2.747609
# EPOCH 143 TOTAL TRAINING LOSS: 1.493274
# EPOCH 144 TOTAL TRAINING LOSS: 1.452265
# EPOCH 145 TOTAL TRAINING LOSS: 1.532813
# EPOCH 146 TOTAL TRAINING LOSS: 1.718907
# EPOCH 147 TOTAL TRAINING LOSS: 2.118461
# EPOCH 148 TOTAL TRAINING LOSS: 2.165477
# EPOCH 149 TOTAL TRAINING LOSS: 2.482418
# EPOCH 150 TOTAL TRAINING LOSS: 3.474371
# EPOCH 150 TOTAL VALIDATION LOSS: 4.2945

# %%
run_name = build_run_name(
    model=clm,
    epochs=EPOCHS_II,
    base_lr=base_lr_II,
    eta_min_coef=eta_min_coef,
    scheduler_class=scheduler_II_class,
    scheduler_cfg=scheduler_II_cfg,
    contrastive_loss_cfg=None,
    modality_list=list(name_emb_dict.keys())
)

# %%
get_cv_results(reg_dict, clf_dict, 'new_onlyFoundation_' + run_name, time=runtime, save=True)
# Out:
#                                                  run  n_folds       time  \
# 0  new_onlyFoundation_ClinicalLinkageModule_E150_...       30  322.41341
#
#    low_rmse_os  avg_rmse_os  up_rmse_os  low_rmse_pfs  avg_rmse_pfs  \
# 0     1.137264     1.177804    1.242923      1.088575      1.139673
#
#    up_rmse_pfs  low_f1_recurrency  avg_f1_recurrency  up_f1_recurrency  \
# 0     1.231798           0.501805           0.516387          0.529024
#
#    low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  sum_reg_avg  sum_clf_avg  \
# 0      0.38023     0.413177    0.439161     2.317477     0.929563
#
#    sum_reg_ci_relative_width  sum_clf_ci_relative_width
# 0                   0.215379                    0.19534

# %% [markdown]
# ## **Results**

# %%
evaluations = {}
for task in cv_scores.keys():
    evaluations[task] = np.mean(cv_scores[task])
    print(f"MCCV score on task {task}: {evaluations[task]}")
# Out:
# MCCV score on task os: 1.1778037925561269
# MCCV score on task pfs: 1.1396733939647674
# MCCV score on task recurrency: 0.5163865808073766
# MCCV score on task mgmt: 0.4131768812491974

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf")

# %% [markdown]
# ## Save ClinicalLinkageModule

# %%
save_model(clm, '../saved_models/new_onlyFoundation_clm.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/new_onlyFoundation_clm.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_new_onlyFoundation_clm.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/new_onlyFoundation_clm.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_new_onlyFoundation_clm.ckpt'))
