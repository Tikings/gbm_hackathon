# %% [markdown]
# # **Early Fusion with Dimensionality Reduction Experiment**
# Poor results expected because:
# - Simple concatenation of modalities
#
# However, better results than Naive Early Fusion are expected due to the dimensionality reduction step.

# %%
import sys
import os

project_path = "/home/sagemaker-user/gbm_hackathon"
if project_path not in sys.path:
    sys.path.append(project_path)
    print(sys.path)
# Out:
# ['/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python310.zip', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/lib-dynload', '', '/home/sagemaker-user/.conda/envs/gbmhackathon/lib/python3.10/site-packages', '/home/sagemaker-user/gbm_hackathon']

# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
import pandas as pd
import numpy as np
import pickle as pkl
import torch
import seaborn as sns
import matplotlib.pyplot as plt 
import subprocess

from foundation.clinical import get_batch
from gbmhackathon.data import MosaicDataset
from gbmhackathon.s3_loader import load_s3, write_s3

# %%
# %load_ext autoreload
# %autoreload 2

from gbmhackathon.training.predictive import *
from gbmhackathon.models.dim_reduction import *
from gbmhackathon.models.mme import GBMNet, PredictiveModule, ClinicalLinkageModule, concat_modality_embeddings
from gbmhackathon.utils.loss_functions import InfoNCELoss, RegularizedInfoNCELoss, SmoothingFunction, RankMe
from gbmhackathon.utils.module_functions import instantiate
from gbmhackathon.utils.model_saving import save_model
from gbmhackathon.training.cv import get_ci, get_cv_results, plot_results_cv, plot_cv_table
from gbmhackathon.s3_loader import load_s3

import os, time
from copy import deepcopy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# To investigate gradients
from torchviz import make_dot
from sklearn.ensemble import GradientBoostingClassifier
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
torch.set_num_threads(32)
torch.get_num_threads()
# Out:
# 32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %%
name_emb_dict = {"hne":"embeddings_HnE_OptimusH0.pkl",
"spatial":"2025-03-23_18-32_spatial_emb_V1.pkl",
"clinical":"2025-05-25_14-36_new_clinical_emb_V1.pkl",
"wes":"2025-04-05_13-40_wes_emb_V1.pkl",
"bulk":"2025-05-03_10-15_bulk_emb_V1.pkl",
"scRNA":"2025-05-04_02-35_scRNA_emb_V1.pkl"}
pkl_storage_folder = "embedding_V1"

# %%
dataset = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=0.0, normalize=True)
print(f"Dataset size: {len(dataset)}")
BATCH_SIZE = 114
dataloader = DataLoader(dataset, BATCH_SIZE, shuffle=True, collate_fn=collate_predictive, generator=torch.Generator(device=dataset.device))
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# spatial tensor([-1.2553, -1.1431, -1.0777, -1.2676, -0.8982, -1.1545, -0.8487, -1.2577,
#         -0.9547, -1.1874, -1.0252, -1.2998, -1.3097, -1.2077, -1.3141, -1.2162,
#         -1.0057, -1.2872, -0.9572, -1.0273, -1.0509, -1.0739, -0.9225, -1.1718,
#         -1.1085, -1.2474, -1.2076, -1.3897, -1.0923, -1.1740, -1.0682, -1.4825,
#         -1.2190, -1.1134, -0.9512, -1.2223, -0.9888, -1.1704, -0.9840, -1.0893,
#         -1.2488, -1.1461, -1.0863, -1.0485, -1.1140, -0.9333, -1.0830, -1.0695,
#         -1.1005, -0.9239, -1.3218, -0.9554, -1.0725, -1.1427, -1.0236, -1.1748,
#         -0.9028, -1.0569, -1.0684, -1.0735, -0.9262, -1.0439, -0.9128, -1.0088,
#         -1.0696, -1.1391, -0.8199, -0.8497, -1.4329, -1.0332, -0.8422, -1.0564,
#         -1.0540, -0.9929, -0.9593, -1.2920, -1.2158, -1.0403, -0.9243, -1.1929,
#         -0.9487, -1.1276, -1.3280, -0.8531, -1.1883, -1.0247], device='cuda:0')
# Normalization applied successfully
# Dataset size: 114

# %%
toy_batch = next(iter(dataloader))
#toy_batch

# %%
type(toy_batch)
# Out:
# tuple

# %%
toy_batch[2]['hne'].size()
# Out:
# torch.Size([114, 1536])

# %%
raw_emb = toy_batch[2]
inpute_size_dict = {}
for mod in raw_emb.keys():
    print(mod, raw_emb[mod].size())
    inpute_size_dict[mod] = raw_emb[mod].size(1)
# Out:
# hne torch.Size([114, 1536])
# spatial torch.Size([114, 64])
# clinical torch.Size([114, 20])
# wes torch.Size([114, 1790])
# bulk torch.Size([114, 3072])
# scRNA torch.Size([114, 3072])

# %%
raw_emb = toy_batch[2]

# 1) collecter les tenseurs et construire input_size_dict
tensors_to_concat = []
input_size_dict = {}

for mod, emb in raw_emb.items():
    if isinstance(emb, torch.Tensor):
        # on suppose que emb a la forme [batch_size, feature_size]
        input_size_dict[mod] = emb.size(1)
        tensors_to_concat.append(emb)
    else:
        # si tu veux voir ce qu'on skip :
        print(f"Skip {mod}: not a Tensor but {type(emb)}")

# 2) concaténation
# attention tous les emb doivent avoir le même batch_size (dim 0)
concat_emb = torch.cat(tensors_to_concat, dim=1)

print("Sizes by module:", input_size_dict)
print("Concatenated tensor size:", concat_emb.size())
# Out:
# Sizes by module: {'hne': 1536, 'spatial': 64, 'clinical': 20, 'wes': 1790, 'bulk': 3072, 'scRNA': 3072}
# Concatenated tensor size: torch.Size([114, 9554])

# %%
X=concat_emb

# %% [markdown]
# ### **Apply dimensionality reduction on X**

# %%
pca = PCA(explained_variance_threshold=0.999)
umap = UMAP(n_components=64)

# %%
pca_emb = {key:pca(val) for key, val in raw_emb.items()}
# Out:
# 84 dimensions hold 99.90% of variance.
# Effective compression ratio: 5.47%
# 8 dimensions hold 99.90% of variance.
# Effective compression ratio: 12.50%
# 20 dimensions hold 99.90% of variance.
# Effective compression ratio: 100.00%
# 107 dimensions hold 99.90% of variance.
# Effective compression ratio: 5.98%
# 63 dimensions hold 99.90% of variance.
# Effective compression ratio: 2.05%
# 53 dimensions hold 99.90% of variance.
# Effective compression ratio: 1.73%

# %%
X_pca = concat_modality_embeddings(pca_emb)

# %%
umap_emb = {key:umap(val) for key, val in raw_emb.items()}

# %%
X_umap = concat_modality_embeddings(umap_emb)

# %%
Y=toy_batch[-2]

# %%
Y[:10]
# Out:
# tensor([[-0.7753, -0.9433,  0.0000,  1.0000,  0.0000,  0.0000,  1.0000],
#         [-0.3673, -0.5415,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [-0.3593,  0.1615,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [ 0.8907,  1.7611,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [-0.3673, -0.5415,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [ 0.1403, -0.8094,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [-1.1496, -0.9247,  0.0000,  1.0000,  0.0000,  0.0000,  1.0000],
#         [-0.9346, -0.9024,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [-0.9107, -0.8280,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000],
#         [-0.2100,  0.0648,  1.0000,  0.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')

# %%
y_reg=Y[:,:2]
y_cat=Y[:,2:]

# %%
print(y_reg.size(),y_cat.size())
# Out:
# torch.Size([114, 2]) torch.Size([114, 5])

# %%
print(X_pca.size(), X_umap.size(),Y.size())
# Out:
# torch.Size([114, 335]) torch.Size([114, 384]) torch.Size([114, 7])

# %%
from sklearn.multioutput import MultiOutputRegressor, MultiOutputClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error, f1_score, root_mean_squared_error
import numpy as np
from sklearn.ensemble import HistGradientBoostingRegressor, HistGradientBoostingClassifier


def train_GBT(splitter, dr='pca'):
    # se_sums = np.zeros(2)
    # f1_rec_sums = np.zeros(1)
    # f1_mgmt_sums = np.zeros(1)

    all_rmse1 = []
    all_rmse2 = []
    all_f1_rec  = []
    all_f1_mgmt  = []
    if dr == 'pca':
        features = X_pca
    elif dr == 'umap':
        features = X_umap
    else:
        features = X
    n_splits = splitter.get_n_splits(features)
    t0 = time.time()
    for i, (train_idx, test_idx) in enumerate(splitter.split(features), 1):
        X_train, X_test = features[train_idx].cpu(), features[test_idx].cpu()
        y_reg_train, y_reg_test = y_reg[train_idx].cpu(), y_reg[test_idx].cpu()
        y_rec_train, y_rec_test = torch.argmax(y_cat[train_idx,:2], dim=1).cpu(), torch.argmax(y_cat[test_idx,:2], dim=1).cpu()
        y_mgmt_train, y_mgmt_test = torch.argmax(y_cat[train_idx,2:], dim=1).cpu(), torch.argmax(y_cat[test_idx,2:], dim=1).cpu()
    
        reg_os = HistGradientBoostingRegressor(max_iter=100, early_stopping=True)
        reg_pfs = HistGradientBoostingRegressor(max_iter=100, early_stopping=True)
        clf_rec = HistGradientBoostingClassifier(max_iter=100, early_stopping=True)
        clf_mgmt = HistGradientBoostingClassifier(max_iter=100, early_stopping=True)
    
        # Training
        # reg_mt.fit(X_train, y_reg_train)
        reg_os.fit(X_train, y_reg_train[:,0])
        reg_pfs.fit(X_train, y_reg_train[:,1])
        clf_rec.fit(X_train, y_rec_train)
        clf_mgmt.fit(X_train, y_mgmt_train)
    
        # Prediction
        # y_reg_pred = reg_mt.predict(X_test)
        y_reg_os = reg_os.predict(X_test)
        y_reg_pfs = reg_pfs.predict(X_test)
        y_rec_pred = clf_rec.predict(X_test)
        y_mgmt_pred = clf_mgmt.predict(X_test)
    
        # # Accumulation of metrics
        # for k in range(2):
        #     rmse = np.sqrt(np.mean((y_reg_pred[:, k] - y_reg_test[:, k].cpu().numpy())**2))
        #     if k == 0:
        #         all_rmse1.append(rmse)
        #     else:
        #         all_rmse2.append(rmse)
        #     # se_sums[k] += np.sum((y_reg_pred[:, k] - y_reg_test[:, k].cpu().numpy())**2)
        all_rmse1.append(root_mean_squared_error(y_reg_os, y_reg_test[:,0].cpu().numpy()))
        all_rmse2.append(root_mean_squared_error(y_reg_pfs, y_reg_test[:,1].cpu().numpy()))
        all_f1_rec.append(f1_score(y_rec_test, y_rec_pred, average='weighted', zero_division=0))
        all_f1_mgmt.append(f1_score(y_mgmt_test, y_mgmt_pred, average='weighted', zero_division=0))
        
        # f1_rec_sums += f1_score(y_rec_test, y_rec_pred, average='weighted', zero_division=0)
        # f1_mgmt_sums += f1_score(y_mgmt_test, y_mgmt_pred, average='weighted', zero_division=0)
    
        print(f"Iteration {i}/{n_splits}", end="\r")
    
    # # Averages over all Monte Carlo iterations
    # avg_rmse = np.sqrt(se_sums / (n_splits * len(test_idx)))
    # avg_f1_rec = f1_rec_sums / n_splits
    # avg_f1_mgmt = f1_mgmt_sums / n_splits
    # print("\nMultitâche CV → RMSE:", avg_rmse, "— F1 Recurrency:", avg_f1_rec, "— F1 MGMT Methylation:", avg_f1_mgmt)
    runtime = time.time() - t0
    if dr == None:
        run_name = f"naive_early_fusion_gbt"
    else:
        run_name = f"{dr}_early_fusion_gbt"
    reg_dict = {'os':all_rmse1, 'pfs':all_rmse2}
    clf_dict = {'recurrency':all_f1_rec, 'mgmt':all_f1_mgmt}
    return get_cv_results(reg_dict, clf_dict, run_name, time=runtime, save=True)
    # # Calcul des moyennes sur tous les folds
    # ci_rmse1 =get_ci(all_rmse1)
    # ci_rmse2 =get_ci(all_rmse2)
    # ci_f1_rec  = get_ci(all_f1_rec)
    # ci_f1_mgmt  = get_ci(all_f1_mgmt)

    # # Affichage final des moyennes globales
    # print("=== Moyennes sur tous les folds ===")
    # print(f"RMSE CI95% for os (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse1]}]")
    # print(f"RMSE CI95% for pfs (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse2]}]")
    # print(f"F1 CI95% for Recurrency (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_rec]}]")
    # print(f"F1 CI95% for MGMT Methylation (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_mgmt]}]")

# %%
X.shape
# Out:
# torch.Size([114, 9554])

# %% [markdown]
# ## **GradientBoosting: Monte Carlo Cross-Validation**
# ### **PCA**

# %%
from sklearn.model_selection import ShuffleSplit

n_splits = 30  # Number of Monte Carlo iterations
test_size = 0.2  # Fraction of data to use for testing in each split
random_state = 62  # For reproducibility

mc_cv = ShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
train_GBT(mc_cv, dr='pca')
# Out:
# Iteration 30/30
#                     run  n_folds      time  low_rmse_os  avg_rmse_os  \
# 0  pca_early_fusion_gbt       30  8.769032     0.902706     0.943449
#
#    up_rmse_os  low_rmse_pfs  avg_rmse_pfs  up_rmse_pfs  low_f1_recurrency  \
# 0    0.986816      0.919317      0.987218     1.068953           0.464504
#
#    avg_f1_recurrency  up_f1_recurrency  low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  \
# 0           0.506408          0.542923     0.458923     0.490909    0.522562
#
#    sum_reg_avg  sum_clf_avg  sum_reg_ci_relative_width  \
# 0     1.930666     0.997317                   0.240726
#
#    sum_clf_ci_relative_width
# 0                   0.284488

# %% [markdown]
# ### **UMAP**

# %%
train_GBT(mc_cv, dr='umap')
# Out:
# Iteration 30/30
#                      run  n_folds      time  low_rmse_os  avg_rmse_os  \
# 0  umap_early_fusion_gbt       30  9.705877     0.749163     0.781766
#
#    up_rmse_os  low_rmse_pfs  avg_rmse_pfs  up_rmse_pfs  low_f1_recurrency  \
# 0    0.814101      0.789432      0.845286     0.904409           0.495646
#
#    avg_f1_recurrency  up_f1_recurrency  low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  \
# 0           0.532778          0.573749     0.471311     0.505803    0.538975
#
#    sum_reg_avg  sum_clf_avg  sum_reg_ci_relative_width  \
# 0     1.627052     1.038581                   0.219088
#
#    sum_clf_ci_relative_width
# 0                   0.280369

# %% [markdown]
# # MLP: Leave One Out Cross-Validation

# %%
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn as nn
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import f1_score

# %%
class TabularDataset(Dataset):
    """
    Dataset PyTorch pour des données tabulaires.
    X: array-like de shape (n_samples, n_features)
    Y: array-like de shape (n_samples, 5) où les 3 premières colonnes sont continues,
       et les 2 dernières sont catégorielles (entiers).
    """
    def __init__(self, X, Y, device='cpu'):
        self.X = torch.from_numpy(np.asarray(X)).float() if isinstance(X, np.ndarray) else X.float()
        self.Y = torch.from_numpy(np.asarray(Y)) if isinstance(Y, np.ndarray) else Y
        self.device = device

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y_cont = self.Y[idx, :2].float()
        y_cat = self.Y[idx, 2:].long()
        return x.to(self.device), y_cont.to(self.device), y_cat.to(self.device)

# def get_loo_loaders(X, Y, batch_size=32, device='cpu'):
#     """
#     Renvoie un itérateur de folds Leave-One-Out.
#     Pour chaque itération, on obtient train_loader, val_loader.
#     """
# #    cpu_count = os.cpu_count() or 1
#     dataset = TabularDataset(X, Y, device=device)
#     loo = LeaveOneOut()
#     for train_idx, val_idx in loo.split(X):
#         train_subset = Subset(dataset, train_idx)
#         val_subset = Subset(dataset, val_idx)

#         train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
#         val_loader = DataLoader(val_subset, batch_size=1, shuffle=False)

        
# #        train_loader = DataLoader(
# #            train_subset,
# #            batch_size=batch_size,
# #            shuffle=True,
# #            num_workers=cpu_count,  # parallélisation du chargement
# #            pin_memory=(device!='cpu')  # épingle en mémoire pour GPU
# #        )
# #        val_loader = DataLoader(
# #            val_subset,
# #            batch_size=1,
# #            shuffle=False,
# #            num_workers=cpu_count//2,
# #            pin_memory=(device!='cpu')
# #        )
#         yield train_loader, val_loader

n_splits = 30  # Number of Monte Carlo iterations
test_size = 0.2  # Fraction of data to use for testing in each split
random_state = 62  # For reproducibility
def get_mccv_loaders(X, Y, batch_size=32, device='cpu'):
    """
    Renvoie un itérateur de folds Leave-One-Out.
    Pour chaque itération, on obtient train_loader, val_loader.
    """
#    cpu_count = os.cpu_count() or 1
    dataset = TabularDataset(X, Y, device=device)
    mccv =  ShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
    for train_idx, val_idx in mccv.split(X):
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, generator=torch.Generator(device=dataset.device))
        val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, generator=torch.Generator(device=dataset.device))
        yield train_loader, val_loader

# %%
dataset = TabularDataset(X, Y, device=device)
dataset_pca = TabularDataset(X_pca, Y, device=device)
dataset_umap = TabularDataset(X_umap, Y, device=device)

loader = DataLoader(dataset, batch_size=32, shuffle=True, generator=torch.Generator(device=dataset.device))
x_batch, y_cont_batch, y_cat_batch = next(iter(loader))
print(f"Batch shapes: X={x_batch.shape}, y_cont={y_cont_batch.shape}, y_cat={y_cat_batch.shape}")
# Out:
# Batch shapes: X=torch.Size([32, 9554]), y_cont=torch.Size([32, 2]), y_cat=torch.Size([32, 5])

# %%
from gbmhackathon.models.mme import PredictiveModule

# %%
in_size = X_pca.shape[1]
norm_fn = nn.BatchNorm1d
dropout = 0.2
layers = [in_size,1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

# %%
def eval_epoch(model, loader, device):
    """
    Évaluation sans rétropropagation. Calcule RMSE et F1 comme train_epoch,
    mais passe en mode eval et n'appelle pas backward/step.
    """
    model.eval()
    se_sums = [0.0, 0.0]
    n_samples = 0
    all_preds_rec, all_labels_rec = [], []
    all_preds_mgmt, all_labels_mgmt = [], []
    # all_preds_a, all_labels_a = [], []
    # all_preds_b, all_labels_b = [], []

    criterion_mse = nn.MSELoss()
    criterion_ce = nn.CrossEntropyLoss()

    for X_batch, y_cont, y_cat in loader:
        out_list = list(model(X_batch).values()) if not isinstance(model, ClinicalLinkageModule) else list(model(X_batch, None, None).values())
        o1, o2, logits = out_list[0], out_list[1], out_list[2:]
        logits_rec, logits_mgmt = logits[0], logits[1]
        
        y1, y2 = y_cont[:, 0], y_cont[:, 1]
        # y_a, y_b = y_cat[:, 0], y_cat[:, 1]
        y_cat_rec = y_cat[:,:2].to(torch.half)
        y_cat_mgmt = y_cat[:,2:].to(torch.half)
        
        loss1 = criterion_mse(o1.squeeze(), y1)
        loss2 = criterion_mse(o2.squeeze(), y2)
        loss3 = criterion_ce(logits_rec, y_cat_rec)
        loss4 = criterion_ce(logits_mgmt, y_cat_mgmt)
        # loss4a = criterion_ce(logits_a, y_a)
        # loss4b = criterion_ce(logits_b, y_b)

        batch_size = X_batch.size(0)
        n_samples += batch_size
        se_sums[0] += loss1.item()
        se_sums[1] += loss2.item()

        preds_rec = torch.argmax(logits_rec, dim=1).cpu().numpy()
        all_preds_rec.extend(preds_rec)
        all_labels_rec.extend(torch.argmax(y_cat_rec, dim=1).cpu().numpy())      # preds_a = torch.argmax(logits_a, dim=1).cpu().numpy()
        
        preds_mgmt = torch.argmax(logits_mgmt, dim=1).cpu().numpy()
        all_preds_mgmt.extend(preds_mgmt)
        all_labels_mgmt.extend(torch.argmax(y_cat_mgmt, dim=1).cpu().numpy())
        # preds_b = torch.argmax(logits_b, dim=1).cpu().numpy()
        # all_preds_a.extend(preds_a)
        # all_preds_b.extend(preds_b)
        # all_labels_a.extend(y_a.cpu().numpy())
        # all_labels_b.extend(y_b.cpu().numpy())

    rmse1 = np.sqrt(se_sums[0] / n_samples)
    rmse2 = np.sqrt(se_sums[1] / n_samples)
    f1_rec = f1_score(all_labels_rec, all_preds_rec, average='weighted')
    f1_mgmt = f1_score(all_labels_mgmt, all_preds_mgmt, average='weighted')
    # f1_a = f1_score(all_labels_a, all_preds_a, average='macro')
    # f1_b = f1_score(all_labels_b, all_preds_b, average='macro')
    return {'rmse1': rmse1, 'rmse2': rmse2, 'f1_rec': f1_rec, 'f1_mgmt': f1_mgmt}

# %%
def train_epoch(model, loader, optimizer, device):
    model.train()
    se_sums = [0.0, 0.0]
    n_samples = 0
    all_preds_rec, all_labels_rec = [], []
    all_preds_mgmt, all_labels_mgmt = [], []

    criterion_mse = nn.MSELoss()
    criterion_ce = nn.CrossEntropyLoss()

    n_batches = len(loader)
    for batch_idx, (X_batch, y_cont, y_cat) in enumerate(loader, 1):
        # Affichage de l'avancement par batch
        #print(f"  Batch {batch_idx}/{n_batches}", end="\r")

        optimizer.zero_grad()
        out_list = list(model(X_batch).values()) if not isinstance(model, ClinicalLinkageModule) else list(model(X_batch, None, None).values())
        o1, o2, logits = out_list[0], out_list[1], out_list[2:]
        logits_rec, logits_mgmt = logits[0], logits[1]
        
        y1, y2 = y_cont[:, 0], y_cont[:, 1]
        # y_a, y_b = y_cat[:, 0], y_cat[:, 1]
        y_cat_rec = y_cat[:,:2].to(torch.half)
        y_cat_mgmt = y_cat[:,2:].to(torch.half)

        loss1 = criterion_mse(o1.squeeze(), y1)
        loss2 = criterion_mse(o2.squeeze(), y2)
        loss3 = criterion_ce(logits_rec, y_cat_rec)
        loss4 = criterion_ce(logits_mgmt, y_cat_mgmt)
        

        loss = loss1 + loss2 + loss3 + loss4
        loss.backward()
        optimizer.step()

        batch_size = X_batch.size(0)
        n_samples += batch_size
        se_sums[0] += loss1.item()
        se_sums[1] += loss2.item()

        preds_rec = torch.argmax(logits_rec, dim=1).cpu().numpy()
        all_preds_rec.extend(preds_rec)
        all_labels_rec.extend(torch.argmax(y_cat_rec, dim=1).cpu().numpy()) 
        
        preds_mgmt = torch.argmax(logits_mgmt, dim=1).cpu().numpy()
        all_preds_mgmt.extend(preds_mgmt)
        all_labels_mgmt.extend(torch.argmax(y_cat_mgmt, dim=1).cpu().numpy()) 

    rmse1 = np.sqrt(se_sums[0] / n_samples)
    rmse2 = np.sqrt(se_sums[1] / n_samples)
    f1_rec = f1_score(all_labels_rec, all_preds_rec, average='weighted')
    f1_mgmt = f1_score(all_labels_mgmt, all_preds_mgmt, average='weighted')
    return {'rmse1': rmse1, 'rmse2': rmse2, 'f1_rec': f1_rec, 'f1_mgmt': f1_mgmt}


def fit(model_class, model_cfg, X, Y, device, get_loaders_func,  num_epochs=20, batch_size=32, scheduler=None, dr='pca', suffix=None):
    """
    Entraîne le modèle avec LOOCV et affiche des statistiques globales.
    Affiche uniquement deux lignes actualisables : une pour le fold courant et une pour l'epoch.
    """
    history = []
    total_folds = len([el for el in enumerate(
            get_loaders_func(X, Y, batch_size=batch_size, device=device), start=1)])
    # Préparation des listes pour statistiques globales
    t0 = time.time()
    for fold, (train_loader, val_loader) in enumerate(
            get_loaders_func(X, Y, batch_size=batch_size, device=device), start=1):
        model = instantiate(model_cfg, model_class)
        # Instanciation du modèle avec layers
        # layers = [X.shape[1], 1024, 512, 64]
        # model = SimpleMLP(layers=layers).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    
        # Affichage du fold courant, actualisable
        print(f"Fold {fold}/{total_folds}")
        for epoch in range(1, num_epochs + 1):
            # Réécrit la ligne pour l'epoch en cours
            print(f"Epoch {epoch}/{num_epochs}.", end='\r')
            train_metrics = train_epoch(model, train_loader, optimizer, device)
            val_metrics = eval_epoch(model, val_loader, device)
            if epoch == 1 or epoch == num_epochs//2 or epoch == num_epochs:
                print(f"Epoch {epoch} training metrics", train_metrics)
                print(f"Epoch {epoch} validation metrics", val_metrics)
            if scheduler:
                scheduler.step(val_metrics['rmse1'])
        # À la fin des epochs, on passe à la ligne suivante
        print()
        history.append({'fold': fold, 'train': train_metrics, 'val': val_metrics})

    # Calcul des moyennes sur tous les folds
    all_rmse1 = [h['val']['rmse1'] for h in history]
    all_rmse2 = [h['val']['rmse2'] for h in history]
    all_f1_rec  = [h['val']['f1_rec']   for h in history]
    all_f1_mgmt  = [h['val']['f1_mgmt']   for h in history]

    runtime = time.time() - t0
    run_name = f"{dr}_early_fusion_nn" if suffix is None else f"{dr}_early_fusion_nn_{suffix}"
    reg_dict = {'os':all_rmse1, 'pfs':all_rmse2}
    clf_dict = {'recurrency':all_f1_rec, 'mgmt':all_f1_mgmt}
    return get_cv_results(reg_dict, clf_dict, run_name, time=runtime, save=True), model
    # ci_rmse1 =get_ci(all_rmse1)
    # ci_rmse2 =get_ci(all_rmse2)
    # ci_f1_rec  = get_ci(all_f1_rec)
    # ci_f1_mgmt  = get_ci(all_f1_mgmt)

    # # Affichage final des moyennes globales
    # print("=== Moyennes sur tous les folds ===")
    # print(f"RMSE CI95% for os (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse1]}]")
    # print(f"RMSE CI95% for pfs (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse2]}]")
    # print(f"F1 CI95% for Recurrency (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_rec]}]")
    # print(f"F1 CI95% for MGMT Methylation (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_mgmt]}]")
    # return history

# %%
# class SimpleMLP(nn.Module):
#     """
#     MLP multitâche avec architecture configurable via `layers`.
#     `layers` est une liste d'entiers [in_dim, h1, h2, ..., hN].
#     """
#     def __init__(self, layers):
#         super().__init__()
#         modules = []
#         for in_dim, out_dim in zip(layers[:-1], layers[1:]):
#             modules.append(nn.Linear(in_dim, out_dim))
#             modules.append(nn.ReLU())
#         self.shared = nn.Sequential(*modules)
#         last = layers[-1]
#         self.out1 = nn.Linear(last, 1)
#         self.out2 = nn.Linear(last, 1)
#         self.out3 = nn.Linear(last, 1)
#         self.clf = nn.Linear(last, 2)

#     def forward(self, x):
#         h = self.shared(x)
#         return (
#             self.out1(h),
#             self.out2(h),
#             self.out3(h),
#             self.clf(h)
#         )

# %% [markdown]
# ## **MLP: Monte Carlo Cross-Validation**
# ### **PCA**

# %%
NN_BATCH = 16

# %%
history, last_model = fit(PredictiveModule, predictive_cfg, X_pca, Y, device, get_mccv_loaders, 
              num_epochs=55, 
              batch_size=NN_BATCH, 
              dr='pca')
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.
# Epoch 27 training metrics {'rmse1': np.float64(0.0749015262721528), 'rmse2': np.float64(0.07172267897119962), 'f1_rec': 0.9890216878168684, 'f1_mgmt': 0.9616871603735314}
# Epoch 27 validation metrics {'rmse1': np.float64(0.29138772471831886), 'rmse2': np.float64(0.23679983781266625), 'f1_rec': 0.5391304347826087, 'f1_mgmt': 0.4535232383808096}
# Epoch 55 training metrics {'rmse1': np.float64(0.06948759479171394), 'rmse2': np.float64(0.07001305503899394), 'f1_rec': 0.978059355610376, 'f1_mgmt': 0.9797239104355208}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2894370435103871), 'rmse2': np.float64(0.2330953299853869), 'f1_rec': 0.6121057118499573, 'f1_mgmt': 0.49275362318840576}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3543393440110886), 'rmse2': np.float64(0.34560307910513627), 'f1_rec': 0.5436177526544954, 'f1_mgmt': 0.3809335181884201}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2471243089199502), 'rmse2': np.float64(0.32344584110740365), 'f1_rec': 0.46020066889632105, 'f1_mgmt': 0.4573578595317726}
# Epoch 27 training metrics {'rmse1': np.float64(0.08969620323486462), 'rmse2': np.float64(0.08293574681149858), 'f1_rec': 0.9672566970543595, 'f1_mgmt': 0.9800868049918282}
# Epoch 27 validation metrics {'rmse1': np.float64(0.23819579959807924), 'rmse2': np.float64(0.2914995011595575), 'f1_rec': 0.5750350631136045, 'f1_mgmt': 0.5370600414078675}
# Epoch 55 training metrics {'rmse1': np.float64(0.07480115330794541), 'rmse2': np.float64(0.069205404943127), 'f1_rec': 0.9564179564179562, 'f1_mgmt': 1.0}
# Epoch 55 validation metrics {'rmse1': np.float64(0.23381338418027486), 'rmse2': np.float64(0.289475407185098), 'f1_rec': 0.6102484472049688, 'f1_mgmt': 0.5947026486756621}

# %%
save_model(last_model, '../saved_models/pca_early_fusion_nn.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/pca_early_fusion_nn.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_pca_early_fusion_nn.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/pca_early_fusion_nn.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_pca_early_fusion_nn.ckpt'))

# %%
os.makedirs('../experiments/early_fusion_embeddings', exist_ok=True)
with open('../experiments/early_fusion_embeddings/pca.pkl', 'wb') as f:
    pkl.dump(pca_emb, f)

# %% [markdown]
# ## With Refinement Block

# %%
refinement_cfg = {"emb_size": in_size,
                "cross_modality_heads": 1,
                "cross_mods_fc_size": 1024,
                "avail_mods_fc_size": 128,
                "avail_mods_len":len(name_emb_dict),
                "avail_mods_dense_size": 32,
                "avail_mods_heads": 1,
                "act_fn": nn.GELU,
                "dropout": dropout,
                "device": device}
clm_cfg = {"refinement_cfg":refinement_cfg,
           "predictive_cfg":predictive_cfg}

# %%
history, last_model = fit(ClinicalLinkageModule, clm_cfg, X_pca, Y, device, get_mccv_loaders, 
              num_epochs=55, 
              batch_size=NN_BATCH, 
              dr='pca',
              suffix='with_refinement')
# Out:
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.38193424735026654), 'rmse2': np.float64(0.34350849074540124), 'f1_rec': 0.5577114488005576, 'f1_mgmt': 0.39382794624730116}
# Epoch 1 validation metrics {'rmse1': np.float64(0.28817752515151035), 'rmse2': np.float64(0.39634311534718747), 'f1_rec': 0.3403726708074534, 'f1_mgmt': 0.3768115942028985}
# Epoch 27 training metrics {'rmse1': np.float64(0.09369922754734858), 'rmse2': np.float64(0.08501647096995613), 'f1_rec': 0.9565149136577709, 'f1_mgmt': 0.9794539611673934}
# Epoch 27 validation metrics {'rmse1': np.float64(0.
30
# Epoch 1 training metrics {'rmse1': np.float64(0.3554236765010527), 'rmse2': np.float64(0.356116140312536), 'f1_rec': 0.5048900494445049, 'f1_mgmt': 0.27564898869246696}
# Epoch 1 validation metrics {'rmse1': np.float64(0.3139888602830413), 'rmse2': np.float64(0.2360519456732644), 'f1_rec': 0.6927536231884057, 'f1_mgmt': 0.3492753623188406}
# Epoch 27 training metrics {'rmse1': np.float64(0.08075126605549604), 'rmse2': np.float64(0.07353103384753655), 'f1_rec': 0.9671049387241017, 'f1_mgmt': 0.950523215533273}
# Epoch 27 validation metrics {'rmse1': np.float64(0.31561926550383074), 'rmse2': np.float64(0.21553928435879813), 'f1_rec': 0.574124702354705, 'f1_mgmt': 0.5292353823088456}
# Epoch 55 training metrics {'rmse1': np.float64(0.0734043659331421), 'rmse2': np.float64(0.07119756992304647), 'f1_rec': 0.978059355610376, 'f1_mgmt': 1.0}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3100975359550391), 'rmse2': np.float64(0.21784194103879198), 'f1_rec': 0.5793361383824217, 'f1_mgmt': 0.5297535564015228}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.33585048087600433), 'rmse2': np.float64(0.30761859387113377), 'f1_rec': 0.5228517823639774, 'f1_mgmt': 0.5048998620427192}
# Epoch 1 validation metrics {'rmse1': np.float64(0.24866037007920394), 'rmse2': np.float64(0.3184999250828884), 'f1_rec': 0.38616175783076206, 'f1_mgmt': 0.4427641251837849}
# Epoch 27 training metrics {'rmse1': np.float64(0.09208631694676762), 'rmse2': np.float64(0.0929728487893531), 'f1_rec': 0.9562548562548562, 'f1_mgmt': 0.9783616010506767}
# Epoch 27 validation metrics {'rmse1': np.float64(0.23549869789229083), 'rmse2': np.float64(0.2958411759206952), 'f1_rec': 0.6102484472049688, 'f1_mgmt': 0.5734989648033126}
# Epoch 55 training metrics {'rmse1': np.float64(0.0818969739458962), 'rmse2': np.float64(0.06913627970372374), 'f1_rec': 0.9562548562548562, 'f1_mgmt': 0.9779061116464003}
# Epoch 55 validation metrics {'rmse1': np.float64(0.23579009943918247), 'rmse2': np.float64(0.2994400181508616), 'f1_rec': 0.5750350631136045, 'f1_mgmt': 0.5734989648033126}

# %%
save_model(last_model, '../saved_models/pca_early_fusion_nn_with_refinement.ckpt')
# Out:
# Model saved at path: /home/sagemaker-user/gbm_hackathon/saved_models/pca_early_fusion_nn_with_refinement.ckpt
# Model config saved at cfg_path: /home/sagemaker-user/gbm_hackathon/saved_models/cfg_pca_early_fusion_nn_with_refinement.ckpt
# You can load it by doing loaded_model = load_model(model_class, path, cfg_path, device)
# (PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/pca_early_fusion_nn_with_refinement.ckpt'),
#  PosixPath('/home/sagemaker-user/gbm_hackathon/saved_models/cfg_pca_early_fusion_nn_with_refinement.ckpt'))

# %% [markdown]
# ### **UMAP**

# %%
in_size = X_umap.shape[1]
norm_fn = nn.BatchNorm1d
dropout = 0.2
layers = [in_size,1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

# %%
history = fit(PredictiveModule, predictive_cfg, X_umap, Y, device, get_mccv_loaders, 
              num_epochs=55, 
              batch_size=NN_BATCH, 
              dr='umap')
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3454294972086477), 'rmse2': np.float64(0.324177959012004), 'f1_rec': 0.5042265426880812, 'f1_mgmt': 0.4263339601574896}
# Epoch 1 validation metrics {'rmse1': np.float64(0.284546027081133), 'rmse2': np.float64(0.35536035451554243), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0

#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3436632075383807), 'rmse2': np.float64(0.32550607713503), 'f1_rec': 0.5009861932938856, 'f1_mgmt': 0.3592185592185592}
# Epoch 1 validation metrics {'rmse1': np.float64(0.30599322415378744), 'rmse2': np.float64(0.3452897848807971), 'f1_rec': 0.40821256038647347, 'f1_mgmt': 0.01391304347826087}
# Epoch 27 training metrics {'rmse1': np.float64(0.22740898701691273), 'rmse2': np.float64(0.21662848178907168), 'f1_rec': 0.6703296703296703, 'f1_mgmt': 0.5548063048063048}
# Epoch 27 validation metrics {'rmse1': np.float64(0.22216481927862006), 'rmse2': np.float64(0.28308996316032325), 'f1_rec': 0.47144075021312876, 'f1_mgmt': 0.309462915601023}
# Epoch 55 training metrics {'rmse1': np.float64(0.22722892997794605), 'rmse2': np.float64(0.22421768161346642), 'f1_rec': 0.653517422748192, 'f1_mgmt': 0.5767232767232767}
# Epoch 55 validation metrics {'rmse1': np.float64(0.20275196856503877), 'rmse2': np.float64(0.28912134613755447), 'f1_rec': 0.4437012263099219, 'f1_mgmt': 0.309462915601023}

# %% [markdown]
# ## With refinement block

# %%
refinement_cfg = {"emb_size": in_size,
                "cross_modality_heads": 1,
                "cross_mods_fc_size": 1024,
                "avail_mods_fc_size": 128,
                "avail_mods_len":len(name_emb_dict),
                "avail_mods_dense_size": 32,
                "avail_mods_heads": 1,
                "act_fn": nn.GELU,
                "dropout": dropout,
                "device": device}
clm_cfg = {"refinement_cfg":refinement_cfg,
           "predictive_cfg":predictive_cfg}

# %%
history = fit(ClinicalLinkageModule, clm_cfg, X_umap, Y, device, get_mccv_loaders, 
              num_epochs=55, 
              batch_size=NN_BATCH, 
              dr='umap',
              suffix='with_refinement')
# Out:
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.34760798524206843), 'rmse2': np.float64(0.2974727860369223), 'f1_rec': 0.4609189829778064, 'f1_mgmt': 0.3163817476804759}
# Epoch 1 validation metrics {'rmse1': np.float64(0.34348095855797706), 'rmse2': np.float64(0.423069839071731), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.35776397515527947}
# Epoch 27 training metrics {'rmse1': np.float64(0.24180578151648072), 'rmse2': np.float64(0.22616646394260737), 'f1_rec': 0.6299929578618103, 'f1_mgmt': 0.5271367648307392}
# Epoch 27 validation metrics {'rmse1': np.float64(0.42009108540977264), 'rmse2': np.float64(0.49519791732912005), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.309462915601023}
# Epoch 55 training metrics {'rmse1': np.float64(0.22650334061772218), 'rmse2': np.float64(0.22740962571278103), 'f1_rec': 0.5789835164835165, 'f1_mgmt': 0.4865993593007135}
# Epoch 55 validation metrics {'rmse1': np.float64(0.41203171858904214), 'rmse2': np.float64(0.43782060142668905), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.309462915601023}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 2/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3426000795003785), 'rmse2': np.float64(0.31366758418404966), 'f1_rec': 0.4649262413327749, 'f1_mgmt': 0.44274071901374173}
# Epoch 1 validation metrics {'rmse1': np.float64(0.4707310816407744), 'rmse2': np.float64(0.41286670106636875), 'f1_rec': 0.5148741418764302, 'f1_mgmt': 0.46859903381642515}
# Epoch 27 training metrics {'rmse1': np.float64(0.24842848094704617), 'rmse2': np.float64(0.2425486654939354), 'f1_rec': 0.5335164835164835, 'f1_mgmt': 0.5677766069546891}
# Epoch 27 validation metrics {'rmse1': np.float64(0.35712920986187624), 'rmse2': np.float64(0.34475198598651025), 'f1_rec': 0.49353701527614574, 'f1_mgmt': 0.4396135265700483}
# Epoch 55 training metrics {'rmse1': np.float64(0.22941355612427652), 'rmse2': np.float64(0.24633273223979046), 'f1_rec': 0.62246437036353, 'f1_mgmt': 0.5894196241316869}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3137292072483927), 'rmse2': np.float64(0.3933284519581855), 'f1_rec': 0.49353701527614574, 'f1_mgmt': 0.4396135265700483}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 3/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3380301962113146), 'rmse2': np.float64(0.30585211477715585), 'f1_rec': 0.5365316752806, 'f1_mgmt': 0.3787216478103178}
# Epoch 1 validation metrics {'rmse1': np.float64(0.28563979990884847), 'rmse2': np.float64(0.3337472267203377), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.309462915601023}
# Epoch 27 training metrics {'rmse1': np.float64(0.21607196652933794), 'rmse2': np.float64(0.25180004606202994), 'f1_rec': 0.6287470948449845, 'f1_mgmt': 0.5384615384615384}
# Epoch 27 validation metrics {'rmse1': np.float64(0.4434511812614115), 'rmse2': np.float64(0.3997548821682195), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.3188405797101449}
# Epoch 55 training metrics {'rmse1': np.float64(0.204358117003983), 'rmse2': np.float64(0.2112878282041097), 'f1_rec': 0.5898739747460549, 'f1_mgmt': 0.5474088752777276}
# Epoch 55 validation metrics {'rmse1': np.float64(0.35842278276614775), 'rmse2': np.float64(0.3426248054988523), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.309462915601023}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 4/30
# Epoch 1 training metrics {'rmse1': np.float64(0.34654949030116533), 'rmse2': np.float64(0.34206474790311814), 'f1_rec': 0.4655089288246472, 'f1_mgmt': 0.40717736369910285}
# Epoch 1 validation metrics {'rmse1': np.float64(0.25476558543452227), 'rmse2': np.float64(0.32639772302437225), 'f1_rec': 0.2608695652173913, 'f1_mgmt': 0.309462915601023}
# Epoch 27 training metrics {'rmse1': np.float64(0.2384765585998496), 'rmse2': np.float64(0.24768332476437735), 'f1_rec': 0.5674881262804992, 'f1_mgmt': 0.4618389205730978}
# Epoch 27 validation metrics {'rmse1': np.float64(0.41497341407556343), 'rmse2': np.float64(0.35751683013168556), 'f1_rec': 0.60608434521478, 'f1_mgmt': 0.2898550724637681}
# Epoch 55 training metrics {'rmse1': np.float64(0.2336004348567221), 'rmse2': np.float64(0.20932805453365472), 'f1_rec': 0.5777214911073179, 'f1_mgmt': 0.6398049524409785}
# Epoch 55 validation metrics {'rmse1': np.float64(0.361956670748377), 'rmse2': np.float64(0.3734662542294755), 'f1_rec': 0.5148741418764302, 'f1_mgmt': 0.309462915601023}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 5/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3364981037236763), 'rmse2': np.float64(0.3541980414907464), 'f1_rec': 0.510892382329617, 'f1_mgmt': 0.3639093015608561}
# Epoch 1 validation metrics {'rmse1': np.float64(0.41008458113574103), 'rmse2': np.float64(0.20164607442925794), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.2635046113306983}
# Epoch 27 training metrics {'rmse1': np.float64(0.23112198337038653), 'rmse2': np.float64(0.23794482022393837), 'f1_rec': 0.5674237508111616, 'f1_mgmt': 0.4238883852565945}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3295835612952968), 'rmse2': np.float64(0.21411915292446473), 'f1_rec': 0.40821256038647347, 'f1_mgmt': 0.309462915601023}
# Epoch 55 training metrics {'rmse1': np.float64(0.2352223773389499), 'rmse2': np.float64(0.22130308188511488), 'f1_rec': 0.5681835357624831, 'f1_mgmt': 0.617568952490668}
# Epoch 55 validation metrics {'rmse1': np.float64(67.71541337007724), 'rmse2': np.float64(243.71818075481113), 'f1_rec': 0.2244039270687237, 'f1_mgmt': 0.01391304347826087}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 6/30
# Epoch 1 training metrics {'rmse1': np.float64(0.29769882219419513), 'rmse2': np.float64(0.3324955067334528), 'f1_rec': 0.5000159723996933, 'f1_mgmt': 0.3468901196842374}
# Epoch 1 validation metrics {'rmse1': np.float64(0.23019118380542067), 'rmse2': np.float64(0.2565332724006764), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.309462915601023}
# Epoch 27 training metrics {'rmse1': np.float64(0.2483552048077581), 'rmse2': np.float64(0.2289017894948235), 'f1_rec': 0.5720640061692693, 'f1_mgmt': 0.5044416848254801}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3305557795100177), 'rmse2': np.float64(0.2864276789169184), 'f1_rec': 0.42140468227424754, 'f1_mgmt': 0.4074074074074074}
# Epoch 55 training metrics {'rmse1': np.float64(0.20996889703229618), 'rmse2': np.float64(0.2145004731170159), 'f1_rec': 0.7046057767369243, 'f1_mgmt': 0.6003256003256003}
# Epoch 55 validation metrics {'rmse1': np.float64(0.28723347195358434), 'rmse2': np.float64(0.26203177890435914), 'f1_rec': 0.32028985507246377, 'f1_mgmt': 0.37176553423693015}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 7/30
# Epoch 1 training metrics {'rmse1': np.float64(0.30849893312257687), 'rmse2': np.float64(0.3503365965672432), 'f1_rec': 0.5651799181210946, 'f1_mgmt': 0.36273100333250713}
# Epoch 1 validation metrics {'rmse1': np.float64(0.45224655079858583), 'rmse2': np.float64(0.2507457029551654), 'f1_rec': 0.4606345475910693, 'f1_mgmt': 0.40821256038647347}
# Epoch 27 training metrics {'rmse1': np.float64(0.2608217456424795), 'rmse2': np.float64(0.2737432426366293), 'f1_rec': 0.5611721611721612, 'f1_mgmt': 0.5413022351797862}
# Epoch 27 validation metrics {'rmse1': np.float64(0.990337461001831), 'rmse2': np.float64(3.613490831906512), 'f1_rec': 0.4396135265700483, 'f1_mgmt': 0.40821256038647347}
# Epoch 55 training metrics {'rmse1': np.float64(0.21930085803960356), 'rmse2': np.float64(0.23128775805847787), 'f1_rec': 0.686279238003376, 'f1_mgmt': 0.5344193061840121}
# Epoch 55 validation metrics {'rmse1': np.float64(14.2016100258656), 'rmse2': np.float64(81.05516774019596), 'f1_rec': 0.22010869565217392, 'f1_mgmt': 0.003623188405797101}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 8/30
# Epoch 1 training metrics {'rmse1': np.float64(0.33664836196962755), 'rmse2': np.float64(0.31737957240923265), 'f1_rec': 0.542386185243328, 'f1_mgmt': 0.31932626344922904}
# Epoch 1 validation metrics {'rmse1': np.float64(0.28802150829512124), 'rmse2': np.float64(0.2094311733505123), 'f1_rec': 0.5148741418764302, 'f1_mgmt': 0.0}
# Epoch 27 training metrics {'rmse1': np.float64(0.2527425713898416), 'rmse2': np.float64(0.23906778341925303), 'f1_rec': 0.5704590746692042, 'f1_mgmt': 0.5003885003885004}
# Epoch 27 validation metrics {'rmse1': np.float64(1.0191896480493616), 'rmse2': np.float64(0.5520357753515739), 'f1_rec': 0.4472049689440994, 'f1_mgmt': 0.48071870497499786}
# Epoch 55 training metrics {'rmse1': np.float64(0.2469184616622435), 'rmse2': np.float64(0.1946622584054048), 'f1_rec': 0.5302452964991664, 'f1_mgmt': 0.49474969474969477}
# Epoch 55 validation metrics {'rmse1': np.float64(43.24771450357358), 'rmse2': np.float64(159.1811246184126), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0
30
# Epoch 1 training metrics {'rmse1': np.float64(0.3370700640870347), 'rmse2': np.float64(0.27708277891519056), 'f1_rec': 0.5566099955538899, 'f1_mgmt': 0.33515741015741013}
# Epoch 1 validation metrics {'rmse1': np.float64(0.38383116155169367), 'rmse2': np.float64(0.3938270554001141), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.328804347826087}
# Epoch 27 training metrics {'rmse1': np.float64(0.26294375077895427), 'rmse2': np.float64(0.22520030331635044), 'f1_rec': 0.5945538365699967, 'f1_mgmt': 0.5063696527321151}
# Epoch 27 validation metrics {'rmse1': np.float64(0.4041582497655468), 'rmse2': np.float64(0.4645737856085092), 'f1_rec': 0.447996589940324, 'f1_mgmt': 0.35776397515527947}
# Epoch 55 training metrics {'rmse1': np.float64(0.2529064321373693), 'rmse2': np.float64(0.2033151661875457), 'f1_rec': 0.6137152465021317, 'f1_mgmt': 0.527619921062544}
# Epoch 55 validation metrics {'rmse1': np.float64(11.946802729114161), 'rmse2': np.float64(6.064106344120485), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.309462915601023}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 26/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3321106611692062), 'rmse2': np.float64(0.36658624241177346), 'f1_rec': 0.4593547478162864, 'f1_mgmt': 0.4126813952597925}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2675077611571574), 'rmse2': np.float64(0.3540327700353427), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.2635046113306983}
# Epoch 27 training metrics {'rmse1': np.float64(0.2615796858899034), 'rmse2': np.float64(0.23648073429138952), 'f1_rec': 0.5489323308270676, 'f1_mgmt': 0.5422370096144083}
# Epoch 27 validation metrics {'rmse1': np.float64(6.748460873677271), 'rmse2': np.float64(22.820788864143008), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.4423346639335419}
# Epoch 55 training metrics {'rmse1': np.float64(0.24046540396132862), 'rmse2': np.float64(0.19148723038174514), 'f1_rec': 0.6158918005071852, 'f1_mgmt': 0.5988678525991958}
# Epoch 55 validation metrics {'rmse1': np.float64(0.25407611944042746), 'rmse2': np.float64(0.4219107006158628), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.2635046113306983}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 27/30
# Epoch 1 training metrics {'rmse1': np.float64(0.32865689682105287), 'rmse2': np.float64(0.33814288288615196), 'f1_rec': 0.5086057318362218, 'f1_mgmt': 0.31094290325059554}
# Epoch 1 validation metrics {'rmse1': np.float64(0.5255505232344998), 'rmse2': np.float64(0.2267191686938721), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.08695652173913043}
# Epoch 27 training metrics {'rmse1': np.float64(0.23890089441415857), 'rmse2': np.float64(0.26069157681456034), 'f1_rec': 0.6585432575898678, 'f1_mgmt': 0.45054945054945056}
# Epoch 27 validation metrics {'rmse1': np.float64(0.27879886876013527), 'rmse2': np.float64(0.22951757341792034), 'f1_rec': 0.49353701527614574, 'f1_mgmt': 0.41739130434782606}
# Epoch 55 training metrics {'rmse1': np.float64(0.24183006509179766), 'rmse2': np.float64(0.22607103174005), 'f1_rec': 0.6682262648649203, 'f1_mgmt': 0.5079417244971316}
# Epoch 55 validation metrics {'rmse1': np.float64(0.25600878951543116), 'rmse2': np.float64(0.19910316659080562), 'f1_rec': 0.49353701527614574, 'f1_mgmt': 0.41739130434782606}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 28/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3210774379683052), 'rmse2': np.float64(0.3189857281153311), 'f1_rec': 0.5013197586726998, 'f1_mgmt': 0.3641631674994274}
# Epoch 1 validation metrics {'rmse1': np.float64(0.35908750633696046), 'rmse2': np.float64(0.2756407358032241), 'f1_rec': 0.43685300207039335, 'f1_mgmt': 0.35776397515527947}
# Epoch 27 training metrics {'rmse1': np.float64(0.22458110035370907), 'rmse2': np.float64(0.25632353489012183), 'f1_rec': 0.5641025641025641, 'f1_mgmt': 0.555587003515335}
# Epoch 27 validation metrics {'rmse1': np.float64(0.39522501673526217), 'rmse2': np.float64(0.2887738823200056), 'f1_rec': 0.40821256038647347, 'f1_mgmt': 0.42898550724637674}
# Epoch 55 training metrics {'rmse1': np.float64(0.20677780783148336), 'rmse2': np.float64(0.22416834721354179), 'f1_rec': 0.6182336182336182, 'f1_mgmt': 0.565997221169635}
# Epoch 55 validation metrics {'rmse1': np.float64(0.32682272548021274), 'rmse2': np.float64(0.21228537172007947), 'f1_rec': 0.40821256038647347, 'f1_mgmt': 0.35776397515527947}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 29/30
# Epoch 1 training metrics {'rmse1': np.float64(0.3501267137915683), 'rmse2': np.float64(0.33661606476284517), 'f1_rec': 0.6153846153846154, 'f1_mgmt': 0.3754682404388862}
# Epoch 1 validation metrics {'rmse1': np.float64(0.3138276962057854), 'rmse2': np.float64(0.38782088514933083), 'f1_rec': 0.05152979066022544, 'f1_mgmt': 0.6871686108165429}
# Epoch 27 training metrics {'rmse1': np.float64(0.240715107515533), 'rmse2': np.float64(0.25492358286168476), 'f1_rec': 0.5233813805242377, 'f1_mgmt': 0.429325934309323}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3917987835180427), 'rmse2': np.float64(0.2441491167001469), 'f1_rec': 0.7474120082815735, 'f1_mgmt': 0.6421404682274247}
# Epoch 55 training metrics {'rmse1': np.float64(0.23855400246371575), 'rmse2': np.float64(0.26260357856311883), 'f1_rec': 0.4812314390783114, 'f1_mgmt': 0.576775191682024}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2623204389147447), 'rmse2': np.float64(0.20751774545667048), 'f1_rec': 0.7021739130434782, 'f1_mgmt': 0.6178489702517163}
#
# Using device: cuda
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.35610370658541884), 'rmse2': np.float64(0.32652367462799003), 'f1_rec': 0.5443786982248521, 'f1_mgmt': 0.47445615081786413}
# Epoch 1 validation metrics {'rmse1': np.float64(0.25436716761031236), 'rmse2': np.float64(0.32292326117474673), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.01391304347826087}
# Epoch 27 training metrics {'rmse1': np.float64(0.2602715254762342), 'rmse2': np.float64(0.2400737591218599), 'f1_rec': 0.5864562787639711, 'f1_mgmt': 0.4963908640379229}
# Epoch 27 validation metrics {'rmse1': np.float64(0.35954565456419874), 'rmse2': np.float64(0.363165667151533), 'f1_rec': 0.40821256038647347, 'f1_mgmt': 0.309462915601023}
# Epoch 55 training metrics {'rmse1': np.float64(0.22359887579572849), 'rmse2': np.float64(0.23092496085761854), 'f1_rec': 0.6240972142611487, 'f1_mgmt': 0.5081992311094479}
# Epoch 55 validation metrics {'rmse1': np.float64(4.562387816076313), 'rmse2': np.float64(3.6703258143545407), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.01391304347826087}

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf", figsize=(25,12))

# %% [markdown]
# ## That's really bad, it kind of blows all visualizations so lets remove it

# %%
cv_table = pd.read_csv('../results/cv_results.csv')
cv_table = cv_table[cv_table['run'] != 'umap_early_fusion_nn_with_refinement']
cv_table.to_csv('../results/cv_results.csv', index=False)

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf", figsize=(25,12))

# %%
plot_results_cv('../results/cv_results.csv', run_filter='early')

# %% [markdown]
# ## **Conclusion**
# The neural network performs notably better than the Gradient Boosting Tree on regression tasks in this huge dimensionality setting. Both ML and DL approaches perform poorly on classification tasks. Though achieving better validation performances for regression tasks, intermediate printing allows us to see that the network overfits (reaches much better performances on training set while validation performances hit a plateau).
