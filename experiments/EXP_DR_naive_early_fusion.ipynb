# %% [markdown]
# # **Early Fusion with Dimensionality Reduction Experiment**
# Poor results expected because:
# - Simple concatenation of modalities
#
# However, better results than Naive Early Fusion are expected due to the dimensionality reduction step.

# %%
import sys
import os

project_path = "/home/sagemaker-user/gbm_hackathon"
if project_path not in sys.path:
    sys.path.append(project_path)
    print(sys.path)

# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
import pandas as pd
import numpy as np
import pickle as pkl
import torch
import seaborn as sns
import matplotlib.pyplot as plt 
import subprocess

from foundation.clinical import get_batch
from gbmhackathon.data import MosaicDataset
from gbmhackathon.s3_loader import load_s3, write_s3

# %%
# %load_ext autoreload
# %autoreload 2

from gbmhackathon.training.predictive import *
from gbmhackathon.models.dim_reduction import *
from gbmhackathon.models.mme import GBMNet
from gbmhackathon.utils.loss_functions import InfoNCELoss, RegularizedInfoNCELoss, SmoothingFunction, RankMe
from gbmhackathon.utils.module_functions import instantiate
from gbmhackathon.training.cv import get_ci, get_cv_results, plot_results_cv, plot_cv_table
from gbmhackathon.s3_loader import load_s3

import os, time
from copy import deepcopy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# To investigate gradients
from torchviz import make_dot
from sklearn.ensemble import GradientBoostingClassifier
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import Adam
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
torch.set_num_threads(32)
torch.get_num_threads()
# Out:
# 32

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %%
name_emb_dict = {"hne":"embeddings_HnE_OptimusH0.pkl",
"spatial":"2025-03-23_18-32_spatial_emb_V1.pkl",
"clinical":"2025-05-25_14-36_new_clinical_emb_V1.pkl",
"wes":"2025-04-05_13-40_wes_emb_V1.pkl",
"bulk":"2025-05-03_10-15_bulk_emb_V1.pkl",
"scRNA":"2025-05-04_02-35_scRNA_emb_V1.pkl"}
pkl_storage_folder = "embedding_V1"

# %%
dataset = PredictiveLearningDataset(name_emb_dict, pkl_storage_folder, device=device, dropout=0.0, normalize=True)
print(f"Dataset size: {len(dataset)}")
BATCH_SIZE = 114
dataloader = DataLoader(dataset, BATCH_SIZE, shuffle=True, collate_fn=collate_predictive, generator=torch.Generator(device=dataset.device))
# Out:
# cas 2 : device reconnu : cuda
# Using device: cuda
# Normalization applied successfully
# Dataset size: 114

# %%
toy_batch = next(iter(dataloader))
#toy_batch

# %%
type(toy_batch)
# Out:
# tuple

# %%
toy_batch[2]['hne'].size()
# Out:
# torch.Size([114, 1536])

# %%
raw_emb = toy_batch[2]
inpute_size_dict = {}
for mod in raw_emb.keys():
    print(mod, raw_emb[mod].size())
    inpute_size_dict[mod] = raw_emb[mod].size(1)
# Out:
# hne torch.Size([114, 1536])
# spatial torch.Size([114, 64])
# clinical torch.Size([114, 20])
# wes torch.Size([114, 1790])
# bulk torch.Size([114, 3072])
# scRNA torch.Size([114, 3072])

# %%
raw_emb = toy_batch[2]

# 1) collecter les tenseurs et construire input_size_dict
tensors_to_concat = []
input_size_dict = {}

for mod, emb in raw_emb.items():
    if isinstance(emb, torch.Tensor):
        # on suppose que emb a la forme [batch_size, feature_size]
        input_size_dict[mod] = emb.size(1)
        tensors_to_concat.append(emb)
    else:
        # si tu veux voir ce qu'on skip :
        print(f"Skip {mod}: not a Tensor but {type(emb)}")

# 2) concaténation
# attention tous les emb doivent avoir le même batch_size (dim 0)
concat_emb = torch.cat(tensors_to_concat, dim=1)

print("Sizes by module:", input_size_dict)
print("Concatenated tensor size:", concat_emb.size())
# Out:
# Sizes by module: {'hne': 1536, 'spatial': 64, 'clinical': 20, 'wes': 1790, 'bulk': 3072, 'scRNA': 3072}
# Concatenated tensor size: torch.Size([114, 9554])

# %%
X=concat_emb

# %% [markdown]
# ### **Apply dimensionality reduction on X**

# %%
pca = PCA(explained_variance_threshold=0.999)
umap = UMAP(n_components=64)

# %%
X_pca = pca(X)
# Out:
# 107 dimensions hold 99.90% of variance.
# Effective compression ratio: 1.12%

# %%
X_umap = umap(X)

# %%
Y=toy_batch[-2]

# %%
Y[:10]
# Out:
# tensor([[-0.9107, -0.8280,  1.0000,  0.0000,  1.0000,  0.0000,  0.0000],
#         [-0.2916, -0.1249,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000],
#         [-0.4569, -0.8615,  1.0000,  0.0000,  1.0000,  0.0000,  0.0000],
#         [-0.8012, -0.6383,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000],
#         [-0.5524, -0.4225,  1.0000,  0.0000,  1.0000,  0.0000,  0.0000],
#         [-0.9366, -0.5267,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000],
#         [ 0.5324, -0.8243,  1.0000,  0.0000,  1.0000,  0.0000,  0.0000],
#         [ 1.6511,  3.2342,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000],
#         [ 0.8927,  1.4040,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000],
#         [-0.3434, -0.4634,  1.0000,  0.0000,  1.0000,  0.0000,  0.0000]],
#        device='cuda:0')

# %%
y_reg=Y[:,:2]
y_cat=Y[:,2:]

# %%
print(y_reg.size(),y_cat.size())
# Out:
# torch.Size([114, 2]) torch.Size([114, 5])

# %%
print(X_pca.size(), X_umap.size(),Y.size())
# Out:
# torch.Size([114, 107]) torch.Size([114, 64]) torch.Size([114, 7])

# %%
from sklearn.multioutput import MultiOutputRegressor, MultiOutputClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error, f1_score
import numpy as np
from sklearn.ensemble import HistGradientBoostingRegressor, HistGradientBoostingClassifier


def train_GBT(splitter, dr='pca'):
    # se_sums = np.zeros(2)
    # f1_rec_sums = np.zeros(1)
    # f1_mgmt_sums = np.zeros(1)

    all_rmse1 = []
    all_rmse2 = []
    all_f1_rec  = []
    all_f1_mgmt  = []
    if dr == 'pca':
        features = X_pca
    elif dr == 'umap':
        features = X_umap
    else:
        features = X
    n_splits = splitter.get_n_splits(features)
    t0 = time.time()
    for i, (train_idx, test_idx) in enumerate(splitter.split(features), 1):
        X_train, X_test = features[train_idx].cpu(), features[test_idx].cpu()
        y_reg_train, y_reg_test = y_reg[train_idx].cpu(), y_reg[test_idx].cpu()
        y_rec_train, y_rec_test = torch.argmax(y_cat[train_idx,:2], dim=1).cpu(), torch.argmax(y_cat[test_idx,:2], dim=1).cpu()
        y_mgmt_train, y_mgmt_test = torch.argmax(y_cat[train_idx,2:], dim=1).cpu(), torch.argmax(y_cat[test_idx,2:], dim=1).cpu()
    
        reg_mt = MultiOutputRegressor(
            HistGradientBoostingRegressor(max_iter=100, early_stopping=True),
            n_jobs=-1)
        clf_rec = HistGradientBoostingClassifier(max_iter=100, early_stopping=True)
        clf_mgmt = HistGradientBoostingClassifier(max_iter=100, early_stopping=True)
    
        # Training
        reg_mt.fit(X_train, y_reg_train)
        clf_rec.fit(X_train, y_rec_train)
        clf_mgmt.fit(X_train, y_mgmt_train)
    
        # Prediction
        y_reg_pred = reg_mt.predict(X_test)
        y_rec_pred = clf_rec.predict(X_test)
        y_mgmt_pred = clf_mgmt.predict(X_test)
    
        # Accumulation of metrics
        for k in range(2):
            rmse = np.sqrt(np.mean((y_reg_pred[:, k] - y_reg_test[:, k].cpu().numpy())**2))
            if k == 0:
                all_rmse1.append(rmse)
            else:
                all_rmse2.append(rmse)
            # se_sums[k] += np.sum((y_reg_pred[:, k] - y_reg_test[:, k].cpu().numpy())**2)

        all_f1_rec.append(f1_score(y_rec_test, y_rec_pred, average='weighted', zero_division=0))
        all_f1_mgmt.append(f1_score(y_mgmt_test, y_mgmt_pred, average='weighted', zero_division=0))
        
        # f1_rec_sums += f1_score(y_rec_test, y_rec_pred, average='weighted', zero_division=0)
        # f1_mgmt_sums += f1_score(y_mgmt_test, y_mgmt_pred, average='weighted', zero_division=0)
    
        print(f"Iteration {i}/{n_splits}", end="\r")
    
    # # Averages over all Monte Carlo iterations
    # avg_rmse = np.sqrt(se_sums / (n_splits * len(test_idx)))
    # avg_f1_rec = f1_rec_sums / n_splits
    # avg_f1_mgmt = f1_mgmt_sums / n_splits
    # print("\nMultitâche CV → RMSE:", avg_rmse, "— F1 Recurrency:", avg_f1_rec, "— F1 MGMT Methylation:", avg_f1_mgmt)
    runtime = time.time() - t0
    if dr == None:
        run_name = f"naive_early_fusion_gbt"
    else:
        run_name = f"{dr}_early_fusion_gbt"
    reg_dict = {'os':all_rmse1, 'pfs':all_rmse2}
    clf_dict = {'recurrency':all_f1_rec, 'mgmt':all_f1_mgmt}
    return get_cv_results(reg_dict, clf_dict, run_name, time=runtime, save=True)
    # # Calcul des moyennes sur tous les folds
    # ci_rmse1 =get_ci(all_rmse1)
    # ci_rmse2 =get_ci(all_rmse2)
    # ci_f1_rec  = get_ci(all_f1_rec)
    # ci_f1_mgmt  = get_ci(all_f1_mgmt)

    # # Affichage final des moyennes globales
    # print("=== Moyennes sur tous les folds ===")
    # print(f"RMSE CI95% for os (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse1]}]")
    # print(f"RMSE CI95% for pfs (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse2]}]")
    # print(f"F1 CI95% for Recurrency (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_rec]}]")
    # print(f"F1 CI95% for MGMT Methylation (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_mgmt]}]")

# %%
X.shape
# Out:
# torch.Size([114, 9554])

# %% [markdown]
# ## **GradientBoosting: Monte Carlo Cross-Validation**
# ### **PCA**

# %%
from sklearn.model_selection import ShuffleSplit

n_splits = 30  # Number of Monte Carlo iterations
test_size = 0.2  # Fraction of data to use for testing in each split
random_state = 62  # For reproducibility

mc_cv = ShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
train_GBT(mc_cv, dr='pca')
# Out:
# Iteration 30/30
#                     run  n_folds       time  low_rmse_os  avg_rmse_os  \
# 0  pca_early_fusion_gbt       30  40.834565     0.954283     1.000285
#
#    up_rmse_os  low_rmse_pfs  avg_rmse_pfs  up_rmse_pfs  low_f1_recurrency  \
# 0    1.052892      0.957121      1.014793     1.079915            0.44505
#
#    avg_f1_recurrency  up_f1_recurrency  low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  \
# 0           0.494342           0.53353     0.417281     0.462766    0.500331
#
#    sum_reg_avg  sum_clf_avg  sum_reg_ci_relative_width  \
# 0     2.015078     0.957108                   0.219585
#
#    sum_clf_ci_relative_width
# 0                   0.358451

# %% [markdown]
# ### **UMAP**

# %%
train_GBT(mc_cv, dr='umap')
# Out:
# Iteration 30/30
#                      run  n_folds      time  low_rmse_os  avg_rmse_os  \
# 0  umap_early_fusion_gbt       30  3.720364     0.964435     1.019832
#
#    up_rmse_os  low_rmse_pfs  avg_rmse_pfs  up_rmse_pfs  low_f1_recurrency  \
# 0    1.083154      0.967034      1.013978     1.067299           0.421225
#
#    avg_f1_recurrency  up_f1_recurrency  low_f1_mgmt  avg_f1_mgmt  up_f1_mgmt  \
# 0           0.455597          0.489848     0.429476     0.463588    0.492688
#
#    sum_reg_avg  sum_clf_avg  sum_reg_ci_relative_width  \
# 0      2.03381     0.919184                   0.215294
#
#    sum_clf_ci_relative_width
# 0                   0.286973

# %% [markdown]
# # MLP: Leave One Out Cross-Validation

# %%
import torch
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn as nn
import numpy as np
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import f1_score

# %%
class TabularDataset(Dataset):
    """
    Dataset PyTorch pour des données tabulaires.
    X: array-like de shape (n_samples, n_features)
    Y: array-like de shape (n_samples, 5) où les 3 premières colonnes sont continues,
       et les 2 dernières sont catégorielles (entiers).
    """
    def __init__(self, X, Y, device='cpu'):
        self.X = torch.from_numpy(np.asarray(X)).float() if isinstance(X, np.ndarray) else X.float()
        self.Y = torch.from_numpy(np.asarray(Y)) if isinstance(Y, np.ndarray) else Y
        self.device = device

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y_cont = self.Y[idx, :2].float()
        y_cat = self.Y[idx, 2:].long()
        return x.to(self.device), y_cont.to(self.device), y_cat.to(self.device)

# def get_loo_loaders(X, Y, batch_size=32, device='cpu'):
#     """
#     Renvoie un itérateur de folds Leave-One-Out.
#     Pour chaque itération, on obtient train_loader, val_loader.
#     """
# #    cpu_count = os.cpu_count() or 1
#     dataset = TabularDataset(X, Y, device=device)
#     loo = LeaveOneOut()
#     for train_idx, val_idx in loo.split(X):
#         train_subset = Subset(dataset, train_idx)
#         val_subset = Subset(dataset, val_idx)

#         train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
#         val_loader = DataLoader(val_subset, batch_size=1, shuffle=False)

        
# #        train_loader = DataLoader(
# #            train_subset,
# #            batch_size=batch_size,
# #            shuffle=True,
# #            num_workers=cpu_count,  # parallélisation du chargement
# #            pin_memory=(device!='cpu')  # épingle en mémoire pour GPU
# #        )
# #        val_loader = DataLoader(
# #            val_subset,
# #            batch_size=1,
# #            shuffle=False,
# #            num_workers=cpu_count//2,
# #            pin_memory=(device!='cpu')
# #        )
#         yield train_loader, val_loader

n_splits = 30  # Number of Monte Carlo iterations
test_size = 0.2  # Fraction of data to use for testing in each split
random_state = 62  # For reproducibility
def get_mccv_loaders(X, Y, batch_size=32, device='cpu'):
    """
    Renvoie un itérateur de folds Leave-One-Out.
    Pour chaque itération, on obtient train_loader, val_loader.
    """
#    cpu_count = os.cpu_count() or 1
    dataset = TabularDataset(X, Y, device=device)
    mccv =  ShuffleSplit(n_splits=n_splits, test_size=test_size, random_state=random_state)
    for train_idx, val_idx in mccv.split(X):
        train_subset = Subset(dataset, train_idx)
        val_subset = Subset(dataset, val_idx)

        train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, generator=torch.Generator(device=dataset.device))
        val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
        yield train_loader, val_loader

# %%
dataset = TabularDataset(X, Y, device=device)
dataset_pca = TabularDataset(X_pca, Y, device=device)
dataset_umap = TabularDataset(X_umap, Y, device=device)

loader = DataLoader(dataset, batch_size=32, shuffle=True, generator=torch.Generator(device=dataset.device))
x_batch, y_cont_batch, y_cat_batch = next(iter(loader))
print(f"Batch shapes: X={x_batch.shape}, y_cont={y_cont_batch.shape}, y_cat={y_cat_batch.shape}")
# Out:
# Batch shapes: X=torch.Size([32, 9554]), y_cont=torch.Size([32, 2]), y_cat=torch.Size([32, 5])

# %%
from gbmhackathon.models.mme import PredictiveModule

# %%
in_size = X_pca.shape[1]
norm_fn = nn.BatchNorm1d
dropout = 0.2
layers = [in_size,1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

# %%
def eval_epoch(model, loader, device):
    """
    Évaluation sans rétropropagation. Calcule RMSE et F1 comme train_epoch,
    mais passe en mode eval et n'appelle pas backward/step.
    """
    model.eval()
    se_sums = [0.0, 0.0]
    n_samples = 0
    all_preds_rec, all_labels_rec = [], []
    all_preds_mgmt, all_labels_mgmt = [], []
    # all_preds_a, all_labels_a = [], []
    # all_preds_b, all_labels_b = [], []

    criterion_mse = nn.MSELoss()
    criterion_ce = nn.CrossEntropyLoss()

    for X_batch, y_cont, y_cat in loader:
        out_list = list(model(X_batch).values())
        o1, o2, logits = out_list[0], out_list[1], out_list[2:]
        logits_rec, logits_mgmt = logits[0], logits[1]
        
        y1, y2 = y_cont[:, 0], y_cont[:, 1]
        # y_a, y_b = y_cat[:, 0], y_cat[:, 1]
        y_cat_rec = y_cat[:,:2].to(torch.half)
        y_cat_mgmt = y_cat[:,2:].to(torch.half)
        
        loss1 = criterion_mse(o1.squeeze(), y1)
        loss2 = criterion_mse(o2.squeeze(), y2)
        loss3 = criterion_ce(logits_rec, y_cat_rec)
        loss4 = criterion_ce(logits_mgmt, y_cat_mgmt)
        # loss4a = criterion_ce(logits_a, y_a)
        # loss4b = criterion_ce(logits_b, y_b)

        batch_size = X_batch.size(0)
        n_samples += batch_size
        se_sums[0] += loss1.item()
        se_sums[1] += loss2.item()

        preds_rec = torch.argmax(logits_rec, dim=1).cpu().numpy()
        all_preds_rec.extend(preds_rec)
        all_labels_rec.extend(torch.argmax(y_cat_rec, dim=1).cpu().numpy())      # preds_a = torch.argmax(logits_a, dim=1).cpu().numpy()
        
        preds_mgmt = torch.argmax(logits_mgmt, dim=1).cpu().numpy()
        all_preds_mgmt.extend(preds_mgmt)
        all_labels_mgmt.extend(torch.argmax(y_cat_mgmt, dim=1).cpu().numpy())
        # preds_b = torch.argmax(logits_b, dim=1).cpu().numpy()
        # all_preds_a.extend(preds_a)
        # all_preds_b.extend(preds_b)
        # all_labels_a.extend(y_a.cpu().numpy())
        # all_labels_b.extend(y_b.cpu().numpy())

    rmse1 = np.sqrt(se_sums[0] / n_samples)
    rmse2 = np.sqrt(se_sums[1] / n_samples)
    f1_rec = f1_score(all_labels_rec, all_preds_rec, average='weighted')
    f1_mgmt = f1_score(all_labels_mgmt, all_preds_mgmt, average='weighted')
    # f1_a = f1_score(all_labels_a, all_preds_a, average='macro')
    # f1_b = f1_score(all_labels_b, all_preds_b, average='macro')
    return {'rmse1': rmse1, 'rmse2': rmse2, 'f1_rec': f1_rec, 'f1_mgmt': f1_mgmt}

# %%
def train_epoch(model, loader, optimizer, device):
    model.train()
    se_sums = [0.0, 0.0]
    n_samples = 0
    all_preds_rec, all_labels_rec = [], []
    all_preds_mgmt, all_labels_mgmt = [], []

    criterion_mse = nn.MSELoss()
    criterion_ce = nn.CrossEntropyLoss()

    n_batches = len(loader)
    for batch_idx, (X_batch, y_cont, y_cat) in enumerate(loader, 1):
        # Affichage de l'avancement par batch
        #print(f"  Batch {batch_idx}/{n_batches}", end="\r")

        optimizer.zero_grad()
        out_list = list(model(X_batch).values())
        o1, o2, logits = out_list[0], out_list[1], out_list[2:]
        logits_rec, logits_mgmt = logits[0], logits[1]
        
        y1, y2 = y_cont[:, 0], y_cont[:, 1]
        # y_a, y_b = y_cat[:, 0], y_cat[:, 1]
        y_cat_rec = y_cat[:,:2].to(torch.half)
        y_cat_mgmt = y_cat[:,2:].to(torch.half)

        loss1 = criterion_mse(o1.squeeze(), y1)
        loss2 = criterion_mse(o2.squeeze(), y2)
        loss3 = criterion_ce(logits_rec, y_cat_rec)
        loss4 = criterion_ce(logits_mgmt, y_cat_mgmt)
        

        loss = loss1 + loss2 + loss3 + loss4
        loss.backward()
        optimizer.step()

        batch_size = X_batch.size(0)
        n_samples += batch_size
        se_sums[0] += loss1.item()
        se_sums[1] += loss2.item()

        preds_rec = torch.argmax(logits_rec, dim=1).cpu().numpy()
        all_preds_rec.extend(preds_rec)
        all_labels_rec.extend(torch.argmax(y_cat_rec, dim=1).cpu().numpy()) 
        
        preds_mgmt = torch.argmax(logits_mgmt, dim=1).cpu().numpy()
        all_preds_mgmt.extend(preds_mgmt)
        all_labels_mgmt.extend(torch.argmax(y_cat_mgmt, dim=1).cpu().numpy()) 

    rmse1 = np.sqrt(se_sums[0] / n_samples)
    rmse2 = np.sqrt(se_sums[1] / n_samples)
    f1_rec = f1_score(all_labels_rec, all_preds_rec, average='weighted')
    f1_mgmt = f1_score(all_labels_mgmt, all_preds_mgmt, average='weighted')
    return {'rmse1': rmse1, 'rmse2': rmse2, 'f1_rec': f1_rec, 'f1_mgmt': f1_mgmt}


def fit(model_class, model_cfg, X, Y, device, get_loaders_func,  num_epochs=20, batch_size=32, scheduler=None, dr='pca'):
    """
    Entraîne le modèle avec LOOCV et affiche des statistiques globales.
    Affiche uniquement deux lignes actualisables : une pour le fold courant et une pour l'epoch.
    """
    history = []
    total_folds = len([el for el in enumerate(
            get_loaders_func(X, Y, batch_size=batch_size, device=device), start=1)])
    # Préparation des listes pour statistiques globales
    t0 = time.time()
    for fold, (train_loader, val_loader) in enumerate(
            get_loaders_func(X, Y, batch_size=batch_size, device=device), start=1):
        model = instantiate(model_cfg, model_class)
        # Instanciation du modèle avec layers
        # layers = [X.shape[1], 1024, 512, 64]
        # model = SimpleMLP(layers=layers).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    
        # Affichage du fold courant, actualisable
        print(f"Fold {fold}/{total_folds}")
        for epoch in range(1, num_epochs + 1):
            # Réécrit la ligne pour l'epoch en cours
            print(f"Epoch {epoch}/{num_epochs}.", end='\r')
            train_metrics = train_epoch(model, train_loader, optimizer, device)
            val_metrics = eval_epoch(model, val_loader, device)
            if epoch == 1 or epoch == num_epochs//2 or epoch == num_epochs:
                print(f"Epoch {epoch} training metrics", train_metrics)
                print(f"Epoch {epoch} validation metrics", val_metrics)
            if scheduler:
                scheduler.step(val_metrics['rmse1'])
        # À la fin des epochs, on passe à la ligne suivante
        print()
        history.append({'fold': fold, 'train': train_metrics, 'val': val_metrics})

    # Calcul des moyennes sur tous les folds
    all_rmse1 = [h['val']['rmse1'] for h in history]
    all_rmse2 = [h['val']['rmse2'] for h in history]
    all_f1_rec  = [h['val']['f1_rec']   for h in history]
    all_f1_mgmt  = [h['val']['f1_mgmt']   for h in history]

    runtime = time.time() - t0
    run_name = f"{dr}_early_fusion_nn"
    reg_dict = {'os':all_rmse1, 'pfs':all_rmse2}
    clf_dict = {'recurrency':all_f1_rec, 'mgmt':all_f1_mgmt}
    return get_cv_results(reg_dict, clf_dict, run_name, time=runtime, save=True)
    # ci_rmse1 =get_ci(all_rmse1)
    # ci_rmse2 =get_ci(all_rmse2)
    # ci_f1_rec  = get_ci(all_f1_rec)
    # ci_f1_mgmt  = get_ci(all_f1_mgmt)

    # # Affichage final des moyennes globales
    # print("=== Moyennes sur tous les folds ===")
    # print(f"RMSE CI95% for os (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse1]}]")
    # print(f"RMSE CI95% for pfs (low, mean, high): [{[f'{val:.4f}' for val in ci_rmse2]}]")
    # print(f"F1 CI95% for Recurrency (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_rec]}]")
    # print(f"F1 CI95% for MGMT Methylation (low, mean, high): [{[f'{val:.4f}' for val in ci_f1_mgmt]}]")
    # return history

# %%
# class SimpleMLP(nn.Module):
#     """
#     MLP multitâche avec architecture configurable via `layers`.
#     `layers` est une liste d'entiers [in_dim, h1, h2, ..., hN].
#     """
#     def __init__(self, layers):
#         super().__init__()
#         modules = []
#         for in_dim, out_dim in zip(layers[:-1], layers[1:]):
#             modules.append(nn.Linear(in_dim, out_dim))
#             modules.append(nn.ReLU())
#         self.shared = nn.Sequential(*modules)
#         last = layers[-1]
#         self.out1 = nn.Linear(last, 1)
#         self.out2 = nn.Linear(last, 1)
#         self.out3 = nn.Linear(last, 1)
#         self.clf = nn.Linear(last, 2)

#     def forward(self, x):
#         h = self.shared(x)
#         return (
#             self.out1(h),
#             self.out2(h),
#             self.out3(h),
#             self.clf(h)
#         )

# %% [markdown]
# ## **MLP: Monte Carlo Cross-Validation**
# ### **PCA**

# %%
history = fit(PredictiveModule, predictive_cfg, X_pca, Y, device, get_mccv_loaders, num_epochs=55, batch_size=32, dr='pca')
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23419992244643031), 'rmse2': np.float64(0.240386116106987), 'f1_rec': 0.49774584389969007, 'f1_mgmt': 0.30212614282736233}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2554757185113504), 'rmse2': np.float64(0.20796977885045398), 'f1_rec': 0.6743691091517178, 'f1_mgmt': 0.5937031484257871}
# Epoch 27 training metrics {'rmse1': np.float64(0.043799486984487934), 'rmse2': np.float64(0.054329464400019234), 'f1_rec': 0.9453403739118025, 'f1_mgmt': 0.9673625343728436}
# Epoch 27 validation metrics {'rmse1': np.float64(0.23277958196694), 'rmse2': np.float64(0.1915820244649191), 'f1_rec': 0.8295376121463078, 'f1_mgmt': 0.7237851662404092}
# Epoch 55 training metrics {'rmse1': np.float64(0.0404707287046456), 'rmse2': np.float64(0.046688233944212836), 'f1_rec': 0.9345992243051067, 'f1_mgmt': 0.9671961028662059}
# Epoch 55 validation metrics {'rmse1': np.float64(0.23727637965217174), 'rmse2': np.float64(0.18860561475474708), 'f1_rec': 0.7788686302010285, 'f1_mgmt': 0.7237851662404092}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 2/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2290583836471407), 'rmse2': np.float64(0.23816677196162428), 'f1_rec': 0.3819400459439786, 'f1_mgmt': 0.3766186974617888}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21145574819085283), 'rmse2': np.float64(0.20088916009063967), 'f1_rec': 0.5042772731281417, 'f1_mgmt': 0.568944099378882}
# Epoch 27 training metrics {'rmse1': np.float64(0.06054233532654397), 'rmse2': np.float64(0.07729063461821956), 'f1_rec': 0.9132149901380671, 'f1_mgmt': 0.9285790240974189}
# Epoch 27 validation metrics {'rmse1': np.float64(0.1997665846894138), 'rmse2': np.float64(0.18822005817559112), 'f1_rec': 0.645272601794341, 'f1_mgmt': 0.6997929606625258}
# Epoch 55 training metrics {'rmse1': np.float64(0.042010837160024024), 'rmse2': np.float64(0.06651930564787578), 'f1_rec': 0.9348025360934993, 'f1_mgmt': 0.9672935759892282}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1917620772643193), 'rmse2': np.float64(0.18894637664430244), 'f1_rec': 0.6694717157550257, 'f1_mgmt': 0.7072463768115942}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 3/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24271833357248226), 'rmse2': np.float64(0.2641435700755298), 'f1_rec': 0.5205950512072961, 'f1_mgmt': 0.3442449454738241}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20720022939557564), 'rmse2': np.float64(0.2527037862545942), 'f1_rec': 0.48861283643892334, 'f1_mgmt': 0.3156076659912977}
# Epoch 27 training metrics {'rmse1': np.float64(0.05891139456627397), 'rmse2': np.float64(0.06623424178769137), 'f1_rec': 0.9453403739118025, 'f1_mgmt': 0.9390146247372076}
# Epoch 27 validation metrics {'rmse1': np.float64(0.15860318082121955), 'rmse2': np.float64(0.20454783620440414), 'f1_rec': 0.6521739130434783, 'f1_mgmt': 0.6521739130434783}
# Epoch 55 training metrics {'rmse1': np.float64(0.0480924813672575), 'rmse2': np.float64(0.03659689834071115), 'f1_rec': 0.9563257255564948, 'f1_mgmt': 0.9461771105606722}
# Epoch 55 validation metrics {'rmse1': np.float64(0.15470671402485822), 'rmse2': np.float64(0.21391166571361875), 'f1_rec': 0.6019635343618515, 'f1_mgmt': 0.6104006820119352}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 4/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24528004790837066), 'rmse2': np.float64(0.2522921699902472), 'f1_rec': 0.5000159723996933, 'f1_mgmt': 0.3786442728400321}
# Epoch 1 validation metrics {'rmse1': np.float64(0.24107059424207467), 'rmse2': np.float64(0.22051955570206183), 'f1_rec': 0.5551839464882944, 'f1_mgmt': 0.5452173913043478}
# Epoch 27 training metrics {'rmse1': np.float64(0.046775520616660626), 'rmse2': np.float64(0.06762452143310166), 'f1_rec': 0.9349074349074349, 'f1_mgmt': 0.9195167022032693}
# Epoch 27 validation metrics {'rmse1': np.float64(0.21277497493671277), 'rmse2': np.float64(0.20174066366416593), 'f1_rec': 0.5105517416730231, 'f1_mgmt': 0.5522774327122153}
# Epoch 55 training metrics {'rmse1': np.float64(0.07330045680806373), 'rmse2': np.float64(0.07395426761345361), 'f1_rec': 0.9344191522762951, 'f1_mgmt': 0.9555904413047269}
# Epoch 55 validation metrics {'rmse1': np.float64(0.21255977502103754), 'rmse2': np.float64(0.1923669839281624), 'f1_rec': 0.5479641131815045, 'f1_mgmt': 0.551984877126654}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 5/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23426592458068285), 'rmse2': np.float64(0.2902287160155197), 'f1_rec': 0.46625663493133374, 'f1_mgmt': 0.40288775673391053}
# Epoch 1 validation metrics {'rmse1': np.float64(0.19775379485998942), 'rmse2': np.float64(0.18101483549603103), 'f1_rec': 0.5329265191965421, 'f1_mgmt': 0.5650206570922683}
# Epoch 27 training metrics {'rmse1': np.float64(0.05670333908732933), 'rmse2': np.float64(0.07772393718724026), 'f1_rec': 0.9454600947780252, 'f1_mgmt': 0.9683191872500762}
# Epoch 27 validation metrics {'rmse1': np.float64(0.1970480722191348), 'rmse2': np.float64(0.2025174012951664), 'f1_rec': 0.7027714213068903, 'f1_mgmt': 0.5891304347826087}
# Epoch 55 training metrics {'rmse1': np.float64(0.033499202731258615), 'rmse2': np.float64(0.029677453514379528), 'f1_rec': 0.9454600947780252, 'f1_mgmt': 1.0}
# Epoch 55 validation metrics {'rmse1': np.float64(0.19392328204433745), 'rmse2': np.float64(0.1913962577371138), 'f1_rec': 0.6590752242926157, 'f1_mgmt': 0.6447417316982534}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 6/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24882615833076813), 'rmse2': np.float64(0.24594828673040375), 'f1_rec': 0.49707207685931093, 'f1_mgmt': 0.41293617907678165}
# Epoch 1 validation metrics {'rmse1': np.float64(0.1961358206793525), 'rmse2': np.float64(0.1517101111053722), 'f1_rec': 0.47035573122529645, 'f1_mgmt': 0.5382648042494591}
# Epoch 27 training metrics {'rmse1': np.float64(0.046955365066171505), 'rmse2': np.float64(0.07493782900998565), 'f1_rec': 0.9563257255564948, 'f1_mgmt': 0.9890276046977077}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18235904956724966), 'rmse2': np.float64(0.1459782755802123), 'f1_rec': 0.5275597495369962, 'f1_mgmt': 0.5855072463768115}
# Epoch 55 training metrics {'rmse1': np.float64(0.038072250929528), 'rmse2': np.float64(0.04704258727417379), 'f1_rec': 0.9562076453834151, 'f1_mgmt': 0.9673066659368029}
# Epoch 55 validation metrics {'rmse1': np.float64(0.18367965057864397), 'rmse2': np.float64(0.14855784550492404), 'f1_rec': 0.5275597495369962, 'f1_mgmt': 0.47198996655518394}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 7/30
# Epoch 1 training metrics {'rmse1': np.float64(0.25024587728265324), 'rmse2': np.float64(0.25036275661179935), 'f1_rec': 0.5978795681765979, 'f1_mgmt': 0.3616229923922232}
# Epoch 1 validation metrics {'rmse1': np.float64(0.17391596570099557), 'rmse2': np.float64(0.1546412620411826), 'f1_rec': 0.4723320158102767, 'f1_mgmt': 0.2783960890368213}
# Epoch 27 training metrics {'rmse1': np.float64(0.06114416327439593), 'rmse2': np.float64(0.05568359477983489), 'f1_rec': 0.9672301530245456, 'f1_mgmt': 0.9579680593379224}
# Epoch 27 validation metrics {'rmse1': np.float64(0.1746746299354087), 'rmse2': np.float64(0.16112615398174265), 'f1_rec': 0.5525362318840579, 'f1_mgmt': 0.48447204968944096}
# Epoch 55 training metrics {'rmse1': np.float64(0.04052067493069851), 'rmse2': np.float64(0.05522224364197392), 'f1_rec': 0.9562309562309563, 'f1_mgmt': 0.9676494890193521}
# Epoch 55 validation metrics {'rmse1': np.float64(0.17233550910655185), 'rmse2': np.float64(0.16911803699059477), 'f1_rec': 0.5525362318840579, 'f1_mgmt': 0.597254004576659}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 8/30
# Epoch 1 training metrics {'rmse1': np.float64(0.26401216302638086), 'rmse2': np.float64(0.24442361314205685), 'f1_rec': 0.5000536049316537, 'f1_mgmt': 0.28296288929773095}
# Epoch 1 validation metrics {'rmse1': np.float64(0.211013915246287), 'rmse2': np.float64(0.2106050829820813), 'f1_rec': 0.4659977703455964, 'f1_mgmt': 0.4924436177633108}
# Epoch 27 training metrics {'rmse1': np.float64(0.04587846329833329), 'rmse2': np.float64(0.06701522926839501), 'f1_rec': 0.9563713347228741, 'f1_mgmt': 0.9385380905137745}
# Epoch 27 validation metrics {'rmse1': np.float64(0.20137378355419708), 'rmse2': np.float64(0.20741938445281843), 'f1_rec': 0.7391304347826086, 'f1_mgmt': 0.5791304347826087}
# Epoch 55 training metrics {'rmse1': np.float64(0.0511735777775213), 'rmse2': np.float64(0.05136073298310467), 'f1_rec': 0.9127426694457479, 'f1_mgmt': 0.9780947127885904}
# Epoch 55 validation metrics {'rmse1': np.float64(0.19661944766205305), 'rmse2': np.float64(0.2068342690937542), 'f1_rec': 0.731521739130435, 'f1_mgmt': 0.6742784070149799}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 9/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2533456994575594), 'rmse2': np.float64(0.25169636470945445), 'f1_rec': 0.5702609208070974, 'f1_mgmt': 0.3934915570860271}
# Epoch 1 validation metrics {'rmse1': np.float64(0.17445774594626226), 'rmse2': np.float64(0.1968235970228801), 'f1_rec': 0.43478260869565216, 'f1_mgmt': 0.3416394569513662}
# Epoch 27 training metrics {'rmse1': np.float64(0.052502374490551285), 'rmse2': np.float64(0.053094078051601705), 'f1_rec': 0.9458301093545419, 'f1_mgmt': 0.9440490406156492}
# Epoch 27 validation metrics {'rmse1': np.float64(0.15729368190058388), 'rmse2': np.float64(0.17249734257536245), 'f1_rec': 0.4693535585148602, 'f1_mgmt': 0.4302457466918714}
# Epoch 55 training metrics {'rmse1': np.float64(0.04368594321895046), 'rmse2': np.float64(0.046625064432493944), 'f1_rec': 0.9781655126482712, 'f1_mgmt': 0.9894591389918493}
# Epoch 55 validation metrics {'rmse1': np.float64(0.15835766863525982), 'rmse2': np.float64(0.1690858695814867), 'f1_rec': 0.4693535585148602, 'f1_mgmt': 0.448688611160007}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 10/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24902727501807065), 'rmse2': np.float64(0.2439925530751897), 'f1_rec': 0.4718616764825441, 'f1_mgmt': 0.37370020160717843}
# Epoch 1 validation metrics {'rmse1': np.float64(0.26104609288869013), 'rmse2': np.float64(0.2844242791401654), 'f1_rec': 0.5551839464882944, 'f1_mgmt': 0.4267189713413969}
# Epoch 27 training metrics {'rmse1': np.float64(0.05091235407153544), 'rmse2': np.float64(0.060994681216051436), 'f1_rec': 0.935014985014985, 'f1_mgmt': 0.9393231996940788}
# Epoch 27 validation metrics {'rmse1': np.float64(0.24681266413369288), 'rmse2': np.float64(0.23975517345608768), 'f1_rec': 0.6314699792960663, 'f1_mgmt': 0.5908584169453736}
# Epoch 55 training metrics {'rmse1': np.float64(0.0350393706331102), 'rmse2': np.float64(0.04472898314447129), 'f1_rec': 0.9457521288507205, 'f1_mgmt': 1.0}
# Epoch 55 validation metrics {'rmse1': np.float64(0.24258990783641635), 'rmse2': np.float64(0.24496794266648825), 'f1_rec': 0.5753593791339624, 'f1_mgmt': 0.5130828251032855}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 11/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23547710319461146), 'rmse2': np.float64(0.22488452663712427), 'f1_rec': 0.4669183844953458, 'f1_mgmt': 0.3558534900935847}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22245764585947977), 'rmse2': np.float64(0.2977854127085284), 'f1_rec': 0.24464238469000793, 'f1_mgmt': 0.4226843100189036}
# Epoch 27 training metrics {'rmse1': np.float64(0.04954055063073654), 'rmse2': np.float64(0.07108699108637724), 'f1_rec': 0.8927182208915955, 'f1_mgmt': 0.8960499908775771}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2218708820509838), 'rmse2': np.float64(0.2568667811551135), 'f1_rec': 0.5701581027667985, 'f1_mgmt': 0.6434782608695653}
# Epoch 55 training metrics {'rmse1': np.float64(0.05292177283840081), 'rmse2': np.float64(0.06031836179798676), 'f1_rec': 0.9036104334295947, 'f1_mgmt': 0.9371938661264321}
# Epoch 55 validation metrics {'rmse1': np.float64(0.22051674699901125), 'rmse2': np.float64(0.26380388822030476), 'f1_rec': 0.47035573122529645, 'f1_mgmt': 0.5454545454545454}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 12/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2633146257578905), 'rmse2': np.float64(0.2563695525953911), 'f1_rec': 0.4969545957918052, 'f1_mgmt': 0.3232708468002585}
# Epoch 1 validation metrics {'rmse1': np.float64(0.1576022635810277), 'rmse2': np.float64(0.20107367048066563), 'f1_rec': 0.5826863354037267, 'f1_mgmt': 0.4549689440993788}
# Epoch 27 training metrics {'rmse1': np.float64(0.08251165789882922), 'rmse2': np.float64(0.06007164607373338), 'f1_rec': 0.9451359749995611, 'f1_mgmt': 0.9377839800052951}
# Epoch 27 validation metrics {'rmse1': np.float64(0.15452097530873418), 'rmse2': np.float64(0.17557985129473894), 'f1_rec': 0.7391304347826086, 'f1_mgmt': 0.4725063938618926}
# Epoch 55 training metrics {'rmse1': np.float64(0.046766191522005666), 'rmse2': np.float64(0.0461223856874288), 'f1_rec': 0.978021978021978, 'f1_mgmt': 0.9404595404595406}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1547353557397169), 'rmse2': np.float64(0.17308161434852556), 'f1_rec': 0.7027465288334852, 'f1_mgmt': 0.6428571428571428}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 13/30
# Epoch 1 training metrics {'rmse1': np.float64(0.22457394673632936), 'rmse2': np.float64(0.26147992119138674), 'f1_rec': 0.5105993920053155, 'f1_mgmt': 0.3068304244774833}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2699803131101051), 'rmse2': np.float64(0.15303859218988813), 'f1_rec': 0.6420289855072463, 'f1_mgmt': 0.49809305873379095}
# Epoch 27 training metrics {'rmse1': np.float64(0.05835481631231096), 'rmse2': np.float64(0.04815702900898198), 'f1_rec': 0.9453835883742425, 'f1_mgmt': 0.967098734488015}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2663186521335582), 'rmse2': np.float64(0.15259871734687863), 'f1_rec': 0.6420289855072463, 'f1_mgmt': 0.48}
# Epoch 55 training metrics {'rmse1': np.float64(0.04607093421854576), 'rmse2': np.float64(0.04292117475649575), 'f1_rec': 0.9453835883742425, 'f1_mgmt': 0.9565967231963206}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2593218781478975), 'rmse2': np.float64(0.15152253770132973), 'f1_rec': 0.6420289855072463, 'f1_mgmt': 0.47845760377729685}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 14/30
# Epoch 1 training metrics {'rmse1': np.float64(0.25695755312718754), 'rmse2': np.float64(0.25675496957086064), 'f1_rec': 0.5421945701357467, 'f1_mgmt': 0.3738777562306974}
# Epoch 1 validation metrics {'rmse1': np.float64(0.23930699300783617), 'rmse2': np.float64(0.21775312323380508), 'f1_rec': 0.6521739130434783, 'f1_mgmt': 0.544927536231884}
# Epoch 27 training metrics {'rmse1': np.float64(0.04806948783779037), 'rmse2': np.float64(0.0460913530338596), 'f1_rec': 0.9237351085535904, 'f1_mgmt': 0.9890276046977077}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18118880524250924), 'rmse2': np.float64(0.17151760743844194), 'f1_rec': 0.6590752242926157, 'f1_mgmt': 0.6356821589205397}
# Epoch 55 training metrics {'rmse1': np.float64(0.04067812990055472), 'rmse2': np.float64(0.05337859426000548), 'f1_rec': 0.9344885883347422, 'f1_mgmt': 0.9670828140931235}
# Epoch 55 validation metrics {'rmse1': np.float64(0.17868723386983168), 'rmse2': np.float64(0.17701350458933227), 'f1_rec': 0.6590752242926157, 'f1_mgmt': 0.6724637681159421}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 15/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23883563905995517), 'rmse2': np.float64(0.21402781725639178), 'f1_rec': 0.5149750090145814, 'f1_mgmt': 0.40288946933465203}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20738426072968497), 'rmse2': np.float64(0.28475384836035095), 'f1_rec': 0.5217391304347826, 'f1_mgmt': 0.35579382254574066}
# Epoch 27 training metrics {'rmse1': np.float64(0.04755796226393647), 'rmse2': np.float64(0.04562443845564982), 'f1_rec': 0.9242950087489488, 'f1_mgmt': 0.9485066215835446}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18351463003399163), 'rmse2': np.float64(0.2513967554704076), 'f1_rec': 0.4762845849802371, 'f1_mgmt': 0.4458498023715415}
# Epoch 55 training metrics {'rmse1': np.float64(0.03887651782181193), 'rmse2': np.float64(0.038910210248071654), 'f1_rec': 0.9457521288507205, 'f1_mgmt': 0.978021978021978}
# Epoch 55 validation metrics {'rmse1': np.float64(0.18938336355412394), 'rmse2': np.float64(0.2535045188688818), 'f1_rec': 0.5393374741200828, 'f1_mgmt': 0.5492352637910294}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 16/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24068280997274302), 'rmse2': np.float64(0.2544410780293824), 'f1_rec': 0.607869203966765, 'f1_mgmt': 0.42259951430683135}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2121544347729856), 'rmse2': np.float64(0.22989972793433436), 'f1_rec': 0.4480040681413679, 'f1_mgmt': 0.4507093821510298}
# Epoch 27 training metrics {'rmse1': np.float64(0.051256690221286205), 'rmse2': np.float64(0.06008730157692923), 'f1_rec': 0.9128598231037255, 'f1_mgmt': 0.9456047711686809}
# Epoch 27 validation metrics {'rmse1': np.float64(0.17866935799133485), 'rmse2': np.float64(0.18796134941055348), 'f1_rec': 0.5738440303657696, 'f1_mgmt': 0.5210350290441824}
# Epoch 55 training metrics {'rmse1': np.float64(0.0470173381156048), 'rmse2': np.float64(0.04699631161333908), 'f1_rec': 0.9453403739118025, 'f1_mgmt': 0.933758217320115}
# Epoch 55 validation metrics {'rmse1': np.float64(0.17509457538239898), 'rmse2': np.float64(0.18359160444080483), 'f1_rec': 0.5329265191965421, 'f1_mgmt': 0.5210350290441824}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 17/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23330995075984504), 'rmse2': np.float64(0.2466099500492938), 'f1_rec': 0.48248222365869425, 'f1_mgmt': 0.3078280775601847}
# Epoch 1 validation metrics {'rmse1': np.float64(0.18311940900286228), 'rmse2': np.float64(0.15986719675054475), 'f1_rec': 0.38663021430461236, 'f1_mgmt': 0.4450936587042447}
# Epoch 27 training metrics {'rmse1': np.float64(0.05324373117380587), 'rmse2': np.float64(0.06179829683479408), 'f1_rec': 0.9130298273155416, 'f1_mgmt': 0.9367747098839537}
# Epoch 27 validation metrics {'rmse1': np.float64(0.17383499020137727), 'rmse2': np.float64(0.15354247096384419), 'f1_rec': 0.48099479671928735, 'f1_mgmt': 0.6151368760064412}
# Epoch 55 training metrics {'rmse1': np.float64(0.048194324938142276), 'rmse2': np.float64(0.07426698202982368), 'f1_rec': 0.9240529803910085, 'f1_mgmt': 0.9778859112585528}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1731977788142684), 'rmse2': np.float64(0.15456932757556818), 'f1_rec': 0.48099479671928735, 'f1_mgmt': 0.5907046476761619}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 18/30
# Epoch 1 training metrics {'rmse1': np.float64(0.262318968218127), 'rmse2': np.float64(0.22010697035967716), 'f1_rec': 0.585968453315392, 'f1_mgmt': 0.3531400725970862}
# Epoch 1 validation metrics {'rmse1': np.float64(0.23663292876979453), 'rmse2': np.float64(0.2364001587535982), 'f1_rec': 0.4480040681413679, 'f1_mgmt': 0.4407114624505929}
# Epoch 27 training metrics {'rmse1': np.float64(0.04362981444508235), 'rmse2': np.float64(0.05009722714681317), 'f1_rec': 0.9563257255564948, 'f1_mgmt': 0.9890287490287492}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18381323385553885), 'rmse2': np.float64(0.22237624800188038), 'f1_rec': 0.4572981366459627, 'f1_mgmt': 0.4435782108945527}
# Epoch 55 training metrics {'rmse1': np.float64(0.05301749708307336), 'rmse2': np.float64(0.037957322829116104), 'f1_rec': 0.9453403739118025, 'f1_mgmt': 0.967086247086247}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1902684101847083), 'rmse2': np.float64(0.22065969864071439), 'f1_rec': 0.421994884910486, 'f1_mgmt': 0.4503105590062112}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 19/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2423908038872809), 'rmse2': np.float64(0.23183276109834286), 'f1_rec': 0.4429126014172743, 'f1_mgmt': 0.3557249527029747}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20322891435168353), 'rmse2': np.float64(0.24759210036423912), 'f1_rec': 0.613167701863354, 'f1_mgmt': 0.4597547380156076}
# Epoch 27 training metrics {'rmse1': np.float64(0.05077655557714415), 'rmse2': np.float64(0.048546428089732384), 'f1_rec': 0.9671075437067645, 'f1_mgmt': 0.942638652508282}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18299751261604227), 'rmse2': np.float64(0.20352527003754697), 'f1_rec': 0.43918976184422404, 'f1_mgmt': 0.5454545454545454}
# Epoch 55 training metrics {'rmse1': np.float64(0.044698940277847724), 'rmse2': np.float64(0.07354955657336698), 'f1_rec': 0.9453835883742425, 'f1_mgmt': 0.9785780775879785}
# Epoch 55 validation metrics {'rmse1': np.float64(0.18130036845228664), 'rmse2': np.float64(0.2214265293695188), 'f1_rec': 0.46304347826086956, 'f1_mgmt': 0.4157437070938216}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 20/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2514897775208253), 'rmse2': np.float64(0.24744423870203894), 'f1_rec': 0.4542872093892502, 'f1_mgmt': 0.3545787545787546}
# Epoch 1 validation metrics {'rmse1': np.float64(0.17077850113789259), 'rmse2': np.float64(0.2529779618349547), 'f1_rec': 0.6154277699859748, 'f1_mgmt': 0.46476761619190404}
# Epoch 27 training metrics {'rmse1': np.float64(0.047544836900416734), 'rmse2': np.float64(0.05364768450944203), 'f1_rec': 0.945390753971612, 'f1_mgmt': 0.9579352977849218}
# Epoch 27 validation metrics {'rmse1': np.float64(0.15124406555519113), 'rmse2': np.float64(0.18679749145483784), 'f1_rec': 0.7250639386189258, 'f1_mgmt': 0.6230179028132993}
# Epoch 55 training metrics {'rmse1': np.float64(0.05951938297201341), 'rmse2': np.float64(0.052676031576682776), 'f1_rec': 0.945298034888793, 'f1_mgmt': 0.9580128205128204}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1516992636719449), 'rmse2': np.float64(0.18886765347530446), 'f1_rec': 0.7014492753623188, 'f1_mgmt': 0.6230179028132993}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 21/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24391034007438822), 'rmse2': np.float64(0.24438874700564403), 'f1_rec': 0.41459276018099545, 'f1_mgmt': 0.36968325791855206}
# Epoch 1 validation metrics {'rmse1': np.float64(0.1664958048674384), 'rmse2': np.float64(0.21528909836855517), 'f1_rec': 0.7339544513457557, 'f1_mgmt': 0.48067632850241543}
# Epoch 27 training metrics {'rmse1': np.float64(0.0766477240334526), 'rmse2': np.float64(0.07067959769031398), 'f1_rec': 0.9451943818141001, 'f1_mgmt': 0.962831286360698}
# Epoch 27 validation metrics {'rmse1': np.float64(0.1519919408439205), 'rmse2': np.float64(0.16270349098626213), 'f1_rec': 0.6318840579710144, 'f1_mgmt': 0.5742491073303928}
# Epoch 55 training metrics {'rmse1': np.float64(0.04925177511020919), 'rmse2': np.float64(0.05821724821662855), 'f1_rec': 0.9343822843822844, 'f1_mgmt': 0.9466945605400651}
# Epoch 55 validation metrics {'rmse1': np.float64(0.14747887086876596), 'rmse2': np.float64(0.16695271094988132), 'f1_rec': 0.6845400828997266, 'f1_mgmt': 0.5358602749907098}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 22/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2471423416711442), 'rmse2': np.float64(0.2609521450946503), 'f1_rec': 0.5652640042883945, 'f1_mgmt': 0.4280957915094298}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22535238268530042), 'rmse2': np.float64(0.26395526589973617), 'f1_rec': 0.3959156785243742, 'f1_mgmt': 0.42134387351778657}
# Epoch 27 training metrics {'rmse1': np.float64(0.04213201589194642), 'rmse2': np.float64(0.04259636043603475), 'f1_rec': 0.9563713347228741, 'f1_mgmt': 0.9890296118230025}
# Epoch 27 validation metrics {'rmse1': np.float64(0.19575307497135008), 'rmse2': np.float64(0.233223460719809), 'f1_rec': 0.40561009817671806, 'f1_mgmt': 0.4756371814092954}
# Epoch 55 training metrics {'rmse1': np.float64(0.0569835787477825), 'rmse2': np.float64(0.03923697074536346), 'f1_rec': 0.9345570020843108, 'f1_mgmt': 0.9572552744638391}
# Epoch 55 validation metrics {'rmse1': np.float64(0.19790481485340614), 'rmse2': np.float64(0.23119062968259155), 'f1_rec': 0.3735507246376812, 'f1_mgmt': 0.5101449275362319}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 23/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24152469912402835), 'rmse2': np.float64(0.24151626489997027), 'f1_rec': 0.5351379602332041, 'f1_mgmt': 0.40684018362589786}
# Epoch 1 validation metrics {'rmse1': np.float64(0.19181771380939416), 'rmse2': np.float64(0.2297766574782352), 'f1_rec': 0.5105517416730231, 'f1_mgmt': 0.5260869565217391}
# Epoch 27 training metrics {'rmse1': np.float64(0.0496167176580737), 'rmse2': np.float64(0.05881395183901569), 'f1_rec': 0.923946984271227, 'f1_mgmt': 0.9563834224028399}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18055479015144163), 'rmse2': np.float64(0.20026328752192937), 'f1_rec': 0.5848840285739484, 'f1_mgmt': 0.5921325051759834}
# Epoch 55 training metrics {'rmse1': np.float64(0.043239679225838754), 'rmse2': np.float64(0.048157479123455624), 'f1_rec': 0.9672839531994462, 'f1_mgmt': 0.9890372748118633}
# Epoch 55 validation metrics {'rmse1': np.float64(0.180392564042715), 'rmse2': np.float64(0.20097635283418722), 'f1_rec': 0.5848840285739484, 'f1_mgmt': 0.5314009661835748}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 24/30
# Epoch 1 training metrics {'rmse1': np.float64(0.21903601711536594), 'rmse2': np.float64(0.2627056772264703), 'f1_rec': 0.4792899408284023, 'f1_mgmt': 0.3328088033970387}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2575016082223933), 'rmse2': np.float64(0.2395560760472733), 'f1_rec': 0.47430830039525695, 'f1_mgmt': 0.4751552795031056}
# Epoch 27 training metrics {'rmse1': np.float64(0.04529625130432188), 'rmse2': np.float64(0.04753721493360525), 'f1_rec': 0.9343822843822844, 'f1_mgmt': 0.9704592482021807}
# Epoch 27 validation metrics {'rmse1': np.float64(0.24278014489112765), 'rmse2': np.float64(0.2303382093410745), 'f1_rec': 0.645272601794341, 'f1_mgmt': 0.6759373349762366}
# Epoch 55 training metrics {'rmse1': np.float64(0.03263595075508533), 'rmse2': np.float64(0.04771391093566874), 'f1_rec': 0.9564179564179562, 'f1_mgmt': 0.946067068282945}
# Epoch 55 validation metrics {'rmse1': np.float64(0.24693531439602331), 'rmse2': np.float64(0.23221512875604822), 'f1_rec': 0.645272601794341, 'f1_mgmt': 0.6280193236714976}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 25/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2598377144457737), 'rmse2': np.float64(0.2625572084361519), 'f1_rec': 0.5470552287831334, 'f1_mgmt': 0.42814659962871926}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20934785175508475), 'rmse2': np.float64(0.17472791340908372), 'f1_rec': 0.43478260869565216, 'f1_mgmt': 0.4774703557312253}
# Epoch 27 training metrics {'rmse1': np.float64(0.050875594256649836), 'rmse2': np.float64(0.0617983239945576), 'f1_rec': 0.935014985014985, 'f1_mgmt': 0.9504362395845911}
# Epoch 27 validation metrics {'rmse1': np.float64(0.18823859653661418), 'rmse2': np.float64(0.1691359876986574), 'f1_rec': 0.6508563899868247, 'f1_mgmt': 0.591304347826087}
# Epoch 55 training metrics {'rmse1': np.float64(0.04920553545348178), 'rmse2': np.float64(0.05721676339871769), 'f1_rec': 0.9240529803910085, 'f1_mgmt': 0.9346882673401365}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1861170268956264), 'rmse2': np.float64(0.1593034516993849), 'f1_rec': 0.6441471571906354, 'f1_mgmt': 0.5421580707621898}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 26/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23064996249418473), 'rmse2': np.float64(0.26136245989479834), 'f1_rec': 0.531612965347905, 'f1_mgmt': 0.3751257579465427}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22093845105187904), 'rmse2': np.float64(0.1776130871176317), 'f1_rec': 0.6086956521739131, 'f1_mgmt': 0.26705845641772413}
# Epoch 27 training metrics {'rmse1': np.float64(0.048323981085095474), 'rmse2': np.float64(0.0402469643497616), 'f1_rec': 0.9344885883347422, 'f1_mgmt': 0.9370022689860745}
# Epoch 27 validation metrics {'rmse1': np.float64(0.19934529401786152), 'rmse2': np.float64(0.1864972112406895), 'f1_rec': 0.660200668896321, 'f1_mgmt': 0.644122383252818}
# Epoch 55 training metrics {'rmse1': np.float64(0.04553796954324855), 'rmse2': np.float64(0.05699948092561755), 'f1_rec': 0.9236441326892353, 'f1_mgmt': 0.9673066659368029}
# Epoch 55 validation metrics {'rmse1': np.float64(0.20314083229036733), 'rmse2': np.float64(0.18510086611286894), 'f1_rec': 0.660200668896321, 'f1_mgmt': 0.6044710438303116}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 27/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23962332538615538), 'rmse2': np.float64(0.2492281058921125), 'f1_rec': 0.5190907132083602, 'f1_mgmt': 0.3630556607825914}
# Epoch 1 validation metrics {'rmse1': np.float64(0.1525681967589898), 'rmse2': np.float64(0.1964544729369161), 'f1_rec': 0.5824706694271912, 'f1_mgmt': 0.5033444816053512}
# Epoch 27 training metrics {'rmse1': np.float64(0.07960141173166801), 'rmse2': np.float64(0.09409666375612284), 'f1_rec': 0.8908335566872152, 'f1_mgmt': 0.9224353309085965}
# Epoch 27 validation metrics {'rmse1': np.float64(0.16101869505080835), 'rmse2': np.float64(0.1860321403379974), 'f1_rec': 0.5802675585284282, 'f1_mgmt': 0.5962732919254659}
# Epoch 55 training metrics {'rmse1': np.float64(0.03995456024397224), 'rmse2': np.float64(0.041880451391572975), 'f1_rec': 0.9562809739280328, 'f1_mgmt': 0.9673126873126873}
# Epoch 55 validation metrics {'rmse1': np.float64(0.163844783532607), 'rmse2': np.float64(0.1883987984758156), 'f1_rec': 0.5802675585284282, 'f1_mgmt': 0.5639055472263869}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 28/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2531210669653283), 'rmse2': np.float64(0.22991716210405713), 'f1_rec': 0.5337442451858084, 'f1_mgmt': 0.4045845353200748}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2105834988165216), 'rmse2': np.float64(0.16900895869144833), 'f1_rec': 0.38669301712779974, 'f1_mgmt': 0.3898550724637682}
# Epoch 27 training metrics {'rmse1': np.float64(0.04909826650054313), 'rmse2': np.float64(0.046221313869316945), 'f1_rec': 0.9346269346269346, 'f1_mgmt': 0.9797194482945666}
# Epoch 27 validation metrics {'rmse1': np.float64(0.17691546155639729), 'rmse2': np.float64(0.16417746928525762), 'f1_rec': 0.5042772731281417, 'f1_mgmt': 0.3799171842650103}
# Epoch 55 training metrics {'rmse1': np.float64(0.05502896658952468), 'rmse2': np.float64(0.056335724262506576), 'f1_rec': 0.9564179564179562, 'f1_mgmt': 0.978021978021978}
# Epoch 55 validation metrics {'rmse1': np.float64(0.17541111109569502), 'rmse2': np.float64(0.16475220548932018), 'f1_rec': 0.46790890269151136, 'f1_mgmt': 0.4265010351966874}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 29/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2529205148391497), 'rmse2': np.float64(0.2532355148400283), 'f1_rec': 0.49105914166155135, 'f1_mgmt': 0.40354462610560166}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2029083206224063), 'rmse2': np.float64(0.20172166393334837), 'f1_rec': 0.5030934824985167, 'f1_mgmt': 0.45913043478260873}
# Epoch 27 training metrics {'rmse1': np.float64(0.0444502341568669), 'rmse2': np.float64(0.060294739561987144), 'f1_rec': 0.9454732553324102, 'f1_mgmt': 0.9560439560439561}
# Epoch 27 validation metrics {'rmse1': np.float64(0.19205284403985445), 'rmse2': np.float64(0.19310932971291664), 'f1_rec': 0.6885329265191965, 'f1_mgmt': 0.4761994002998501}
# Epoch 55 training metrics {'rmse1': np.float64(0.04903755964934685), 'rmse2': np.float64(0.045006780675368986), 'f1_rec': 0.9022175512058633, 'f1_mgmt': 0.9671118244355897}
# Epoch 55 validation metrics {'rmse1': np.float64(0.19258473814978808), 'rmse2': np.float64(0.19629809940304108), 'f1_rec': 0.5271739130434783, 'f1_mgmt': 0.5845410628019324}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.25498499782811695), 'rmse2': np.float64(0.2455345092804843), 'f1_rec': 0.5633342267488609, 'f1_mgmt': 0.38402505069171733}
# Epoch 1 validation metrics {'rmse1': np.float64(0.15842978866074328), 'rmse2': np.float64(0.17507943370500115), 'f1_rec': 0.5802675585284282, 'f1_mgmt': 0.4039855072463768}
# Epoch 27 training metrics {'rmse1': np.float64(0.06059841233012079), 'rmse2': np.float64(0.07672153956949485), 'f1_rec': 0.934500134012329, 'f1_mgmt': 0.9601963672066766}
# Epoch 27 validation metrics {'rmse1': np.float64(0.16467190142018792), 'rmse2': np.float64(0.16663997546991424), 'f1_rec': 0.7467391304347827, 'f1_mgmt': 0.5057760974585171}
# Epoch 55 training metrics {'rmse1': np.float64(0.06506552265456865), 'rmse2': np.float64(0.04905751516405975), 'f1_rec': 0.945390753971612, 'f1_mgmt': 0.9578605917891632}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1666089550594581), 'rmse2': np.float64(0.16752881640798656), 'f1_rec': 0.7467391304347827, 'f1_mgmt': 0.5579710144927535}

# %% [markdown]
# ### **UMAP**

# %%
in_size = X_umap.shape[1]
norm_fn = nn.BatchNorm1d
dropout = 0.2
layers = [in_size,1024,512,128]
act_fn = [nn.GELU] * (len(layers) - 1) + [None]
reg_head_cfg = {"layers": layers + [1],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
binary_clf_head_cfg = {"layers": layers + [2],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}
multi_clf_head_cfg = {"layers": layers + [3],
        "dropout": dropout,
        # NO ACTIVATION FOR THE LAST LAYER ! (no need for regression and already in the loss module for classification)
        "act_fn": act_fn,
        "norm_layer":norm_fn,
        "device":device}

# %%
os_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
pfs_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": reg_head_cfg}
recurrency_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": binary_clf_head_cfg}
mgmt_head_cfg = {"net_type": "mlp",
            "device": device,
            "net_config": multi_clf_head_cfg}

# %%
predictive_cfg = {"heads_configs":{"os": os_head_cfg,
                  "pfs": pfs_head_cfg,
                  "recurrency":recurrency_head_cfg,
                  "mgmt":mgmt_head_cfg}}

# %%
history = fit(PredictiveModule, predictive_cfg, X_umap, Y, device, get_mccv_loaders, num_epochs=55, batch_size=32, dr='umap')
# Out:
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 1/30
# Epoch 1 training metrics {'rmse1': np.float64(0.251778220587767), 'rmse2': np.float64(0.2671386703548248), 'f1_rec': 0.4545425504727831, 'f1_mgmt': 0.34385506385506387}
# Epoch 1 validation metrics {'rmse1': np.float64(0.25638230873448314), 'rmse2': np.float64(0.20919709615386264), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.617056856187291}
# Epoch 27 training metrics {'rmse1': np.float64(0.20435123866071306), 'rmse2': np.float64(0.18556271910656866), 'f1_rec': 0.5533056358138866, 'f1_mgmt': 0.5378993350552683}
# Epoch 27 validation metrics {'rmse1': np.float64(0.28178505059835945), 'rmse2': np.float64(0.3660354113995568), 'f1_rec': 0.26702898550724635, 'f1_mgmt': 0.6857142857142857}
# Epoch 55 training metrics {'rmse1': np.float64(0.20544994588418058), 'rmse2': np.float64(0.19971086856141337), 'f1_rec': 0.5704590746692042, 'f1_mgmt': 0.5370068214433151}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3009528817944998), 'rmse2': np.float64(0.5481807119389989), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.7245203309276537}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 2/30
# Epoch 1 training metrics {'rmse1': np.float64(0.26924894213913086), 'rmse2': np.float64(0.2445642010428245), 'f1_rec': 0.5554305593632127, 'f1_mgmt': 0.3447808690715803}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21082666651946175), 'rmse2': np.float64(0.1937292061089645), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.2635046113306983}
# Epoch 27 training metrics {'rmse1': np.float64(0.2182651728350588), 'rmse2': np.float64(0.1973500490830785), 'f1_rec': 0.5525081930762463, 'f1_mgmt': 0.5351643661502817}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3268311860345447), 'rmse2': np.float64(0.2504734138675969), 'f1_rec': 0.6956521739130435, 'f1_mgmt': 0.49247491638795987}
# Epoch 55 training metrics {'rmse1': np.float64(0.216888876505864), 'rmse2': np.float64(0.18391413513470237), 'f1_rec': 0.5824175824175825, 'f1_mgmt': 0.514972376358515}
# Epoch 55 validation metrics {'rmse1': np.float64(0.29709067465027206), 'rmse2': np.float64(0.384814008248246), 'f1_rec': 0.6012422360248447, 'f1_mgmt': 0.2635046113306983}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 3/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2546479382621008), 'rmse2': np.float64(0.2341807472176987), 'f1_rec': 0.49880391717126404, 'f1_mgmt': 0.4389323283554053}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21441131616869985), 'rmse2': np.float64(0.24472200647618522), 'f1_rec': 0.5148741418764302, 'f1_mgmt': 0.3171355498721228}
# Epoch 27 training metrics {'rmse1': np.float64(0.22939344542417972), 'rmse2': np.float64(0.20622932706484579), 'f1_rec': 0.6287686672302056, 'f1_mgmt': 0.5660737809155038}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2154674899398802), 'rmse2': np.float64(0.3031506857938885), 'f1_rec': 0.5752508361204014, 'f1_mgmt': 0.32173913043478264}
# Epoch 55 training metrics {'rmse1': np.float64(0.2071418348224271), 'rmse2': np.float64(0.19154452154392285), 'f1_rec': 0.585968453315392, 'f1_mgmt': 0.5696668410954125}
# Epoch 55 validation metrics {'rmse1': np.float64(0.31044611810149797), 'rmse2': np.float64(0.36280406912823077), 'f1_rec': 0.5477484472049688, 'f1_mgmt': 0.3861892583120205}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 4/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2397375341135458), 'rmse2': np.float64(0.25117256209179895), 'f1_rec': 0.5343732572648235, 'f1_mgmt': 0.4062904479571146}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21899464355576673), 'rmse2': np.float64(0.21702744519927405), 'f1_rec': 0.3081400476232472, 'f1_mgmt': 0.29891304347826086}
# Epoch 27 training metrics {'rmse1': np.float64(0.19869918158789696), 'rmse2': np.float64(0.18030418215670532), 'f1_rec': 0.6401234851939077, 'f1_mgmt': 0.5435897435897437}
# Epoch 27 validation metrics {'rmse1': np.float64(0.4020536060119004), 'rmse2': np.float64(0.3009244985887993), 'f1_rec': 0.3550724637681159, 'f1_mgmt': 0.4669187145557656}
# Epoch 55 training metrics {'rmse1': np.float64(0.19391490371607142), 'rmse2': np.float64(0.18283207397061346), 'f1_rec': 0.6603018630721594, 'f1_mgmt': 0.6004077266213189}
# Epoch 55 validation metrics {'rmse1': np.float64(0.6252756920504985), 'rmse2': np.float64(0.416892515699377), 'f1_rec': 0.34726507713884996, 'f1_mgmt': 0.3460228411140052}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 5/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24316718440705654), 'rmse2': np.float64(0.2470442380336583), 'f1_rec': 0.48538847886437586, 'f1_mgmt': 0.3184803001876173}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21341025042846212), 'rmse2': np.float64(0.20950747933395877), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.0}
# Epoch 27 training metrics {'rmse1': np.float64(0.21585015122958337), 'rmse2': np.float64(0.20466342519166172), 'f1_rec': 0.6404655117526404, 'f1_mgmt': 0.5989160866411276}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2719801551190607), 'rmse2': np.float64(0.3553406784952244), 'f1_rec': 0.43478260869565216, 'f1_mgmt': 0.4161490683229814}
# Epoch 55 training metrics {'rmse1': np.float64(0.22074691900352297), 'rmse2': np.float64(0.18905759816652742), 'f1_rec': 0.6124564434423589, 'f1_mgmt': 0.5796414112203586}
# Epoch 55 validation metrics {'rmse1': np.float64(0.42089200945705574), 'rmse2': np.float64(0.4363286229549823), 'f1_rec': 0.5217391304347826, 'f1_mgmt': 0.16231884057971016}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 6/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2572836671451678), 'rmse2': np.float64(0.2639727231930801), 'f1_rec': 0.4334305150631681, 'f1_mgmt': 0.4131082110176187}
# Epoch 1 validation metrics {'rmse1': np.float64(0.215962664907369), 'rmse2': np.float64(0.1927923265265923), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.4606345475910693}
# Epoch 27 training metrics {'rmse1': np.float64(0.20925285877361077), 'rmse2': np.float64(0.1884874378635987), 'f1_rec': 0.6287686672302056, 'f1_mgmt': 0.6025388916077176}
# Epoch 27 validation metrics {'rmse1': np.float64(0.28063711015212894), 'rmse2': np.float64(0.3443585313115948), 'f1_rec': 0.49030100334448157, 'f1_mgmt': 0.43685300207039335}
# Epoch 55 training metrics {'rmse1': np.float64(0.19755552985045058), 'rmse2': np.float64(0.1873606943337257), 'f1_rec': 0.6182206634461765, 'f1_mgmt': 0.6425993898436861}
# Epoch 55 validation metrics {'rmse1': np.float64(0.30304670019354357), 'rmse2': np.float64(0.6111851644399666), 'f1_rec': 0.4455486542443064, 'f1_mgmt': 0.40579710144927533}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 7/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23870028521220704), 'rmse2': np.float64(0.26344682080642784), 'f1_rec': 0.4436289663149917, 'f1_mgmt': 0.3307276057276057}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21230980393290727), 'rmse2': np.float64(0.1733508020734322), 'f1_rec': 0.4606345475910693, 'f1_mgmt': 0.01391304347826087}
# Epoch 27 training metrics {'rmse1': np.float64(0.2175390209105455), 'rmse2': np.float64(0.20254613729839205), 'f1_rec': 0.6395316832700011, 'f1_mgmt': 0.584552590266876}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2796538389462911), 'rmse2': np.float64(0.318442719651908), 'f1_rec': 0.4822134387351778, 'f1_mgmt': 0.5124223602484472}
# Epoch 55 training metrics {'rmse1': np.float64(0.2047279198322159), 'rmse2': np.float64(0.2150949082859016), 'f1_rec': 0.5424335560610707, 'f1_mgmt': 0.5935238541945859}
# Epoch 55 validation metrics {'rmse1': np.float64(0.29105629148437134), 'rmse2': np.float64(0.2739701384812831), 'f1_rec': 0.5220841959972394, 'f1_mgmt': 0.45260599513907634}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 8/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2662987256057109), 'rmse2': np.float64(0.25828526429537596), 'f1_rec': 0.4348432055749129, 'f1_mgmt': 0.2769611341039912}
# Epoch 1 validation metrics {'rmse1': np.float64(0.1893058625143113), 'rmse2': np.float64(0.2085509131544132), 'f1_rec': 0.22010869565217392, 'f1_mgmt': 0.003623188405797101}
# Epoch 27 training metrics {'rmse1': np.float64(0.220097263059727), 'rmse2': np.float64(0.19675569490888786), 'f1_rec': 0.5483071680254779, 'f1_mgmt': 0.5229690943976657}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2557129946043071), 'rmse2': np.float64(0.23773638966003527), 'f1_rec': 0.5959079283887467, 'f1_mgmt': 0.6004140786749482}
# Epoch 55 training metrics {'rmse1': np.float64(0.193738655372123), 'rmse2': np.float64(0.19118948085166262), 'f1_rec': 0.5285414597969581, 'f1_mgmt': 0.5899630323593457}
# Epoch 55 validation metrics {'rmse1': np.float64(0.28132896420543285), 'rmse2': np.float64(0.513080071238508), 'f1_rec': 0.5884992987377279, 'f1_mgmt': 0.45483508245877063}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 9/30
# Epoch 1 training metrics {'rmse1': np.float64(0.25759743819931646), 'rmse2': np.float64(0.25937237853770095), 'f1_rec': 0.5229257176931595, 'f1_mgmt': 0.4659026125931314}
# Epoch 1 validation metrics {'rmse1': np.float64(0.18391832990162268), 'rmse2': np.float64(0.16818573516422197), 'f1_rec': 0.46790890269151136, 'f1_mgmt': 0.39641943734015345}
# Epoch 27 training metrics {'rmse1': np.float64(0.22677624771733984), 'rmse2': np.float64(0.20001222146075154), 'f1_rec': 0.624042624042624, 'f1_mgmt': 0.6146661940210327}
# Epoch 27 validation metrics {'rmse1': np.float64(0.32585422946150727), 'rmse2': np.float64(0.27112770455831553), 'f1_rec': 0.4303754555470803, 'f1_mgmt': 0.3130434782608696}
# Epoch 55 training metrics {'rmse1': np.float64(0.21796538521541511), 'rmse2': np.float64(0.1961187602331864), 'f1_rec': 0.6742421665022285, 'f1_mgmt': 0.6703596403596404}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2860117762574757), 'rmse2': np.float64(0.33088341284861544), 'f1_rec': 0.4303754555470803, 'f1_mgmt': 0.5129232618713685}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 10/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24359174596203617), 'rmse2': np.float64(0.2433857206550252), 'f1_rec': 0.4393557422969187, 'f1_mgmt': 0.3410104310491574}
# Epoch 1 validation metrics {'rmse1': np.float64(0.23346071902584944), 'rmse2': np.float64(0.25745529941369666), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.003623188405797101}
# Epoch 27 training metrics {'rmse1': np.float64(0.20217548466250168), 'rmse2': np.float64(0.21617985063815956), 'f1_rec': 0.5884282384282384, 'f1_mgmt': 0.5250990506092547}
# Epoch 27 validation metrics {'rmse1': np.float64(0.28178423208653736), 'rmse2': np.float64(0.23428825210464693), 'f1_rec': 0.5848840285739484, 'f1_mgmt': 0.5565217391304348}
# Epoch 55 training metrics {'rmse1': np.float64(0.2162073782529203), 'rmse2': np.float64(0.19208573341378138), 'f1_rec': 0.5920165304780689, 'f1_mgmt': 0.5953177257525084}
# Epoch 55 validation metrics {'rmse1': np.float64(0.31413564125315746), 'rmse2': np.float64(0.32531109850559725), 'f1_rec': 0.6217391304347826, 'f1_mgmt': 0.5565217391304348}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 11/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24503861295199966), 'rmse2': np.float64(0.25081589155156514), 'f1_rec': 0.562924925541748, 'f1_mgmt': 0.38579517557338194}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20995005086633167), 'rmse2': np.float64(0.2707091794329249), 'f1_rec': 0.4416615221800865, 'f1_mgmt': 0.391304347826087}
# Epoch 27 training metrics {'rmse1': np.float64(0.2283112805480207), 'rmse2': np.float64(0.1918146601704498), 'f1_rec': 0.666768403562693, 'f1_mgmt': 0.5191909539735626}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2436466001980533), 'rmse2': np.float64(0.38802437900792913), 'f1_rec': 0.16231884057971016, 'f1_mgmt': 0.5768115942028985}
# Epoch 55 training metrics {'rmse1': np.float64(0.199742879360814), 'rmse2': np.float64(0.18081546667205642), 'f1_rec': 0.666768403562693, 'f1_mgmt': 0.547602267826526}
# Epoch 55 validation metrics {'rmse1': np.float64(0.4210486927437464), 'rmse2': np.float64(0.4539960413133499), 'f1_rec': 0.47035573122529645, 'f1_mgmt': 0.6521739130434783}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 12/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2634209276696094), 'rmse2': np.float64(0.24656393055062573), 'f1_rec': 0.5408163265306122, 'f1_mgmt': 0.3590377190377191}
# Epoch 1 validation metrics {'rmse1': np.float64(0.15814969793114483), 'rmse2': np.float64(0.21641688322984687), 'f1_rec': 0.315527950310559, 'f1_mgmt': 0.10794602698650675}
# Epoch 27 training metrics {'rmse1': np.float64(0.22912474625807946), 'rmse2': np.float64(0.21275685204532313), 'f1_rec': 0.5953858724943062, 'f1_mgmt': 0.55317440035048}
# Epoch 27 validation metrics {'rmse1': np.float64(0.24515270859243987), 'rmse2': np.float64(0.3025178410446416), 'f1_rec': 0.6288920056100982, 'f1_mgmt': 0.34782608695652173}
# Epoch 55 training metrics {'rmse1': np.float64(0.21167230147226376), 'rmse2': np.float64(0.20719854819365238), 'f1_rec': 0.573000157158573, 'f1_mgmt': 0.5702396693296593}
# Epoch 55 validation metrics {'rmse1': np.float64(0.1702275764780364), 'rmse2': np.float64(0.2882681487544809), 'f1_rec': 0.5852842809364549, 'f1_mgmt': 0.3102974828375286}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 13/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23371290651569038), 'rmse2': np.float64(0.24054991959571345), 'f1_rec': 0.40225341215440225, 'f1_mgmt': 0.4411999990093296}
# Epoch 1 validation metrics {'rmse1': np.float64(0.27849061877993125), 'rmse2': np.float64(0.17875032541460553), 'f1_rec': 0.22010869565217392, 'f1_mgmt': 0.2028985507246377}
# Epoch 27 training metrics {'rmse1': np.float64(0.17698425458893885), 'rmse2': np.float64(0.1966545194530124), 'f1_rec': 0.6413520472926414, 'f1_mgmt': 0.5035675435675435}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3535808033068021), 'rmse2': np.float64(0.42021604904598464), 'f1_rec': 0.718167701863354, 'f1_mgmt': 0.5522329333071021}
# Epoch 55 training metrics {'rmse1': np.float64(0.17355982937152742), 'rmse2': np.float64(0.1848711407548463), 'f1_rec': 0.6162546765789194, 'f1_mgmt': 0.5120812922017741}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3933405551350495), 'rmse2': np.float64(0.548989268908518), 'f1_rec': 0.731521739130435, 'f1_mgmt': 0.5522329333071021}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 14/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23975319695070854), 'rmse2': np.float64(0.24596423312927385), 'f1_rec': 0.487324890913437, 'f1_mgmt': 0.321665988332655}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20665808100965768), 'rmse2': np.float64(0.2241039567679231), 'f1_rec': 0.6826086956521739, 'f1_mgmt': 0.17952314165497896}
# Epoch 27 training metrics {'rmse1': np.float64(0.2114483489420002), 'rmse2': np.float64(0.2082339444472897), 'f1_rec': 0.49638792190927244, 'f1_mgmt': 0.553077874506446}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2831377997829046), 'rmse2': np.float64(0.36944849458849127), 'f1_rec': 0.6019635343618515, 'f1_mgmt': 0.1947826086956522}
# Epoch 55 training metrics {'rmse1': np.float64(0.1975266331220462), 'rmse2': np.float64(0.18537722278450752), 'f1_rec': 0.5238750590863267, 'f1_mgmt': 0.5063398140321218}
# Epoch 55 validation metrics {'rmse1': np.float64(0.23700195047446856), 'rmse2': np.float64(0.2352679725454352), 'f1_rec': 0.6482213438735178, 'f1_mgmt': 0.1947826086956522}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 15/30
# Epoch 1 training metrics {'rmse1': np.float64(0.28137391077447094), 'rmse2': np.float64(0.22087841497859784), 'f1_rec': 0.5365316752806, 'f1_mgmt': 0.39695688926458156}
# Epoch 1 validation metrics {'rmse1': np.float64(0.21080253571054547), 'rmse2': np.float64(0.2681559114701104), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.003623188405797101}
# Epoch 27 training metrics {'rmse1': np.float64(0.22084143612738266), 'rmse2': np.float64(0.19970221974765714), 'f1_rec': 0.6227583403446744, 'f1_mgmt': 0.5092666962818044}
# Epoch 27 validation metrics {'rmse1': np.float64(0.24821854357640913), 'rmse2': np.float64(0.30260570300880096), 'f1_rec': 0.4575569358178054, 'f1_mgmt': 0.5652173913043478}
# Epoch 55 training metrics {'rmse1': np.float64(0.21671071921424384), 'rmse2': np.float64(0.19039767617804806), 'f1_rec': 0.568624027412508, 'f1_mgmt': 0.5597088478531778}
# Epoch 55 validation metrics {'rmse1': np.float64(0.23709365161956647), 'rmse2': np.float64(0.5308220351756139), 'f1_rec': 0.4476858345021038, 'f1_mgmt': 0.27706389720119695}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 16/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2463945765558054), 'rmse2': np.float64(0.24884521577302796), 'f1_rec': 0.519997444416049, 'f1_mgmt': 0.34234787715800374}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2168093661674267), 'rmse2': np.float64(0.21036210263363073), 'f1_rec': 0.5738440303657696, 'f1_mgmt': 0.17952314165497896}
# Epoch 27 training metrics {'rmse1': np.float64(0.21514821919742982), 'rmse2': np.float64(0.20032110420950203), 'f1_rec': 0.5860841597426962, 'f1_mgmt': 0.6311496196111581}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2251085701282332), 'rmse2': np.float64(0.32284753103043645), 'f1_rec': 0.3188405797101449, 'f1_mgmt': 0.5096408317580341}
# Epoch 55 training metrics {'rmse1': np.float64(0.21317708490948042), 'rmse2': np.float64(0.19659120275252764), 'f1_rec': 0.6991108160788808, 'f1_mgmt': 0.5458339129225206}
# Epoch 55 validation metrics {'rmse1': np.float64(0.21097802649750436), 'rmse2': np.float64(0.4746961857209918), 'f1_rec': 0.17952314165497896, 'f1_mgmt': 0.4031620553359684}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 17/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2675799853736864), 'rmse2': np.float64(0.25118135528226004), 'f1_rec': 0.4718616764825441, 'f1_mgmt': 0.42694005837012644}
# Epoch 1 validation metrics {'rmse1': np.float64(0.19102591880886943), 'rmse2': np.float64(0.18660451063624658), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.35776397515527947}
# Epoch 27 training metrics {'rmse1': np.float64(0.22521524090007497), 'rmse2': np.float64(0.19292817257488176), 'f1_rec': 0.5234432234432235, 'f1_mgmt': 0.5441519316651033}
# Epoch 27 validation metrics {'rmse1': np.float64(0.26887543955133886), 'rmse2': np.float64(0.26077193311199065), 'f1_rec': 0.43478260869565216, 'f1_mgmt': 0.5313043478260869}
# Epoch 55 training metrics {'rmse1': np.float64(0.21094088770964348), 'rmse2': np.float64(0.19384505446265493), 'f1_rec': 0.6622242705351593, 'f1_mgmt': 0.5829106790645252}
# Epoch 55 validation metrics {'rmse1': np.float64(0.21572159861063359), 'rmse2': np.float64(0.5065980608529376), 'f1_rec': 0.46622073578595324, 'f1_mgmt': 0.5479641131815045}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 18/30
# Epoch 1 training metrics {'rmse1': np.float64(0.23577194029586646), 'rmse2': np.float64(0.26421130424144085), 'f1_rec': 0.5086057318362218, 'f1_mgmt': 0.41147617564621614}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22184632881708713), 'rmse2': np.float64(0.22561997354856597), 'f1_rec': 0.3561872909698997, 'f1_mgmt': 0.1605351170568562}
# Epoch 27 training metrics {'rmse1': np.float64(0.20971639866139563), 'rmse2': np.float64(0.18592400952364185), 'f1_rec': 0.5955187669473384, 'f1_mgmt': 0.5636092433547366}
# Epoch 27 validation metrics {'rmse1': np.float64(0.245863212188376), 'rmse2': np.float64(0.43989379607523665), 'f1_rec': 0.3561872909698997, 'f1_mgmt': 0.3176201372997712}
# Epoch 55 training metrics {'rmse1': np.float64(0.20249782970716093), 'rmse2': np.float64(0.19622946650934184), 'f1_rec': 0.6182206634461765, 'f1_mgmt': 0.6451483452897879}
# Epoch 55 validation metrics {'rmse1': np.float64(0.29225767668068375), 'rmse2': np.float64(0.8190475029710879), 'f1_rec': 0.3561872909698997, 'f1_mgmt': 0.3064371704308029}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 19/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24816565043537925), 'rmse2': np.float64(0.25046297318992394), 'f1_rec': 0.4888482538722184, 'f1_mgmt': 0.3844074702173125}
# Epoch 1 validation metrics {'rmse1': np.float64(0.20777454210382496), 'rmse2': np.float64(0.24390649864210243), 'f1_rec': 0.4606345475910693, 'f1_mgmt': 0.22010869565217392}
# Epoch 27 training metrics {'rmse1': np.float64(0.22346967528359096), 'rmse2': np.float64(0.20510286334676453), 'f1_rec': 0.640502354788069, 'f1_mgmt': 0.5171879791940582}
# Epoch 27 validation metrics {'rmse1': np.float64(0.27031900801186), 'rmse2': np.float64(0.3333569998563299), 'f1_rec': 0.4606345475910693, 'f1_mgmt': 0.4608695652173913}
# Epoch 55 training metrics {'rmse1': np.float64(0.21028072377175308), 'rmse2': np.float64(0.19926021007241468), 'f1_rec': 0.6381829807744097, 'f1_mgmt': 0.5833852924995415}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2748922943769489), 'rmse2': np.float64(0.5222614798884215), 'f1_rec': 0.5254682600220357, 'f1_mgmt': 0.5310559006211181}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 20/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24092126679053325), 'rmse2': np.float64(0.2542667902167896), 'f1_rec': 0.4542872093892502, 'f1_mgmt': 0.3138805240670377}
# Epoch 1 validation metrics {'rmse1': np.float64(0.17807250977162814), 'rmse2': np.float64(0.24605140295361347), 'f1_rec': 0.14202898550724638, 'f1_mgmt': 0.08695652173913043}
# Epoch 27 training metrics {'rmse1': np.float64(0.2257322135945895), 'rmse2': np.float64(0.20883849663649412), 'f1_rec': 0.5618484080022542, 'f1_mgmt': 0.593227910301081}
# Epoch 27 validation metrics {'rmse1': np.float64(0.233980416120924), 'rmse2': np.float64(0.24384988207660638), 'f1_rec': 0.5995743387047735, 'f1_mgmt': 0.5010526315789474}
# Epoch 55 training metrics {'rmse1': np.float64(0.20828189808776365), 'rmse2': np.float64(0.19075143847536333), 'f1_rec': 0.5958915793899292, 'f1_mgmt': 0.6260529921007375}
# Epoch 55 validation metrics {'rmse1': np.float64(0.19922917591596045), 'rmse2': np.float64(0.23863541920433937), 'f1_rec': 0.5217391304347826, 'f1_mgmt': 0.4150197628458498}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 21/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2583597797697934), 'rmse2': np.float64(0.25641312510244585), 'f1_rec': 0.5551530129843384, 'f1_mgmt': 0.3826169841662001}
# Epoch 1 validation metrics {'rmse1': np.float64(0.18407188777365077), 'rmse2': np.float64(0.20906473945106954), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.2635046113306983}
# Epoch 27 training metrics {'rmse1': np.float64(0.22604857363523398), 'rmse2': np.float64(0.20635593030082142), 'f1_rec': 0.5771910524385773, 'f1_mgmt': 0.6139039531896674}
# Epoch 27 validation metrics {'rmse1': np.float64(0.21945892989024013), 'rmse2': np.float64(0.28193165461943825), 'f1_rec': 0.40393253665564877, 'f1_mgmt': 0.26438296003513395}
# Epoch 55 training metrics {'rmse1': np.float64(0.21669880138832878), 'rmse2': np.float64(0.18753762967973586), 'f1_rec': 0.680419490731149, 'f1_mgmt': 0.5413542285521605}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2629030576765675), 'rmse2': np.float64(0.3619484584630928), 'f1_rec': 0.46020066889632105, 'f1_mgmt': 0.3680124223602484}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 22/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2702297970792157), 'rmse2': np.float64(0.25746488303017734), 'f1_rec': 0.5097759383473669, 'f1_mgmt': 0.3470472882237588}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22359878689675033), 'rmse2': np.float64(0.2527303353517361), 'f1_rec': 0.4606345475910693, 'f1_mgmt': 0.22010869565217392}
# Epoch 27 training metrics {'rmse1': np.float64(0.2226556998945287), 'rmse2': np.float64(0.21270178391792138), 'f1_rec': 0.5801805337519623, 'f1_mgmt': 0.473634405461648}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2684206855189206), 'rmse2': np.float64(0.3573060358927852), 'f1_rec': 0.45418060200668897, 'f1_mgmt': 0.2019635343618513}
# Epoch 55 training metrics {'rmse1': np.float64(0.1914850035756168), 'rmse2': np.float64(0.18133454766674212), 'f1_rec': 0.5855276798673025, 'f1_mgmt': 0.6203663003663005}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3357046031652069), 'rmse2': np.float64(0.5371775370533939), 'f1_rec': 0.26051680042331776, 'f1_mgmt': 0.453416149068323}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 23/30
# Epoch 1 training metrics {'rmse1': np.float64(0.25565882911949606), 'rmse2': np.float64(0.24124881776023602), 'f1_rec': 0.4917236534398251, 'f1_mgmt': 0.38285231252264224}
# Epoch 1 validation metrics {'rmse1': np.float64(0.17807603158598628), 'rmse2': np.float64(0.21092052053522856), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.309462915601023}
# Epoch 27 training metrics {'rmse1': np.float64(0.22307736735355707), 'rmse2': np.float64(0.19735218813852), 'f1_rec': 0.62995892995893, 'f1_mgmt': 0.5979511003901248}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3784538519540305), 'rmse2': np.float64(0.36948700233271664), 'f1_rec': 0.4127468429527926, 'f1_mgmt': 0.3188405797101449}
# Epoch 55 training metrics {'rmse1': np.float64(0.1977034073078905), 'rmse2': np.float64(0.19777784356622893), 'f1_rec': 0.6703296703296703, 'f1_mgmt': 0.6129828933952646}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3790913484107111), 'rmse2': np.float64(0.4431587237190875), 'f1_rec': 0.5652173913043478, 'f1_mgmt': 0.32365067466266867}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 24/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24667556311970654), 'rmse2': np.float64(0.2682802244041295), 'f1_rec': 0.5439560439560439, 'f1_mgmt': 0.3213665366891173}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2628799906539673), 'rmse2': np.float64(0.23023992323335), 'f1_rec': 0.2635046113306983, 'f1_mgmt': 0.35776397515527947}
# Epoch 27 training metrics {'rmse1': np.float64(0.21023018056796502), 'rmse2': np.float64(0.19177616200746891), 'f1_rec': 0.5877712031558184, 'f1_mgmt': 0.5472391385704078}
# Epoch 27 validation metrics {'rmse1': np.float64(0.32437906752767864), 'rmse2': np.float64(0.40081457870308823), 'f1_rec': 0.40217391304347827, 'f1_mgmt': 0.46082949308755766}
# Epoch 55 training metrics {'rmse1': np.float64(0.20482159454067944), 'rmse2': np.float64(0.17709987832691995), 'f1_rec': 0.6500388500388501, 'f1_mgmt': 0.575970695970696}
# Epoch 55 validation metrics {'rmse1': np.float64(0.2823671369907346), 'rmse2': np.float64(0.4758448727286468), 'f1_rec': 0.40217391304347827, 'f1_mgmt': 0.46376811594202894}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 25/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2519179905500424), 'rmse2': np.float64(0.2643608212424198), 'f1_rec': 0.568624027412508, 'f1_mgmt': 0.4444134974088891}
# Epoch 1 validation metrics {'rmse1': np.float64(0.2139148518936587), 'rmse2': np.float64(0.17625063087663362), 'f1_rec': 0.49534161490683226, 'f1_mgmt': 0.35776397515527947}
# Epoch 27 training metrics {'rmse1': np.float64(0.20778598006298568), 'rmse2': np.float64(0.21893601465904736), 'f1_rec': 0.6214750437447435, 'f1_mgmt': 0.5224786532087041}
# Epoch 27 validation metrics {'rmse1': np.float64(0.249333581859199), 'rmse2': np.float64(0.4652484530015527), 'f1_rec': 0.5271739130434783, 'f1_mgmt': 0.4473378284119972}
# Epoch 55 training metrics {'rmse1': np.float64(0.19893746387752542), 'rmse2': np.float64(0.20420857943418205), 'f1_rec': 0.5920165304780689, 'f1_mgmt': 0.5489911426366276}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3332078618096412), 'rmse2': np.float64(0.605182835937874), 'f1_rec': 0.35776397515527947, 'f1_mgmt': 0.6144927536231883}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 26/30
# Epoch 1 training metrics {'rmse1': np.float64(0.257765210184688), 'rmse2': np.float64(0.25663779582876134), 'f1_rec': 0.487324890913437, 'f1_mgmt': 0.3454416777930002}
# Epoch 1 validation metrics {'rmse1': np.float64(0.23462687793160492), 'rmse2': np.float64(0.18234919396542457), 'f1_rec': 0.49353701527614574, 'f1_mgmt': 0.17952314165497896}
# Epoch 27 training metrics {'rmse1': np.float64(0.2141940083088345), 'rmse2': np.float64(0.19942030669596292), 'f1_rec': 0.606931530008453, 'f1_mgmt': 0.6348998291549413}
# Epoch 27 validation metrics {'rmse1': np.float64(0.2668454360550868), 'rmse2': np.float64(0.38890657012871366), 'f1_rec': 0.6161490683229813, 'f1_mgmt': 0.45548654244306414}
# Epoch 55 training metrics {'rmse1': np.float64(0.2026352027645447), 'rmse2': np.float64(0.19134977148639565), 'f1_rec': 0.5839726311424425, 'f1_mgmt': 0.5993398129470016}
# Epoch 55 validation metrics {'rmse1': np.float64(0.4810054689834514), 'rmse2': np.float64(0.457371930998418), 'f1_rec': 0.6161490683229813, 'f1_mgmt': 0.34407796101949023}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 27/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2550950815338465), 'rmse2': np.float64(0.2701377915171634), 'f1_rec': 0.4757219524661386, 'f1_mgmt': 0.43626760368841816}
# Epoch 1 validation metrics {'rmse1': np.float64(0.16446387119829975), 'rmse2': np.float64(0.2149051985485793), 'f1_rec': 0.14202898550724638, 'f1_mgmt': 0.14202898550724638}
# Epoch 27 training metrics {'rmse1': np.float64(0.2323705285546039), 'rmse2': np.float64(0.19245848808729077), 'f1_rec': 0.5740478809785741, 'f1_mgmt': 0.4913427362685329}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3855203548085585), 'rmse2': np.float64(0.31314731395573575), 'f1_rec': 0.6885578189926015, 'f1_mgmt': 0.4322981366459627}
# Epoch 55 training metrics {'rmse1': np.float64(0.2223109017342118), 'rmse2': np.float64(0.18752929786973996), 'f1_rec': 0.5604395604395604, 'f1_mgmt': 0.6047014210279515}
# Epoch 55 validation metrics {'rmse1': np.float64(0.28388270064908916), 'rmse2': np.float64(0.3813920972302668), 'f1_rec': 0.6623188405797101, 'f1_mgmt': 0.45620667926906117}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 28/30
# Epoch 1 training metrics {'rmse1': np.float64(0.22688711082610438), 'rmse2': np.float64(0.25168749842722343), 'f1_rec': 0.500523286237572, 'f1_mgmt': 0.43306367284381714}
# Epoch 1 validation metrics {'rmse1': np.float64(0.22345695005007685), 'rmse2': np.float64(0.17716341492520668), 'f1_rec': 0.2244039270687237, 'f1_mgmt': 0.2244039270687237}
# Epoch 27 training metrics {'rmse1': np.float64(0.21443900626880816), 'rmse2': np.float64(0.19883867999763183), 'f1_rec': 0.5578312296578551, 'f1_mgmt': 0.5547110323697729}
# Epoch 27 validation metrics {'rmse1': np.float64(0.36952096157021147), 'rmse2': np.float64(0.45382624729492144), 'f1_rec': 0.4693535585148602, 'f1_mgmt': 0.24456521739130435}
# Epoch 55 training metrics {'rmse1': np.float64(0.2067628307228018), 'rmse2': np.float64(0.18969536136897877), 'f1_rec': 0.5674237508111616, 'f1_mgmt': 0.5521821199039674}
# Epoch 55 validation metrics {'rmse1': np.float64(0.5793614148880818), 'rmse2': np.float64(0.2741364732590263), 'f1_rec': 0.24456521739130435, 'f1_mgmt': 0.18633540372670807}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 29/30
# Epoch 1 training metrics {'rmse1': np.float64(0.24442196240564606), 'rmse2': np.float64(0.2604599773456295), 'f1_rec': 0.4477450260582791, 'f1_mgmt': 0.43897413562047705}
# Epoch 1 validation metrics {'rmse1': np.float64(0.18321260452676932), 'rmse2': np.float64(0.20739352642315725), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.2013729977116705}
# Epoch 27 training metrics {'rmse1': np.float64(0.21571667565149713), 'rmse2': np.float64(0.2114262691837115), 'f1_rec': 0.6401234851939077, 'f1_mgmt': 0.5514774114774116}
# Epoch 27 validation metrics {'rmse1': np.float64(0.3901620925014464), 'rmse2': np.float64(0.26279509840907844), 'f1_rec': 0.48099479671928735, 'f1_mgmt': 0.46687370600414074}
# Epoch 55 training metrics {'rmse1': np.float64(0.20641546957253887), 'rmse2': np.float64(0.1763124109840047), 'f1_rec': 0.6656151052337493, 'f1_mgmt': 0.5672597244025817}
# Epoch 55 validation metrics {'rmse1': np.float64(0.3845812360569288), 'rmse2': np.float64(0.3709592806908811), 'f1_rec': 0.309462915601023, 'f1_mgmt': 0.5067287784679089}
#
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Using device(prediction head) : cuda
# No potential residual connections found
# Fold 30/30
# Epoch 1 training metrics {'rmse1': np.float64(0.2698571594545895), 'rmse2': np.float64(0.24174663304325691), 'f1_rec': 0.5525211067379742, 'f1_mgmt': 0.44258241758241756}
# Epoch 1 validation metrics {'rmse1': np.float64(0.15265928187246952), 'rmse2': np.float64(0.18223970197758305), 'f1_rec': 0.14202898550724638, 'f1_mgmt': 0.007561436672967864}
# Epoch 27 training metrics {'rmse1': np.float64(0.22034105388343567), 'rmse2': np.float64(0.20923077272478807), 'f1_rec': 0.5958915793899292, 'f1_mgmt': 0.576299318540628}
# Epoch 27 validation metrics {'rmse1': np.float64(0.20131037377992245), 'rmse2': np.float64(0.27455831611354214), 'f1_rec': 0.6521739130434783, 'f1_mgmt': 0.45897051474262873}
# Epoch 55 training metrics {'rmse1': np.float64(0.22499806853922075), 'rmse2': np.float64(0.1965243561401399), 'f1_rec': 0.6923076923076923, 'f1_mgmt': 0.5809504377143635}
# Epoch 55 validation metrics {'rmse1': np.float64(0.222478776934292), 'rmse2': np.float64(0.47260069443506864), 'f1_rec': 0.4861660079051383, 'f1_mgmt': 0.14202898550724638}

# %%
plot_cv_table('../results/cv_results.csv', save=True, out_file="results/cv_results_table.pdf")

# %%
# plot_results_cv('../results/cv_results.csv')

# %% [markdown]
# ## **Conclusion**
# The neural network performs notably better than the Gradient Boosting Tree on regression tasks in this huge dimensionality setting. Both ML and DL approaches perform poorly on classification tasks. Though achieving better validation performances for regression tasks, intermediate printing allows us to see that the network overfits (reaches much better performances on training set while validation performances hit a plateau).
